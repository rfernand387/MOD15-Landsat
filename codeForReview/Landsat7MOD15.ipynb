# %%
import ee
import numpy as np
import pandas as pd
import pickle
import datetime

# %%
ee.Authenticate()
# Out:
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=I9pqw6XuQKCUb6PW7qXH9NyVzr551pGbiS_ekhTteKE&tc=6zH39Yu3k8jvdm6vbImk9WAOQ1rTg4scuH7xopjm_70&cc=2MIJX_1WX52SNJFs_6cXs_zsq3zCtTp-brJmWIuVudc>https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=I9pqw6XuQKCUb6PW7qXH9NyVzr551pGbiS_ekhTteKE&tc=6zH39Yu3k8jvdm6vbImk9WAOQ1rTg4scuH7xopjm_70&cc=2MIJX_1WX52SNJFs_6cXs_zsq3zCtTp-brJmWIuVudc</a></p>
#         <p>The authorization workflow will generate a code, which you
#         should paste in the box below</p>
# Enter verification code:  4/1AWgavdfHHu7jQMfi2wGnvOCgbn3chbL2Hiwo-058b3zTp4TGNx30Yfzi3YA
# Successfully saved authorization token.

# %%
ee.Initialize()

# %%
# sampling paramaters
randomSeed = 29
collectionLandsatL1c = "LANDSAT/LE07/C02/T1_TOA" # landsat image collection
collectionLandsatL2a= "LANDSAT/LE07/C02/T1_L2" # landsat image collection
cloudCoverL0X = 80# maximum cloud cover of sampled Landsat images
maxSample = 10000 # maximum samples to extract from each Landsat image
outputScale = 500 # scale of output comparisons , increasing this will eventually exceed memory
subimageSize = 40000 # m dimension of subimage we will randomly extract from Landsat image to avoid memory limits
minfracAreaLC = 0.5 # minimum cloud free valid  Landsat subimage fraction
minfracAreaMCD15 = 0.25 # minimum cloud free valid MODIS area in Landsat subimage fraction's unmasked area
minfracAreaLCtoMCD = 0.10 # valid aggregated landsat fraction
minfracValidLC = 0.9 # minimum facation of valid landsat pixels in each aggregated modis pixels to estimate mean values
deltaRow = 1  # skip this many WRS rows when sampling Landsat scenes
deltaPath = 1 # skip this many WRS paths when sampling Landsat scenes
deltaDay = 15 # search this many contiguous days when looking for a cloud free Landsat scene
maxPixels = 300 # max landsat pixels allowed to be aggregated in an output pixel, should be about 20% larger than the ratio of (outputScale/30) (cannot exceed 1024)
startPath = 1 # start Landsat WRS 1 path for sampling region
endPath = 233 # endLandsat WRS 1 path for sampling region
startRow = 1 # start Landsat WRS 1 row for sampling region
endRow = 248 # end Landsat WRS 1 row for sampling region
startYear = 2004 # first year to sample
endYear = 2020
# last year to sample, restricted by available Landsat 7 data

#output files
InputFileNameB36 = '/home/richard_fernandes/LUTinputLC07B36LC07v1'
InputFileNameB45 = '/home/richard_fernandes/LUTinputLC07B45LC07v1'
InputFileNameMOD09 = '/home/richard_fernandes/LUTinputMOD09LC07v1'
InputFileNameMOD09bands = '/home/richard_fernandes/LUTinputMOD09bandsLC07v1'
InputFileNameLat = '/home/richard_fernandes/LUTinputLC07LatLC07v1'
InputFileNameLon = '/home/richard_fernandes/LUTinputLC07LonLC07v1'
OutputFileName = '/home/richard_fernandes/LUToutputLC07LC07v1'
YearFileName = '/home/richard_fernandes/YearLC07LC07v1'
MonthFileName = '/home/richard_fernandes/MonthLC07LC07v1'
DayFileName = '/home/richard_fernandes/DayLC07LC07v1'
PathFileName = '/home/richard_fernandes/PathLC07LC07v1'
RowFileName = '/home/richard_fernandes/RowLC07LC07v1'
FparLai_QCName = '/home/richard_fernandes/FparLai_QCLC07v1'
FparExtra_QCName = '/home/richard_fernandes/FparExtra_QCLC07v1'

# %%
# Match MOD09A1.006 daily reflectance data and MCD12Q1 annual biome type to  MCD15A3H.006 image composite
# masking any dates without exactly one MOD09A1 valid clear sky value and one valid MCD153AH terra retrieval
def matchMOD09A1toMCD15(imageMCD15):
    
    # get date range of MCD15A3Himage
    d1 = ee.Date(imageMCD15.get('system:time_start'));
    d2 = ee.Date(imageMCD15.get('system:time_end'));
    
#    print(d1.getInfo())
#    print(d2.getInfo())
    # find MOD09A1 products within date range of MCD15 and mask them 
    colMOD09A1 = ee.ImageCollection("MODIS/006/MOD09GA").filterDate(d1,d2).map(lambda image: image.updateMask(image.select('QC_500m').bitwiseAnd(1<<1).eq(0)) \
                                                                                                  .updateMask(image.select('state_1km').bitwiseAnd(1<<0).eq(0)) \
                                                                                                  .updateMask(image.select('state_1km').bitwiseAnd(1<<1).eq(0)) \
                                                                                                  .updateMask(image.select('state_1km').bitwiseAnd(1<<2).eq(0)) \
                                                                                                  .addBands(image.select('sur_refl_b02').divide(image.select('sur_refl_b01').add(1)).rename('SR_VI')))
                                                                                                 # .updateMask(image.select('state_1km').bitwiseAnd(1<<3).eq(1)) )
                                                                                                #  .updateMask(image.select('state_1km').bitwiseAnd(1<<4).eq(0)) \
                                                                                                #   .updateMask(image.select('state_1km').bitwiseAnd(1<<5).eq(0)) \
                                                                                               #   .updateMask(image.select('state_1km').bitwiseAnd(1<<6).gt(-1)) \
                                                                                              #    .updateMask(image.select('state_1km').bitwiseAnd(1<<7).eq(0)) \
                                                                                                #  .updateMask(image.select('state_1km').bitwiseAnd(1<<8).eq(8)) \
                                                                                                #  .updateMask(image.select('state_1km').bitwiseAnd(1<<9).eq(0)) \
                                                                                               #   .updateMask(image.select('state_1km').bitwiseAnd(1<<10).eq(0)) \
                                                                                                #  .updateMask(image.select('state_1km').bitwiseAnd(1<<11).eq(1)) \
                                                                                                 # .updateMask(image.select('state_1km').bitwiseAnd(1<<12).eq(0)) \
                                                                                                 # .updateMask(image.select('state_1km').bitwiseAnd(1<<13).eq(0)) \
                                                                                                 # .updateMask(image.select('state_1km').bitwiseAnd(1<<14).eq(0)) \
                                                                                                 # .updateMask(image.select('state_1km').bitwiseAnd(1<<15).eq(0)))
    #    print(colMOD09A1.size().getInfo())
    # get biome type map
    imageMCD12Q1 = ee.ImageCollection("MODIS/006/MCD12Q1").map(lambda image: image.set('daterange',ee.DateRange(ee.Date(image.get('system:time_start')),ee.Date(image.get('system:time_end')))))\
                                                            .filter(ee.Filter.dateRangeContains('daterange', d1)) \
                                                            .first() \
                                                            .select('LC_Type3') 
#    print(imageMCD12Q1.getInfo())

# make mask of pixels containing only one valid cloud free MOD09 500m retrieval
    # and a primary algorithm retyrieval from terra wigthout significant clouds
    # and add MOD09A1 composite created by apply the MCD15 mask to the MOOD9A1 collection and composite it
    # and add biome type
    imageMCD15 = imageMCD15.updateMask( colMOD09A1.count().select('sur_refl_b01').gt(-1) ) \
                            .updateMask( imageMCD15.select('FparLai_QC').bitwiseAnd(1<<0).eq(0)) \
                            .updateMask( imageMCD15.select('FparLai_QC').bitwiseAnd(1<<1).eq(0)) \
                            .updateMask( imageMCD15.select('FparLai_QC').bitwiseAnd(1<<2).eq(0)) \
                            .updateMask( imageMCD15.select('FparLai_QC').bitwiseAnd(1<<3).eq(0)) \
                            .updateMask( imageMCD15.select('FparLai_QC').bitwiseAnd(1<<4).eq(0)) \
                            .updateMask(imageMCD15.select('FparLai_QC').bitwiseAnd(1<<6).eq(0)) \
                            .updateMask(imageMCD15.select('FparLai_QC').bitwiseAnd(1<<7).eq(0)) \
                            .updateMask(imageMCD15.select('FparExtra_QC').bitwiseAnd(1<<1).eq(0)) \
                            .updateMask( imageMCD12Q1.select('LC_Type3').gt(0)) \
                            .addBands( imageMCD12Q1 )
    imageMCD15 = imageMCD15.addBands(colMOD09A1.map(lambda image: image.mask(imageMCD15.select('Lai'))).qualityMosaic('SR_VI'))


    
   
    
    
    return imageMCD15

# %%
# coded LUT for output MODIS MCD15
def getLUTout(imageMCD15):
    imageMCD15 = ee.Image(imageMCD15);

    return imageMCD15.select('Lai').min(99).multiply(1).toInt64() \
                        .add(imageMCD15.select('LaiStdDev').min(99).multiply(1e2).toInt64()) \
                        .add(imageMCD15.select('Fpar').min(99).multiply(1e4).toInt64()) \
                        .add(imageMCD15.select('FparStdDev').min(99).multiply(1e6).toInt64()) \
                        .add(imageMCD15.select('satFlag').multiply(100).multiply(1e9).toInt64()) \
                        .add(imageMCD15.select('snowFlag').multiply(100).multiply(1e12).toInt64()) \
                        .add(imageMCD15.select('LC_Type3').multiply(1e14).toInt64()) \
                        .rename('LUTout')

# %%
# Code LUT for an input MOD09 image , same as getLUTin but no satFlag
def getLUTinMOD09(imageMCD15MOD09):
    
     return imageMCD15MOD09.select('sur_refl_b01').add(100).max(0).min(9999).floor().toInt64().multiply(1).toInt64() \
                        .add(imageMCD15MOD09.select('sur_refl_b02').add(100).max(0).min(9999).floor().toInt64().multiply(1e4).toInt64()) \
                        .add(imageMCD15MOD09.select('SolarZenith').multiply(0.01).max(0).min(99).floor().toInt64().multiply(1e8).toInt64()) \
                        .add(imageMCD15MOD09.select('SolarAzimuth').multiply(0.01).add(180).max(0).min(360).floor().toInt64().multiply(1e10).toInt64()) \
                        .add(imageMCD15MOD09.select('SensorZenith').multiply(0.01).max(0).min(99).floor().toInt64().multiply(1e13).toInt64()) \
                        .add(imageMCD15MOD09.select('SensorAzimuth',).multiply(0.01).add(180).max(0).min(360).floor().toInt64().multiply(1e15).toInt64()) \
                        .rename('LUTinMOD09')

# %%
# Code LUT for an input MOD09 image , same as getLUTin but no satFlag
def getLUTinMOD09bands(imageMCD15MOD09):
    
     return imageMCD15MOD09.select('sur_refl_b03').add(100).max(0).min(9999).floor().toInt64().multiply(1).toInt64() \
                        .add(imageMCD15MOD09.select('sur_refl_b04').add(100).max(0).min(9999).floor().toInt64().multiply(1e4).toInt64()) \
                        .add(imageMCD15MOD09.select('sur_refl_b06').add(100).max(0).min(9999).floor().toInt64().multiply(1e8).toInt64()) \
                        .add(imageMCD15MOD09.select('sur_refl_b07').add(100).max(0).min(9999).floor().toInt64().multiply(1e12).toInt64()) \
                        .rename('LUTinMOD09bands')

# %%
# coded LUT for input landsat image red and nir band
def getLUTL0XinB45(imageMCD15):
    imageMCD15 = ee.Image(imageMCD15);
    return imageMCD15.select('SR_B3').multiply(2.75e-05).add(-0.02).max(0).min(0.999).multiply(1000).floor().multiply(1).toInt64() \
                        .add(imageMCD15.select('SR_B4').multiply(2.75e-05).add(-0.02).max(0).min(0.999).multiply(1000).floor().multiply(1e3).toInt64()) \
                        .add(imageMCD15.select('VZA').multiply(0.01).round().multiply(1e6).toInt64()) \
                        .add(imageMCD15.select('VAA').multiply(0.01).add(180).round().multiply(1e8).toInt64()) \
                        .add(imageMCD15.select('SZA').multiply(0.01).round().multiply(1e11).toInt64()) \
                        .add(imageMCD15.select('SAA').multiply(0.01).add(180).round().multiply(1e13).toInt64()) \
                        .rename('LUTL0XinB45')

# %%
# coded LUT for input landsat image green and swir
def getLUTL0XinB36(imageMCD15):
    imageMCD15 = ee.Image(imageMCD15);
    return imageMCD15.select('SR_B2').multiply(2.75e-05).add(-0.02).max(0).min(0.999).multiply(1000).floor().multiply(1).toInt64() \
                        .add(imageMCD15.select('SR_B5').multiply(2.75e-05).add(-0.02).max(0).min(0.999).multiply(1000).floor().multiply(1e3).toInt64()) \
                        .add(imageMCD15.select('VZA').multiply(0.01).round().multiply(1e6).toInt64()) \
                        .add(imageMCD15.select('VAA').multiply(0.01).add(180).round().multiply(1e8).toInt64()) \
                        .add(imageMCD15.select('SZA').multiply(0.01).round().multiply(1e11).toInt64()) \
                        .add(imageMCD15.select('SAA').multiply(0.01).add(180).round().multiply(1e13).toInt64()) \
                        .rename('LUTL0XinB36')

# %%
cumsam =0
for year in range(startYear,endYear):

        
    # specify land cover projected into MOD15 projection and aggregated using median to outputScale    
    projectionMCD15=  ee.ImageCollection('MODIS/006/MCD15A3H').first().select('Lai').projection()
    projectionMCD12 =  ee.ImageCollection("MODIS/006/MCD12Q1").first().select('LC_Type3').projection()
    imageMCD12Q1 = ee.ImageCollection("MODIS/006/MCD12Q1").filterDate(ee.Date.fromYMD(year,1,1),ee.Date.fromYMD(year,12,31)).first() \
                     .select('LC_Type3') \
                     .reproject(crs= projectionMCD15,crsTransform= None,scale=projectionMCD12.nominalScale() ) \
                     .reduceResolution(reducer= ee.Reducer.median(),maxPixels= 1024,bestEffort=False) \
                     .reproject(crs= projectionMCD15.atScale(outputScale))      
    print(year)
    # sample monthly data
    for month in [7,6,5,8,4,9,3,10,2,11,1,12]:  
        
        print('year',year,'month',month)

        #sample WRS path rows
        for path in range(startPath,endPath,deltaPath): 
            for row in range(startRow,endRow,deltaRow): 
                
                # sample deltaDay intervals of each month
                for daystart in range (1,30-deltaDay,deltaDay):
                    
                    # find Landsat images for paht , row and date interval between 0 and maxCloudCover
                    imageLC = ee.ImageCollection(collectionLandsatL2a).filterMetadata('WRS_PATH','equals',path) \
                                                                          .filterMetadata('WRS_ROW','equals',row) \
                                                                          .filterDate(ee.Date.fromYMD(year,month,daystart),ee.Date.fromYMD(year,month,daystart).advance(deltaDay,'days')) \
                                                                          .filter(ee.Filter.lte('CLOUD_COVER_LAND',cloudCoverL0X))
                    
                    # only proceed if there is at least one filtered landsat image (we will only use the first one found)
                    if (imageLC.size().getInfo() > 0) : 

                        # only sample the first scene we found in the interval of deltaDay's 
                        imageLC = imageLC.first()
                        projectionLC = imageLC.select('QA_PIXEL').projection()
                        
                        # get date range of imageLC and print it out
                        d1 = ee.Date(imageLC.get('system:time_start'))
                        d2 = ee.Date(imageLC.get('system:time_end'))     

                        # get  MOD15 product containing the aquistion of the  Landsat image
                        imageMCD15 = ee.ImageCollection('MODIS/006/MCD15A3H') \
                                                    .map(lambda image: image.set('daterange',ee.DateRange(ee.Date(image.get('system:time_start')),ee.Date(image.get('system:time_end')))))\
                                                    .filter(ee.Filter.dateRangeContains('daterange', d1)) \
                                                    .map(lambda image: matchMOD09A1toMCD15(image) ) 

                        # only proceed if there is a MCD15 product containing the Landsat image aquisition
                        if (imageMCD15.size().getInfo() > 0)  :

                            print('year',year,'month',month,'path',path,'row',row)
                            
                            #randomly sample a sub-image to avoid memory issues, 
                            # add a validPixel we will use to determine aggregation and unmask since we will accept some missing data
                            imageGRID = imageLC.geometry().coveringGrid(projectionMCD15,subimageSize).randomColumn(columnName='randomIndex',seed=randomSeed)                                
                            imageLC = imageLC.addBands(ee.ImageCollection(collectionLandsatL1c) \
                                                                          .filterMetadata('system:index','equals',imageLC.get('system:index')) \
                                                                          .first() \
                                                                          .select(['VZA','VAA','SZA','SAA'])) \
                                             .clip(ee.Feature(imageGRID.sort('randomIndex').first()).geometry()) \
                                             .updateMask(imageLC.select('QA_PIXEL').bitwiseAnd(1<<0).eq(0)) \
                                             .updateMask(imageLC.select('QA_PIXEL').bitwiseAnd(1<<1).eq(0)) \
                                             .updateMask(imageLC.select('QA_PIXEL').bitwiseAnd(1<<2).eq(0)) \
                                             .updateMask(imageLC.select('QA_PIXEL').bitwiseAnd(1<<3).eq(0)) \
                                             .updateMask(imageLC.select('QA_PIXEL').bitwiseAnd(1<<4).eq(0)) 
        
                            
                            # get the fraction of area with unmasked LC data 
                            validArea = ee.Number(ee.Image.pixelArea().mask(imageLC.select('QA_PIXEL').mask()).reduceRegion(reducer=ee.Reducer.sum(),geometry=imageLC.geometry(),scale=30,bestEffort=True).get('area')).getInfo()
                            totalArea = ee.Number(ee.Image.pixelArea().mask(imageLC.select('QA_PIXEL').unmask().mask()).reduceRegion(reducer=ee.Reducer.sum(),geometry=imageLC.geometry(),scale=30,bestEffort=True).get('area')).getInfo()
                            
                            fracAreaLC = 0 
                            if (totalArea > 0) :
                                fracAreaLC = validArea / totalArea
                            #print('fracAreaLC:',fracAreaLC)  

                            # proceed if there is sufficient landsat area
                            if ( fracAreaLC > minfracAreaLC) :
                                                
                                # get MCD15 image from collection, clip to Landsat subimage
                                imageMCD15 = imageMCD15.first().clip(imageLC.geometry()) 
                                                
                                # update mask and add land cover and a saturation flag band
                                imageMCD15 = imageMCD15.updateMask( imageMCD15.select('FparLai_QC').bitwiseAnd(1<<0).eq(0)) \
                                                .updateMask( imageMCD15.select('FparLai_QC').bitwiseAnd(1<<2).eq(0)) \
                                                .updateMask( imageMCD15.select('FparLai_QC').bitwiseAnd(1<<3).eq(0)) \
                                                .updateMask( imageMCD15.select('FparLai_QC').bitwiseAnd(1<<4).eq(0)) \
                                                .updateMask( imageMCD15.select('FparLai_QC').bitwiseAnd(1<<6).eq(0)) \
                                                .updateMask( imageMCD15.select('FparLai_QC').bitwiseAnd(1<<7).eq(0)) \
                                                .addBands(imageMCD15.select('FparLai_QC').rename(['satFlag']).bitwiseAnd(1<<5).eq(1)) \
                                                .addBands(imageMCD15.select('FparExtra_QC').rename(['snowFlag']).bitwiseAnd(1<<2).eq(1)) \
                                                .updateMask( imageMCD15.select('FparExtra_QC').bitwiseAnd(1<<0).eq(0)) \
                                                .updateMask( imageMCD15.select('FparExtra_QC').bitwiseAnd(1<<1).eq(0)) \
                                                .updateMask( imageMCD15.select('FparExtra_QC').bitwiseAnd(1<<3).eq(0)) \
                                                .updateMask( imageMCD15.select('FparExtra_QC').bitwiseAnd(1<<4).eq(0)) \
                                                .updateMask( imageMCD15.select('FparExtra_QC').bitwiseAnd(1<<5).eq(0)) \
                                                .updateMask( imageMCD15.select('FparExtra_QC').bitwiseAnd(1<<6).eq(0)) \


                            
                                # get the fraction of area with unmasked MCD15 data 
                                validArea = ee.Number(ee.Image.pixelArea().mask(imageMCD15.select('Lai').mask()).reduceRegion(reducer=ee.Reducer.sum(),geometry=imageLC.geometry(),crs=projectionMCD15.atScale(outputScale)).get('area')).getInfo()
                                totalArea = ee.Number(ee.Image.pixelArea().mask(imageMCD15.select('Lai').unmask().mask()).reduceRegion(reducer=ee.Reducer.sum(),geometry=imageLC.geometry(),crs=projectionMCD15.atScale(outputScale)).get('area')).getInfo()
                                fracAreaMCD15 = 0 
                                if (totalArea > 0) :
                                    fracAreaMCD15 = validArea / totalArea
                                print('fracAreaMCD15:',fracAreaMCD15) 
                           
                                # sample if there is sufficient unmasked area
                                if ( fracAreaMCD15> minfracAreaMCD15 ) :
                                                
                                    
                                    # add a view zenith angle band and a validPixel band to the landsat image
                                    # then unmask and aggregate to output scale, we unmask first to allow for <100% validPixel s
                                    imageLCtoMCD = imageLC.addBands(imageLC.select('QA_PIXEL').gt(-1).rename('validPixel')) \
                                                         .unmask() \
                                                         .reproject(crs= projectionMCD15,scale=projectionLC.nominalScale() ) \
                                                         .reduceResolution(reducer= ee.Reducer.mean(),maxPixels=maxPixels,bestEffort=False) \
                                                         .reproject(crs= projectionMCD15 , scale= outputScale) \
                                                         .updateMask(imageMCD15.select('FparLai_QC').mask())
                                   
                                    # mask bands not meeting fractional pixel threshold
                                    # we then have to divide by the fractional validPixel band to adjust for  zero masked values 
                                    validLCtoMCD = imageLCtoMCD.select('validPixel').gte(minfracValidLC);
                                    imageLCtoMCD = imageLCtoMCD.updateMask(validLCtoMCD) \
                                                     .divide(imageLCtoMCD.select('validPixel'))


                                    # add the aggregated LC image to the modis image and update the MCD image with the valid mask
                                    imageMCD15 = imageMCD15.addBands(imageLCtoMCD) \
                                                            .updateMask(validLCtoMCD) 
                                                            
                                    # get the fraction of area with unmasked LC data 
                                    validArea = ee.Number(ee.Image.pixelArea().mask(imageMCD15.select('QA_PIXEL').mask()).reduceRegion(reducer=ee.Reducer.sum(),geometry=imageMCD15.geometry(),scale=outputScale,bestEffort=True).get('area')).getInfo()
                                    totalArea = ee.Number(ee.Image.pixelArea().mask(imageMCD15.select('QA_PIXEL').unmask().mask()).reduceRegion(reducer=ee.Reducer.sum(),geometry=imageMCD15.geometry(),scale=outputScale,bestEffort=True).get('area')).getInfo()
                                    fracAreaLCtoMCD = 0 
                                    if (totalArea > 0) :
                                        fracAreaLCtoMCD = validArea / totalArea
                                    print('fracAreaLCtoMCD:',fracAreaLCtoMCD)  
                                    
                                    # check if we have enough valid cloud free aggregated matches
                                    if ( fracAreaLCtoMCD > minfracAreaLCtoMCD ) :
 

                                        imageMCD15 = imageMCD15.select(['satFlag','snowFlag','FparLai_QC','FparExtra_QC']) \
                                                                .addBands(getLUTout(imageMCD15)) \
                                                                 .addBands(getLUTL0XinB45(imageMCD15)) \
                                                                 .addBands(getLUTL0XinB36(imageMCD15)) \
                                                                 .addBands(getLUTinMOD09(imageMCD15)) \
                                                                 .addBands(getLUTinMOD09bands(imageMCD15)) \
                                                                 .addBands(ee.Image.pixelLonLat()) \
                                                                 .updateMask(validLCtoMCD)
        
                                        sampleData = imageMCD15.sample(projection=projectionMCD15.atScale(outputScale), numPixels=maxSample, dropNulls=True)
                                        sampleOutput = sampleData.aggregate_array('LUTout').flatten().getInfo()
                                        sampleInputB45 = sampleData.aggregate_array('LUTL0XinB45').flatten().getInfo()
                                        sampleInputB36 = sampleData.aggregate_array('LUTL0XinB36').flatten().getInfo()
                                        sampleInputMOD09 = sampleData.aggregate_array('LUTinMOD09').flatten().getInfo()
                                        sampleInputMOD09bands = sampleData.aggregate_array('LUTinMOD09bands').flatten().getInfo()
                                        sampleInputLon = sampleData.aggregate_array('longitude').flatten().getInfo()
                                        sampleInputLat = sampleData.aggregate_array('latitude').flatten().getInfo()
                                        sampleFparLai_QC = sampleData.aggregate_array('FparLai_QC').flatten().getInfo()
                                        sampleFparExtra_QC = sampleData.aggregate_array('FparExtra_QC').flatten().getInfo() 
                            
                                        if (len(sampleOutput)>0) :

                                            numsam = len(sampleOutput)
                                            cumsam = cumsam + numsam
                                            print('cumulative samples:',cumsam,'nsaminput',numsam)
                                            
                                            # write list after each landsat scene is done (comment out if it is too frequent)
                                            with open(InputFileNameLon, 'ab') as fp1:
                                                pickle.dump(sampleInputLon, fp1)
                                            with open(InputFileNameLat, 'ab') as fp1:
                                                pickle.dump(sampleInputLat, fp1)
                                            with open(InputFileNameB36, 'ab') as fp1:
                                                pickle.dump(sampleInputB36, fp1)
                                            with open(InputFileNameB45, 'ab') as fp1:
                                                pickle.dump(sampleInputB45, fp1)
                                            with open(InputFileNameMOD09, 'ab') as fp1:
                                                pickle.dump(sampleInputMOD09, fp1)
                                            with open(InputFileNameMOD09bands, 'ab') as fp1:
                                                pickle.dump(sampleInputMOD09bands, fp1)
                                            with open(OutputFileName, 'ab') as fp1:
                                                pickle.dump(sampleOutput, fp1)                                        
                                            with open(YearFileName, 'ab') as fp1:
                                                pickle.dump([year]*numsam, fp1)
                                            with open(MonthFileName, 'ab') as fp1:
                                                pickle.dump([month]*numsam, fp1)
                                            with open(DayFileName, 'ab') as fp1:
                                                pickle.dump([daystart]*numsam, fp1)
                                            with open(PathFileName, 'ab') as fp1:
                                                pickle.dump([path]*numsam, fp1 ) 
                                            with open(RowFileName, 'ab') as fp1:
                                                pickle.dump([row]*numsam, fp1)  
                                            with open(FparLai_QCName, 'ab') as fp1:
                                                pickle.dump(sampleFparLai_QC, fp1 ) 
                                            with open(FparExtra_QCName, 'ab') as fp1:
                                                pickle.dump(sampleFparExtra_QC, fp1)
# Out:
# 2004
# year 2004 month 7
# year 2004 month 7 path 1 row 5
# year 2004 month 7 path 1 row 6
# year 2004 month 7 path 1 row 7
# year 2004 month 7 path 1 row 8
# year 2004 month 7 path 1 row 53
# fracAreaMCD15: 0.0
# year 2004 month 7 path 1 row 54
# year 2004 month 7 path 1 row 57
# year 2004 month 7 path 1 row 58
# year 2004 month 7 path 1 row 63
# fracAreaMCD15: 0.6669884214008728
# fracAreaLCtoMCD: 0.1674664882488343
# cumulative samples: 418 nsaminput 418
# year 2004 month 7 path 1 row 64
# fracAreaMCD15: 0.8950214173721056
# fracAreaLCtoMCD: 0.26598087174696244
# cumulative samples: 1672 nsaminput 1254
# year 2004 month 7 path 1 row 65
# fracAreaMCD15: 1.0
# fracAreaLCtoMCD: 0.5514004950611299
# year 2004 month 7 path 1 row 66
# year 2004 month 7 path 1 row 67
# year 2004 month 7 path 1 row 68
# year 2004 month 7 path 1 row 69
# fracAreaMCD15: 0.4795138116066634
# fracAreaLCtoMCD: 0.0779815320350721
# year 2004 month 7 path 1 row 70
# year 2004 month 7 path 1 row 71
# year 2004 month 7 path 1 row 72
# fracAreaMCD15: 0.5783509766015328
# fracAreaLCtoMCD: 0.22473415053784804
# cumulative samples: 2779 nsaminput 1107
# year 2004 month 7 path 1 row 75
# fracAreaMCD15: 0.02312717287999904
# year 2004 month 7 path 1 row 76
# year 2004 month 7 path 1 row 77
# fracAreaMCD15: 0.00015626926416753196
# year 2004 month 7 path 1 row 78
# fracAreaMCD15: 0.004358327708796204
# year 2004 month 7 path 1 row 79
# year 2004 month 7 path 1 row 80
# year 2004 month 7 path 1 row 81
# year 2004 month 7 path 1 row 82
# fracAreaMCD15: 0.0
# year 2004 month 7 path 1 row 83
# year 2004 month 7 path 1 row 84
# fracAreaMCD15: 0.0
# year 2004 month 7 path 2 row 6
# fracAreaMCD15: 0.0
# year 2004 month 7 path 2 row 7
# fracAreaMCD15: 0.0
# year 2004 month 7 path 2 row 8
# year 2004 month 7 path 2 row 17
# fracAreaMCD15: 0.0
# year 2004 month 7 path 2 row 26
# year 2004 month 7 path 2 row 27
# year 2004 month 7 path 2 row 54
# year 2004 month 7 path 2 row 55
# year 2004 month 7 path 2 row 56
# year 2004 month 7 path 2 row 57
# year 2004 month 7 path 2 row 58
# year 2004 month 7 path 2 row 66
# fracAreaMCD15: 0.2147129274793764
# year 2004 month 7 path 2 row 67
# fracAreaMCD15: 0.9716376793232074
# fracAreaLCtoMCD: 0.21023605770858592
# cumulative samples: 3712 nsaminput 933
# year 2004 month 7 path 2 row 68
# fracAreaMCD15: 0.7344145299252266
# fracAreaLCtoMCD: 0.2812273152788726
# cumulative samples: 5514 nsaminput 1802
# year 2004 month 7 path 2 row 69
# year 2004 month 7 path 2 row 70
# fracAreaMCD15: 0.5503132038278649
# fracAreaLCtoMCD: 0.2824914704090869
# cumulative samples: 7311 nsaminput 1797
# year 2004 month 7 path 2 row 71
# fracAreaMCD15: 0.5678072768674126
# fracAreaLCtoMCD: 0.06263201008541532
# year 2004 month 7 path 2 row 72
# year 2004 month 7 path 2 row 73
# year 2004 month 7 path 2 row 74
# fracAreaMCD15: 0.00253753351087874
# year 2004 month 7 path 2 row 75
# year 2004 month 7 path 2 row 76
# year 2004 month 7 path 3 row 4
# fracAreaMCD15: 0.0
# year 2004 month 7 path 3 row 5
# fracAreaMCD15: 0.0013533439652559612
# year 2004 month 7 path 3 row 6
# fracAreaMCD15: 0.0
# year 2004 month 7 path 3 row 25
# fracAreaMCD15: 0.0005830536249272654
# year 2004 month 7 path 3 row 26
# year 2004 month 7 path 3 row 27
# fracAreaMCD15: 0.10860315911367846
# year 2004 month 7 path 3 row 63
# year 2004 month 7 path 3 row 64
# year 2004 month 7 path 3 row 65
# fracAreaMCD15: 0.3269833126475479
# fracAreaLCtoMCD: 0.17661364093632584
# cumulative samples: 7990 nsaminput 679
# year 2004 month 7 path 3 row 66
# fracAreaMCD15: 0.0981221512570966
# year 2004 month 7 path 3 row 67
# fracAreaMCD15: 0.17943037117173302
# year 2004 month 7 path 3 row 68
# year 2004 month 7 path 3 row 69
# year 2004 month 7 path 3 row 70
# fracAreaMCD15: 0.3998107931325651
# fracAreaLCtoMCD: 0.2979493992637483
# cumulative samples: 9904 nsaminput 1914
# year 2004 month 7 path 3 row 71
# year 2004 month 7 path 3 row 72
# year 2004 month 7 path 4 row 5
# fracAreaMCD15: 0.0
# year 2004 month 7 path 4 row 6
# fracAreaMCD15: 0.0
# year 2004 month 7 path 4 row 16
# year 2004 month 7 path 4 row 17
# year 2004 month 7 path 4 row 24
# year 2004 month 7 path 4 row 25
# year 2004 month 7 path 4 row 26
# fracAreaMCD15: 0.1297528159592594
# year 2004 month 7 path 4 row 27
# fracAreaMCD15: 0.0
# year 2004 month 7 path 4 row 52
# year 2004 month 7 path 4 row 53
# fracAreaMCD15: 0.0
# year 2004 month 7 path 4 row 54
# year 2004 month 7 path 4 row 55
# year 2004 month 7 path 4 row 57
# year 2004 month 7 path 4 row 58
# fracAreaMCD15: 0.2065553270251143
# year 2004 month 7 path 4 row 67
# fracAreaMCD15: 0.07182531543682229
# year 2004 month 7 path 4 row 68
# year 2004 month 7 path 4 row 69
# fracAreaMCD15: 0.09327902487439783
# year 2004 month 7 path 4 row 70
# fracAreaMCD15: 0.6317110936299689
# fracAreaLCtoMCD: 0.24824084644954653
# cumulative samples: 11485 nsaminput 1581
# year 2004 month 7 path 4 row 71
# fracAreaMCD15: 0.0
# year 2004 month 7 path 4 row 72
# year 2004 month 7 path 5 row 4
# fracAreaMCD15: 0.0
# year 2004 month 7 path 5 row 5
# fracAreaMCD15: 0.0
# year 2004 month 7 path 5 row 23
# fracAreaMCD15: 0.0
# year 2004 month 7 path 5 row 24
# fracAreaMCD15: 0.04871093692732904
# year 2004 month 7 path 5 row 25
# fracAreaMCD15: 0.0
# year 2004 month 7 path 5 row 26
# year 2004 month 7 path 5 row 47
# year 2004 month 7 path 5 row 48
# fracAreaMCD15: 0.0
# year 2004 month 7 path 5 row 52
# year 2004 month 7 path 5 row 53
# year 2004 month 7 path 5 row 58
# year 2004 month 7 path 5 row 70
# year 2004 month 7 path 5 row 247
# fracAreaMCD15: 0.0
# year 2004 month 7 path 6 row 37
# fracAreaMCD15: 0.0
# year 2004 month 7 path 6 row 38
# fracAreaMCD15: 0.0
# year 2004 month 7 path 6 row 52
# year 2004 month 7 path 6 row 53
# year 2004 month 7 path 6 row 54
# year 2004 month 7 path 6 row 55
# year 2004 month 7 path 6 row 56
# year 2004 month 7 path 6 row 60
# year 2004 month 7 path 6 row 64
# year 2004 month 7 path 6 row 66
# year 2004 month 7 path 6 row 67
# year 2004 month 7 path 6 row 69
# fracAreaMCD15: 0.7421665441004679
# fracAreaLCtoMCD: 0.3749579897372804
# cumulative samples: 12823 nsaminput 1338
# year 2004 month 7 path 6 row 71
# year 2004 month 7 path 6 row 247
# fracAreaMCD15: 0.0
# year 2004 month 7 path 7 row 14
# year 2004 month 7 path 7 row 15
# year 2004 month 7 path 7 row 22
# year 2004 month 7 path 7 row 23
# year 2004 month 7 path 7 row 24
# year 2004 month 7 path 7 row 25
# year 2004 month 7 path 7 row 26
# year 2004 month 7 path 7 row 28
# year 2004 month 7 path 7 row 29
# year 2004 month 7 path 7 row 51
# fracAreaMCD15: 0.0
# year 2004 month 7 path 7 row 52
# year 2004 month 7 path 7 row 247
# year 2004 month 7 path 8 row 23
# fracAreaMCD15: 0.0
# year 2004 month 7 path 8 row 24
# fracAreaMCD15: 0.018961899966137473
# year 2004 month 7 path 8 row 25
# year 2004 month 7 path 8 row 52
# year 2004 month 7 path 8 row 53
# year 2004 month 7 path 8 row 54
# year 2004 month 7 path 8 row 56
# year 2004 month 7 path 8 row 57
# fracAreaMCD15: 0.24829714778208198
# year 2004 month 7 path 8 row 58
# year 2004 month 7 path 8 row 59
# year 2004 month 7 path 8 row 60
# fracAreaMCD15: 0.14808179375220784
# year 2004 month 7 path 8 row 61
# year 2004 month 7 path 8 row 64
# fracAreaMCD15: 0.12091737502586083
# year 2004 month 7 path 8 row 65
# fracAreaMCD15: 0.42941952717543036
# fracAreaLCtoMCD: 0.1544793453231141
# cumulative samples: 13631 nsaminput 808
# year 2004 month 7 path 8 row 66
# fracAreaMCD15: 0.5989597720811041
# fracAreaLCtoMCD: 0.0928767363839768
# year 2004 month 7 path 8 row 67
# year 2004 month 7 path 8 row 68
# year 2004 month 7 path 8 row 247
# year 2004 month 7 path 9 row 2
# year 2004 month 7 path 9 row 3
# fracAreaMCD15: 0.0
# year 2004 month 7 path 9 row 4
# fracAreaMCD15: 0.0
# year 2004 month 7 path 9 row 13
# fracAreaMCD15: 0.0
# year 2004 month 7 path 9 row 14
# year 2004 month 7 path 9 row 58
# year 2004 month 7 path 9 row 65
# fracAreaMCD15: 0.4665424278712557
# fracAreaLCtoMCD: 0.15911142920432614
# cumulative samples: 14157 nsaminput 526
# year 2004 month 7 path 9 row 66
# fracAreaMCD15: 0.4137974770104008
# fracAreaLCtoMCD: 0.10201647891188158
# cumulative samples: 14181 nsaminput 24
# year 2004 month 7 path 10 row 1
# fracAreaMCD15: 0.0
# year 2004 month 7 path 10 row 2
# year 2004 month 7 path 10 row 3
# fracAreaMCD15: 0.0
# year 2004 month 7 path 10 row 12
# year 2004 month 7 path 10 row 20
# year 2004 month 7 path 10 row 21
# year 2004 month 7 path 10 row 22
# year 2004 month 7 path 10 row 23
# year 2004 month 7 path 10 row 24
# year 2004 month 7 path 10 row 25
# year 2004 month 7 path 10 row 65
# year 2004 month 7 path 10 row 247
# fracAreaMCD15: 0.0008935911898163884
# year 2004 month 7 path 11 row 9
# fracAreaMCD15: 0.0
# year 2004 month 7 path 11 row 19
# fracAreaMCD15: 0.0
# year 2004 month 7 path 11 row 20
# fracAreaMCD15: 0.0015626216719302416
# year 2004 month 7 path 11 row 21
# year 2004 month 7 path 11 row 28
# year 2004 month 7 path 11 row 29
# year 2004 month 7 path 11 row 30
# fracAreaMCD15: 0.0
# year 2004 month 7 path 11 row 64
# year 2004 month 7 path 11 row 247
# fracAreaMCD15: 0.0
# year 2004 month 7 path 12 row 22
# year 2004 month 7 path 12 row 23
# year 2004 month 7 path 12 row 24
# year 2004 month 7 path 12 row 26
# year 2004 month 7 path 12 row 27
# year 2004 month 7 path 12 row 28
# fracAreaMCD15: 0.06359894220156719
# year 2004 month 7 path 12 row 29
# fracAreaMCD15: 0.0039034526628839855
# year 2004 month 7 path 12 row 30
# fracAreaMCD15: 0.19248025492260987
# year 2004 month 7 path 12 row 31
# fracAreaMCD15: 0.007037817340195863
# year 2004 month 7 path 12 row 32
# fracAreaMCD15: 0.0
# year 2004 month 7 path 12 row 42
# fracAreaMCD15: 0.0
# year 2004 month 7 path 12 row 43
# fracAreaMCD15: 0.0
# year 2004 month 7 path 12 row 44
# year 2004 month 7 path 12 row 45
# fracAreaMCD15: 0.4029820835564148
# fracAreaLCtoMCD: 0.19414109007101
# cumulative samples: 14276 nsaminput 95
# year 2004 month 7 path 12 row 46
# year 2004 month 7 path 12 row 47
# fracAreaMCD15: 0.0
# year 2004 month 7 path 13 row 20
# fracAreaMCD15: 0.03644061904271953
# year 2004 month 7 path 13 row 21
# fracAreaMCD15: 0.0010356554678388008
# year 2004 month 7 path 13 row 22
# year 2004 month 7 path 13 row 23
# fracAreaMCD15: 0.0
# year 2004 month 7 path 13 row 24
# fracAreaMCD15: 0.0007101818523437709
# year 2004 month 7 path 13 row 25
# fracAreaMCD15: 0.0
# year 2004 month 7 path 13 row 26
# year 2004 month 7 path 13 row 27
# fracAreaMCD15: 0.0
# year 2004 month 7 path 13 row 28
# fracAreaMCD15: 0.0
# year 2004 month 7 path 13 row 29
# fracAreaMCD15: 0.0
# year 2004 month 7 path 13 row 30
# year 2004 month 7 path 13 row 31
# fracAreaMCD15: 0.005313371850336954
# year 2004 month 7 path 13 row 32
# fracAreaMCD15: 0.07425291419119273
# year 2004 month 7 path 13 row 33
# year 2004 month 7 path 14 row 1
# year 2004 month 7 path 14 row 2
# fracAreaMCD15: 0.0003837344838263098
# year 2004 month 7 path 14 row 19
# fracAreaMCD15: 0.07065934301787131
# year 2004 month 7 path 14 row 20
# fracAreaMCD15: 0.006944234775603906
# year 2004 month 7 path 14 row 21
# year 2004 month 7 path 14 row 22
# year 2004 month 7 path 14 row 26
# year 2004 month 7 path 14 row 28
# year 2004 month 7 path 14 row 29
# year 2004 month 7 path 14 row 30
# fracAreaMCD15: 0.2574785985393954
# fracAreaLCtoMCD: 0.17641982969448436
# cumulative samples: 15390 nsaminput 1114
# year 2004 month 7 path 14 row 31
# fracAreaMCD15: 0.0002731937015643032
# year 2004 month 7 path 14 row 32
# fracAreaMCD15: 0.0
# year 2004 month 7 path 14 row 33
# year 2004 month 7 path 14 row 34
# year 2004 month 7 path 14 row 36
# year 2004 month 7 path 14 row 41
# fracAreaMCD15: 0.0
# year 2004 month 7 path 14 row 42
# fracAreaMCD15: 0.0
# year 2004 month 7 path 14 row 43
# fracAreaMCD15: 0.0
# year 2004 month 7 path 14 row 44
# fracAreaMCD15: 0.1256112046298772
# year 2004 month 7 path 15 row 8
# year 2004 month 7 path 15 row 9
# fracAreaMCD15: 0.0
# year 2004 month 7 path 15 row 13
# fracAreaMCD15: 0.0
# year 2004 month 7 path 15 row 14
# fracAreaMCD15: 0.0
# year 2004 month 7 path 15 row 15
# fracAreaMCD15: 0.00046882531778857055
# year 2004 month 7 path 15 row 16
# year 2004 month 7 path 15 row 17
# fracAreaMCD15: 0.0
# year 2004 month 7 path 15 row 18
# fracAreaMCD15: 0.0
# year 2004 month 7 path 15 row 19
# year 2004 month 7 path 15 row 20
# fracAreaMCD15: 0.0
# year 2004 month 7 path 15 row 21
# fracAreaMCD15: 0.0
# year 2004 month 7 path 15 row 22
# fracAreaMCD15: 0.0
# year 2004 month 7 path 15 row 23
# fracAreaMCD15: 0.0
# year 2004 month 7 path 15 row 28
# year 2004 month 7 path 15 row 29
# year 2004 month 7 path 15 row 32
# year 2004 month 7 path 15 row 33
# fracAreaMCD15: 0.021065419384694358
# year 2004 month 7 path 15 row 34
# fracAreaMCD15: 0.003466169853861505
# year 2004 month 7 path 15 row 35
# fracAreaMCD15: 0.2027394607637645
# year 2004 month 7 path 15 row 36
# fracAreaMCD15: 0.011484940183610752
# year 2004 month 7 path 15 row 37
# fracAreaMCD15: 0.0
# year 2004 month 7 path 15 row 40
# fracAreaMCD15: 0.0
# year 2004 month 7 path 15 row 41
# year 2004 month 7 path 15 row 42
# year 2004 month 7 path 15 row 43
# fracAreaMCD15: 0.0032817320086827987
# year 2004 month 7 path 15 row 247
# year 2004 month 7 path 17 row 7
# fracAreaMCD15: 0.0
# year 2004 month 7 path 17 row 8
# year 2004 month 7 path 17 row 13
# year 2004 month 7 path 17 row 14
# year 2004 month 7 path 17 row 20
# year 2004 month 7 path 17 row 21
# fracAreaMCD15: 0.0
# year 2004 month 7 path 17 row 22
# year 2004 month 7 path 17 row 23
# fracAreaMCD15: 0.0
# year 2004 month 7 path 17 row 24
# fracAreaMCD15: 0.0
# year 2004 month 7 path 17 row 25
# fracAreaMCD15: 0.00021337952407236027
# year 2004 month 7 path 17 row 34
# fracAreaMCD15: 0.6704109997389909
# fracAreaLCtoMCD: 0.1347580679542335
# cumulative samples: 15398 nsaminput 8
# year 2004 month 7 path 17 row 35
# fracAreaMCD15: 0.15624970163293808
# year 2004 month 7 path 17 row 36
# year 2004 month 7 path 17 row 37
# fracAreaMCD15: 0.3951568339611628
# fracAreaLCtoMCD: 0.1875761887628845
# cumulative samples: 16599 nsaminput 1201
# year 2004 month 7 path 17 row 38
# fracAreaMCD15: 0.0
# year 2004 month 7 path 17 row 39
# year 2004 month 7 path 17 row 40
# year 2004 month 7 path 17 row 41
# fracAreaMCD15: 0.0
# year 2004 month 7 path 17 row 44
# fracAreaMCD15: 0.0
# year 2004 month 7 path 17 row 246
# fracAreaMCD15: 0.0
# year 2004 month 7 path 17 row 247
# year 2004 month 7 path 18 row 14
# year 2004 month 7 path 18 row 15
# fracAreaMCD15: 0.0
# year 2004 month 7 path 18 row 16
# fracAreaMCD15: 0.0
# year 2004 month 7 path 18 row 17
# fracAreaMCD15: 0.0
# year 2004 month 7 path 18 row 18
# fracAreaMCD15: 0.041406287752415304
# year 2004 month 7 path 18 row 19
# fracAreaMCD15: 0.020627822856294536
# year 2004 month 7 path 18 row 20
# year 2004 month 7 path 18 row 21
# year 2004 month 7 path 18 row 22
# year 2004 month 7 path 18 row 31
# year 2004 month 7 path 18 row 32
# year 2004 month 7 path 18 row 33
# year 2004 month 7 path 18 row 35
# year 2004 month 7 path 18 row 36
# year 2004 month 7 path 18 row 37
# fracAreaMCD15: 0.23860417227273092
# year 2004 month 7 path 18 row 38
# fracAreaMCD15: 0.11192954891376954
# year 2004 month 7 path 18 row 39
# year 2004 month 7 path 18 row 40
# year 2004 month 7 path 18 row 45
# year 2004 month 7 path 18 row 46
# fracAreaMCD15: 0.0
# year 2004 month 7 path 18 row 47
# year 2004 month 7 path 18 row 49
# year 2004 month 7 path 18 row 50
# year 2004 month 7 path 18 row 51
# year 2004 month 7 path 18 row 60
# year 2004 month 7 path 19 row 1
# year 2004 month 7 path 19 row 22
# fracAreaMCD15: 0.08669826054868289
# year 2004 month 7 path 19 row 23
# fracAreaMCD15: 0.007103532409488572
# year 2004 month 7 path 19 row 24
# fracAreaMCD15: 0.2794597866118593
# fracAreaLCtoMCD: 0.1979421693023837
# cumulative samples: 17839 nsaminput 1240
# year 2004 month 7 path 19 row 25
# fracAreaMCD15: 0.800374761388546
# fracAreaLCtoMCD: 0.23756457672037395
# cumulative samples: 17851 nsaminput 12
# year 2004 month 7 path 19 row 26
# year 2004 month 7 path 19 row 31
# year 2004 month 7 path 19 row 32
# year 2004 month 7 path 19 row 33
# year 2004 month 7 path 19 row 34
# year 2004 month 7 path 19 row 35
# year 2004 month 7 path 19 row 36
# year 2004 month 7 path 19 row 37
# year 2004 month 7 path 19 row 38
# year 2004 month 7 path 19 row 39
# year 2004 month 7 path 19 row 45
# fracAreaMCD15: 0.0
# year 2004 month 7 path 19 row 46
# year 2004 month 7 path 19 row 47
# fracAreaMCD15: 0.0
# year 2004 month 7 path 19 row 48
# fracAreaMCD15: 0.009050079073352247
# year 2004 month 7 path 19 row 246
# fracAreaMCD15: 0.002546456072163859
# year 2004 month 7 path 19 row 247
# fracAreaMCD15: 0.0
# year 2004 month 7 path 20 row 6
# fracAreaMCD15: 0.0
# year 2004 month 7 path 20 row 7
# year 2004 month 7 path 20 row 13
# fracAreaMCD15: 0.0003125596286605617
# year 2004 month 7 path 20 row 14
# fracAreaMCD15: 0.003125898552073635
# year 2004 month 7 path 20 row 15
# fracAreaMCD15: 0.0
# year 2004 month 7 path 20 row 16
# fracAreaMCD15: 0.0
# year 2004 month 7 path 20 row 17
# fracAreaMCD15: 0.029726881247310634
# year 2004 month 7 path 20 row 18
# fracAreaMCD15: 0.0
# year 2004 month 7 path 20 row 19
# year 2004 month 7 path 20 row 20
# year 2004 month 7 path 20 row 24
# year 2004 month 7 path 20 row 25
# year 2004 month 7 path 20 row 26
# fracAreaMCD15: 0.07234394705179437
# year 2004 month 7 path 20 row 27
# fracAreaMCD15: 0.32465614662111664
# fracAreaLCtoMCD: 0.20280814066516514
# cumulative samples: 18728 nsaminput 877
# year 2004 month 7 path 20 row 28
# year 2004 month 7 path 20 row 29
# fracAreaMCD15: 0.0
# year 2004 month 7 path 20 row 30
# year 2004 month 7 path 20 row 32
# year 2004 month 7 path 20 row 35
# year 2004 month 7 path 20 row 36
# year 2004 month 7 path 20 row 37
# year 2004 month 7 path 20 row 38
# year 2004 month 7 path 20 row 39
# year 2004 month 7 path 20 row 45
# year 2004 month 7 path 20 row 46
# fracAreaMCD15: 0.72265022138899
# fracAreaLCtoMCD: 0.15462817377767543
# cumulative samples: 19478 nsaminput 750
# year 2004 month 7 path 20 row 47
# year 2004 month 7 path 20 row 48
# year 2004 month 7 path 20 row 49
# year 2004 month 7 path 20 row 247
# fracAreaMCD15: 0.0
# year 2004 month 7 path 21 row 1
# fracAreaMCD15: 0.0
# year 2004 month 7 path 21 row 16
# year 2004 month 7 path 21 row 18
# year 2004 month 7 path 21 row 19
# year 2004 month 7 path 21 row 26
# fracAreaMCD15: 0.0
# year 2004 month 7 path 21 row 27
# fracAreaMCD15: 0.018119098765085776
# year 2004 month 7 path 21 row 28
# fracAreaMCD15: 0.03391037792829466
# year 2004 month 7 path 21 row 29
# fracAreaMCD15: 0.31046746339868164
# fracAreaLCtoMCD: 0.22851820474165233
# cumulative samples: 20956 nsaminput 1478
# year 2004 month 7 path 21 row 30
# fracAreaMCD15: 0.038362009863895506
# year 2004 month 7 path 21 row 31
# year 2004 month 7 path 21 row 32
# year 2004 month 7 path 21 row 34
# year 2004 month 7 path 21 row 35
# year 2004 month 7 path 21 row 37
# year 2004 month 7 path 21 row 38
# year 2004 month 7 path 21 row 39
# year 2004 month 7 path 21 row 40
# year 2004 month 7 path 21 row 45
# year 2004 month 7 path 21 row 46
# fracAreaMCD15: 0.0
# year 2004 month 7 path 21 row 47
# fracAreaMCD15: 0.27770061970311744
# fracAreaLCtoMCD: 0.05608347712615113
# year 2004 month 7 path 21 row 48
# fracAreaMCD15: 0.3514107838593208
# fracAreaLCtoMCD: 0.23069466926991666
# cumulative samples: 22415 nsaminput 1459
# year 2004 month 7 path 21 row 49
# fracAreaMCD15: 0.24675122119663256
# year 2004 month 7 path 21 row 246
# year 2004 month 7 path 21 row 247
# year 2004 month 7 path 22 row 1
# fracAreaMCD15: 0.0
# year 2004 month 7 path 22 row 6
# year 2004 month 7 path 22 row 11
# fracAreaMCD15: 0.0
# year 2004 month 7 path 22 row 12
# fracAreaMCD15: 0.0
# year 2004 month 7 path 22 row 13
# fracAreaMCD15: 0.004759616297541311
# year 2004 month 7 path 22 row 14
# fracAreaMCD15: 0.027179022870919504
# year 2004 month 7 path 22 row 15
# year 2004 month 7 path 22 row 16
# fracAreaMCD15: 0.0
# year 2004 month 7 path 22 row 17
# year 2004 month 7 path 22 row 18
# fracAreaMCD15: 0.0
# year 2004 month 7 path 22 row 19
# fracAreaMCD15: 0.0
# year 2004 month 7 path 22 row 20
# fracAreaMCD15: 0.0
# year 2004 month 7 path 22 row 21
# fracAreaMCD15: 0.0
# year 2004 month 7 path 22 row 22
# fracAreaMCD15: 0.0
# year 2004 month 7 path 22 row 23
# fracAreaMCD15: 0.027975810516487325
# year 2004 month 7 path 22 row 24
# fracAreaMCD15: 0.15623995330108806
# year 2004 month 7 path 22 row 25
# year 2004 month 7 path 22 row 26
# fracAreaMCD15: 0.02078535176066016
# year 2004 month 7 path 22 row 27
# fracAreaMCD15: 0.009572661453738167
# year 2004 month 7 path 22 row 28
# year 2004 month 7 path 22 row 29
# year 2004 month 7 path 22 row 30
# fracAreaMCD15: 0.12885664046709183
# year 2004 month 7 path 22 row 31
# year 2004 month 7 path 22 row 33
# year 2004 month 7 path 22 row 34
# year 2004 month 7 path 22 row 35
# year 2004 month 7 path 22 row 36
# year 2004 month 7 path 22 row 37
# year 2004 month 7 path 22 row 38
# fracAreaMCD15: 0.14967178434969944
# year 2004 month 7 path 22 row 39
# year 2004 month 7 path 22 row 40
# fracAreaMCD15: 0.0
# year 2004 month 7 path 22 row 246
# fracAreaMCD15: 0.0
# year 2004 month 7 path 22 row 247
# fracAreaMCD15: 0.0
# year 2004 month 7 path 23 row 1
# fracAreaMCD15: 0.0
# year 2004 month 7 path 23 row 10
# year 2004 month 7 path 23 row 18
# year 2004 month 7 path 23 row 19
# fracAreaMCD15: 0.0
# year 2004 month 7 path 23 row 21
# fracAreaMCD15: 0.0
# year 2004 month 7 path 23 row 22
# fracAreaMCD15: 0.0
# year 2004 month 7 path 23 row 23
# fracAreaMCD15: 0.24285563631523008
# year 2004 month 7 path 23 row 24
# fracAreaMCD15: 0.40046344911938353
# fracAreaLCtoMCD: 0.2632995220782261
# cumulative samples: 24118 nsaminput 1703
# year 2004 month 7 path 23 row 25
# year 2004 month 7 path 23 row 27
# fracAreaMCD15: 0.0
# year 2004 month 7 path 23 row 28
# fracAreaMCD15: 0.0
# year 2004 month 7 path 23 row 29
# year 2004 month 7 path 23 row 30
# year 2004 month 7 path 23 row 31
# fracAreaMCD15: 0.0
# year 2004 month 7 path 23 row 32
# fracAreaMCD15: 0.022187793032171714
# year 2004 month 7 path 23 row 33
# year 2004 month 7 path 23 row 49
# fracAreaMCD15: 0.03344508032607406
# year 2004 month 7 path 23 row 246
# fracAreaMCD15: 0.0002643978787242421
# year 2004 month 7 path 23 row 247
# fracAreaMCD15: 0.0
# year 2004 month 7 path 24 row 11
# year 2004 month 7 path 24 row 12
# fracAreaMCD15: 0.03129278836592057
# year 2004 month 7 path 24 row 13
# fracAreaMCD15: 0.016564506184456575
# year 2004 month 7 path 24 row 14
# year 2004 month 7 path 24 row 15
# fracAreaMCD15: 0.0
# year 2004 month 7 path 24 row 16
# year 2004 month 7 path 24 row 17
# year 2004 month 7 path 24 row 18
# fracAreaMCD15: 0.0
# year 2004 month 7 path 24 row 19
# fracAreaMCD15: 0.0
# year 2004 month 7 path 24 row 21
# fracAreaMCD15: 0.0
# year 2004 month 7 path 24 row 22
# fracAreaMCD15: 0.0
# year 2004 month 7 path 24 row 23
# fracAreaMCD15: 0.005625749252632848
# year 2004 month 7 path 24 row 24
# fracAreaMCD15: 0.0
# year 2004 month 7 path 24 row 25
# fracAreaMCD15: 0.0
# year 2004 month 7 path 24 row 26
# fracAreaMCD15: 0.052944079568202636
# year 2004 month 7 path 24 row 27
# fracAreaMCD15: 0.0030266581148168112
# year 2004 month 7 path 24 row 30
# fracAreaMCD15: 0.07359178243166266
# year 2004 month 7 path 24 row 31
# year 2004 month 7 path 24 row 33
# year 2004 month 7 path 24 row 34
# year 2004 month 7 path 24 row 35
# year 2004 month 7 path 24 row 36
# year 2004 month 7 path 24 row 37
# year 2004 month 7 path 24 row 38
# year 2004 month 7 path 24 row 39
# year 2004 month 7 path 24 row 40
# year 2004 month 7 path 24 row 46
# year 2004 month 7 path 24 row 47
# year 2004 month 7 path 24 row 48
# year 2004 month 7 path 24 row 49
# year 2004 month 7 path 24 row 246
# year 2004 month 7 path 24 row 247
# year 2004 month 7 path 25 row 10
# year 2004 month 7 path 25 row 11
# year 2004 month 7 path 25 row 17
# year 2004 month 7 path 25 row 22
# year 2004 month 7 path 25 row 25
# year 2004 month 7 path 25 row 26
# fracAreaMCD15: 0.23703580852961126
# year 2004 month 7 path 25 row 28
# fracAreaMCD15: 0.1439170678541878
# year 2004 month 7 path 25 row 29
# year 2004 month 7 path 25 row 30
# year 2004 month 7 path 25 row 31
# year 2004 month 7 path 25 row 32
# fracAreaMCD15: 0.04084898589649421
# year 2004 month 7 path 25 row 33
# year 2004 month 7 path 25 row 34
# fracAreaMCD15: 0.7859404595360291
# fracAreaLCtoMCD: 0.2726732355204271
# cumulative samples: 25142 nsaminput 1024
# year 2004 month 7 path 25 row 35
# year 2004 month 7 path 25 row 36
# fracAreaMCD15: 0.44644581997855126
# fracAreaLCtoMCD: 0.13563649943029576
# cumulative samples: 25558 nsaminput 416
# year 2004 month 7 path 25 row 37
# year 2004 month 7 path 25 row 38
# fracAreaMCD15: 0.18535762125425828
# year 2004 month 7 path 25 row 39
# fracAreaMCD15: 0.31146588012075405
# fracAreaLCtoMCD: 0.0977622012197287
# year 2004 month 7 path 25 row 40
# fracAreaMCD15: 0.016099866912696267
# year 2004 month 7 path 25 row 45
# year 2004 month 7 path 25 row 46
# fracAreaMCD15: 0.0
# year 2004 month 7 path 25 row 47
# fracAreaMCD15: 0.5300216845183836
# fracAreaLCtoMCD: 0.36914358173064926
# cumulative samples: 27892 nsaminput 2334
# year 2004 month 7 path 25 row 48
# year 2004 month 7 path 25 row 49
# year 2004 month 7 path 25 row 246
# year 2004 month 7 path 25 row 247
# fracAreaMCD15: 0.0
# year 2004 month 7 path 26 row 11
# year 2004 month 7 path 26 row 12
# year 2004 month 7 path 26 row 21
# fracAreaMCD15: 0.0631625639306226
# year 2004 month 7 path 26 row 22
# year 2004 month 7 path 26 row 23
# fracAreaMCD15: 0.0
# year 2004 month 7 path 26 row 24
# year 2004 month 7 path 26 row 33
# fracAreaMCD15: 0.5471674672021488
# fracAreaLCtoMCD: 0.10768518859390945
# cumulative samples: 27972 nsaminput 80
# year 2004 month 7 path 26 row 34
# year 2004 month 7 path 26 row 35
# year 2004 month 7 path 26 row 37
# fracAreaMCD15: 0.5900283162834887
# fracAreaLCtoMCD: 0.1536296876734965
# cumulative samples: 28182 nsaminput 210
# year 2004 month 7 path 26 row 38
# year 2004 month 7 path 26 row 39
# year 2004 month 7 path 26 row 40
# year 2004 month 7 path 26 row 41
# fracAreaMCD15: 0.0
# year 2004 month 7 path 26 row 42
# fracAreaMCD15: 0.5220620758488846
# fracAreaLCtoMCD: 0.10517711106520349
# cumulative samples: 28262 nsaminput 80
# year 2004 month 7 path 26 row 43
# fracAreaMCD15: 0.3595392978491468
# fracAreaLCtoMCD: 0.14771348804301107
# cumulative samples: 29202 nsaminput 940
# year 2004 month 7 path 26 row 44
# year 2004 month 7 path 26 row 45
# fracAreaMCD15: 0.0
# year 2004 month 7 path 26 row 46
# year 2004 month 7 path 26 row 47
# year 2004 month 7 path 27 row 1
# fracAreaMCD15: 0.0
# year 2004 month 7 path 27 row 5
# fracAreaMCD15: 0.0
# year 2004 month 7 path 27 row 6
# year 2004 month 7 path 27 row 12
# fracAreaMCD15: 0.0
# year 2004 month 7 path 27 row 13
# fracAreaMCD15: 0.0
# year 2004 month 7 path 27 row 15
# year 2004 month 7 path 27 row 16
# fracAreaMCD15: 0.0
# year 2004 month 7 path 27 row 20
# fracAreaMCD15: 0.0
# year 2004 month 7 path 27 row 21
# year 2004 month 7 path 27 row 22
# fracAreaMCD15: 0.2279400910291313
# year 2004 month 7 path 27 row 23
# year 2004 month 7 path 27 row 24
# year 2004 month 7 path 27 row 25
# year 2004 month 7 path 27 row 27
# year 2004 month 7 path 27 row 28
# year 2004 month 7 path 27 row 29
# fracAreaMCD15: 0.3812374961512215
# fracAreaLCtoMCD: 0.2558105778679843
# cumulative samples: 30849 nsaminput 1647
# year 2004 month 7 path 27 row 30
# year 2004 month 7 path 27 row 31
# year 2004 month 7 path 27 row 32
# fracAreaMCD15: 0.7023351766797485
# fracAreaLCtoMCD: 0.4097425561029697
# cumulative samples: 33445 nsaminput 2596
# year 2004 month 7 path 27 row 33
# fracAreaMCD15: 0.5345512418594877
# fracAreaLCtoMCD: 0.14207903745148845
# cumulative samples: 33652 nsaminput 207
# year 2004 month 7 path 27 row 34
# fracAreaMCD15: 0.4961208953092469
# fracAreaLCtoMCD: 0.2752963595103839
# cumulative samples: 35411 nsaminput 1759
# year 2004 month 7 path 27 row 35
# fracAreaMCD15: 0.7215577735071285
# fracAreaLCtoMCD: 0.3318475665884744
# cumulative samples: 35629 nsaminput 218
# year 2004 month 7 path 27 row 36
# fracAreaMCD15: 0.8992126156369301
# fracAreaLCtoMCD: 0.17689906679320905
# cumulative samples: 35664 nsaminput 35
# year 2004 month 7 path 27 row 37
# fracAreaMCD15: 0.4349413570910331
# fracAreaLCtoMCD: 0.23793898689856668
# cumulative samples: 36209 nsaminput 545
# year 2004 month 7 path 27 row 38
# fracAreaMCD15: 0.4341731319572161
# fracAreaLCtoMCD: 0.13270244717881474
# cumulative samples: 36664 nsaminput 455
# year 2004 month 7 path 27 row 39
# fracAreaMCD15: 0.7412636542235875
# fracAreaLCtoMCD: 0.15419671437504404
# cumulative samples: 36836 nsaminput 172
# year 2004 month 7 path 27 row 40
# fracAreaMCD15: 0.7186720298796702
# fracAreaLCtoMCD: 0.13661858263834445
# cumulative samples: 36899 nsaminput 63
# year 2004 month 7 path 27 row 41
# year 2004 month 7 path 27 row 42
# fracAreaMCD15: 0.012741372494280843
# year 2004 month 7 path 27 row 43
# year 2004 month 7 path 27 row 44
# fracAreaMCD15: 0.5415323925716661
# fracAreaLCtoMCD: 0.1697316587966645
# cumulative samples: 37979 nsaminput 1080
# year 2004 month 7 path 27 row 45
# fracAreaMCD15: 0.1860763562162363
# year 2004 month 7 path 27 row 246
# fracAreaMCD15: 0.0019579212020273884
# year 2004 month 7 path 27 row 247
# fracAreaMCD15: 0.0
# year 2004 month 7 path 28 row 5
# fracAreaMCD15: 0.0
# year 2004 month 7 path 28 row 11
# year 2004 month 7 path 28 row 12
# year 2004 month 7 path 28 row 13
# year 2004 month 7 path 28 row 14
# year 2004 month 7 path 28 row 15
# fracAreaMCD15: 0.01986313222096422
# year 2004 month 7 path 28 row 16
# year 2004 month 7 path 28 row 22
# year 2004 month 7 path 28 row 23
# fracAreaMCD15: 0.09450695043797655
# year 2004 month 7 path 28 row 29
# year 2004 month 7 path 28 row 30
# fracAreaMCD15: 0.5948396908918969
# fracAreaLCtoMCD: 0.3435607912212461
# cumulative samples: 40191 nsaminput 2212
# year 2004 month 7 path 28 row 31
# fracAreaMCD15: 0.6803116366135621
# fracAreaLCtoMCD: 0.3844049670386075
# cumulative samples: 42628 nsaminput 2437
# year 2004 month 7 path 28 row 32
# fracAreaMCD15: 0.4899352494534401
# fracAreaLCtoMCD: 0.1968553174369336
# cumulative samples: 43282 nsaminput 654
# year 2004 month 7 path 28 row 33
# year 2004 month 7 path 28 row 34
# year 2004 month 7 path 28 row 35
# fracAreaMCD15: 0.04855857154866197
# year 2004 month 7 path 28 row 36
# year 2004 month 7 path 28 row 37
# year 2004 month 7 path 28 row 38
# fracAreaMCD15: 0.45827844900651415
# fracAreaLCtoMCD: 0.3109802696715387
# cumulative samples: 45226 nsaminput 1944
# year 2004 month 7 path 28 row 39
# fracAreaMCD15: 0.3715119632525846
# fracAreaLCtoMCD: 0.10673676585461091
# cumulative samples: 45263 nsaminput 37
# year 2004 month 7 path 28 row 40
# fracAreaMCD15: 0.5445453541669003
# fracAreaLCtoMCD: 0.1742740445843856
# cumulative samples: 46345 nsaminput 1082
# year 2004 month 7 path 28 row 41
# fracAreaMCD15: 0.1046759857397576
# year 2004 month 7 path 28 row 42
# fracAreaMCD15: 0.4858401942637846
# fracAreaLCtoMCD: 0.10045194687295642
# cumulative samples: 46426 nsaminput 81
# year 2004 month 7 path 28 row 43
# year 2004 month 7 path 28 row 44
# fracAreaMCD15: 0.13117789435345575
# year 2004 month 7 path 28 row 246
# year 2004 month 7 path 28 row 247
# year 2004 month 7 path 29 row 5
# year 2004 month 7 path 29 row 6
# year 2004 month 7 path 29 row 12
# year 2004 month 7 path 29 row 13
# fracAreaMCD15: 0.0
# year 2004 month 7 path 29 row 14
# fracAreaMCD15: 0.03263292368870589
# year 2004 month 7 path 29 row 15
# fracAreaMCD15: 0.0
# year 2004 month 7 path 29 row 16
# year 2004 month 7 path 29 row 20
# year 2004 month 7 path 29 row 21
# year 2004 month 7 path 29 row 22
# year 2004 month 7 path 29 row 23
# year 2004 month 7 path 29 row 24
# fracAreaMCD15: 0.20865896143686716
# year 2004 month 7 path 29 row 25
# year 2004 month 7 path 29 row 26
# fracAreaMCD15: 0.1603212767183793
# year 2004 month 7 path 29 row 27
# year 2004 month 7 path 29 row 28
# fracAreaMCD15: 0.5159312401817386
# fracAreaLCtoMCD: 0.19104854374828786
# cumulative samples: 47582 nsaminput 1156
# year 2004 month 7 path 29 row 29
# fracAreaMCD15: 0.4940686761853495
# fracAreaLCtoMCD: 0.2603834964959095
# cumulative samples: 49250 nsaminput 1668
# year 2004 month 7 path 29 row 30
# fracAreaMCD15: 0.7263913527458009
# fracAreaLCtoMCD: 0.2412639764021001
# cumulative samples: 50296 nsaminput 1046
# year 2004 month 7 path 29 row 31
# year 2004 month 7 path 29 row 32
# fracAreaMCD15: 0.45217385094039975
# fracAreaLCtoMCD: 0.0805021336163679
# year 2004 month 7 path 29 row 33
# fracAreaMCD15: 0.4106785363735629
# fracAreaLCtoMCD: 0.29806348606574073
# cumulative samples: 50944 nsaminput 648
# year 2004 month 7 path 29 row 34
# fracAreaMCD15: 0.3189610141644843
# fracAreaLCtoMCD: 0.2070235324034696
# cumulative samples: 51442 nsaminput 498
# year 2004 month 7 path 29 row 35
# fracAreaMCD15: 0.5616970383560479
# fracAreaLCtoMCD: 0.15419754787151246
# cumulative samples: 51714 nsaminput 272
# year 2004 month 7 path 29 row 36
# fracAreaMCD15: 0.6740624657787598
# fracAreaLCtoMCD: 0.2732894321835132
# cumulative samples: 53454 nsaminput 1740
# year 2004 month 7 path 29 row 37
# fracAreaMCD15: 0.7023448245846518
# fracAreaLCtoMCD: 0.26319465375766216
# cumulative samples: 54470 nsaminput 1016
# year 2004 month 7 path 29 row 38
# fracAreaMCD15: 0.6389089283625888
# fracAreaLCtoMCD: 0.3401556141087113
# cumulative samples: 56652 nsaminput 2182
# year 2004 month 7 path 29 row 39
# fracAreaMCD15: 0.41505928779866136
# fracAreaLCtoMCD: 0.1276782185017758
# cumulative samples: 57353 nsaminput 701
# year 2004 month 7 path 29 row 40
# year 2004 month 7 path 29 row 41
# fracAreaMCD15: 0.3979981007492214
# fracAreaLCtoMCD: 0.09490863850278908
# year 2004 month 7 path 29 row 42
# fracAreaMCD15: 0.150224505052427
# year 2004 month 7 path 29 row 43
# fracAreaMCD15: 0.3923856183304491
# fracAreaLCtoMCD: 0.10536212131303753
# cumulative samples: 57482 nsaminput 129
# year 2004 month 7 path 29 row 44
# year 2004 month 7 path 29 row 45
# fracAreaMCD15: 0.25180643519029716
# fracAreaLCtoMCD: 0.11526962481389645
# cumulative samples: 57565 nsaminput 83
# year 2004 month 7 path 29 row 46
# year 2004 month 7 path 29 row 47
# year 2004 month 7 path 29 row 246
# fracAreaMCD15: 0.0
# year 2004 month 7 path 29 row 247
# fracAreaMCD15: 0.0
# year 2004 month 7 path 30 row 5
# year 2004 month 7 path 30 row 6
# year 2004 month 7 path 30 row 9
# fracAreaMCD15: 0.0
# year 2004 month 7 path 30 row 10
# year 2004 month 7 path 30 row 11
# fracAreaMCD15: 0.0
# year 2004 month 7 path 30 row 12
# fracAreaMCD15: 0.0
# year 2004 month 7 path 30 row 13
# year 2004 month 7 path 30 row 23
# year 2004 month 7 path 30 row 33
# year 2004 month 7 path 30 row 34
# fracAreaMCD15: 0.7003561606881883
# fracAreaLCtoMCD: 0.19069848331871136
# cumulative samples: 57636 nsaminput 71
# year 2004 month 7 path 30 row 35
# fracAreaMCD15: 0.51300742466506
# fracAreaLCtoMCD: 0.12518642085944365
# cumulative samples: 57672 nsaminput 36
# year 2004 month 7 path 30 row 36
# fracAreaMCD15: 0.31091265946259605
# fracAreaLCtoMCD: 0.16170155908589703
# cumulative samples: 58072 nsaminput 400
# year 2004 month 7 path 30 row 37
# fracAreaMCD15: 0.5185467630418602
# fracAreaLCtoMCD: 0.12707277379836918
# cumulative samples: 58180 nsaminput 108
# year 2004 month 7 path 30 row 38
# fracAreaMCD15: 0.619609379370437
# fracAreaLCtoMCD: 0.1400852614857469
# cumulative samples: 58364 nsaminput 184
# year 2004 month 7 path 30 row 39
# fracAreaMCD15: 0.5237683181666359
# fracAreaLCtoMCD: 0.32130847026378784
# cumulative samples: 60429 nsaminput 2065
# year 2004 month 7 path 30 row 40
# fracAreaMCD15: 0.4422134764163825
# fracAreaLCtoMCD: 0.20010723015869436
# cumulative samples: 61689 nsaminput 1260
# year 2004 month 7 path 30 row 41
# fracAreaMCD15: 0.45044196078183557
# fracAreaLCtoMCD: 0.10377591601863573
# cumulative samples: 61888 nsaminput 199
# year 2004 month 7 path 30 row 42
# fracAreaMCD15: 0.2781362779627763
# fracAreaLCtoMCD: 0.10809270317020675
# cumulative samples: 62169 nsaminput 281
# year 2004 month 7 path 30 row 43
# fracAreaMCD15: 0.33385094796669756
# fracAreaLCtoMCD: 0.09242269370364752
# year 2004 month 7 path 30 row 44
# fracAreaMCD15: 0.5436495939209731
# fracAreaLCtoMCD: 0.13307838209866157
# cumulative samples: 62498 nsaminput 329
# year 2004 month 7 path 30 row 45
# fracAreaMCD15: 0.2195715081640942
# year 2004 month 7 path 30 row 46
# fracAreaMCD15: 0.4013970498203346
# fracAreaLCtoMCD: 0.20859228810317842
# cumulative samples: 63827 nsaminput 1329
# year 2004 month 7 path 30 row 246
# year 2004 month 7 path 30 row 247
# year 2004 month 7 path 31 row 1
# fracAreaMCD15: 0.0
# year 2004 month 7 path 31 row 8
# fracAreaMCD15: 0.0
# year 2004 month 7 path 31 row 9
# fracAreaMCD15: 0.019847259600640543
# year 2004 month 7 path 31 row 10
# year 2004 month 7 path 31 row 11
# year 2004 month 7 path 31 row 12
# year 2004 month 7 path 31 row 13
# fracAreaMCD15: 0.0
# year 2004 month 7 path 31 row 14
# year 2004 month 7 path 31 row 15
# fracAreaMCD15: 0.0
# year 2004 month 7 path 31 row 16
# fracAreaMCD15: 0.0
# year 2004 month 7 path 31 row 17
# fracAreaMCD15: 0.0
# year 2004 month 7 path 31 row 19
# fracAreaMCD15: 0.0
# year 2004 month 7 path 31 row 20
# fracAreaMCD15: 0.0
# year 2004 month 7 path 31 row 21
# year 2004 month 7 path 31 row 25
# year 2004 month 7 path 31 row 26
# fracAreaMCD15: 0.4765012271166012
# fracAreaLCtoMCD: 0.1363253845787012
# cumulative samples: 64001 nsaminput 174
# year 2004 month 7 path 31 row 27
# fracAreaMCD15: 0.34536832913086635
# fracAreaLCtoMCD: 0.12261973755606718
# cumulative samples: 64592 nsaminput 591
# year 2004 month 7 path 31 row 28
# fracAreaMCD15: 0.340895159635281
# fracAreaLCtoMCD: 0.10743946124574795
# cumulative samples: 64873 nsaminput 281
# year 2004 month 7 path 31 row 29
# year 2004 month 7 path 31 row 30
# fracAreaMCD15: 0.11715499452407079
# year 2004 month 7 path 31 row 31
# year 2004 month 7 path 31 row 32
# fracAreaMCD15: 0.24044964050174686
# year 2004 month 7 path 31 row 33
# year 2004 month 7 path 31 row 34
# fracAreaMCD15: 0.1397466489610653
# year 2004 month 7 path 31 row 35
# fracAreaMCD15: 0.2600221847837461
# fracAreaLCtoMCD: 0.07212481104593625
# year 2004 month 7 path 31 row 36
# fracAreaMCD15: 0.14226331405352433
# year 2004 month 7 path 31 row 37
# fracAreaMCD15: 0.1637774899420712
# year 2004 month 7 path 31 row 38
# fracAreaMCD15: 0.4575603397899803
# fracAreaLCtoMCD: 0.2274017106404338
# cumulative samples: 65204 nsaminput 331
# year 2004 month 7 path 31 row 39
# fracAreaMCD15: 0.19640246280635817
# year 2004 month 7 path 31 row 40
# fracAreaMCD15: 0.18165295064032597
# year 2004 month 7 path 31 row 41
# fracAreaMCD15: 0.1192060300424546
# year 2004 month 7 path 31 row 42
# fracAreaMCD15: 0.5598534047596998
# fracAreaLCtoMCD: 0.11810159561079255
# cumulative samples: 65436 nsaminput 232
# year 2004 month 7 path 31 row 246
# year 2004 month 7 path 31 row 247
# fracAreaMCD15: 0.0
# year 2004 month 7 path 33 row 13
# year 2004 month 7 path 33 row 14
# fracAreaMCD15: 0.0
# year 2004 month 7 path 33 row 15
# year 2004 month 7 path 33 row 16
# fracAreaMCD15: 0.0
# year 2004 month 7 path 33 row 17
# fracAreaMCD15: 0.0
# year 2004 month 7 path 33 row 18
# fracAreaMCD15: 0.00031361451049936694
# year 2004 month 7 path 33 row 19
# fracAreaMCD15: 0.0
# year 2004 month 7 path 33 row 20
# fracAreaMCD15: 0.0
# year 2004 month 7 path 33 row 21
# year 2004 month 7 path 33 row 22
# fracAreaMCD15: 0.5187799597253917
# fracAreaLCtoMCD: 0.25805777438253336
# cumulative samples: 67117 nsaminput 1681
# year 2004 month 7 path 33 row 23
# fracAreaMCD15: 0.05060310742191059
# year 2004 month 7 path 33 row 24
# fracAreaMCD15: 0.3367804948053066
# fracAreaLCtoMCD: 0.10597487305860716
# cumulative samples: 67225 nsaminput 108
# year 2004 month 7 path 33 row 25
# year 2004 month 7 path 33 row 27
# year 2004 month 7 path 33 row 28
# year 2004 month 7 path 33 row 29
# fracAreaMCD15: 0.39657105997966
# fracAreaLCtoMCD: 0.059441810982357374
# year 2004 month 7 path 33 row 30
# fracAreaMCD15: 0.5363041648007805
# fracAreaLCtoMCD: 0.43453041275916404
# cumulative samples: 67451 nsaminput 226
# year 2004 month 7 path 33 row 31
# year 2004 month 7 path 33 row 32
# fracAreaMCD15: 0.2850538882730508
# fracAreaLCtoMCD: 0.1135326496037325
# cumulative samples: 67906 nsaminput 455
# year 2004 month 7 path 33 row 33
# fracAreaMCD15: 0.2434614813538333
# year 2004 month 7 path 33 row 34
# fracAreaMCD15: 0.40578927447444824
# fracAreaLCtoMCD: 0.17439452724268723
# cumulative samples: 69025 nsaminput 1119
# year 2004 month 7 path 33 row 35
# fracAreaMCD15: 0.1882872182340997
# year 2004 month 7 path 33 row 36
# fracAreaMCD15: 0.4685988457306992
# fracAreaLCtoMCD: 0.17272156057162213
# cumulative samples: 69618 nsaminput 593
# year 2004 month 7 path 33 row 37
# fracAreaMCD15: 0.39474344433699204
# fracAreaLCtoMCD: 0.13994595615323024
# cumulative samples: 70390 nsaminput 772
# year 2004 month 7 path 33 row 38
# fracAreaMCD15: 0.12077917901948258
# year 2004 month 7 path 33 row 246
# year 2004 month 7 path 34 row 7
# fracAreaMCD15: 0.0
# year 2004 month 7 path 34 row 13
# year 2004 month 7 path 34 row 16
# fracAreaMCD15: 0.026829299392491204
# year 2004 month 7 path 34 row 17
# year 2004 month 7 path 34 row 18
# year 2004 month 7 path 34 row 20
# year 2004 month 7 path 34 row 21
# year 2004 month 7 path 34 row 22
# fracAreaMCD15: 0.13033293017106942
# year 2004 month 7 path 34 row 23
# fracAreaMCD15: 0.013129706502090704
# year 2004 month 7 path 34 row 24
# year 2004 month 7 path 34 row 25
# fracAreaMCD15: 0.42352310857700787
# fracAreaLCtoMCD: 0.27766713076667077
# cumulative samples: 71575 nsaminput 1185
# year 2004 month 7 path 34 row 26
# year 2004 month 7 path 34 row 27
# fracAreaMCD15: 0.760517732834934
# fracAreaLCtoMCD: 0.3093519651867318
# cumulative samples: 73323 nsaminput 1748
# year 2004 month 7 path 34 row 28
# fracAreaMCD15: 0.7178416402024888
# fracAreaLCtoMCD: 0.4782358473752396
# cumulative samples: 76432 nsaminput 3109
# year 2004 month 7 path 34 row 29
# fracAreaMCD15: 0.47722551733401075
# fracAreaLCtoMCD: 0.15753752512880984
# cumulative samples: 76840 nsaminput 408
# year 2004 month 7 path 34 row 30
# fracAreaMCD15: 0.8913137708108962
# fracAreaLCtoMCD: 0.23061449180570215
# cumulative samples: 76909 nsaminput 69
# year 2004 month 7 path 34 row 31
# year 2004 month 7 path 34 row 32
# fracAreaMCD15: 0.27365330549009736
# fracAreaLCtoMCD: 0.08487546684822063
# year 2004 month 7 path 34 row 33
# year 2004 month 7 path 34 row 34
# fracAreaMCD15: 0.37757139173043025
# fracAreaLCtoMCD: 0.129258045405176
# cumulative samples: 77608 nsaminput 699
# year 2004 month 7 path 34 row 35
# fracAreaMCD15: 0.2952320199176355
# fracAreaLCtoMCD: 0.23606230688332625
# cumulative samples: 77930 nsaminput 322
# year 2004 month 7 path 34 row 36
# fracAreaMCD15: 0.5259255603192337
# fracAreaLCtoMCD: 0.2947416543326757
# cumulative samples: 79819 nsaminput 1889
# year 2004 month 7 path 34 row 37
# fracAreaMCD15: 0.42848702679850287
# fracAreaLCtoMCD: 0.15179223867315292
# cumulative samples: 80258 nsaminput 439
# year 2004 month 7 path 34 row 38
# year 2004 month 7 path 35 row 1
# fracAreaMCD15: 0.0
# year 2004 month 7 path 35 row 7
# fracAreaMCD15: 0.0
# year 2004 month 7 path 35 row 8
# fracAreaMCD15: 0.0020317000919982766
# year 2004 month 7 path 35 row 9
# year 2004 month 7 path 35 row 10
# fracAreaMCD15: 0.0
# year 2004 month 7 path 35 row 11
# fracAreaMCD15: 0.0
# year 2004 month 7 path 35 row 12
# fracAreaMCD15: 0.0
# year 2004 month 7 path 35 row 13
# year 2004 month 7 path 35 row 14
# year 2004 month 7 path 35 row 15
# fracAreaMCD15: 0.06816323707656387
# year 2004 month 7 path 35 row 16
# fracAreaMCD15: 0.0006660218263732407
# year 2004 month 7 path 35 row 17
# fracAreaMCD15: 0.02657193873786434
# year 2004 month 7 path 35 row 18
# fracAreaMCD15: 0.0
# year 2004 month 7 path 35 row 19
# fracAreaMCD15: 0.003814033959428045
# year 2004 month 7 path 35 row 20
# fracAreaMCD15: 0.0
# year 2004 month 7 path 35 row 21
# fracAreaMCD15: 0.035467770897897793
# year 2004 month 7 path 35 row 22
# fracAreaMCD15: 0.05273328878096432
# year 2004 month 7 path 35 row 23
# fracAreaMCD15: 0.26931742840708084
# fracAreaLCtoMCD: 0.10812123625971203
# cumulative samples: 80841 nsaminput 583
# year 2004 month 7 path 35 row 24
# year 2004 month 7 path 35 row 30
# year 2004 month 7 path 35 row 31
# year 2004 month 7 path 35 row 32
# year 2004 month 7 path 35 row 33
# year 2004 month 7 path 35 row 34
# year 2004 month 7 path 35 row 35
# fracAreaMCD15: 0.39918779474919786
# fracAreaLCtoMCD: 0.24663069071027224
# cumulative samples: 82403 nsaminput 1562
# year 2004 month 7 path 35 row 36
# fracAreaMCD15: 0.5650749920162004
# fracAreaLCtoMCD: 0.15878594046255726
# cumulative samples: 82690 nsaminput 287
# year 2004 month 7 path 35 row 37
# fracAreaMCD15: 0.3760456137431555
# fracAreaLCtoMCD: 0.13550069971526985
# cumulative samples: 83152 nsaminput 462
# year 2004 month 7 path 35 row 38
# fracAreaMCD15: 0.25888940355186396
# fracAreaLCtoMCD: 0.027460490368951603
# year 2004 month 7 path 35 row 246
# year 2004 month 7 path 35 row 247
# year 2004 month 7 path 36 row 1
# fracAreaMCD15: 0.0
# year 2004 month 7 path 36 row 7
# year 2004 month 7 path 36 row 8
# fracAreaMCD15: 1.0
# fracAreaLCtoMCD: 0.0
# year 2004 month 7 path 36 row 9
# fracAreaMCD15: 0.0
# year 2004 month 7 path 36 row 10
# fracAreaMCD15: 0.0
# year 2004 month 7 path 36 row 11
# fracAreaMCD15: 0.0
# year 2004 month 7 path 36 row 12
# fracAreaMCD15: 0.05501291168216881
# year 2004 month 7 path 36 row 13
# fracAreaMCD15: 0.0
# year 2004 month 7 path 36 row 14
# year 2004 month 7 path 36 row 15
# year 2004 month 7 path 36 row 16
# fracAreaMCD15: 0.0
# year 2004 month 7 path 36 row 17
# fracAreaMCD15: 0.003136189212004212
# year 2004 month 7 path 36 row 18
# fracAreaMCD15: 0.004375457548088063
# year 2004 month 7 path 36 row 19
# year 2004 month 7 path 36 row 20
# year 2004 month 7 path 36 row 25
# year 2004 month 7 path 36 row 26
# fracAreaMCD15: 0.11545766120923188
# year 2004 month 7 path 36 row 27
# fracAreaMCD15: 0.14374552732337356
# year 2004 month 7 path 36 row 28
# fracAreaMCD15: 0.434923119284961
# fracAreaLCtoMCD: 0.1670962411005197
# cumulative samples: 83384 nsaminput 232
# year 2004 month 7 path 36 row 29
# fracAreaMCD15: 0.6071861404583534
# fracAreaLCtoMCD: 0.20231627191314244
# cumulative samples: 83722 nsaminput 338
# year 2004 month 7 path 36 row 30
# fracAreaMCD15: 0.47482875918382395
# fracAreaLCtoMCD: 0.2955239255205126
# cumulative samples: 85604 nsaminput 1882
# year 2004 month 7 path 36 row 31
# fracAreaMCD15: 0.4839222717791275
# fracAreaLCtoMCD: 0.29011471790463156
# cumulative samples: 87474 nsaminput 1870
# year 2004 month 7 path 36 row 32
# fracAreaMCD15: 0.4606062355226566
# fracAreaLCtoMCD: 0.18320730116607514
# cumulative samples: 88569 nsaminput 1095
# year 2004 month 7 path 36 row 33
# fracAreaMCD15: 0.3691325504555903
# fracAreaLCtoMCD: 0.13652196805400388
# cumulative samples: 89052 nsaminput 483
# year 2004 month 7 path 36 row 34
# fracAreaMCD15: 0.6534003528639963
# fracAreaLCtoMCD: 0.1874308646539372
# cumulative samples: 89303 nsaminput 251
# year 2004 month 7 path 36 row 35
# fracAreaMCD15: 0.5024283173557164
# fracAreaLCtoMCD: 0.09966257538322267
# year 2004 month 7 path 36 row 36
# fracAreaMCD15: 0.7480864105598404
# fracAreaLCtoMCD: 0.2957672220091734
# cumulative samples: 91228 nsaminput 1925
# year 2004 month 7 path 36 row 37
# fracAreaMCD15: 0.3016554557305157
# fracAreaLCtoMCD: 0.08398231762617972
# year 2004 month 7 path 36 row 38
# fracAreaMCD15: 0.4072052658088066
# fracAreaLCtoMCD: 0.09917235304044619
# year 2004 month 7 path 36 row 39
# fracAreaMCD15: 0.22658086297914035
# year 2004 month 7 path 36 row 40
# fracAreaMCD15: 0.4452762398370943
# fracAreaLCtoMCD: 0.15708295969885486
# cumulative samples: 92154 nsaminput 926
# year 2004 month 7 path 36 row 42
# year 2004 month 7 path 36 row 246
# fracAreaMCD15: 0.0
# year 2004 month 7 path 36 row 247
# fracAreaMCD15: 0.0
# year 2004 month 7 path 37 row 7
# year 2004 month 7 path 37 row 8
# year 2004 month 7 path 37 row 9
# year 2004 month 7 path 37 row 10
# year 2004 month 7 path 37 row 17
# year 2004 month 7 path 37 row 18
# year 2004 month 7 path 37 row 19
# year 2004 month 7 path 37 row 20
# year 2004 month 7 path 37 row 21
# fracAreaMCD15: 0.21831594946926733
# year 2004 month 7 path 37 row 22
# year 2004 month 7 path 37 row 26
# fracAreaMCD15: 0.17435259940228287
# year 2004 month 7 path 37 row 27
# fracAreaMCD15: 0.17369517596378015
# year 2004 month 7 path 37 row 28
# year 2004 month 7 path 37 row 29
# year 2004 month 7 path 37 row 30
# year 2004 month 7 path 37 row 31
# fracAreaMCD15: 0.4712229125380453
# fracAreaLCtoMCD: 0.17840348149416935
# cumulative samples: 93154 nsaminput 1000
# year 2004 month 7 path 37 row 32
# fracAreaMCD15: 0.25994312972050515
# fracAreaLCtoMCD: 0.042345371709283465
# year 2004 month 7 path 37 row 33
# fracAreaMCD15: 0.5028096335600103
# fracAreaLCtoMCD: 0.20706091696391632
# cumulative samples: 94460 nsaminput 1306
# year 2004 month 7 path 37 row 34
# fracAreaMCD15: 0.39072875012745517
# fracAreaLCtoMCD: 0.17874406818831393
# cumulative samples: 95584 nsaminput 1124
# year 2004 month 7 path 37 row 35
# fracAreaMCD15: 0.4427665718324714
# fracAreaLCtoMCD: 0.2374356085082222
# cumulative samples: 95973 nsaminput 389
# year 2004 month 7 path 37 row 36
# fracAreaMCD15: 0.6745264272619106
# fracAreaLCtoMCD: 0.22482519874278684
# cumulative samples: 96715 nsaminput 742
# year 2004 month 7 path 37 row 37
# fracAreaMCD15: 0.4177736578691137
# fracAreaLCtoMCD: 0.15024150064863515
# cumulative samples: 97566 nsaminput 851
# year 2004 month 7 path 37 row 38
# fracAreaMCD15: 0.7407214721739984
# fracAreaLCtoMCD: 0.22595701209206723
# cumulative samples: 98347 nsaminput 781
# year 2004 month 7 path 37 row 39
# year 2004 month 7 path 38 row 4
# fracAreaMCD15: 0.0
# year 2004 month 7 path 38 row 5
# fracAreaMCD15: 0.0
# year 2004 month 7 path 38 row 6
# fracAreaMCD15: 0.0
# year 2004 month 7 path 38 row 7
# fracAreaMCD15: 0.0
# year 2004 month 7 path 38 row 10
# year 2004 month 7 path 38 row 11
# year 2004 month 7 path 38 row 13
# fracAreaMCD15: 0.004085773173242911
# year 2004 month 7 path 38 row 14
# fracAreaMCD15: 0.0
# year 2004 month 7 path 38 row 15
# fracAreaMCD15: 0.0
# year 2004 month 7 path 38 row 16
# fracAreaMCD15: 0.0
# year 2004 month 7 path 38 row 17
# fracAreaMCD15: 0.0
# year 2004 month 7 path 38 row 18
# fracAreaMCD15: 0.0
# year 2004 month 7 path 38 row 19
# fracAreaMCD15: 0.0
# ...
# year 2004 month 9 path 173 row 30
# fracAreaMCD15: 0.0
# year 2004 month 9 path 173 row 31
# year 2004 month 9 path 173 row 32
# fracAreaMCD15: 0.6251601756436445
# fracAreaLCtoMCD: 0.18781394324618372
# cumulative samples: 3443623 nsaminput 1209
# year 2004 month 9 path 173 row 33
# fracAreaMCD15: 0.6135922922806186
# fracAreaLCtoMCD: 0.4558599894517126
# cumulative samples: 3444164 nsaminput 541
# year 2004 month 9 path 173 row 34
# fracAreaMCD15: 0.5090732409995411
# fracAreaLCtoMCD: 0.4269708545621449
# cumulative samples: 3444731 nsaminput 567
# year 2004 month 9 path 173 row 35
# fracAreaMCD15: 0.5207403689961428
# fracAreaLCtoMCD: 0.09206677561376349
# year 2004 month 9 path 173 row 36
# fracAreaMCD15: 0.0
# year 2004 month 9 path 173 row 37
# fracAreaMCD15: 0.1856235181171059
# year 2004 month 9 path 173 row 38
# fracAreaMCD15: 0.030936843493615803
# year 2004 month 9 path 173 row 45
# fracAreaMCD15: 0.0
# year 2004 month 9 path 173 row 46
# fracAreaMCD15: 0.0
# year 2004 month 9 path 173 row 47
# fracAreaMCD15: 0.0
# year 2004 month 9 path 173 row 48
# fracAreaMCD15: 0.0
# year 2004 month 9 path 173 row 57
# fracAreaMCD15: 0.9598436798824446
# fracAreaLCtoMCD: 0.4118741015714586
# cumulative samples: 3447386 nsaminput 2655
# year 2004 month 9 path 173 row 58
# year 2004 month 9 path 173 row 59
# year 2004 month 9 path 173 row 60
# year 2004 month 9 path 173 row 61
# fracAreaMCD15: 0.08738502592771878
# year 2004 month 9 path 173 row 62
# fracAreaMCD15: 0.2739192444164311
# fracAreaLCtoMCD: 0.04905899833278244
# year 2004 month 9 path 173 row 63
# fracAreaMCD15: 0.4768860695174664
# fracAreaLCtoMCD: 0.09324941895311607
# year 2004 month 9 path 173 row 64
# fracAreaMCD15: 0.0
# year 2004 month 9 path 173 row 65
# fracAreaMCD15: 0.0
# year 2004 month 9 path 173 row 66
# fracAreaMCD15: 0.000323904231375716
# year 2004 month 9 path 173 row 67
# fracAreaMCD15: 0.0
# year 2004 month 9 path 173 row 68
# fracAreaMCD15: 0.0
# year 2004 month 9 path 173 row 69
# fracAreaMCD15: 0.00046971439069332213
# year 2004 month 9 path 173 row 70
# fracAreaMCD15: 0.0
# year 2004 month 9 path 173 row 71
# fracAreaMCD15: 0.0
# year 2004 month 9 path 173 row 72
# fracAreaMCD15: 0.26251144761492323
# fracAreaLCtoMCD: 0.16801112251895126
# cumulative samples: 3448411 nsaminput 1025
# year 2004 month 9 path 173 row 73
# fracAreaMCD15: 0.17809283785942429
# year 2004 month 9 path 173 row 74
# fracAreaMCD15: 0.4991485270422517
# fracAreaLCtoMCD: 0.11670945608863308
# cumulative samples: 3449041 nsaminput 630
# year 2004 month 9 path 173 row 75
# fracAreaMCD15: 0.6292122351558757
# fracAreaLCtoMCD: 0.12444628536514935
# cumulative samples: 3449319 nsaminput 278
# year 2004 month 9 path 173 row 76
# fracAreaMCD15: 0.5778366181436203
# fracAreaLCtoMCD: 0.12490649980883778
# cumulative samples: 3449707 nsaminput 388
# year 2004 month 9 path 173 row 77
# fracAreaMCD15: 0.09063887303449103
# year 2004 month 9 path 173 row 78
# fracAreaMCD15: 0.1784229878675816
# year 2004 month 9 path 173 row 79
# fracAreaMCD15: 0.18111529763144374
# year 2004 month 9 path 173 row 80
# fracAreaMCD15: 0.39207772108800876
# fracAreaLCtoMCD: 0.07186630021662876
# year 2004 month 9 path 173 row 81
# fracAreaMCD15: 0.3766316866699511
# fracAreaLCtoMCD: 0.2503622739576341
# cumulative samples: 3451185 nsaminput 1478
# year 2004 month 9 path 173 row 82
# fracAreaMCD15: 0.3853030858785267
# fracAreaLCtoMCD: 0.0860766422636563
# year 2004 month 9 path 173 row 83
# fracAreaMCD15: 0.5388918364712405
# fracAreaLCtoMCD: 0.21762342727846357
# cumulative samples: 3452541 nsaminput 1356
# year 2004 month 9 path 173 row 84
# fracAreaMCD15: 0.7378640776699029
# fracAreaLCtoMCD: 0.0
# year 2004 month 9 path 174 row 22
# year 2004 month 9 path 174 row 23
# fracAreaMCD15: 0.23968742114560534
# year 2004 month 9 path 174 row 24
# fracAreaMCD15: 0.4307185794957726
# fracAreaLCtoMCD: 0.052066419228030736
# year 2004 month 9 path 174 row 35
# fracAreaMCD15: 0.2848806081193354
# fracAreaLCtoMCD: 0.06041554364327986
# year 2004 month 9 path 174 row 36
# fracAreaMCD15: 0.3046108665576484
# fracAreaLCtoMCD: 0.13467447498998897
# cumulative samples: 3453375 nsaminput 834
# year 2004 month 9 path 174 row 37
# year 2004 month 9 path 174 row 38
# fracAreaMCD15: 0.10671759668971117
# year 2004 month 9 path 174 row 39
# fracAreaMCD15: 0.000558448479183884
# year 2004 month 9 path 174 row 40
# fracAreaMCD15: 0.0
# year 2004 month 9 path 174 row 41
# fracAreaMCD15: 0.0
# year 2004 month 9 path 174 row 42
# fracAreaMCD15: 0.00031251039674151914
# year 2004 month 9 path 174 row 43
# fracAreaMCD15: 0.005312374860996175
# year 2004 month 9 path 174 row 44
# fracAreaMCD15: 0.0
# year 2004 month 9 path 174 row 45
# fracAreaMCD15: 0.0
# year 2004 month 9 path 174 row 46
# fracAreaMCD15: 0.0
# year 2004 month 9 path 174 row 47
# fracAreaMCD15: 0.0
# year 2004 month 9 path 174 row 48
# fracAreaMCD15: 0.0
# year 2004 month 9 path 174 row 55
# fracAreaMCD15: 0.5171700321579169
# fracAreaLCtoMCD: 0.09102752139532409
# year 2004 month 9 path 174 row 56
# fracAreaMCD15: 0.02937493188147771
# year 2004 month 9 path 174 row 57
# year 2004 month 9 path 174 row 58
# year 2004 month 9 path 174 row 59
# year 2004 month 9 path 174 row 65
# fracAreaMCD15: 0.0
# year 2004 month 9 path 174 row 66
# fracAreaMCD15: 0.0
# year 2004 month 9 path 174 row 67
# fracAreaMCD15: 0.0029607663044464703
# year 2004 month 9 path 174 row 68
# fracAreaMCD15: 0.0
# year 2004 month 9 path 174 row 69
# year 2004 month 9 path 174 row 70
# fracAreaMCD15: 0.42220583556761043
# fracAreaLCtoMCD: 0.24046328071057416
# cumulative samples: 3454559 nsaminput 1184
# year 2004 month 9 path 174 row 71
# fracAreaMCD15: 0.4537326487552595
# fracAreaLCtoMCD: 0.3276667461023204
# cumulative samples: 3456662 nsaminput 2103
# year 2004 month 9 path 174 row 72
# fracAreaMCD15: 0.7267040651541694
# fracAreaLCtoMCD: 0.301097876924216
# cumulative samples: 3458606 nsaminput 1944
# year 2004 month 9 path 174 row 73
# fracAreaMCD15: 0.681666600455273
# fracAreaLCtoMCD: 0.14217123713532198
# cumulative samples: 3458752 nsaminput 146
# year 2004 month 9 path 174 row 74
# fracAreaMCD15: 0.5908027147768813
# fracAreaLCtoMCD: 0.4193908002207919
# cumulative samples: 3461440 nsaminput 2688
# year 2004 month 9 path 174 row 75
# fracAreaMCD15: 0.6178445213552118
# fracAreaLCtoMCD: 0.44530429467202054
# cumulative samples: 3464329 nsaminput 2889
# year 2004 month 9 path 174 row 76
# fracAreaMCD15: 0.4430307490722619
# fracAreaLCtoMCD: 0.1250147628651447
# cumulative samples: 3464336 nsaminput 7
# year 2004 month 9 path 174 row 77
# fracAreaMCD15: 0.5497079629085182
# fracAreaLCtoMCD: 0.3590961191491258
# cumulative samples: 3465833 nsaminput 1497
# year 2004 month 9 path 174 row 78
# fracAreaMCD15: 0.1459666386813213
# year 2004 month 9 path 174 row 79
# fracAreaMCD15: 0.5387438148875752
# fracAreaLCtoMCD: 0.18275599623036856
# cumulative samples: 3466971 nsaminput 1138
# year 2004 month 9 path 175 row 18
# fracAreaMCD15: 0.12999998729568887
# year 2004 month 9 path 175 row 19
# year 2004 month 9 path 175 row 20
# year 2004 month 9 path 175 row 27
# year 2004 month 9 path 175 row 28
# year 2004 month 9 path 175 row 29
# year 2004 month 9 path 175 row 34
# fracAreaMCD15: 0.33050236253416304
# fracAreaLCtoMCD: 0.13265267372553424
# cumulative samples: 3467786 nsaminput 815
# year 2004 month 9 path 175 row 35
# fracAreaMCD15: 0.02688069343684197
# year 2004 month 9 path 175 row 36
# fracAreaMCD15: 0.0
# year 2004 month 9 path 175 row 37
# fracAreaMCD15: 0.0
# year 2004 month 9 path 175 row 38
# fracAreaMCD15: 0.0
# year 2004 month 9 path 175 row 44
# fracAreaMCD15: 0.0
# year 2004 month 9 path 175 row 45
# fracAreaMCD15: 0.0
# year 2004 month 9 path 175 row 46
# fracAreaMCD15: 0.0
# year 2004 month 9 path 175 row 47
# fracAreaMCD15: 0.0
# year 2004 month 9 path 175 row 55
# year 2004 month 9 path 175 row 56
# year 2004 month 9 path 175 row 63
# year 2004 month 9 path 175 row 64
# year 2004 month 9 path 175 row 65
# fracAreaMCD15: 0.0
# year 2004 month 9 path 175 row 66
# year 2004 month 9 path 175 row 67
# fracAreaMCD15: 0.0015627841998478139
# year 2004 month 9 path 175 row 68
# fracAreaMCD15: 0.0
# year 2004 month 9 path 175 row 69
# fracAreaMCD15: 0.003880488855663921
# year 2004 month 9 path 175 row 70
# fracAreaMCD15: 0.2798411288699417
# fracAreaLCtoMCD: 0.0575219628813349
# year 2004 month 9 path 175 row 71
# fracAreaMCD15: 0.3283218925957337
# fracAreaLCtoMCD: 0.06030283568582027
# year 2004 month 9 path 175 row 72
# year 2004 month 9 path 175 row 73
# fracAreaMCD15: 0.5102772009563722
# fracAreaLCtoMCD: 0.11745414755961707
# cumulative samples: 3467902 nsaminput 116
# year 2004 month 9 path 175 row 77
# fracAreaMCD15: 0.5841901700863376
# fracAreaLCtoMCD: 0.1441892619325107
# cumulative samples: 3468719 nsaminput 817
# year 2004 month 9 path 176 row 6
# fracAreaMCD15: 0.0
# year 2004 month 9 path 176 row 7
# fracAreaMCD15: 0.0
# year 2004 month 9 path 176 row 8
# year 2004 month 9 path 176 row 9
# year 2004 month 9 path 176 row 17
# year 2004 month 9 path 176 row 29
# fracAreaMCD15: 0.0
# year 2004 month 9 path 176 row 31
# fracAreaMCD15: 0.0
# year 2004 month 9 path 176 row 32
# fracAreaMCD15: 0.17234551797178776
# year 2004 month 9 path 176 row 38
# fracAreaMCD15: 0.0
# year 2004 month 9 path 176 row 39
# fracAreaMCD15: 0.004970165799266067
# year 2004 month 9 path 176 row 40
# fracAreaMCD15: 0.0
# year 2004 month 9 path 176 row 41
# fracAreaMCD15: 0.0
# year 2004 month 9 path 176 row 42
# fracAreaMCD15: 0.0
# year 2004 month 9 path 176 row 43
# fracAreaMCD15: 0.0
# year 2004 month 9 path 176 row 44
# fracAreaMCD15: 0.0
# year 2004 month 9 path 176 row 45
# year 2004 month 9 path 176 row 46
# year 2004 month 9 path 176 row 47
# fracAreaMCD15: 0.0
# year 2004 month 9 path 176 row 68
# fracAreaMCD15: 0.001093920484275249
# year 2004 month 9 path 176 row 69
# fracAreaMCD15: 0.035901770895856125
# year 2004 month 9 path 176 row 70
# fracAreaMCD15: 0.1838412410371698
# year 2004 month 9 path 176 row 71
# year 2004 month 9 path 176 row 72
# fracAreaMCD15: 0.3729393381222595
# fracAreaLCtoMCD: 0.12604950402361992
# cumulative samples: 3469517 nsaminput 798
# year 2004 month 9 path 176 row 73
# fracAreaMCD15: 0.3156169029128139
# fracAreaLCtoMCD: 0.10700128519646283
# cumulative samples: 3470211 nsaminput 694
# year 2004 month 9 path 176 row 78
# fracAreaMCD15: 0.17757096794948668
# year 2004 month 9 path 176 row 79
# fracAreaMCD15: 0.7790231954568976
# fracAreaLCtoMCD: 0.6069237149870668
# cumulative samples: 3470214 nsaminput 3
# year 2004 month 9 path 176 row 80
# fracAreaMCD15: 0.7096265888975344
# fracAreaLCtoMCD: 0.18991373225000485
# cumulative samples: 3471358 nsaminput 1144
# year 2004 month 9 path 176 row 81
# fracAreaMCD15: 0.41674719608916844
# fracAreaLCtoMCD: 0.31790028570698275
# cumulative samples: 3473343 nsaminput 1985
# year 2004 month 9 path 176 row 82
# fracAreaMCD15: 0.11943777327788391
# year 2004 month 9 path 176 row 83
# fracAreaMCD15: 0.0
# year 2004 month 9 path 177 row 18
# year 2004 month 9 path 177 row 19
# year 2004 month 9 path 177 row 20
# year 2004 month 9 path 177 row 38
# fracAreaMCD15: 0.0
# year 2004 month 9 path 177 row 39
# fracAreaMCD15: 0.0
# year 2004 month 9 path 177 row 40
# fracAreaMCD15: 0.0
# year 2004 month 9 path 177 row 41
# fracAreaMCD15: 0.0
# year 2004 month 9 path 177 row 42
# fracAreaMCD15: 0.0
# year 2004 month 9 path 177 row 43
# fracAreaMCD15: 0.0
# year 2004 month 9 path 177 row 44
# year 2004 month 9 path 177 row 45
# fracAreaMCD15: 0.0
# year 2004 month 9 path 177 row 46
# fracAreaMCD15: 0.0
# year 2004 month 9 path 177 row 53
# fracAreaMCD15: 0.8645350828347943
# fracAreaLCtoMCD: 0.19474888389561842
# cumulative samples: 3474323 nsaminput 980
# year 2004 month 9 path 177 row 54
# fracAreaMCD15: 0.0
# year 2004 month 9 path 177 row 55
# year 2004 month 9 path 177 row 56
# year 2004 month 9 path 177 row 57
# fracAreaMCD15: 0.0429444246244341
# year 2004 month 9 path 177 row 58
# fracAreaMCD15: 0.06781912857104891
# year 2004 month 9 path 177 row 71
# fracAreaMCD15: 0.08322688914534386
# year 2004 month 9 path 177 row 72
# fracAreaMCD15: 0.08179037155858145
# year 2004 month 9 path 177 row 73
# fracAreaMCD15: 0.4526405479719468
# fracAreaLCtoMCD: 0.13925868891421933
# cumulative samples: 3475211 nsaminput 888
# year 2004 month 9 path 177 row 74
# fracAreaMCD15: 0.5329035042880769
# fracAreaLCtoMCD: 0.12346801125072832
# cumulative samples: 3475508 nsaminput 297
# year 2004 month 9 path 177 row 75
# fracAreaMCD15: 0.4369802565475534
# fracAreaLCtoMCD: 0.1846531841387017
# cumulative samples: 3476682 nsaminput 1174
# year 2004 month 9 path 177 row 76
# fracAreaMCD15: 0.6454403770775047
# fracAreaLCtoMCD: 0.16616814972670707
# cumulative samples: 3477767 nsaminput 1085
# year 2004 month 9 path 177 row 77
# fracAreaMCD15: 0.4010227212504529
# fracAreaLCtoMCD: 0.15137935390294172
# cumulative samples: 3478747 nsaminput 980
# year 2004 month 9 path 177 row 78
# fracAreaMCD15: 0.4307756428173635
# fracAreaLCtoMCD: 0.2074898323948917
# cumulative samples: 3480006 nsaminput 1259
# year 2004 month 9 path 177 row 79
# fracAreaMCD15: 0.5526736026364134
# fracAreaLCtoMCD: 0.08050015063736085
# year 2004 month 9 path 177 row 80
# fracAreaMCD15: 0.42273269361774085
# fracAreaLCtoMCD: 0.12140992397937264
# cumulative samples: 3480780 nsaminput 774
# year 2004 month 9 path 178 row 12
# year 2004 month 9 path 178 row 13
# year 2004 month 9 path 178 row 15
# year 2004 month 9 path 178 row 16
# fracAreaMCD15: 0.46180000695938
# fracAreaLCtoMCD: 0.05806305546500557
# year 2004 month 9 path 178 row 17
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# File ~/anaconda3/envs/landsatModis/lib/python3.9/site-packages/ee/data.py:328, in _execute_cloud_call(call, num_retries)
#     327 try:
# --> 328   return call.execute(num_retries=num_retries)
#     329 except googleapiclient.errors.HttpError as e:
#
# File ~/anaconda3/envs/landsatModis/lib/python3.9/site-packages/googleapiclient/_helpers.py:134, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     133         logger.warning(message)
# --> 134 return wrapped(*args, **kwargs)
#
# File ~/anaconda3/envs/landsatModis/lib/python3.9/site-packages/googleapiclient/http.py:915, in HttpRequest.execute(self, http, num_retries)
#     914 if resp.status >= 300:
# --> 915     raise HttpError(resp, content, uri=self.uri)
#     916 return self.postproc(resp, content)
#
# HttpError: <HttpError 403 when requesting https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/value:compute?prettyPrint=false&alt=json returned "The caller does not have permission". Details: "The caller does not have permission">
#
# During handling of the above exception, another exception occurred:
#
# EEException                               Traceback (most recent call last)
# Input In [41], in <cell line: 2>()
#      69 # get the fraction of area with unmasked LC data
#      70 validArea = ee.Number(ee.Image.pixelArea().mask(imageLC.select('QA_PIXEL').mask()).reduceRegion(reducer=ee.Reducer.sum(),geometry=imageLC.geometry(),scale=30,bestEffort=True).get('area')).getInfo()
# ---> 71 totalArea = ee.Number(ee.Image.pixelArea().mask(imageLC.select('QA_PIXEL').unmask().mask()).reduceRegion(reducer=ee.Reducer.sum(),geometry=imageLC.geometry(),scale=30,bestEffort=True).get('area')).getInfo()
#      73 fracAreaLC = 0
#      74 if (totalArea > 0) :
#
# File ~/anaconda3/envs/landsatModis/lib/python3.9/site-packages/ee/computedobject.py:98, in ComputedObject.getInfo(self)
#      92 def getInfo(self):
#      93   """Fetch and return information about this object.
#      94
#      95   Returns:
#      96     The object can evaluate to anything.
#      97   """
# ---> 98   return data.computeValue(self)
#
# File ~/anaconda3/envs/landsatModis/lib/python3.9/site-packages/ee/data.py:735, in computeValue(obj)
#     725 """Sends a request to compute a value.
#     726
#     727 Args:
#    (...)
#     731   The result of evaluating that object on the server.
#     732 """
#     733 body = {'expression': serializer.encode(obj, for_cloud_api=True)}
# --> 735 return _execute_cloud_call(
#     736     _get_cloud_api_resource().projects().value().compute(
#     737         body=body,
#     738         project=_get_projects_path(),
#     739         prettyPrint=False))['result']
#
# File ~/anaconda3/envs/landsatModis/lib/python3.9/site-packages/ee/data.py:330, in _execute_cloud_call(call, num_retries)
#     328   return call.execute(num_retries=num_retries)
#     329 except googleapiclient.errors.HttpError as e:
# --> 330   raise _translate_cloud_exception(e)
#
# EEException: The caller does not have permission
