# %%
import ee
import numpy as np
import pandas as pd
import pickle
import datetime

# %%
ee.Authenticate()
# Out:
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://accounts.google.com/o/oauth2/auth?client_id=517222506229-vsmmajv00ul0bs7p89v5m89qs8eb9359.apps.googleusercontent.com&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fearthengine+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdevstorage.full_control&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&response_type=code&code_challenge=LbAkvUSZTAYnKMupHjwG7XqGckSy7bbpffuLIQyh0XQ&code_challenge_method=S256>https://accounts.google.com/o/oauth2/auth?client_id=517222506229-vsmmajv00ul0bs7p89v5m89qs8eb9359.apps.googleusercontent.com&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fearthengine+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdevstorage.full_control&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&response_type=code&code_challenge=LbAkvUSZTAYnKMupHjwG7XqGckSy7bbpffuLIQyh0XQ&code_challenge_method=S256</a></p>
#         <p>The authorization workflow will generate a code, which you
#         should paste in the box below</p>
# Enter verification code:  4/1AX4XfWhLXLirweEmiwxJ4ln1D6d9fk_2f-4oC-gZ1oenG0DaylDU_-k0C0I
# Successfully saved authorization token.

# %%
ee.Initialize()

# %%
# sampling paramaters
randomSeed = 50
collectionLandsatL1c = "LANDSAT/LC08/C02/T1_TOA" # landsat image collection
collectionLandsatL2a= "LANDSAT/LC08/C02/T1_L2" # landsat image collection
cloudCoverL0X = 10# maximum cloud cover of sampled Landsat images
maxSample = 10000 # maximum samples to extract from each Landsat image
outputScale = 500 # scale of output comparisons , increasing this will eventually exceed memory
subimageSize = 40000 # m dimension of subimage we will randomly extract from Landsat image to avoid memory limits
minfracAreaLC = 0.5 # minimum cloud free valid  Landsat subimage fraction
minfracAreaMCD15 = 0.25 # minimum cloud free valid MODIS area in Landsat subimage fraction's unmasked area
minfracAreaLCtoMCD = 0.10 # valid aggregated landsat fraction
minfracValidLC = 0.9 # minimum facation of valid landsat pixels in each aggregated modis pixels to estimate mean values
deltaRow = 1  # skip this many WRS rows when sampling Landsat scenes
deltaPath = 1 # skip this many WRS paths when sampling Landsat scenes
deltaDay = 15 # search this many contiguous days when looking for a cloud free Landsat scene
maxPixels = 300 # max landsat pixels allowed to be aggregated in an output pixel, should be about 20% larger than the ratio of (outputScale/30) (cannot exceed 1024)

#output files
InputFileNameB36 = '/home/richard_fernandes/LUTinputLC0XB36cal'
InputFileNameB45 = '/home/richard_fernandes/LUTinputLC0XB45cal'
InputFileNameMOD09 = '/home/richard_fernandes/LUTinputMOD09cal'
InputFileNameMOD09bands = '/home/richard_fernandes/LUTinputMOD09bandscal'
InputFileNameLat = '/home/richard_fernandes/LUTinputLC0XLatcal'
InputFileNameLon = '/home/richard_fernandes/LUTinputLC0XLoncal'
OutputFileName = '/home/richard_fernandes/LUToutputLC0Xcal'
YearFileName = '/home/richard_fernandes/YearLC0Xcal'
MonthFileName = '/home/richard_fernandes/MonthLC0Xcal'
DayFileName = '/home/richard_fernandes/DayLC0Xcal'
PathFileName = '/home/richard_fernandes/PathLC0Xcal'
RowFileName = '/home/richard_fernandes/RowLC0Xcal'

# %%
# Match MOD09A1.006 daily reflectance data and MCD12Q1 annual biome type to  MCD15A3H.006 image composite
# masking any dates without exactly one MOD09A1 valid clear sky value and one valid MCD153AH terra retrieval
def matchMOD09A1toMCD15(imageMCD15):
    
    # get date range of MCD15A3Himage
    d1 = ee.Date(imageMCD15.get('system:time_start'));
    d2 = ee.Date(imageMCD15.get('system:time_end'));
    
#    print(d1.getInfo())
#    print(d2.getInfo())
    # find MOD09A1 products within date range of MCD15 and mask them 
    colMOD09A1 = ee.ImageCollection("MODIS/006/MOD09GA").filterDate(d1,d2).map(lambda image: image.updateMask(image.select('QC_500m').bitwiseAnd(1<<1).eq(0)) \
                                                                                                  .updateMask(image.select('state_1km').bitwiseAnd(1<<0).eq(0)) \
                                                                                                  .updateMask(image.select('state_1km').bitwiseAnd(1<<1).eq(0)) \
                                                                                                  .updateMask(image.select('state_1km').bitwiseAnd(1<<2).eq(0)) \
                                                                                                  .addBands(image.select('sur_refl_b02').divide(image.select('sur_refl_b01').add(1)).rename('SR_VI')))
                                                                                                 # .updateMask(image.select('state_1km').bitwiseAnd(1<<3).eq(1)) )
                                                                                                #  .updateMask(image.select('state_1km').bitwiseAnd(1<<4).eq(0)) \
                                                                                                #   .updateMask(image.select('state_1km').bitwiseAnd(1<<5).eq(0)) \
                                                                                               #   .updateMask(image.select('state_1km').bitwiseAnd(1<<6).gt(-1)) \
                                                                                              #    .updateMask(image.select('state_1km').bitwiseAnd(1<<7).eq(0)) \
                                                                                                #  .updateMask(image.select('state_1km').bitwiseAnd(1<<8).eq(8)) \
                                                                                                #  .updateMask(image.select('state_1km').bitwiseAnd(1<<9).eq(0)) \
                                                                                               #   .updateMask(image.select('state_1km').bitwiseAnd(1<<10).eq(0)) \
                                                                                                #  .updateMask(image.select('state_1km').bitwiseAnd(1<<11).eq(1)) \
                                                                                                 # .updateMask(image.select('state_1km').bitwiseAnd(1<<12).eq(0)) \
                                                                                                 # .updateMask(image.select('state_1km').bitwiseAnd(1<<13).eq(0)) \
                                                                                                 # .updateMask(image.select('state_1km').bitwiseAnd(1<<14).eq(0)) \
                                                                                                 # .updateMask(image.select('state_1km').bitwiseAnd(1<<15).eq(0)))
    #    print(colMOD09A1.size().getInfo())
    # get biome type map
    imageMCD12Q1 = ee.ImageCollection("MODIS/006/MCD12Q1").map(lambda image: image.set('daterange',ee.DateRange(ee.Date(image.get('system:time_start')),ee.Date(image.get('system:time_end')))))\
                                                            .filter(ee.Filter.dateRangeContains('daterange', d1)) \
                                                            .first() \
                                                            .select('LC_Type3') 
#    print(imageMCD12Q1.getInfo())

# make mask of pixels containing only one valid cloud free MOD09 500m retrieval
    # and a primary algorithm retyrieval from terra wigthout significant clouds
    # and add MOD09A1 composite created by apply the MCD15 mask to the MOOD9A1 collection and composite it
    # and add biome type
    imageMCD15 = imageMCD15.updateMask( colMOD09A1.count().select('sur_refl_b01').gt(-1) ) \
                            .updateMask( imageMCD15.select('FparLai_QC').bitwiseAnd(1<<0).eq(0)) \
                            .updateMask( imageMCD15.select('FparLai_QC').bitwiseAnd(1<<1).eq(0)) \
                            .updateMask( imageMCD15.select('FparLai_QC').bitwiseAnd(1<<2).eq(0)) \
                            .updateMask( imageMCD15.select('FparLai_QC').bitwiseAnd(1<<3).eq(0)) \
                            .updateMask( imageMCD15.select('FparLai_QC').bitwiseAnd(1<<4).eq(0)) \
                            .updateMask(imageMCD15.select('FparLai_QC').bitwiseAnd(1<<6).eq(0)) \
                            .updateMask(imageMCD15.select('FparLai_QC').bitwiseAnd(1<<7).eq(0)) \
                            .updateMask(imageMCD15.select('FparExtra_QC').bitwiseAnd(1<<1).eq(0)) \
                            .updateMask( imageMCD12Q1.select('LC_Type3').gt(0)) \
                            .addBands( imageMCD12Q1 )
    imageMCD15 = imageMCD15.addBands(colMOD09A1.map(lambda image: image.mask(imageMCD15.select('Lai'))).qualityMosaic('SR_VI'))


    
   
    
    
    return imageMCD15

# %%
# coded LUT for output MODIS MCD15
def getLUTout(imageMCD15):
    imageMCD15 = ee.Image(imageMCD15);

    return imageMCD15.select('Lai').min(99).multiply(1).toInt64() \
                        .add(imageMCD15.select('LaiStdDev').min(99).multiply(1e2).toInt64()) \
                        .add(imageMCD15.select('Fpar').min(99).multiply(1e4).toInt64()) \
                        .add(imageMCD15.select('FparStdDev').min(99).multiply(1e6).toInt64()) \
                        .add(imageMCD15.select('satFlag').multiply(100).multiply(1e9).toInt64()) \
                        .add(imageMCD15.select('snowFlag').multiply(100).multiply(1e12).toInt64()) \
                        .add(imageMCD15.select('LC_Type3').multiply(1e14).toInt64()) \
                        .rename('LUTout')

# %%
# Code LUT for an input MOD09 image , same as getLUTin but no satFlag
def getLUTinMOD09(imageMCD15MOD09):
    
     return imageMCD15MOD09.select('sur_refl_b01').add(100).max(0).min(9999).floor().toInt64().multiply(1).toInt64() \
                        .add(imageMCD15MOD09.select('sur_refl_b02').add(100).max(0).min(9999).floor().toInt64().multiply(1e4).toInt64()) \
                        .add(imageMCD15MOD09.select('SolarZenith').multiply(0.01).max(0).min(99).floor().toInt64().multiply(1e8).toInt64()) \
                        .add(imageMCD15MOD09.select('SolarAzimuth').multiply(0.01).add(180).max(0).min(360).floor().toInt64().multiply(1e10).toInt64()) \
                        .add(imageMCD15MOD09.select('SensorZenith').multiply(0.01).max(0).min(99).floor().toInt64().multiply(1e13).toInt64()) \
                        .add(imageMCD15MOD09.select('SensorAzimuth',).multiply(0.01).add(180).max(0).min(360).floor().toInt64().multiply(1e15).toInt64()) \
                        .rename('LUTinMOD09')

# %%
# Code LUT for an input MOD09 image , same as getLUTin but no satFlag
def getLUTinMOD09bands(imageMCD15MOD09):
    
     return imageMCD15MOD09.select('sur_refl_b03').add(100).max(0).min(9999).floor().toInt64().multiply(1).toInt64() \
                        .add(imageMCD15MOD09.select('sur_refl_b04').add(100).max(0).min(9999).floor().toInt64().multiply(1e4).toInt64()) \
                        .add(imageMCD15MOD09.select('sur_refl_b06').add(100).max(0).min(9999).floor().toInt64().multiply(1e8).toInt64()) \
                        .add(imageMCD15MOD09.select('sur_refl_b07').add(100).max(0).min(9999).floor().toInt64().multiply(1e12).toInt64()) \
                        .rename('LUTinMOD09bands')

# %%
# coded LUT for input landsat image red and nir band
def getLUTL0XinB45(imageMCD15):
    imageMCD15 = ee.Image(imageMCD15);
    return imageMCD15.select('SR_B4').multiply(2.75e-05).add(-0.02).max(0).min(0.999).multiply(1000).floor().multiply(1).toInt64() \
                        .add(imageMCD15.select('SR_B5').multiply(2.75e-05).add(-0.02).max(0).min(0.999).multiply(1000).floor().multiply(1e3).toInt64()) \
                        .add(imageMCD15.select('VZA').multiply(0.01).round().multiply(1e6).toInt64()) \
                        .add(imageMCD15.select('VAA').multiply(0.01).add(180).round().multiply(1e8).toInt64()) \
                        .add(imageMCD15.select('SZA').multiply(0.01).round().multiply(1e11).toInt64()) \
                        .add(imageMCD15.select('SAA').multiply(0.01).add(180).round().multiply(1e13).toInt64()) \
                        .rename('LUTL0XinB45')

# %%
# coded LUT for input landsat image green and swir
def getLUTL0XinB36(imageMCD15):
    imageMCD15 = ee.Image(imageMCD15);
    return imageMCD15.select('SR_B3').multiply(2.75e-05).add(-0.02).max(0).min(0.999).multiply(1000).floor().multiply(1).toInt64() \
                        .add(imageMCD15.select('SR_B6').multiply(2.75e-05).add(-0.02).max(0).min(0.999).multiply(1000).floor().multiply(1e3).toInt64()) \
                        .add(imageMCD15.select('VZA').multiply(0.01).round().multiply(1e6).toInt64()) \
                        .add(imageMCD15.select('VAA').multiply(0.01).add(180).round().multiply(1e8).toInt64()) \
                        .add(imageMCD15.select('SZA').multiply(0.01).round().multiply(1e11).toInt64()) \
                        .add(imageMCD15.select('SAA').multiply(0.01).add(180).round().multiply(1e13).toInt64()) \
                        .rename('LUTL0XinB36')

# %%
# sample worldwide 
# check each year and month
cumsam = 0
for year in range(2013,2022):#

        
    # specify land cover projected into MOD15 projection and aggregated using median to outputScale    
    projectionMCD15=  ee.ImageCollection('MODIS/006/MCD15A3H').first().select('Lai').projection()
    projectionMCD12 =  ee.ImageCollection("MODIS/006/MCD12Q1").first().select('LC_Type3').projection()
    imageMCD12Q1 = ee.ImageCollection("MODIS/006/MCD12Q1").filterDate(ee.Date.fromYMD(year,1,1),ee.Date.fromYMD(year,12,31)).first() \
                     .select('LC_Type3') \
                     .reproject(crs= projectionMCD15,crsTransform= None,scale=projectionMCD12.nominalScale() ) \
                     .reduceResolution(reducer= ee.Reducer.median(),maxPixels= 1024,bestEffort=False) \
                     .reproject(crs= projectionMCD15.atScale(outputScale))      

    # sample monthly data
    for month in [6,7,5,8,4,9,3,10,2,11,1,12]:  
        
        #sample WRS path rows
        for path in range(1,233,deltaPath): 
            for row in range(1,248,deltaRow): 
                
                # sample deltaDay intervals of each month
                for daystart in range (1,30-deltaDay,deltaDay):
                    
                    # find Landsat images for paht , row and date interval between 0 and maxCloudCover
                    imageLC = ee.ImageCollection(collectionLandsatL2a).filterMetadata('WRS_PATH','equals',path) \
                                                                          .filterMetadata('WRS_ROW','equals',row) \
                                                                          .filterDate(ee.Date.fromYMD(year,month,daystart),ee.Date.fromYMD(year,month,daystart).advance(deltaDay,'days')) \
                                                                          .filter(ee.Filter.lte('CLOUD_COVER_LAND',cloudCoverL0X))
                    
                    # only proceed if there is at least one filtered landsat image (we will only use the first one found)
                    if (imageLC.size().getInfo() > 0) : 

                        # only sample the first scene we found in the interval of deltaDay's 
                        imageLC = imageLC.first()
                        projectionLC = imageLC.select('QA_PIXEL').projection()
                        
                        # get date range of imageLC and print it out
                        d1 = ee.Date(imageLC.get('system:time_start'))
                        d2 = ee.Date(imageLC.get('system:time_end'))     
                        print('year',year,'month',month,'path',path,'row',row)

                        # get  MOD15 product containing the aquistion of the  Landsat image
                        imageMCD15 = ee.ImageCollection('MODIS/006/MCD15A3H') \
                                                    .map(lambda image: image.set('daterange',ee.DateRange(ee.Date(image.get('system:time_start')),ee.Date(image.get('system:time_end')))))\
                                                    .filter(ee.Filter.dateRangeContains('daterange', d1)) \
                                                    .map(lambda image: matchMOD09A1toMCD15(image) ) 

                        # only proceed if there is a MCD15 product containing the Landsat image aquisition
                        if (imageMCD15.size().getInfo() > 0)  :

                            
                            #randomly sample a sub-image to avoid memory issues, 
                            # add a validPixel we will use to determine aggregation and unmask since we will accept some missing data
                            imageGRID = imageLC.geometry().coveringGrid(projectionMCD15,subimageSize).randomColumn(columnName='randomIndex',seed=randomSeed)                                
                            imageLC = imageLC.addBands(ee.ImageCollection(collectionLandsatL1c) \
                                                                          .filterMetadata('system:index','equals',imageLC.get('system:index')) \
                                                                          .first() \
                                                                          .select(['VZA','VAA','SZA','SAA'])) \
                                             .clip(ee.Feature(imageGRID.sort('randomIndex').first()).geometry()) \
                                             .updateMask(imageLC.select('QA_PIXEL').bitwiseAnd(1<<0).eq(0)) \
                                             .updateMask(imageLC.select('QA_PIXEL').bitwiseAnd(1<<1).eq(0)) \
                                             .updateMask(imageLC.select('QA_PIXEL').bitwiseAnd(1<<2).eq(0)) \
                                             .updateMask(imageLC.select('QA_PIXEL').bitwiseAnd(1<<3).eq(0)) \
                                             .updateMask(imageLC.select('QA_PIXEL').bitwiseAnd(1<<4).eq(0)) 
        
                            
                            # get the fraction of area with unmasked LC data 
                            validArea = ee.Number(ee.Image.pixelArea().mask(imageLC.select('QA_PIXEL').mask()).reduceRegion(reducer=ee.Reducer.sum(),geometry=imageLC.geometry(),scale=30,bestEffort=True).get('area')).getInfo()
                            totalArea = ee.Number(ee.Image.pixelArea().mask(imageLC.select('QA_PIXEL').unmask().mask()).reduceRegion(reducer=ee.Reducer.sum(),geometry=imageLC.geometry(),scale=30,bestEffort=True).get('area')).getInfo()
                            
                            fracAreaLC = 0 
                            if (totalArea > 0) :
                                fracAreaLC = validArea / totalArea
                            #print('fracAreaLC:',fracAreaLC)  

                            # proceed if there is sufficient landsat area
                            if ( fracAreaLC > minfracAreaLC) :
                                                
                                # get MCD15 image from collection, clip to Landsat subimage
                                imageMCD15 = imageMCD15.first().clip(imageLC.geometry()) 
                                                
                                # update mask and add land cover and a saturation flag band
                                imageMCD15 = imageMCD15.updateMask( imageMCD15.select('FparLai_QC').bitwiseAnd(1<<0).eq(0)) \
                                                .updateMask( imageMCD15.select('FparLai_QC').bitwiseAnd(1<<2).eq(0)) \
                                                .updateMask( imageMCD15.select('FparLai_QC').bitwiseAnd(1<<3).eq(0)) \
                                                .updateMask( imageMCD15.select('FparLai_QC').bitwiseAnd(1<<4).eq(0)) \
                                                .updateMask( imageMCD15.select('FparLai_QC').bitwiseAnd(1<<6).eq(0)) \
                                                .updateMask( imageMCD15.select('FparLai_QC').bitwiseAnd(1<<7).eq(0)) \
                                                .addBands(imageMCD15.select('FparLai_QC').rename(['satFlag']).bitwiseAnd(1<<5).eq(1)) \
                                                .addBands(imageMCD15.select('FparExtra_QC').rename(['snowFlag']).bitwiseAnd(1<<2).eq(1)) \
                                                .updateMask( imageMCD15.select('FparExtra_QC').bitwiseAnd(1<<0).eq(0)) \
                                                .updateMask( imageMCD15.select('FparExtra_QC').bitwiseAnd(1<<1).eq(0)) \
                                                .updateMask( imageMCD15.select('FparExtra_QC').bitwiseAnd(1<<3).eq(0)) \
                                                .updateMask( imageMCD15.select('FparExtra_QC').bitwiseAnd(1<<4).eq(0)) \
                                                .updateMask( imageMCD15.select('FparExtra_QC').bitwiseAnd(1<<5).eq(0)) \
                                                .updateMask( imageMCD15.select('FparExtra_QC').bitwiseAnd(1<<6).eq(0)) \


                            
                                # get the fraction of area with unmasked MCD15 data 
                                validArea = ee.Number(ee.Image.pixelArea().mask(imageMCD15.select('Lai').mask()).reduceRegion(reducer=ee.Reducer.sum(),geometry=imageLC.geometry(),crs=projectionMCD15.atScale(outputScale)).get('area')).getInfo()
                                totalArea = ee.Number(ee.Image.pixelArea().mask(imageMCD15.select('Lai').unmask().mask()).reduceRegion(reducer=ee.Reducer.sum(),geometry=imageLC.geometry(),crs=projectionMCD15.atScale(outputScale)).get('area')).getInfo()
                                fracAreaMCD15 = 0 
                                if (totalArea > 0) :
                                    fracAreaMCD15 = validArea / totalArea
                                print('fracAreaMCD15:',fracAreaMCD15) 
                           
                                # sample if there is sufficient unmasked area
                                if ( fracAreaMCD15> minfracAreaMCD15 ) :
                                                
                                    
                                    # add a view zenith angle band and a validPixel band to the landsat image
                                    # then unmask and aggregate to output scale, we unmask first to allow for <100% validPixel s
                                    imageLCtoMCD = imageLC.addBands(imageLC.select('QA_PIXEL').gt(-1).rename('validPixel')) \
                                                         .unmask() \
                                                         .reproject(crs= projectionMCD15,scale=projectionLC.nominalScale() ) \
                                                         .reduceResolution(reducer= ee.Reducer.mean(),maxPixels=maxPixels,bestEffort=False) \
                                                         .reproject(crs= projectionMCD15 , scale= outputScale) \
                                                         .updateMask(imageMCD15.select('FparLai_QC').mask())
                                   
                                    # mask bands not meeting fractional pixel threshold
                                    # we then have to divide by the fractional validPixel band to adjust for  zero masked values 
                                    validLCtoMCD = imageLCtoMCD.select('validPixel').gte(minfracValidLC);
                                    imageLCtoMCD = imageLCtoMCD.updateMask(validLCtoMCD) \
                                                     .divide(imageLCtoMCD.select('validPixel'))


                                    # add the aggregated LC image to the modis image and update the MCD image with the valid mask
                                    imageMCD15 = imageMCD15.addBands(imageLCtoMCD) \
                                                            .updateMask(validLCtoMCD) 
                                                            
                                    # get the fraction of area with unmasked LC data 
                                    validArea = ee.Number(ee.Image.pixelArea().mask(imageMCD15.select('QA_PIXEL').mask()).reduceRegion(reducer=ee.Reducer.sum(),geometry=imageMCD15.geometry(),scale=outputScale,bestEffort=True).get('area')).getInfo()
                                    totalArea = ee.Number(ee.Image.pixelArea().mask(imageMCD15.select('QA_PIXEL').unmask().mask()).reduceRegion(reducer=ee.Reducer.sum(),geometry=imageMCD15.geometry(),scale=outputScale,bestEffort=True).get('area')).getInfo()
                                    fracAreaLCtoMCD = 0 
                                    if (totalArea > 0) :
                                        fracAreaLCtoMCD = validArea / totalArea
                                    print('fracAreaLCtoMCD:',fracAreaLCtoMCD)  
                                    
                                    # check if we have enough valid cloud free aggregated matches
                                    if ( fracAreaLCtoMCD > minfracAreaLCtoMCD ) :
 

                                        imageMCD15 = imageMCD15.select(['satFlag','snowFlag']) \
                                                                .addBands(getLUTout(imageMCD15)) \
                                                                 .addBands(getLUTL0XinB45(imageMCD15)) \
                                                                 .addBands(getLUTL0XinB36(imageMCD15)) \
                                                                 .addBands(getLUTinMOD09(imageMCD15)) \
                                                                 .addBands(getLUTinMOD09bands(imageMCD15)) \
                                                                 .addBands(ee.Image.pixelLonLat()) \
                                                                 .updateMask(validLCtoMCD)
        
                                        sampleData = imageMCD15.sample(projection=projectionMCD15.atScale(outputScale), numPixels=maxSample, dropNulls=True)
                                        sampleOutput = sampleData.aggregate_array('LUTout').flatten().getInfo()
                                        sampleInputB45 = sampleData.aggregate_array('LUTL0XinB45').flatten().getInfo()
                                        sampleInputB36 = sampleData.aggregate_array('LUTL0XinB36').flatten().getInfo()
                                        sampleInputMOD09 = sampleData.aggregate_array('LUTinMOD09').flatten().getInfo()
                                        sampleInputMOD09bands = sampleData.aggregate_array('LUTinMOD09bands').flatten().getInfo()
                                        sampleInputLon = sampleData.aggregate_array('longitude').flatten().getInfo()
                                        sampleInputLat = sampleData.aggregate_array('latitude').flatten().getInfo()
                            
                                        if (len(sampleOutput)>0) :

                                            numsam = len(sampleOutput)
                                            cumsam = cumsam + numsam
                                            print('cumulative samples:',cumsam,'nsaminput',numsam)
                                            
                                            # write list after each landsat scene is done (comment out if it is too frequent)
                                            with open(InputFileNameLon, 'ab') as fp1:
                                                pickle.dump(sampleInputLon, fp1)
                                            with open(InputFileNameLat, 'ab') as fp1:
                                                pickle.dump(sampleInputLat, fp1)
                                            with open(InputFileNameB36, 'ab') as fp1:
                                                pickle.dump(sampleInputB36, fp1)
                                            with open(InputFileNameB45, 'ab') as fp1:
                                                pickle.dump(sampleInputB45, fp1)
                                            with open(InputFileNameMOD09, 'ab') as fp1:
                                                pickle.dump(sampleInputMOD09, fp1)
                                            with open(InputFileNameMOD09bands, 'ab') as fp1:
                                                pickle.dump(sampleInputMOD09bands, fp1)
                                            with open(OutputFileName, 'ab') as fp1:
                                                pickle.dump(sampleOutput, fp1)                                        
                                            with open(YearFileName, 'ab') as fp1:
                                                pickle.dump([year]*numsam, fp1)
                                            with open(MonthFileName, 'ab') as fp1:
                                                pickle.dump([month]*numsam, fp1)
                                            with open(DayFileName, 'ab') as fp1:
                                                pickle.dump([daystart]*numsam, fp1)
                                            with open(PathFileName, 'ab') as fp1:
                                                pickle.dump([path]*numsam, fp1 ) 
                                            with open(RowFileName, 'ab') as fp1:
                                                pickle.dump([row]*numsam, fp1)
# Out:
# year 2013 month 6 path 1 row 60
# fracAreaMCD15: 0.0
# year 2013 month 6 path 1 row 61
# year 2013 month 6 path 1 row 72
# fracAreaMCD15: 0.6511498315467701
# fracAreaLCtoMCD: 0.5769494050937428
# cumulative samples: 189 nsaminput 189
# year 2013 month 6 path 1 row 73
# fracAreaMCD15: 0.09078781113922828
# year 2013 month 6 path 1 row 74
# fracAreaMCD15: 0.0026602874354454686
# year 2013 month 6 path 1 row 75
# fracAreaMCD15: 0.0
# year 2013 month 6 path 1 row 76
# year 2013 month 6 path 1 row 77
# year 2013 month 6 path 1 row 78
# year 2013 month 6 path 1 row 82
# fracAreaMCD15: 0.26169397143213036
# fracAreaLCtoMCD: 0.2498647464061742
# cumulative samples: 844 nsaminput 655
# year 2013 month 6 path 1 row 83
# fracAreaMCD15: 0.0
# year 2013 month 6 path 1 row 84
# fracAreaMCD15: 0.0
# year 2013 month 6 path 1 row 85
# fracAreaMCD15: 0.425126339443315
# fracAreaLCtoMCD: 0.42788569812864996
# cumulative samples: 3452 nsaminput 2608
# year 2013 month 6 path 2 row 64
# fracAreaMCD15: 0.05281146890976853
# year 2013 month 6 path 2 row 65
# fracAreaMCD15: 0.16182570867192156
# year 2013 month 6 path 2 row 66
# fracAreaMCD15: 0.174203695157399
# year 2013 month 6 path 2 row 67
# fracAreaMCD15: 0.8223353267685446
# fracAreaLCtoMCD: 0.43866989110257987
# cumulative samples: 3484 nsaminput 32
# year 2013 month 6 path 2 row 75
# year 2013 month 6 path 4 row 67
# fracAreaMCD15: 0.003076766198373332
# year 2013 month 6 path 5 row 70
# year 2013 month 6 path 5 row 71
# fracAreaMCD15: 0.07557513072715938
# year 2013 month 6 path 6 row 22
# fracAreaMCD15: 0.0
# year 2013 month 6 path 8 row 26
# fracAreaMCD15: 0.00019558393444404378
# year 2013 month 6 path 10 row 27
# fracAreaMCD15: 0.27097838496942517
# fracAreaLCtoMCD: 0.07771798906574173
# year 2013 month 6 path 10 row 28
# fracAreaMCD15: 0.2039061168143388
# year 2013 month 6 path 10 row 53
# fracAreaMCD15: 0.0
# year 2013 month 6 path 11 row 10
# fracAreaMCD15: 0.0
# year 2013 month 6 path 11 row 12
# fracAreaMCD15: 0.0
# year 2013 month 6 path 11 row 19
# fracAreaMCD15: 0.0
# year 2013 month 6 path 11 row 21
# fracAreaMCD15: 0.0006251427694894019
# year 2013 month 6 path 11 row 22
# fracAreaMCD15: 0.0
# year 2013 month 6 path 11 row 23
# fracAreaMCD15: 0.01171967003506562
# year 2013 month 6 path 11 row 24
# fracAreaMCD15: 0.15822296949057027
# year 2013 month 6 path 11 row 25
# fracAreaMCD15: 0.16130635172162053
# year 2013 month 6 path 11 row 63
# fracAreaMCD15: 0.0
# year 2013 month 6 path 12 row 18
# year 2013 month 6 path 12 row 19
# year 2013 month 6 path 13 row 16
# fracAreaMCD15: 0.0
# year 2013 month 6 path 13 row 17
# fracAreaMCD15: 0.0
# year 2013 month 6 path 13 row 18
# fracAreaMCD15: 0.00032836912052825254
# year 2013 month 6 path 13 row 19
# fracAreaMCD15: 0.0006250324734481262
# year 2013 month 6 path 13 row 20
# fracAreaMCD15: 0.10139655731782321
# year 2013 month 6 path 13 row 21
# fracAreaMCD15: 0.2131528351009336
# year 2013 month 6 path 13 row 28
# year 2013 month 6 path 13 row 247
# fracAreaMCD15: 0.0
# year 2013 month 6 path 14 row 31
# fracAreaMCD15: 0.10607212677704339
# year 2013 month 6 path 14 row 32
# fracAreaMCD15: 0.23355775432119003
# year 2013 month 6 path 14 row 33
# year 2013 month 6 path 14 row 34
# fracAreaMCD15: 0.011875269945640036
# year 2013 month 6 path 14 row 35
# fracAreaMCD15: 0.5086144232731726
# fracAreaLCtoMCD: 0.4874108674964933
# cumulative samples: 5890 nsaminput 2406
# year 2013 month 6 path 15 row 13
# fracAreaMCD15: 0.0
# year 2013 month 6 path 15 row 14
# year 2013 month 6 path 15 row 16
# fracAreaMCD15: 0.0
# year 2013 month 6 path 15 row 18
# fracAreaMCD15: 0.0
# year 2013 month 6 path 15 row 19
# fracAreaMCD15: 0.04812882789382625
# year 2013 month 6 path 15 row 20
# fracAreaMCD15: 0.035039994174984754
# year 2013 month 6 path 15 row 21
# fracAreaMCD15: 0.015263039579889684
# year 2013 month 6 path 15 row 22
# fracAreaMCD15: 0.02458718270134351
# year 2013 month 6 path 15 row 23
# year 2013 month 6 path 16 row 32
# fracAreaMCD15: 0.07564512018586929
# year 2013 month 6 path 16 row 35
# fracAreaMCD15: 0.04014989389367903
# year 2013 month 6 path 16 row 36
# fracAreaMCD15: 0.7167351087798439
# fracAreaLCtoMCD: 0.6669281183777358
# cumulative samples: 9369 nsaminput 3479
# year 2013 month 6 path 16 row 48
# fracAreaMCD15: 0.0
# year 2013 month 6 path 17 row 12
# fracAreaMCD15: 0.0
# year 2013 month 6 path 17 row 13
# fracAreaMCD15: 0.0
# year 2013 month 6 path 17 row 14
# fracAreaMCD15: 0.0
# year 2013 month 6 path 17 row 15
# year 2013 month 6 path 17 row 22
# fracAreaMCD15: 0.10062840893462446
# year 2013 month 6 path 17 row 23
# fracAreaMCD15: 0.24205538514347838
# year 2013 month 6 path 17 row 24
# fracAreaMCD15: 0.07126996256414529
# year 2013 month 6 path 17 row 25
# fracAreaMCD15: 0.430323997411362
# fracAreaLCtoMCD: 0.4290998050953772
# cumulative samples: 11155 nsaminput 1786
# year 2013 month 6 path 17 row 26
# fracAreaMCD15: 0.337203604797564
# fracAreaLCtoMCD: 0.3189569453009433
# cumulative samples: 11611 nsaminput 456
# year 2013 month 6 path 17 row 27
# year 2013 month 6 path 18 row 21
# fracAreaMCD15: 0.12623437451895442
# year 2013 month 6 path 18 row 22
# fracAreaMCD15: 0.06320657342987394
# year 2013 month 6 path 18 row 36
# fracAreaMCD15: 0.0
# year 2013 month 6 path 18 row 37
# fracAreaMCD15: 0.2925449093948165
# fracAreaLCtoMCD: 0.2719073773681695
# cumulative samples: 11906 nsaminput 295
# year 2013 month 6 path 18 row 38
# fracAreaMCD15: 0.0
# year 2013 month 6 path 19 row 27
# fracAreaMCD15: 0.08708766688141766
# year 2013 month 6 path 19 row 28
# fracAreaMCD15: 0.18046557409092917
# year 2013 month 6 path 19 row 29
# fracAreaMCD15: 0.008749667267083283
# year 2013 month 6 path 19 row 30
# fracAreaMCD15: 0.27421566182127477
# fracAreaLCtoMCD: 0.268855777411764
# cumulative samples: 13640 nsaminput 1734
# year 2013 month 6 path 19 row 31
# year 2013 month 6 path 19 row 32
# fracAreaMCD15: 0.0481568487031885
# year 2013 month 6 path 19 row 33
# fracAreaMCD15: 0.07736659429125806
# year 2013 month 6 path 20 row 1
# fracAreaMCD15: 0.002813086529910171
# year 2013 month 6 path 20 row 6
# fracAreaMCD15: 0.0
# year 2013 month 6 path 20 row 19
# fracAreaMCD15: 0.0003125591557321049
# year 2013 month 6 path 20 row 20
# fracAreaMCD15: 0.0
# year 2013 month 6 path 20 row 21
# fracAreaMCD15: 0.03425389604356439
# year 2013 month 6 path 21 row 19
# fracAreaMCD15: 0.0
# year 2013 month 6 path 22 row 7
# fracAreaMCD15: 0.0
# year 2013 month 6 path 22 row 10
# fracAreaMCD15: 0.0
# year 2013 month 6 path 22 row 11
# fracAreaMCD15: 0.0
# year 2013 month 6 path 22 row 12
# fracAreaMCD15: 0.0
# year 2013 month 6 path 22 row 13
# fracAreaMCD15: 0.0
# year 2013 month 6 path 22 row 14
# fracAreaMCD15: 0.0
# year 2013 month 6 path 22 row 15
# fracAreaMCD15: 0.0
# year 2013 month 6 path 22 row 16
# fracAreaMCD15: 0.0
# year 2013 month 6 path 22 row 20
# fracAreaMCD15: 0.0
# year 2013 month 6 path 22 row 21
# fracAreaMCD15: 0.0
# year 2013 month 6 path 22 row 22
# fracAreaMCD15: 0.0
# year 2013 month 6 path 22 row 23
# fracAreaMCD15: 0.1580639901358638
# year 2013 month 6 path 22 row 24
# fracAreaMCD15: 0.08812750077305896
# year 2013 month 6 path 22 row 25
# fracAreaMCD15: 0.30812506353554703
# fracAreaLCtoMCD: 0.2941996279380326
# cumulative samples: 13675 nsaminput 35
# year 2013 month 6 path 22 row 26
# fracAreaMCD15: 0.05603977811221288
# year 2013 month 6 path 24 row 10
# fracAreaMCD15: 0.00015626336135035878
# year 2013 month 6 path 24 row 12
# fracAreaMCD15: 0.0
# year 2013 month 6 path 24 row 13
# fracAreaMCD15: 0.0
# year 2013 month 6 path 24 row 14
# fracAreaMCD15: 0.0
# year 2013 month 6 path 24 row 15
# fracAreaMCD15: 0.0
# year 2013 month 6 path 24 row 16
# fracAreaMCD15: 0.0
# year 2013 month 6 path 24 row 21
# fracAreaMCD15: 0.0
# year 2013 month 6 path 24 row 22
# year 2013 month 6 path 24 row 35
# fracAreaMCD15: 0.012659778688393738
# year 2013 month 6 path 24 row 36
# fracAreaMCD15: 0.0
# year 2013 month 6 path 24 row 78
# fracAreaMCD15: 0.0
# year 2013 month 6 path 25 row 10
# fracAreaMCD15: 0.001427019519084869
# year 2013 month 6 path 25 row 11
# fracAreaMCD15: 0.0
# year 2013 month 6 path 25 row 12
# fracAreaMCD15: 0.0
# year 2013 month 6 path 25 row 13
# fracAreaMCD15: 0.0
# year 2013 month 6 path 25 row 14
# year 2013 month 6 path 25 row 21
# fracAreaMCD15: 0.06650935777878768
# year 2013 month 6 path 25 row 22
# fracAreaMCD15: 0.41542878772414443
# fracAreaLCtoMCD: 0.3789376726977827
# cumulative samples: 13734 nsaminput 59
# year 2013 month 6 path 25 row 23
# fracAreaMCD15: 0.20222587437936335
# year 2013 month 6 path 25 row 24
# fracAreaMCD15: 0.011720128197971883
# year 2013 month 6 path 25 row 25
# fracAreaMCD15: 0.0
# year 2013 month 6 path 25 row 26
# fracAreaMCD15: 0.10640077969671416
# year 2013 month 6 path 25 row 27
# fracAreaMCD15: 0.055394560389145614
# year 2013 month 6 path 25 row 35
# fracAreaMCD15: 0.0034995570301127113
# year 2013 month 6 path 25 row 36
# fracAreaMCD15: 0.08571186564393886
# year 2013 month 6 path 25 row 37
# fracAreaMCD15: 0.005083625547448254
# year 2013 month 6 path 25 row 38
# fracAreaMCD15: 0.11858588866090536
# year 2013 month 6 path 26 row 21
# fracAreaMCD15: 0.0779766454454491
# year 2013 month 6 path 26 row 22
# fracAreaMCD15: 0.023408437417363065
# year 2013 month 6 path 26 row 23
# fracAreaMCD15: 0.0
# year 2013 month 6 path 26 row 41
# fracAreaMCD15: 0.20250114327330526
# year 2013 month 6 path 26 row 42
# fracAreaMCD15: 0.193118364680774
# year 2013 month 6 path 26 row 43
# year 2013 month 6 path 26 row 44
# year 2013 month 6 path 26 row 45
# fracAreaMCD15: 0.08547990081979687
# year 2013 month 6 path 26 row 46
# fracAreaMCD15: 0.19503567158277066
# year 2013 month 6 path 27 row 20
# fracAreaMCD15: 0.0
# year 2013 month 6 path 27 row 32
# fracAreaMCD15: 0.0010305737006724134
# year 2013 month 6 path 27 row 33
# fracAreaMCD15: 0.18633587777413668
# year 2013 month 6 path 27 row 34
# fracAreaMCD15: 0.5804654112078442
# fracAreaLCtoMCD: 0.5794666653438288
# cumulative samples: 17448 nsaminput 3714
# year 2013 month 6 path 27 row 35
# fracAreaMCD15: 0.6756218746375803
# fracAreaLCtoMCD: 0.6750418411730773
# cumulative samples: 21772 nsaminput 4324
# year 2013 month 6 path 27 row 36
# fracAreaMCD15: 0.24588755521782832
# year 2013 month 6 path 27 row 37
# fracAreaMCD15: 0.5774222353523705
# fracAreaLCtoMCD: 0.5127631835568264
# cumulative samples: 25028 nsaminput 3256
# year 2013 month 6 path 27 row 247
# fracAreaMCD15: 0.0
# year 2013 month 6 path 28 row 22
# fracAreaMCD15: 0.16146685598652794
# year 2013 month 6 path 28 row 23
# fracAreaMCD15: 0.09640646835782621
# year 2013 month 6 path 28 row 24
# fracAreaMCD15: 0.007924691102862612
# year 2013 month 6 path 28 row 25
# fracAreaMCD15: 0.07672873165708234
# year 2013 month 6 path 28 row 26
# year 2013 month 6 path 28 row 31
# fracAreaMCD15: 0.002905778952008801
# year 2013 month 6 path 28 row 32
# fracAreaMCD15: 0.43931251491744744
# fracAreaLCtoMCD: 0.0
# year 2013 month 6 path 28 row 40
# year 2013 month 6 path 28 row 41
# fracAreaMCD15: 0.03609821952677448
# year 2013 month 6 path 28 row 42
# fracAreaMCD15: 0.41093744245755237
# fracAreaLCtoMCD: 0.38581186715203686
# cumulative samples: 25126 nsaminput 98
# year 2013 month 6 path 28 row 43
# fracAreaMCD15: 0.3860204259520375
# fracAreaLCtoMCD: 0.3480104418833788
# cumulative samples: 27122 nsaminput 1996
# year 2013 month 6 path 29 row 20
# fracAreaMCD15: 0.35797314556714427
# fracAreaLCtoMCD: 0.31235031850982065
# cumulative samples: 27517 nsaminput 395
# year 2013 month 6 path 29 row 33
# fracAreaMCD15: 0.25062258361161466
# fracAreaLCtoMCD: 0.2112931001836697
# cumulative samples: 27638 nsaminput 121
# year 2013 month 6 path 29 row 34
# fracAreaMCD15: 0.3747124938436173
# fracAreaLCtoMCD: 0.3667666269526083
# cumulative samples: 30036 nsaminput 2398
# year 2013 month 6 path 29 row 35
# fracAreaMCD15: 0.6896898606579244
# fracAreaLCtoMCD: 0.6869393568314643
# cumulative samples: 34450 nsaminput 4414
# year 2013 month 6 path 29 row 36
# fracAreaMCD15: 0.5417244272021198
# fracAreaLCtoMCD: 0.5324896590086922
# cumulative samples: 37917 nsaminput 3467
# year 2013 month 6 path 29 row 37
# fracAreaMCD15: 0.2517409015424673
# fracAreaLCtoMCD: 0.24484887809905634
# cumulative samples: 37936 nsaminput 19
# year 2013 month 6 path 29 row 38
# fracAreaMCD15: 0.5594657530536464
# fracAreaLCtoMCD: 0.5546538028705374
# cumulative samples: 39749 nsaminput 1813
# year 2013 month 6 path 29 row 39
# fracAreaMCD15: 0.5172193085102642
# fracAreaLCtoMCD: 0.4685895501483842
# cumulative samples: 39938 nsaminput 189
# year 2013 month 6 path 29 row 46
# fracAreaMCD15: 0.051409549309041985
# year 2013 month 6 path 30 row 24
# year 2013 month 6 path 30 row 35
# fracAreaMCD15: 0.1723281734537125
# year 2013 month 6 path 30 row 36
# fracAreaMCD15: 0.3146874737430894
# fracAreaLCtoMCD: 0.314431277018377
# cumulative samples: 41952 nsaminput 2014
# year 2013 month 6 path 30 row 37
# fracAreaMCD15: 0.3784423973936659
# fracAreaLCtoMCD: 0.3702058444270553
# cumulative samples: 44373 nsaminput 2421
# year 2013 month 6 path 30 row 38
# fracAreaMCD15: 0.4464064753413183
# fracAreaLCtoMCD: 0.3819229389396886
# cumulative samples: 46791 nsaminput 2418
# year 2013 month 6 path 30 row 39
# fracAreaMCD15: 0.14061623372225024
# year 2013 month 6 path 30 row 40
# fracAreaMCD15: 0.3986146573686225
# fracAreaLCtoMCD: 0.3680155891330373
# cumulative samples: 46993 nsaminput 202
# year 2013 month 6 path 30 row 45
# fracAreaMCD15: 0.08391946017392535
# year 2013 month 6 path 30 row 46
# fracAreaMCD15: 0.007346076009993997
# year 2013 month 6 path 30 row 245
# fracAreaMCD15: 0.0
# year 2013 month 6 path 30 row 246
# fracAreaMCD15: 0.0
# year 2013 month 6 path 31 row 8
# fracAreaMCD15: 0.0
# year 2013 month 6 path 31 row 9
# fracAreaMCD15: 0.0
# year 2013 month 6 path 31 row 10
# fracAreaMCD15: 0.0
# year 2013 month 6 path 31 row 11
# fracAreaMCD15: 0.0
# year 2013 month 6 path 31 row 13
# fracAreaMCD15: 0.0003125488862297671
# year 2013 month 6 path 31 row 14
# fracAreaMCD15: 0.0
# year 2013 month 6 path 31 row 15
# fracAreaMCD15: 0.0045408789536875785
# year 2013 month 6 path 31 row 22
# year 2013 month 6 path 31 row 23
# fracAreaMCD15: 0.04059013364601345
# year 2013 month 6 path 31 row 35
# fracAreaMCD15: 0.30673024763149936
# fracAreaLCtoMCD: 0.15396211517067268
# cumulative samples: 47428 nsaminput 435
# year 2013 month 6 path 31 row 36
# fracAreaMCD15: 0.4163646965448494
# fracAreaLCtoMCD: 0.37404628279016605
# cumulative samples: 47833 nsaminput 405
# year 2013 month 6 path 31 row 37
# fracAreaMCD15: 0.27469270726912765
# fracAreaLCtoMCD: 0.2701266229356284
# cumulative samples: 49591 nsaminput 1758
# year 2013 month 6 path 31 row 38
# fracAreaMCD15: 0.3635792688136005
# fracAreaLCtoMCD: 0.36090998490670123
# cumulative samples: 51918 nsaminput 2327
# year 2013 month 6 path 31 row 39
# fracAreaMCD15: 0.09560888046538091
# year 2013 month 6 path 31 row 40
# fracAreaMCD15: 0.4117006014732314
# fracAreaLCtoMCD: 0.36404714686804224
# cumulative samples: 52082 nsaminput 164
# year 2013 month 6 path 31 row 41
# fracAreaMCD15: 0.2968650434437482
# fracAreaLCtoMCD: 0.27955735282379196
# cumulative samples: 52435 nsaminput 353
# year 2013 month 6 path 31 row 42
# fracAreaMCD15: 0.4496858558806857
# fracAreaLCtoMCD: 0.45143631040488724
# cumulative samples: 55313 nsaminput 2878
# year 2013 month 6 path 31 row 43
# fracAreaMCD15: 0.5617095246671204
# fracAreaLCtoMCD: 0.5557398721049048
# cumulative samples: 58908 nsaminput 3595
# year 2013 month 6 path 31 row 44
# fracAreaMCD15: 0.43357431026546966
# fracAreaLCtoMCD: 0.425436896355651
# cumulative samples: 59268 nsaminput 360
# year 2013 month 6 path 31 row 45
# year 2013 month 6 path 32 row 9
# fracAreaMCD15: 0.0024163108312290496
# year 2013 month 6 path 32 row 10
# fracAreaMCD15: 0.0
# year 2013 month 6 path 32 row 11
# fracAreaMCD15: 0.0
# year 2013 month 6 path 32 row 12
# fracAreaMCD15: 0.0032528551844782394
# year 2013 month 6 path 32 row 13
# fracAreaMCD15: 0.0
# year 2013 month 6 path 32 row 15
# fracAreaMCD15: 0.0
# year 2013 month 6 path 32 row 16
# fracAreaMCD15: 0.0
# year 2013 month 6 path 32 row 17
# fracAreaMCD15: 0.0
# year 2013 month 6 path 32 row 18
# fracAreaMCD15: 0.0
# year 2013 month 6 path 32 row 19
# fracAreaMCD15: 0.0009375622707190762
# year 2013 month 6 path 32 row 27
# fracAreaMCD15: 0.12402661137549732
# year 2013 month 6 path 32 row 28
# fracAreaMCD15: 0.23772970583711658
# year 2013 month 6 path 32 row 33
# fracAreaMCD15: 0.18706112901889616
# year 2013 month 6 path 32 row 34
# fracAreaMCD15: 0.43944061965479275
# fracAreaLCtoMCD: 0.43846942785560755
# cumulative samples: 61482 nsaminput 2214
# year 2013 month 6 path 32 row 35
# fracAreaMCD15: 0.40084797567954616
# fracAreaLCtoMCD: 0.3991603703262026
# cumulative samples: 61556 nsaminput 74
# year 2013 month 6 path 32 row 36
# fracAreaMCD15: 0.5069658058184262
# fracAreaLCtoMCD: 0.38117583380571884
# cumulative samples: 61562 nsaminput 6
# year 2013 month 6 path 32 row 37
# fracAreaMCD15: 0.27026672870265767
# fracAreaLCtoMCD: 0.2492929525394054
# cumulative samples: 63148 nsaminput 1586
# year 2013 month 6 path 32 row 38
# fracAreaMCD15: 0.3153177733651297
# fracAreaLCtoMCD: 0.31328216618498245
# cumulative samples: 65166 nsaminput 2018
# year 2013 month 6 path 32 row 39
# fracAreaMCD15: 0.5018784983797001
# fracAreaLCtoMCD: 0.4903582937230569
# cumulative samples: 68303 nsaminput 3137
# year 2013 month 6 path 32 row 40
# fracAreaMCD15: 0.5109131914892203
# fracAreaLCtoMCD: 0.4816162625041206
# cumulative samples: 69112 nsaminput 809
# year 2013 month 6 path 32 row 43
# fracAreaMCD15: 0.8592937503297471
# fracAreaLCtoMCD: 0.6221738689806335
# cumulative samples: 69120 nsaminput 8
# year 2013 month 6 path 33 row 14
# fracAreaMCD15: 0.005157097989087495
# year 2013 month 6 path 33 row 15
# fracAreaMCD15: 0.0021965699697176332
# year 2013 month 6 path 33 row 16
# fracAreaMCD15: 0.005302926446058563
# year 2013 month 6 path 33 row 17
# fracAreaMCD15: 0.0
# year 2013 month 6 path 33 row 18
# fracAreaMCD15: 0.0
# year 2013 month 6 path 33 row 30
# fracAreaMCD15: 0.08065518970483596
# year 2013 month 6 path 33 row 31
# fracAreaMCD15: 0.09843452407331617
# year 2013 month 6 path 33 row 32
# fracAreaMCD15: 0.37762224350343
# fracAreaLCtoMCD: 0.3797563958435262
# cumulative samples: 70115 nsaminput 995
# year 2013 month 6 path 33 row 33
# fracAreaMCD15: 0.26841905198061783
# fracAreaLCtoMCD: 0.27124735657500826
# cumulative samples: 70620 nsaminput 505
# year 2013 month 6 path 33 row 34
# fracAreaMCD15: 0.2595354284538882
# fracAreaLCtoMCD: 0.26291985757911557
# cumulative samples: 72092 nsaminput 1472
# year 2013 month 6 path 33 row 37
# fracAreaMCD15: 0.4361716212181081
# fracAreaLCtoMCD: 0.3666565053652469
# cumulative samples: 72199 nsaminput 107
# year 2013 month 6 path 33 row 38
# fracAreaMCD15: 0.05859856072071709
# year 2013 month 6 path 33 row 39
# fracAreaMCD15: 0.4835880462308231
# fracAreaLCtoMCD: 0.48880025873355576
# cumulative samples: 75294 nsaminput 3095
# year 2013 month 6 path 33 row 40
# fracAreaMCD15: 0.6670713887464323
# fracAreaLCtoMCD: 0.6211273554974563
# cumulative samples: 75835 nsaminput 541
# year 2013 month 6 path 33 row 41
# fracAreaMCD15: 0.3284092051460497
# fracAreaLCtoMCD: 0.3251860027820326
# cumulative samples: 77937 nsaminput 2102
# year 2013 month 6 path 33 row 42
# fracAreaMCD15: 0.020784096675219153
# year 2013 month 6 path 34 row 7
# fracAreaMCD15: 0.0
# year 2013 month 6 path 34 row 8
# fracAreaMCD15: 0.0033329395289914574
# year 2013 month 6 path 34 row 9
# fracAreaMCD15: 0.0
# year 2013 month 6 path 34 row 10
# fracAreaMCD15: 0.0010890828825357848
# year 2013 month 6 path 34 row 11
# fracAreaMCD15: 0.0
# year 2013 month 6 path 34 row 12
# fracAreaMCD15: 0.0
# year 2013 month 6 path 34 row 13
# fracAreaMCD15: 0.0
# year 2013 month 6 path 34 row 17
# fracAreaMCD15: 0.01254609105303033
# year 2013 month 6 path 34 row 27
# fracAreaMCD15: 0.7081717696924197
# fracAreaLCtoMCD: 0.6062700129036226
# cumulative samples: 77967 nsaminput 30
# year 2013 month 6 path 34 row 37
# fracAreaMCD15: 0.2111844277455476
# year 2013 month 6 path 34 row 38
# fracAreaMCD15: 0.36330132948275834
# fracAreaLCtoMCD: 0.3656076900571259
# cumulative samples: 78703 nsaminput 736
# year 2013 month 6 path 34 row 39
# fracAreaMCD15: 0.41295772003894704
# fracAreaLCtoMCD: 0.40873666689409754
# cumulative samples: 80013 nsaminput 1310
# year 2013 month 6 path 34 row 40
# fracAreaMCD15: 0.23030192087674617
# year 2013 month 6 path 34 row 41
# fracAreaMCD15: 0.3539020249069824
# fracAreaLCtoMCD: 0.3562629068683696
# cumulative samples: 82278 nsaminput 2265
# year 2013 month 6 path 34 row 43
# fracAreaMCD15: 0.0
# year 2013 month 6 path 35 row 11
# fracAreaMCD15: 0.0
# year 2013 month 6 path 35 row 12
# fracAreaMCD15: 0.0
# year 2013 month 6 path 35 row 13
# fracAreaMCD15: 0.01083767840053191
# year 2013 month 6 path 35 row 14
# year 2013 month 6 path 35 row 15
# fracAreaMCD15: 0.0012000052536630284
# year 2013 month 6 path 35 row 19
# fracAreaMCD15: 0.051921709413492126
# year 2013 month 6 path 35 row 20
# fracAreaMCD15: 0.050186582991722455
# year 2013 month 6 path 35 row 22
# fracAreaMCD15: 0.4943828767961677
# fracAreaLCtoMCD: 0.4798012507320167
# cumulative samples: 83492 nsaminput 1214
# year 2013 month 6 path 35 row 23
# fracAreaMCD15: 0.5415559162709649
# fracAreaLCtoMCD: 0.5478314236381646
# cumulative samples: 86958 nsaminput 3466
# year 2013 month 6 path 35 row 24
# fracAreaMCD15: 0.42151493652324196
# fracAreaLCtoMCD: 0.3750358016293789
# cumulative samples: 86981 nsaminput 23
# year 2013 month 6 path 35 row 31
# fracAreaMCD15: 0.25898052053374393
# fracAreaLCtoMCD: 0.2342548522251411
# cumulative samples: 88056 nsaminput 1075
# year 2013 month 6 path 35 row 32
# fracAreaMCD15: 0.5096788518760834
# fracAreaLCtoMCD: 0.461998377450077
# cumulative samples: 88874 nsaminput 818
# year 2013 month 6 path 35 row 35
# fracAreaMCD15: 0.6915625372284359
# fracAreaLCtoMCD: 0.6946720726906603
# cumulative samples: 92102 nsaminput 3228
# year 2013 month 6 path 35 row 36
# fracAreaMCD15: 0.4834612587076807
# fracAreaLCtoMCD: 0.47616265294278576
# cumulative samples: 95170 nsaminput 3068
# year 2013 month 6 path 35 row 37
# fracAreaMCD15: 0.39297193849959106
# fracAreaLCtoMCD: 0.3919333630966529
# cumulative samples: 97685 nsaminput 2515
# year 2013 month 6 path 35 row 38
# fracAreaMCD15: 0.4255012344504284
# fracAreaLCtoMCD: 0.4242643647091159
# cumulative samples: 100324 nsaminput 2639
# year 2013 month 6 path 35 row 39
# fracAreaMCD15: 0.5933101715563045
# fracAreaLCtoMCD: 0.5853384678353513
# cumulative samples: 102507 nsaminput 2183
# year 2013 month 6 path 35 row 40
# fracAreaMCD15: 0.5985848311604943
# fracAreaLCtoMCD: 0.5950269636684853
# cumulative samples: 106338 nsaminput 3831
# year 2013 month 6 path 35 row 41
# fracAreaMCD15: 0.525285141463441
# fracAreaLCtoMCD: 0.5171352314938701
# cumulative samples: 107872 nsaminput 1534
# year 2013 month 6 path 36 row 14
# fracAreaMCD15: 0.0
# year 2013 month 6 path 36 row 19
# fracAreaMCD15: 0.033574162846284505
# year 2013 month 6 path 36 row 33
# fracAreaMCD15: 0.5009204127976564
# fracAreaLCtoMCD: 0.5033623909171033
# cumulative samples: 111078 nsaminput 3206
# year 2013 month 6 path 36 row 34
# fracAreaMCD15: 0.3654498141434157
# fracAreaLCtoMCD: 0.37063034112198534
# cumulative samples: 113417 nsaminput 2339
# year 2013 month 6 path 36 row 35
# fracAreaMCD15: 0.34345338340677317
# fracAreaLCtoMCD: 0.18429838618224098
# cumulative samples: 114612 nsaminput 1195
# year 2013 month 6 path 36 row 37
# year 2013 month 6 path 36 row 38
# fracAreaMCD15: 0.632443360192532
# fracAreaLCtoMCD: 0.6333143063495935
# cumulative samples: 118624 nsaminput 4012
# year 2013 month 6 path 37 row 18
# fracAreaMCD15: 0.016228378945111203
# year 2013 month 6 path 37 row 19
# fracAreaMCD15: 0.03282991286849173
# year 2013 month 6 path 37 row 20
# fracAreaMCD15: 0.053491161440805686
# year 2013 month 6 path 37 row 21
# fracAreaMCD15: 0.045047466890619794
# year 2013 month 6 path 37 row 22
# fracAreaMCD15: 0.2887749632653927
# fracAreaLCtoMCD: 0.2871346978582035
# cumulative samples: 120214 nsaminput 1590
# year 2013 month 6 path 37 row 31
# fracAreaMCD15: 0.4730581877084847
# fracAreaLCtoMCD: 0.4664704425848178
# cumulative samples: 121087 nsaminput 873
# year 2013 month 6 path 37 row 32
# fracAreaMCD15: 0.552361472084326
# fracAreaLCtoMCD: 0.5261901636772528
# cumulative samples: 124148 nsaminput 3061
# year 2013 month 6 path 37 row 33
# fracAreaMCD15: 0.3209522334766383
# fracAreaLCtoMCD: 0.2920281001312653
# cumulative samples: 124292 nsaminput 144
# year 2013 month 6 path 37 row 35
# fracAreaMCD15: 0.20029297633399515
# year 2013 month 6 path 37 row 36
# fracAreaMCD15: 0.1648478997047602
# year 2013 month 6 path 37 row 37
# fracAreaMCD15: 0.2940464137823334
# fracAreaLCtoMCD: 0.2970651658778727
# cumulative samples: 126174 nsaminput 1882
# year 2013 month 6 path 37 row 38
# fracAreaMCD15: 0.522078309726209
# fracAreaLCtoMCD: 0.5146315538750776
# cumulative samples: 128525 nsaminput 2351
# year 2013 month 6 path 37 row 39
# fracAreaMCD15: 0.4062503670515626
# fracAreaLCtoMCD: 0.3993366141215702
# cumulative samples: 129380 nsaminput 855
# year 2013 month 6 path 38 row 27
# fracAreaMCD15: 0.11363348917532334
# year 2013 month 6 path 38 row 28
# fracAreaMCD15: 0.17695390669422756
# year 2013 month 6 path 38 row 29
# fracAreaMCD15: 0.11743356204891445
# year 2013 month 6 path 38 row 30
# fracAreaMCD15: 0.1931209030933951
# year 2013 month 6 path 38 row 31
# fracAreaMCD15: 0.030731420097691045
# year 2013 month 6 path 38 row 32
# fracAreaMCD15: 0.0583377296661335
# year 2013 month 6 path 38 row 33
# fracAreaMCD15: 0.0
# year 2013 month 6 path 38 row 34
# fracAreaMCD15: 0.474812745495229
# fracAreaLCtoMCD: 0.480679262271515
# cumulative samples: 129393 nsaminput 13
# year 2013 month 6 path 38 row 35
# fracAreaMCD15: 0.22779646907538673
# year 2013 month 6 path 38 row 36
# fracAreaMCD15: 0.44250330668369187
# fracAreaLCtoMCD: 0.4425476755874114
# cumulative samples: 132225 nsaminput 2832
# year 2013 month 6 path 38 row 37
# fracAreaMCD15: 0.2263860015545274
# year 2013 month 6 path 40 row 30
# fracAreaMCD15: 0.4977811352628354
# fracAreaLCtoMCD: 0.44885669986435367
# cumulative samples: 132367 nsaminput 142
# year 2013 month 6 path 40 row 31
# fracAreaMCD15: 0.04361977793325087
# year 2013 month 6 path 40 row 33
# fracAreaMCD15: 0.315509646949376
# fracAreaLCtoMCD: 0.30148878308525673
# cumulative samples: 133135 nsaminput 768
# year 2013 month 6 path 40 row 34
# fracAreaMCD15: 0.45114643817152517
# fracAreaLCtoMCD: 0.438102059661579
# cumulative samples: 134917 nsaminput 1782
# year 2013 month 6 path 40 row 35
# fracAreaMCD15: 0.24422925951649835
# year 2013 month 6 path 40 row 36
# fracAreaMCD15: 0.3545487852903123
# fracAreaLCtoMCD: 0.3010013874962539
# cumulative samples: 136878 nsaminput 1961
# year 2013 month 6 path 41 row 8
# fracAreaMCD15: 0.0
# year 2013 month 6 path 41 row 9
# fracAreaMCD15: 0.0003126113726547813
# year 2013 month 6 path 41 row 10
# fracAreaMCD15: 0.0
# year 2013 month 6 path 41 row 33
# fracAreaMCD15: 0.48559881788173304
# fracAreaLCtoMCD: 0.4056725683741415
# cumulative samples: 138579 nsaminput 1701
# year 2013 month 6 path 41 row 34
# fracAreaMCD15: 0.13203161802135513
# year 2013 month 6 path 41 row 35
# fracAreaMCD15: 0.2553037305178955
# fracAreaLCtoMCD: 0.25567743762884926
# cumulative samples: 139639 nsaminput 1060
# year 2013 month 6 path 41 row 36
# year 2013 month 6 path 42 row 11
# fracAreaMCD15: 0.0
# year 2013 month 6 path 42 row 14
# fracAreaMCD15: 0.0027311594650117504
# year 2013 month 6 path 42 row 15
# fracAreaMCD15: 0.0
# year 2013 month 6 path 42 row 16
# fracAreaMCD15: 0.0006251525901650504
# year 2013 month 6 path 42 row 27
# fracAreaMCD15: 0.30991533545962163
# fracAreaLCtoMCD: 0.08136430035279872
# year 2013 month 6 path 42 row 28
# fracAreaMCD15: 0.3003319693282376
# fracAreaLCtoMCD: 0.29308039739913055
# cumulative samples: 139900 nsaminput 261
# year 2013 month 6 path 42 row 29
# fracAreaMCD15: 0.1446863308264261
# year 2013 month 6 path 42 row 30
# fracAreaMCD15: 0.39365178029268744
# fracAreaLCtoMCD: 0.3962566314217101
# cumulative samples: 142121 nsaminput 2221
# year 2013 month 6 path 42 row 31
# fracAreaMCD15: 0.35641384332817955
# fracAreaLCtoMCD: 0.3424920114242038
# cumulative samples: 144400 nsaminput 2279
# year 2013 month 6 path 42 row 32
# fracAreaMCD15: 0.3075743444021766
# fracAreaLCtoMCD: 0.30617582672913846
# cumulative samples: 146091 nsaminput 1691
# year 2013 month 6 path 42 row 33
# fracAreaMCD15: 0.30837343599707956
# fracAreaLCtoMCD: 0.2967836911799517
# cumulative samples: 147406 nsaminput 1315
# year 2013 month 6 path 42 row 34
# fracAreaMCD15: 0.12369810458657537
# year 2013 month 6 path 42 row 35
# fracAreaMCD15: 0.24786548093726263
# year 2013 month 6 path 42 row 36
# fracAreaMCD15: 0.2988097353081093
# fracAreaLCtoMCD: 0.3038819193643348
# cumulative samples: 149092 nsaminput 1686
# year 2013 month 6 path 43 row 1
# year 2013 month 6 path 43 row 6
# fracAreaMCD15: 0.0
# year 2013 month 6 path 43 row 11
# year 2013 month 6 path 43 row 12
# fracAreaMCD15: 0.003104828673129466
# year 2013 month 6 path 43 row 16
# fracAreaMCD15: 0.015733925368392757
# year 2013 month 6 path 43 row 30
# fracAreaMCD15: 0.1793321940871709
# year 2013 month 6 path 43 row 31
# fracAreaMCD15: 0.07373707928027957
# year 2013 month 6 path 43 row 32
# fracAreaMCD15: 0.14717086752752992
# year 2013 month 6 path 43 row 33
# fracAreaMCD15: 0.2936205117026978
# fracAreaLCtoMCD: 0.24619028358221698
# cumulative samples: 149144 nsaminput 52
# year 2013 month 6 path 43 row 34
# fracAreaMCD15: 0.40499925819019106
# fracAreaLCtoMCD: 0.40361195594348087
# cumulative samples: 151736 nsaminput 2592
# year 2013 month 6 path 43 row 35
# fracAreaMCD15: 0.33795199069935494
# fracAreaLCtoMCD: 0.3359418132723092
# cumulative samples: 153855 nsaminput 2119
# year 2013 month 6 path 44 row 5
# fracAreaMCD15: 0.0
# year 2013 month 6 path 44 row 10
# fracAreaMCD15: 0.0
# year 2013 month 6 path 44 row 11
# fracAreaMCD15: 0.0
# year 2013 month 6 path 44 row 12
# fracAreaMCD15: 0.002135442183067136
# year 2013 month 6 path 44 row 13
# fracAreaMCD15: 0.000543366790000986
# year 2013 month 6 path 44 row 14
# fracAreaMCD15: 0.0
# year 2013 month 6 path 44 row 15
# fracAreaMCD15: 0.0010989301485275515
# year 2013 month 6 path 44 row 28
# fracAreaMCD15: 0.23338280554514623
# year 2013 month 6 path 44 row 29
# fracAreaMCD15: 0.3830723085727232
# fracAreaLCtoMCD: 0.36571689590675666
# cumulative samples: 155374 nsaminput 1519
# year 2013 month 6 path 44 row 30
# fracAreaMCD15: 0.4678687106161981
# fracAreaLCtoMCD: 0.40550556930958387
# cumulative samples: 155441 nsaminput 67
# year 2013 month 6 path 44 row 31
# fracAreaMCD15: 0.4274985099794749
# fracAreaLCtoMCD: 0.42404903865772337
# cumulative samples: 156605 nsaminput 1164
# year 2013 month 6 path 44 row 32
# fracAreaMCD15: 0.678768547602978
# fracAreaLCtoMCD: 0.6651766134199744
# cumulative samples: 160229 nsaminput 3624
# year 2013 month 6 path 44 row 33
# fracAreaMCD15: 0.3561923933189575
# fracAreaLCtoMCD: 0.3407582977527269
# cumulative samples: 160695 nsaminput 466
# year 2013 month 6 path 44 row 34
# fracAreaMCD15: 0.32093833167287833
# fracAreaLCtoMCD: 0.31785015168103337
# cumulative samples: 162749 nsaminput 2054
# year 2013 month 6 path 45 row 12
# fracAreaMCD15: 0.0
# year 2013 month 6 path 45 row 13
# fracAreaMCD15: 0.05563610557130615
# year 2013 month 6 path 45 row 14
# fracAreaMCD15: 0.11917186352180609
# year 2013 month 6 path 45 row 27
# fracAreaMCD15: 0.12838335965712344
# year 2013 month 6 path 45 row 28
# fracAreaMCD15: 0.24921970765667953
# year 2013 month 6 path 45 row 29
# fracAreaMCD15: 0.09578019992593297
# year 2013 month 6 path 45 row 30
# fracAreaMCD15: 0.2442327296656917
# year 2013 month 6 path 45 row 73
# fracAreaMCD15: 0.0
# year 2013 month 6 path 46 row 14
# fracAreaMCD15: 0.0
# year 2013 month 6 path 46 row 15
# fracAreaMCD15: 0.0
# year 2013 month 6 path 46 row 30
# fracAreaMCD15: 0.614737616200192
# fracAreaLCtoMCD: 0.608740445404977
# cumulative samples: 164171 nsaminput 1422
# year 2013 month 6 path 46 row 31
# fracAreaMCD15: 1.0
# fracAreaLCtoMCD: 0.0
# year 2013 month 6 path 46 row 32
# fracAreaMCD15: 0.0
# year 2013 month 6 path 46 row 243
# fracAreaMCD15: 0.0
# year 2013 month 6 path 47 row 28
# year 2013 month 6 path 47 row 29
# fracAreaMCD15: 0.007813854641691495
# year 2013 month 6 path 47 row 30
# fracAreaMCD15: 0.0
# year 2013 month 6 path 48 row 8
# fracAreaMCD15: 0.0
# year 2013 month 6 path 49 row 19
# fracAreaMCD15: 0.178315162559006
# year 2013 month 6 path 49 row 79
# year 2013 month 6 path 50 row 8
# fracAreaMCD15: 0.0
# year 2013 month 6 path 50 row 9
# fracAreaMCD15: 0.0
# year 2013 month 6 path 50 row 10
# fracAreaMCD15: 0.00015705795469868976
# year 2013 month 6 path 50 row 11
# fracAreaMCD15: 0.0013886647281614417
# year 2013 month 6 path 51 row 11
# fracAreaMCD15: 0.0001562664371405542
# year 2013 month 6 path 51 row 12
# fracAreaMCD15: 0.010058275319563352
# year 2013 month 6 path 51 row 13
# fracAreaMCD15: 0.0
# year 2013 month 6 path 51 row 14
# fracAreaMCD15: 0.0
# year 2013 month 6 path 52 row 7
# fracAreaMCD15: 0.0
# year 2013 month 6 path 52 row 11
# fracAreaMCD15: 0.009065888491194262
# year 2013 month 6 path 52 row 12
# fracAreaMCD15: 0.0
# year 2013 month 6 path 52 row 13
# fracAreaMCD15: 0.014241179264323504
# year 2013 month 6 path 52 row 14
# fracAreaMCD15: 0.0
# year 2013 month 6 path 52 row 15
# fracAreaMCD15: 0.10130600884825683
# year 2013 month 6 path 52 row 16
# fracAreaMCD15: 0.42799854511742874
# fracAreaLCtoMCD: 0.3491817649763143
# cumulative samples: 164835 nsaminput 664
# year 2013 month 6 path 52 row 18
# fracAreaMCD15: 0.4523813399233783
# fracAreaLCtoMCD: 0.4466338895360673
# cumulative samples: 167351 nsaminput 2516
# year 2013 month 6 path 52 row 76
# year 2013 month 6 path 53 row 13
# year 2013 month 6 path 54 row 10
# fracAreaMCD15: 0.0020516020768341467
# year 2013 month 6 path 57 row 8
# fracAreaMCD15: 0.0015727154770330258
# year 2013 month 6 path 57 row 9
# fracAreaMCD15: 0.0018753276867222253
# year 2013 month 6 path 57 row 19
# fracAreaMCD15: 0.16052241590711566
# year 2013 month 6 path 59 row 9
# fracAreaMCD15: 0.003997603437224059
# year 2013 month 6 path 59 row 10
# fracAreaMCD15: 0.0
# year 2013 month 6 path 59 row 19
# fracAreaMCD15: 0.0013076709490240199
# year 2013 month 6 path 60 row 11
# fracAreaMCD15: 0.0
# year 2013 month 6 path 60 row 13
# fracAreaMCD15: 0.15578194597377992
# year 2013 month 6 path 60 row 17
# fracAreaMCD15: 0.08414944388984362
# year 2013 month 6 path 60 row 66
# year 2013 month 6 path 61 row 7
# fracAreaMCD15: 0.0
# year 2013 month 6 path 61 row 59
# fracAreaMCD15: 0.0
# year 2013 month 6 path 62 row 243
# fracAreaMCD15: 0.0
# year 2013 month 6 path 63 row 11
# fracAreaMCD15: 0.0
# year 2013 month 6 path 63 row 12
# fracAreaMCD15: 0.0
# year 2013 month 6 path 63 row 13
# fracAreaMCD15: 0.3342737193224035
# fracAreaLCtoMCD: 0.30785351084212487
# cumulative samples: 169229 nsaminput 1878
# year 2013 month 6 path 63 row 57
# fracAreaMCD15: 0.0
# year 2013 month 6 path 63 row 69
# fracAreaMCD15: 0.0
# year 2013 month 6 path 64 row 16
# fracAreaMCD15: 0.3033094889519331
# fracAreaLCtoMCD: 0.30741754665036597
# cumulative samples: 169692 nsaminput 463
# year 2013 month 6 path 64 row 17
# fracAreaMCD15: 0.17195597545933033
# year 2013 month 6 path 65 row 68
# fracAreaMCD15: 0.0
# year 2013 month 6 path 66 row 11
# year 2013 month 6 path 66 row 13
# fracAreaMCD15: 0.0
# year 2013 month 6 path 66 row 14
# year 2013 month 6 path 66 row 70
# fracAreaMCD15: 0.0
# year 2013 month 6 path 68 row 18
# fracAreaMCD15: 0.0
# year 2013 month 6 path 68 row 20
# fracAreaMCD15: 0.0
# year 2013 month 6 path 68 row 68
# fracAreaMCD15: 0.0
# year 2013 month 6 path 69 row 11
# fracAreaMCD15: 0.06378889424991947
# year 2013 month 6 path 69 row 12
# fracAreaMCD15: 0.4596810019229025
# fracAreaLCtoMCD: 0.4441018182217106
# cumulative samples: 172333 nsaminput 2641
# year 2013 month 6 path 69 row 13
# fracAreaMCD15: 0.0467903728830556
# year 2013 month 6 path 69 row 14
# fracAreaMCD15: 0.054313404348456995
# year 2013 month 6 path 69 row 66
# fracAreaMCD15: 0.0
# year 2013 month 6 path 70 row 17
# fracAreaMCD15: 0.036618433818046484
# year 2013 month 6 path 70 row 20
# fracAreaMCD15: 0.03642452272323874
# year 2013 month 6 path 72 row 10
# year 2013 month 6 path 72 row 22
# fracAreaMCD15: 0.0
# year 2013 month 6 path 72 row 88
# fracAreaMCD15: 0.2427907095093705
# year 2013 month 6 path 73 row 14
# fracAreaMCD15: 0.4304783131843258
# fracAreaLCtoMCD: 0.42112037425417065
# cumulative samples: 172918 nsaminput 585
# year 2013 month 6 path 74 row 42
# year 2013 month 6 path 74 row 86
# fracAreaMCD15: 0.0
# year 2013 month 6 path 74 row 87
# year 2013 month 6 path 74 row 88
# year 2013 month 6 path 74 row 91
# year 2013 month 6 path 75 row 10
# fracAreaMCD15: 0.008880698324689804
# year 2013 month 6 path 75 row 11
# year 2013 month 6 path 75 row 15
# fracAreaMCD15: 0.5768263666834029
# fracAreaLCtoMCD: 0.4760149730313266
# cumulative samples: 173378 nsaminput 460
# year 2013 month 6 path 75 row 16
# fracAreaMCD15: 0.4601012409050229
# fracAreaLCtoMCD: 0.4589621771519952
# cumulative samples: 176263 nsaminput 2885
# year 2013 month 6 path 75 row 17
# fracAreaMCD15: 0.001453107200499551
# year 2013 month 6 path 75 row 42
# year 2013 month 6 path 78 row 12
# fracAreaMCD15: 0.01081377483646445
# year 2013 month 6 path 78 row 13
# fracAreaMCD15: 0.027649371427735714
# year 2013 month 6 path 78 row 14
# fracAreaMCD15: 0.37522164263026103
# fracAreaLCtoMCD: 0.5161638477906126
# cumulative samples: 176268 nsaminput 5
# year 2013 month 6 path 78 row 15
# fracAreaMCD15: 0.05272083777220625
# year 2013 month 6 path 78 row 16
# fracAreaMCD15: 0.0
# year 2013 month 6 path 78 row 240
# fracAreaMCD15: 0.0
# year 2013 month 6 path 82 row 13
# fracAreaMCD15: 0.0
# year 2013 month 6 path 82 row 15
# fracAreaMCD15: 0.0
# year 2013 month 6 path 82 row 16
# year 2013 month 6 path 84 row 13
# year 2013 month 6 path 84 row 60
# fracAreaMCD15: 0.0
# year 2013 month 6 path 85 row 13
# fracAreaMCD15: 0.0
# year 2013 month 6 path 85 row 14
# fracAreaMCD15: 0.0
# year 2013 month 6 path 86 row 75
# year 2013 month 6 path 88 row 66
# year 2013 month 6 path 89 row 65
# fracAreaMCD15: 0.0
# year 2013 month 6 path 89 row 78
# fracAreaMCD15: 0.0003917351664904115
# year 2013 month 6 path 92 row 76
# fracAreaMCD15: 0.13356908614246138
# year 2013 month 6 path 92 row 77
# fracAreaMCD15: 0.3525071983859959
# fracAreaLCtoMCD: 0.34313175353946146
# cumulative samples: 176549 nsaminput 281
# year 2013 month 6 path 92 row 78
# fracAreaMCD15: 0.5620376986485344
# fracAreaLCtoMCD: 0.5432833428776235
# cumulative samples: 178495 nsaminput 1946
# year 2013 month 6 path 92 row 79
# fracAreaMCD15: 0.1666398863355065
# year 2013 month 6 path 92 row 80
# fracAreaMCD15: 0.12399353287245084
# year 2013 month 6 path 92 row 81
# fracAreaMCD15: 0.262505965754599
# fracAreaLCtoMCD: 0.24650669054747062
# cumulative samples: 180037 nsaminput 1542
# year 2013 month 6 path 93 row 11
# year 2013 month 6 path 93 row 78
# year 2013 month 6 path 93 row 79
# fracAreaMCD15: 0.21159780903068323
# year 2013 month 6 path 93 row 80
# fracAreaMCD15: 0.03485127931462601
# year 2013 month 6 path 94 row 74
# year 2013 month 6 path 94 row 75
# fracAreaMCD15: 0.0085852143595802
# year 2013 month 6 path 94 row 84
# fracAreaMCD15: 0.0
# year 2013 month 6 path 95 row 14
# fracAreaMCD15: 0.07955344305926931
# year 2013 month 6 path 95 row 82
# fracAreaMCD15: 0.18426841554435894
# year 2013 month 6 path 95 row 83
# fracAreaMCD15: 0.3947692422801396
# fracAreaLCtoMCD: 0.3928928581654753
# cumulative samples: 180759 nsaminput 722
# year 2013 month 6 path 96 row 10
# year 2013 month 6 path 97 row 73
# fracAreaMCD15: 0.7545263198269535
# fracAreaLCtoMCD: 0.7557771151513825
# cumulative samples: 185588 nsaminput 4829
# year 2013 month 6 path 97 row 74
# fracAreaMCD15: 0.5758436973332725
# fracAreaLCtoMCD: 0.5747298414310722
# cumulative samples: 188727 nsaminput 3139
# year 2013 month 6 path 97 row 75
# fracAreaMCD15: 0.6221318951347166
# fracAreaLCtoMCD: 0.6145475268985636
# cumulative samples: 190191 nsaminput 1464
# year 2013 month 6 path 98 row 14
# fracAreaMCD15: 0.017278442004007025
# year 2013 month 6 path 98 row 15
# fracAreaMCD15: 0.01078309141190656
# year 2013 month 6 path 98 row 16
# fracAreaMCD15: 0.0
# year 2013 month 6 path 98 row 17
# fracAreaMCD15: 0.5783857692850488
# fracAreaLCtoMCD: 0.23418231265692635
# cumulative samples: 190651 nsaminput 460
# year 2013 month 6 path 98 row 19
# fracAreaMCD15: 0.0
# year 2013 month 6 path 98 row 70
# fracAreaMCD15: 0.0
# year 2013 month 6 path 98 row 71
# fracAreaMCD15: 0.20376433371410524
# year 2013 month 6 path 98 row 72
# fracAreaMCD15: 0.36239017187605066
# fracAreaLCtoMCD: 0.3691159870959032
# cumulative samples: 191601 nsaminput 950
# year 2013 month 6 path 98 row 73
# fracAreaMCD15: 0.6508043921099569
# fracAreaLCtoMCD: 0.6444201469274324
# cumulative samples: 195766 nsaminput 4165
# year 2013 month 6 path 98 row 74
# fracAreaMCD15: 0.4202511476765595
# fracAreaLCtoMCD: 0.4164690603164008
# cumulative samples: 195937 nsaminput 171
# year 2013 month 6 path 98 row 75
# fracAreaMCD15: 0.2791929273460828
# fracAreaLCtoMCD: 0.27903749151769375
# cumulative samples: 196532 nsaminput 595
# year 2013 month 6 path 98 row 76
# fracAreaMCD15: 0.12603667976705074
# year 2013 month 6 path 98 row 77
# fracAreaMCD15: 0.16799758102486484
# year 2013 month 6 path 98 row 78
# fracAreaMCD15: 0.33772883792427744
# fracAreaLCtoMCD: 0.3283919003661096
# cumulative samples: 198478 nsaminput 1946
# year 2013 month 6 path 98 row 79
# fracAreaMCD15: 0.5003511342694681
# fracAreaLCtoMCD: 0.500040201289916
# cumulative samples: 201644 nsaminput 3166
# year 2013 month 6 path 98 row 80
# fracAreaMCD15: 0.1056692337555011
# year 2013 month 6 path 99 row 18
# fracAreaMCD15: 0.005043203408918938
# year 2013 month 6 path 99 row 23
# fracAreaMCD15: 0.0022413558350151868
# year 2013 month 6 path 99 row 24
# fracAreaMCD15: 0.0
# year 2013 month 6 path 99 row 70
# fracAreaMCD15: 0.0
# year 2013 month 6 path 99 row 71
# fracAreaMCD15: 0.0
# year 2013 month 6 path 99 row 72
# fracAreaMCD15: 0.11792199529994264
# year 2013 month 6 path 99 row 73
# fracAreaMCD15: 0.02174746240590999
# year 2013 month 6 path 99 row 74
# fracAreaMCD15: 0.18357200914526572
# year 2013 month 6 path 100 row 73
# fracAreaMCD15: 0.5937048293495537
# fracAreaLCtoMCD: 0.5943518172889509
# cumulative samples: 204980 nsaminput 3336
# year 2013 month 6 path 100 row 74
# year 2013 month 6 path 100 row 75
# fracAreaMCD15: 0.5129250350961054
# fracAreaLCtoMCD: 0.4999745531400175
# cumulative samples: 205177 nsaminput 197
# year 2013 month 6 path 100 row 76
# fracAreaMCD15: 0.35425179639342536
# fracAreaLCtoMCD: 0.354693321501438
# cumulative samples: 207444 nsaminput 2267
# year 2013 month 6 path 100 row 77
# fracAreaMCD15: 0.4255864718514159
# fracAreaLCtoMCD: 0.42237789305354706
# cumulative samples: 210045 nsaminput 2601
# year 2013 month 6 path 101 row 16
# fracAreaMCD15: 0.0
# year 2013 month 6 path 101 row 23
# year 2013 month 6 path 101 row 55
# fracAreaMCD15: 0.0
# year 2013 month 6 path 101 row 71
# fracAreaMCD15: 0.5750140073523938
# fracAreaLCtoMCD: 0.5720104662175644
# cumulative samples: 213725 nsaminput 3680
# year 2013 month 6 path 101 row 72
# fracAreaMCD15: 0.7092408370443862
# fracAreaLCtoMCD: 0.7029347636280536
# cumulative samples: 218103 nsaminput 4378
# year 2013 month 6 path 101 row 73
# fracAreaMCD15: 0.5667441886174995
# fracAreaLCtoMCD: 0.5671087437157032
# cumulative samples: 221107 nsaminput 3004
# year 2013 month 6 path 101 row 74
# fracAreaMCD15: 0.24262251412388386
# year 2013 month 6 path 102 row 72
# fracAreaMCD15: 0.42887687413958486
# fracAreaLCtoMCD: 0.4347335801362076
# cumulative samples: 223211 nsaminput 2104
# year 2013 month 6 path 102 row 73
# fracAreaMCD15: 0.3872829684344667
# fracAreaLCtoMCD: 0.39027694879043057
# cumulative samples: 224431 nsaminput 1220
# year 2013 month 6 path 102 row 74
# fracAreaMCD15: 0.5511118498964047
# fracAreaLCtoMCD: 0.5409163569762282
# cumulative samples: 226389 nsaminput 1958
# year 2013 month 6 path 102 row 75
# fracAreaMCD15: 0.7177139945959048
# fracAreaLCtoMCD: 0.7023773124127303
# cumulative samples: 228754 nsaminput 2365
# year 2013 month 6 path 102 row 76
# fracAreaMCD15: 0.27455090667469856
# fracAreaLCtoMCD: 0.26645713082405176
# cumulative samples: 229036 nsaminput 282
# year 2013 month 6 path 102 row 81
# fracAreaMCD15: 0.022874334512194915
# year 2013 month 6 path 103 row 70
# fracAreaMCD15: 0.13451365320077271
# year 2013 month 6 path 103 row 71
# fracAreaMCD15: 0.48250627855319717
# fracAreaLCtoMCD: 0.47344622394544644
# cumulative samples: 231689 nsaminput 2653
# year 2013 month 6 path 103 row 72
# fracAreaMCD15: 0.23606253949846406
# year 2013 month 6 path 103 row 73
# fracAreaMCD15: 0.6049990290049551
# fracAreaLCtoMCD: 0.6020116988549064
# cumulative samples: 235561 nsaminput 3872
# year 2013 month 6 path 103 row 74
# fracAreaMCD15: 0.20767581833654652
# year 2013 month 6 path 103 row 75
# fracAreaMCD15: 0.3721957327140605
# fracAreaLCtoMCD: 0.3695052287833779
# cumulative samples: 237943 nsaminput 2382
# year 2013 month 6 path 104 row 11
# fracAreaMCD15: 0.07700924750391308
# year 2013 month 6 path 104 row 12
# fracAreaMCD15: 0.2092734344079889
# year 2013 month 6 path 104 row 75
# fracAreaMCD15: 0.1756352314497072
# year 2013 month 6 path 105 row 11
# fracAreaMCD15: 0.0
# year 2013 month 6 path 105 row 69
# fracAreaMCD15: 0.17753502408978195
# year 2013 month 6 path 105 row 70
# fracAreaMCD15: 0.4082761502399018
# fracAreaLCtoMCD: 0.3579214066340861
# cumulative samples: 240249 nsaminput 2306
# year 2013 month 6 path 105 row 71
# year 2013 month 6 path 105 row 72
# fracAreaMCD15: 0.3585610724855285
# fracAreaLCtoMCD: 0.3573663672185177
# cumulative samples: 242514 nsaminput 2265
# year 2013 month 6 path 105 row 73
# fracAreaMCD15: 0.2113431140434622
# year 2013 month 6 path 105 row 74
# fracAreaMCD15: 0.0
# year 2013 month 6 path 106 row 12
# fracAreaMCD15: 0.22042220618674427
# year 2013 month 6 path 106 row 32
# fracAreaMCD15: 0.00019627385228847047
# year 2013 month 6 path 106 row 80
# fracAreaMCD15: 0.3981558255052402
# fracAreaLCtoMCD: 0.36394930323161667
# cumulative samples: 244845 nsaminput 2331
# year 2013 month 6 path 106 row 81
# fracAreaMCD15: 0.0579713635955606
# year 2013 month 6 path 106 row 82
# fracAreaMCD15: 0.10201618568074558
# year 2013 month 6 path 107 row 14
# fracAreaMCD15: 0.24142865618237005
# year 2013 month 6 path 107 row 15
# fracAreaMCD15: 0.0
# year 2013 month 6 path 107 row 16
# fracAreaMCD15: 0.010284865838434073
# year 2013 month 6 path 107 row 17
# fracAreaMCD15: 0.008432523470846413
# year 2013 month 6 path 107 row 18
# fracAreaMCD15: 0.0032634660699514717
# year 2013 month 6 path 107 row 70
# fracAreaMCD15: 0.0
# year 2013 month 6 path 107 row 71
# fracAreaMCD15: 0.5226221818612828
# fracAreaLCtoMCD: 0.5227057190358458
# cumulative samples: 248190 nsaminput 3345
# year 2013 month 6 path 107 row 72
# fracAreaMCD15: 0.7283343228675202
# fracAreaLCtoMCD: 0.7049442746882356
# cumulative samples: 248895 nsaminput 705
# year 2013 month 6 path 107 row 73
# fracAreaMCD15: 0.7521773033213713
# fracAreaLCtoMCD: 0.7495664477572874
# cumulative samples: 253672 nsaminput 4777
# year 2013 month 6 path 107 row 74
# fracAreaMCD15: 0.6073744558260638
# fracAreaLCtoMCD: 0.5936037180589591
# cumulative samples: 254959 nsaminput 1287
# year 2013 month 6 path 107 row 75
# fracAreaMCD15: 0.4299205096867638
# fracAreaLCtoMCD: 0.43329646368981806
# cumulative samples: 256217 nsaminput 1258
# year 2013 month 6 path 107 row 76
# fracAreaMCD15: 0.39988316870351914
# fracAreaLCtoMCD: 0.4098131058334882
# cumulative samples: 258776 nsaminput 2559
# year 2013 month 6 path 107 row 77
# fracAreaMCD15: 0.4469988679237571
# fracAreaLCtoMCD: 0.4454916252019556
# cumulative samples: 261111 nsaminput 2335
# year 2013 month 6 path 107 row 78
# fracAreaMCD15: 0.1322131587417759
# year 2013 month 6 path 107 row 79
# fracAreaMCD15: 0.09096818118909915
# year 2013 month 6 path 108 row 15
# year 2013 month 6 path 108 row 30
# fracAreaMCD15: 0.04527828254519111
# year 2013 month 6 path 108 row 31
# fracAreaMCD15: 0.03797609670916734
# year 2013 month 6 path 108 row 32
# year 2013 month 6 path 108 row 33
# fracAreaMCD15: 0.10046115945873552
# year 2013 month 6 path 108 row 34
# fracAreaMCD15: 0.08848590439399683
# year 2013 month 6 path 108 row 70
# fracAreaMCD15: 0.0
# year 2013 month 6 path 108 row 71
# year 2013 month 6 path 109 row 69
# fracAreaMCD15: 0.0
# year 2013 month 6 path 109 row 70
# fracAreaMCD15: 0.1647906526929745
# year 2013 month 6 path 109 row 71
# fracAreaMCD15: 0.6372711995095741
# fracAreaLCtoMCD: 0.6263312608570808
# cumulative samples: 262136 nsaminput 1025
# year 2013 month 6 path 109 row 72
# fracAreaMCD15: 0.5128756928386662
# fracAreaLCtoMCD: 0.5141348370020625
# cumulative samples: 265418 nsaminput 3282
# year 2013 month 6 path 109 row 73
# fracAreaMCD15: 0.5936267884602952
# fracAreaLCtoMCD: 0.5923677952845956
# cumulative samples: 269046 nsaminput 3628
# year 2013 month 6 path 109 row 74
# fracAreaMCD15: 0.44555759428558434
# fracAreaLCtoMCD: 0.44537065822096766
# cumulative samples: 271877 nsaminput 2831
# year 2013 month 6 path 109 row 75
# fracAreaMCD15: 0.5481288882763129
# fracAreaLCtoMCD: 0.526191822227267
# cumulative samples: 272125 nsaminput 248
# year 2013 month 6 path 109 row 76
# fracAreaMCD15: 0.3673640597514012
# fracAreaLCtoMCD: 0.3547989283084199
# cumulative samples: 272278 nsaminput 153
# year 2013 month 6 path 109 row 77
# fracAreaMCD15: 0.16958806419518177
# year 2013 month 6 path 109 row 78
# fracAreaMCD15: 0.0
# year 2013 month 6 path 109 row 79
# fracAreaMCD15: 0.08027424598993735
# year 2013 month 6 path 109 row 80
# fracAreaMCD15: 0.1485604535674815
# year 2013 month 6 path 110 row 27
# year 2013 month 6 path 110 row 70
# year 2013 month 6 path 111 row 29
# year 2013 month 6 path 111 row 42
# fracAreaMCD15: 0.0
# year 2013 month 6 path 111 row 60
# fracAreaMCD15: 0.0
# year 2013 month 6 path 111 row 67
# fracAreaMCD15: 0.09828142504161251
# year 2013 month 6 path 111 row 68
# fracAreaMCD15: 0.0
# year 2013 month 6 path 111 row 69
# fracAreaMCD15: 0.0
# year 2013 month 6 path 111 row 71
# fracAreaMCD15: 0.0
# year 2013 month 6 path 111 row 72
# fracAreaMCD15: 0.0
# year 2013 month 6 path 111 row 74
# fracAreaMCD15: 0.07312839208614309
# year 2013 month 6 path 111 row 75
# fracAreaMCD15: 0.1126067966419663
# ...
# cumulative samples: 1470950 nsaminput 2282
# year 2013 month 7 path 159 row 72
# fracAreaMCD15: 0.1396316309777163
# year 2013 month 7 path 159 row 73
# fracAreaMCD15: 0.10139379622900443
# year 2013 month 7 path 159 row 74
# fracAreaMCD15: 0.2285956868642963
# year 2013 month 7 path 160 row 30
# fracAreaMCD15: 0.21758791565580748
# year 2013 month 7 path 160 row 31
# fracAreaMCD15: 0.18256459061687058
# year 2013 month 7 path 160 row 32
# fracAreaMCD15: 0.0014065877819536131
# year 2013 month 7 path 160 row 33
# fracAreaMCD15: 0.14545066766855508
# year 2013 month 7 path 160 row 34
# fracAreaMCD15: 0.33583362639501396
# fracAreaLCtoMCD: 0.3297820683320775
# cumulative samples: 1471377 nsaminput 427
# year 2013 month 7 path 160 row 35
# fracAreaMCD15: 0.23890370785868545
# year 2013 month 7 path 160 row 36
# fracAreaMCD15: 0.35304802713365846
# fracAreaLCtoMCD: 0.34211159555407866
# cumulative samples: 1472008 nsaminput 631
# year 2013 month 7 path 160 row 37
# fracAreaMCD15: 0.0
# year 2013 month 7 path 160 row 38
# fracAreaMCD15: 0.00031129962946070135
# year 2013 month 7 path 160 row 39
# fracAreaMCD15: 0.09583719571279459
# year 2013 month 7 path 160 row 40
# fracAreaMCD15: 0.0014066990930613889
# year 2013 month 7 path 160 row 41
# fracAreaMCD15: 0.00015626645808968835
# year 2013 month 7 path 160 row 42
# fracAreaMCD15: 0.0
# year 2013 month 7 path 160 row 43
# fracAreaMCD15: 0.0
# year 2013 month 7 path 160 row 44
# fracAreaMCD15: 0.0
# year 2013 month 7 path 160 row 45
# fracAreaMCD15: 0.0
# year 2013 month 7 path 160 row 46
# fracAreaMCD15: 0.0
# year 2013 month 7 path 160 row 47
# fracAreaMCD15: 0.0
# year 2013 month 7 path 160 row 53
# fracAreaMCD15: 0.0
# year 2013 month 7 path 160 row 70
# fracAreaMCD15: 0.2262545347348393
# year 2013 month 7 path 160 row 71
# fracAreaMCD15: 0.4402256780914859
# fracAreaLCtoMCD: 0.43522625580139235
# cumulative samples: 1472111 nsaminput 103
# year 2013 month 7 path 160 row 72
# fracAreaMCD15: 0.6098899717070154
# fracAreaLCtoMCD: 0.6142485270123501
# cumulative samples: 1475836 nsaminput 3725
# year 2013 month 7 path 160 row 73
# fracAreaMCD15: 0.6276590961838295
# fracAreaLCtoMCD: 0.6235994284126974
# cumulative samples: 1479853 nsaminput 4017
# year 2013 month 7 path 160 row 74
# fracAreaMCD15: 0.29763140501720514
# fracAreaLCtoMCD: 0.302922132065476
# cumulative samples: 1481758 nsaminput 1905
# year 2013 month 7 path 160 row 75
# fracAreaMCD15: 0.4763863159992465
# fracAreaLCtoMCD: 0.458560483089446
# cumulative samples: 1482582 nsaminput 824
# year 2013 month 7 path 160 row 76
# fracAreaMCD15: 0.5482929601806178
# fracAreaLCtoMCD: 0.5541143841891886
# cumulative samples: 1486091 nsaminput 3509
# year 2013 month 7 path 160 row 77
# fracAreaMCD15: 0.5862366408763642
# fracAreaLCtoMCD: 0.5057498665839582
# cumulative samples: 1486188 nsaminput 97
# year 2013 month 7 path 160 row 78
# fracAreaMCD15: 0.0
# year 2013 month 7 path 161 row 7
# fracAreaMCD15: 0.00798030843063415
# year 2013 month 7 path 161 row 8
# year 2013 month 7 path 161 row 9
# fracAreaMCD15: 0.25077310803283637
# fracAreaLCtoMCD: 0.2534324255102792
# cumulative samples: 1486192 nsaminput 4
# year 2013 month 7 path 161 row 10
# fracAreaMCD15: 0.12531868023829265
# year 2013 month 7 path 161 row 11
# fracAreaMCD15: 0.13642957454841784
# year 2013 month 7 path 161 row 12
# fracAreaMCD15: 0.2790525446859586
# fracAreaLCtoMCD: 0.26899478456325276
# cumulative samples: 1486389 nsaminput 197
# year 2013 month 7 path 161 row 14
# fracAreaMCD15: 0.19579842603104491
# year 2013 month 7 path 161 row 15
# fracAreaMCD15: 0.2056340000107115
# year 2013 month 7 path 161 row 24
# fracAreaMCD15: 0.133777376495273
# year 2013 month 7 path 161 row 26
# fracAreaMCD15: 0.10595686042245878
# year 2013 month 7 path 161 row 27
# fracAreaMCD15: 0.2014075033583912
# year 2013 month 7 path 161 row 34
# fracAreaMCD15: 0.43624673547804504
# fracAreaLCtoMCD: 0.3306016127691419
# cumulative samples: 1488490 nsaminput 2101
# year 2013 month 7 path 161 row 35
# fracAreaMCD15: 0.04258271492250698
# year 2013 month 7 path 161 row 36
# fracAreaMCD15: 0.05467145557317912
# year 2013 month 7 path 161 row 37
# fracAreaMCD15: 0.0
# year 2013 month 7 path 161 row 38
# fracAreaMCD15: 0.005770615884030691
# year 2013 month 7 path 161 row 39
# fracAreaMCD15: 0.00018089057529259062
# year 2013 month 7 path 161 row 40
# fracAreaMCD15: 0.21544879071512468
# year 2013 month 7 path 161 row 42
# fracAreaMCD15: 0.0
# year 2013 month 7 path 161 row 43
# fracAreaMCD15: 0.0
# year 2013 month 7 path 161 row 47
# fracAreaMCD15: 0.0
# year 2013 month 7 path 161 row 50
# year 2013 month 7 path 161 row 53
# fracAreaMCD15: 0.00015626388749474853
# year 2013 month 7 path 161 row 55
# fracAreaMCD15: 0.0014063796801576883
# year 2013 month 7 path 161 row 56
# year 2013 month 7 path 161 row 73
# fracAreaMCD15: 0.0
# year 2013 month 7 path 161 row 74
# fracAreaMCD15: 0.0
# year 2013 month 7 path 161 row 75
# fracAreaMCD15: 0.50590242752348
# fracAreaLCtoMCD: 0.48622468821100423
# cumulative samples: 1488620 nsaminput 130
# year 2013 month 7 path 161 row 76
# fracAreaMCD15: 0.0
# year 2013 month 7 path 163 row 24
# fracAreaMCD15: 0.0
# year 2013 month 7 path 163 row 27
# fracAreaMCD15: 0.10554883224892439
# year 2013 month 7 path 163 row 28
# fracAreaMCD15: 0.43201998884737763
# fracAreaLCtoMCD: 0.43379043038565646
# cumulative samples: 1490495 nsaminput 1875
# year 2013 month 7 path 163 row 29
# fracAreaMCD15: 0.4401704240360603
# fracAreaLCtoMCD: 0.44259611833956325
# cumulative samples: 1493312 nsaminput 2817
# year 2013 month 7 path 163 row 30
# fracAreaMCD15: 0.1337741581821405
# year 2013 month 7 path 163 row 31
# fracAreaMCD15: 0.0
# year 2013 month 7 path 163 row 34
# fracAreaMCD15: 0.0
# year 2013 month 7 path 163 row 35
# fracAreaMCD15: 0.10968530046755302
# year 2013 month 7 path 163 row 36
# fracAreaMCD15: 0.0
# year 2013 month 7 path 163 row 37
# fracAreaMCD15: 0.09764115059022278
# year 2013 month 7 path 163 row 38
# fracAreaMCD15: 0.03009193991926059
# year 2013 month 7 path 163 row 39
# fracAreaMCD15: 0.519055595213923
# fracAreaLCtoMCD: 0.509823918800814
# cumulative samples: 1496634 nsaminput 3322
# year 2013 month 7 path 163 row 40
# fracAreaMCD15: 0.018371722881896153
# year 2013 month 7 path 163 row 41
# fracAreaMCD15: 0.0
# year 2013 month 7 path 163 row 43
# fracAreaMCD15: 0.0
# year 2013 month 7 path 163 row 52
# fracAreaMCD15: 0.0
# year 2013 month 7 path 164 row 25
# fracAreaMCD15: 0.08005392302826914
# year 2013 month 7 path 164 row 30
# fracAreaMCD15: 0.1589186359777224
# year 2013 month 7 path 164 row 31
# fracAreaMCD15: 0.355698976159138
# fracAreaLCtoMCD: 0.3455258182030497
# cumulative samples: 1498773 nsaminput 2139
# year 2013 month 7 path 164 row 32
# fracAreaMCD15: 0.0003125626301058193
# year 2013 month 7 path 164 row 33
# fracAreaMCD15: 0.0
# year 2013 month 7 path 164 row 34
# fracAreaMCD15: 0.001178206482425525
# year 2013 month 7 path 164 row 36
# fracAreaMCD15: 0.27893704345967163
# fracAreaLCtoMCD: 0.2703146513266075
# cumulative samples: 1499642 nsaminput 869
# year 2013 month 7 path 164 row 37
# fracAreaMCD15: 0.025319501169430648
# year 2013 month 7 path 164 row 38
# fracAreaMCD15: 0.3375569649265598
# fracAreaLCtoMCD: 0.3470335750646806
# cumulative samples: 1501796 nsaminput 2154
# year 2013 month 7 path 164 row 39
# fracAreaMCD15: 0.0
# year 2013 month 7 path 164 row 40
# fracAreaMCD15: 0.00031253396368124346
# year 2013 month 7 path 164 row 41
# fracAreaMCD15: 0.0
# year 2013 month 7 path 164 row 42
# fracAreaMCD15: 0.0
# year 2013 month 7 path 164 row 43
# fracAreaMCD15: 0.0
# year 2013 month 7 path 164 row 44
# fracAreaMCD15: 0.0
# year 2013 month 7 path 164 row 45
# fracAreaMCD15: 0.0
# year 2013 month 7 path 164 row 46
# fracAreaMCD15: 0.0
# year 2013 month 7 path 164 row 47
# fracAreaMCD15: 0.0
# year 2013 month 7 path 164 row 48
# fracAreaMCD15: 0.0
# year 2013 month 7 path 164 row 67
# fracAreaMCD15: 0.0
# year 2013 month 7 path 164 row 68
# year 2013 month 7 path 164 row 69
# fracAreaMCD15: 0.19371554618742629
# year 2013 month 7 path 164 row 70
# fracAreaMCD15: 0.4043184173208506
# fracAreaLCtoMCD: 0.38096570520781464
# cumulative samples: 1501912 nsaminput 116
# year 2013 month 7 path 165 row 16
# fracAreaMCD15: 0.07259868745587351
# year 2013 month 7 path 165 row 17
# fracAreaMCD15: 0.3807615326902968
# fracAreaLCtoMCD: 0.364027801937925
# cumulative samples: 1502378 nsaminput 466
# year 2013 month 7 path 165 row 18
# fracAreaMCD15: 0.19173011174216772
# year 2013 month 7 path 165 row 36
# fracAreaMCD15: 0.4020285448052222
# fracAreaLCtoMCD: 0.4002540401983754
# cumulative samples: 1504951 nsaminput 2573
# year 2013 month 7 path 165 row 37
# fracAreaMCD15: 0.4926455784589852
# fracAreaLCtoMCD: 0.4922659085223095
# cumulative samples: 1508104 nsaminput 3153
# year 2013 month 7 path 165 row 38
# fracAreaMCD15: 0.03093997807358589
# year 2013 month 7 path 165 row 39
# fracAreaMCD15: 0.003524278023168254
# year 2013 month 7 path 165 row 40
# fracAreaMCD15: 0.0
# year 2013 month 7 path 165 row 41
# fracAreaMCD15: 0.0
# year 2013 month 7 path 165 row 42
# fracAreaMCD15: 0.0
# year 2013 month 7 path 165 row 43
# fracAreaMCD15: 0.0
# year 2013 month 7 path 165 row 44
# fracAreaMCD15: 0.0
# year 2013 month 7 path 165 row 45
# fracAreaMCD15: 0.0
# year 2013 month 7 path 165 row 46
# fracAreaMCD15: 0.0
# year 2013 month 7 path 165 row 47
# fracAreaMCD15: 0.0
# year 2013 month 7 path 165 row 48
# year 2013 month 7 path 165 row 49
# fracAreaMCD15: 0.0
# year 2013 month 7 path 165 row 50
# fracAreaMCD15: 0.0
# year 2013 month 7 path 165 row 51
# fracAreaMCD15: 0.00015626285293042063
# year 2013 month 7 path 165 row 52
# year 2013 month 7 path 165 row 54
# fracAreaMCD15: 0.0020340741050048315
# year 2013 month 7 path 165 row 57
# fracAreaMCD15: 0.0
# year 2013 month 7 path 165 row 72
# fracAreaMCD15: 0.0
# year 2013 month 7 path 166 row 35
# year 2013 month 7 path 166 row 36
# fracAreaMCD15: 0.03378678119511989
# year 2013 month 7 path 166 row 37
# fracAreaMCD15: 0.23983451002463893
# year 2013 month 7 path 166 row 38
# fracAreaMCD15: 0.06541302834558517
# year 2013 month 7 path 166 row 39
# fracAreaMCD15: 0.0
# year 2013 month 7 path 166 row 40
# fracAreaMCD15: 0.0
# year 2013 month 7 path 166 row 41
# fracAreaMCD15: 0.0
# year 2013 month 7 path 166 row 42
# fracAreaMCD15: 0.0
# year 2013 month 7 path 166 row 43
# fracAreaMCD15: 0.0
# year 2013 month 7 path 166 row 44
# fracAreaMCD15: 0.0
# year 2013 month 7 path 166 row 45
# fracAreaMCD15: 0.0
# year 2013 month 7 path 166 row 46
# fracAreaMCD15: 0.0
# year 2013 month 7 path 166 row 51
# fracAreaMCD15: 0.0
# year 2013 month 7 path 166 row 53
# year 2013 month 7 path 167 row 11
# fracAreaMCD15: 0.0
# year 2013 month 7 path 167 row 12
# fracAreaMCD15: 0.27365422545912405
# fracAreaLCtoMCD: 0.27234131501668346
# cumulative samples: 1509214 nsaminput 1110
# year 2013 month 7 path 167 row 13
# fracAreaMCD15: 0.49171994828667803
# fracAreaLCtoMCD: 0.4853869529912271
# cumulative samples: 1512070 nsaminput 2856
# year 2013 month 7 path 167 row 14
# fracAreaMCD15: 0.540705540141373
# fracAreaLCtoMCD: 0.5393297201424258
# cumulative samples: 1514955 nsaminput 2885
# year 2013 month 7 path 167 row 15
# fracAreaMCD15: 0.3132819457770425
# fracAreaLCtoMCD: 0.29510213275875574
# cumulative samples: 1516852 nsaminput 1897
# year 2013 month 7 path 167 row 16
# fracAreaMCD15: 0.28328796265878753
# fracAreaLCtoMCD: 0.28136487547261374
# cumulative samples: 1518665 nsaminput 1813
# year 2013 month 7 path 167 row 27
# fracAreaMCD15: 0.05155984759984364
# year 2013 month 7 path 167 row 28
# fracAreaMCD15: 0.0
# year 2013 month 7 path 167 row 35
# fracAreaMCD15: 0.5110277042245888
# fracAreaLCtoMCD: 0.4335009837039725
# cumulative samples: 1518694 nsaminput 29
# year 2013 month 7 path 167 row 36
# fracAreaMCD15: 0.5549997862977456
# fracAreaLCtoMCD: 0.5505787768708295
# cumulative samples: 1522236 nsaminput 3542
# year 2013 month 7 path 167 row 37
# fracAreaMCD15: 0.013750110667539108
# year 2013 month 7 path 167 row 38
# fracAreaMCD15: 0.009460996739181306
# year 2013 month 7 path 167 row 39
# fracAreaMCD15: 0.0007813194017022625
# year 2013 month 7 path 167 row 40
# fracAreaMCD15: 0.0
# year 2013 month 7 path 167 row 41
# fracAreaMCD15: 0.0
# year 2013 month 7 path 167 row 42
# fracAreaMCD15: 0.0
# year 2013 month 7 path 167 row 43
# fracAreaMCD15: 0.0
# year 2013 month 7 path 167 row 44
# fracAreaMCD15: 0.0
# year 2013 month 7 path 167 row 45
# fracAreaMCD15: 0.0
# year 2013 month 7 path 167 row 46
# fracAreaMCD15: 0.0
# year 2013 month 7 path 167 row 47
# fracAreaMCD15: 0.024687037696641528
# year 2013 month 7 path 167 row 48
# fracAreaMCD15: 0.013282369963967207
# year 2013 month 7 path 167 row 49
# fracAreaMCD15: 0.02617956562165145
# year 2013 month 7 path 167 row 52
# year 2013 month 7 path 167 row 71
# fracAreaMCD15: 0.45999956643036743
# fracAreaLCtoMCD: 0.4417626701118588
# cumulative samples: 1525084 nsaminput 2848
# year 2013 month 7 path 167 row 72
# fracAreaMCD15: 0.3321232394970079
# fracAreaLCtoMCD: 0.2844361577992519
# cumulative samples: 1525177 nsaminput 93
# year 2013 month 7 path 167 row 73
# fracAreaMCD15: 0.15015630606330077
# year 2013 month 7 path 167 row 76
# fracAreaMCD15: 0.0031917384468248588
# year 2013 month 7 path 167 row 77
# fracAreaMCD15: 0.0
# year 2013 month 7 path 167 row 78
# fracAreaMCD15: 0.0024943128517341874
# year 2013 month 7 path 167 row 79
# fracAreaMCD15: 0.0
# year 2013 month 7 path 167 row 80
# year 2013 month 7 path 168 row 26
# fracAreaMCD15: 5.1501717077709284e-05
# year 2013 month 7 path 168 row 27
# fracAreaMCD15: 0.2602954359729293
# fracAreaLCtoMCD: 0.2554357052291228
# cumulative samples: 1526842 nsaminput 1665
# year 2013 month 7 path 168 row 28
# fracAreaMCD15: 0.10922921028953074
# year 2013 month 7 path 168 row 30
# year 2013 month 7 path 168 row 33
# fracAreaMCD15: 0.38919459351756547
# fracAreaLCtoMCD: 0.38831273274629347
# cumulative samples: 1529333 nsaminput 2491
# year 2013 month 7 path 168 row 34
# fracAreaMCD15: 0.34750200748944826
# fracAreaLCtoMCD: 0.33944406129960963
# cumulative samples: 1530265 nsaminput 932
# year 2013 month 7 path 168 row 35
# fracAreaMCD15: 0.7273204621452106
# fracAreaLCtoMCD: 0.7228637896393235
# cumulative samples: 1534709 nsaminput 4444
# year 2013 month 7 path 168 row 36
# fracAreaMCD15: 0.23455285047754354
# year 2013 month 7 path 168 row 37
# fracAreaMCD15: 0.25125223840994987
# fracAreaLCtoMCD: 0.24934089408909668
# cumulative samples: 1536317 nsaminput 1608
# year 2013 month 7 path 168 row 38
# fracAreaMCD15: 0.0
# year 2013 month 7 path 168 row 39
# fracAreaMCD15: 0.0
# year 2013 month 7 path 168 row 40
# fracAreaMCD15: 0.0
# year 2013 month 7 path 168 row 41
# fracAreaMCD15: 0.0
# year 2013 month 7 path 168 row 42
# fracAreaMCD15: 0.0020313207425455256
# year 2013 month 7 path 168 row 45
# year 2013 month 7 path 168 row 47
# fracAreaMCD15: 0.047814792339885254
# year 2013 month 7 path 168 row 63
# fracAreaMCD15: 0.34467031487297317
# fracAreaLCtoMCD: 0.3407360751793466
# cumulative samples: 1538491 nsaminput 2174
# year 2013 month 7 path 168 row 64
# fracAreaMCD15: 0.8316191493206501
# fracAreaLCtoMCD: 0.8186068192528843
# cumulative samples: 1541003 nsaminput 2512
# year 2013 month 7 path 168 row 65
# fracAreaMCD15: 0.8459264333268439
# fracAreaLCtoMCD: 0.8419418778760392
# cumulative samples: 1544787 nsaminput 3784
# year 2013 month 7 path 168 row 66
# fracAreaMCD15: 0.8067182249690722
# fracAreaLCtoMCD: 0.804508761282993
# cumulative samples: 1549947 nsaminput 5160
# year 2013 month 7 path 168 row 75
# fracAreaMCD15: 0.6229000579378171
# fracAreaLCtoMCD: 0.3535913167897123
# cumulative samples: 1549990 nsaminput 43
# year 2013 month 7 path 169 row 2
# fracAreaMCD15: 0.0
# year 2013 month 7 path 169 row 8
# fracAreaMCD15: 0.0
# year 2013 month 7 path 169 row 11
# fracAreaMCD15: 0.0
# year 2013 month 7 path 169 row 15
# fracAreaMCD15: 0.38250145621518983
# fracAreaLCtoMCD: 0.38302728827243204
# cumulative samples: 1552438 nsaminput 2448
# year 2013 month 7 path 169 row 16
# fracAreaMCD15: 0.603329023169082
# fracAreaLCtoMCD: 0.5953038357467024
# cumulative samples: 1554646 nsaminput 2208
# year 2013 month 7 path 169 row 17
# fracAreaMCD15: 0.6374111984401621
# fracAreaLCtoMCD: 0.615179273800529
# cumulative samples: 1556353 nsaminput 1707
# year 2013 month 7 path 169 row 18
# fracAreaMCD15: 0.43944498413668165
# fracAreaLCtoMCD: 0.43035739748511526
# cumulative samples: 1556564 nsaminput 211
# year 2013 month 7 path 169 row 19
# fracAreaMCD15: 0.4427246656028746
# fracAreaLCtoMCD: 0.37014893968130763
# cumulative samples: 1557148 nsaminput 584
# year 2013 month 7 path 169 row 20
# fracAreaMCD15: 0.355533993064118
# fracAreaLCtoMCD: 0.35324976448688006
# cumulative samples: 1557500 nsaminput 352
# year 2013 month 7 path 169 row 21
# fracAreaMCD15: 0.417981109262953
# fracAreaLCtoMCD: 0.410190421879694
