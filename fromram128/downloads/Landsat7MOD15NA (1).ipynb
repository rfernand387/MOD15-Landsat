# %%
import ee
import numpy as np
import pandas as pd
import pickle
import datetime

# %%
ee.Authenticate()
# Out:
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://accounts.google.com/o/oauth2/auth?client_id=517222506229-vsmmajv00ul0bs7p89v5m89qs8eb9359.apps.googleusercontent.com&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fearthengine+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdevstorage.full_control&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&response_type=code&code_challenge=-C7znDQhYJ6yzKBg2LI8slZ7c8YJ6BPfHlvce3LtSeo&code_challenge_method=S256>https://accounts.google.com/o/oauth2/auth?client_id=517222506229-vsmmajv00ul0bs7p89v5m89qs8eb9359.apps.googleusercontent.com&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fearthengine+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdevstorage.full_control&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&response_type=code&code_challenge=-C7znDQhYJ6yzKBg2LI8slZ7c8YJ6BPfHlvce3LtSeo&code_challenge_method=S256</a></p>
#         <p>The authorization workflow will generate a code, which you
#         should paste in the box below</p>
# Enter verification code:  4/1AX4XfWjOla0aggoxBUmdDmadlWZW2enpRDNLz3s-76YtCPThsnhhVjR5eZE
# Successfully saved authorization token.

# %%
ee.Initialize()

# %%
# sampling paramaters
randomSeed = 109
collectionLandsatL1c = "LANDSAT/LC08/C02/T1_TOA" # landsat image collection
collectionLandsatL2a= "LANDSAT/LC08/C02/T1_L2" # landsat image collection
cloudCoverL0X = 10# maximum cloud cover of sampled Landsat images
maxSample = 10000 # maximum samples to extract from each Landsat image
outputScale = 500 # scale of output comparisons , increasing this will eventually exceed memory
subimageSize = 40000 # m dimension of subimage we will randomly extract from Landsat image to avoid memory limits
minfracAreaLC = 0.5 # minimum cloud free valid  Landsat subimage fraction
minfracAreaMCD15 = 0.25 # minimum cloud free valid MODIS area in Landsat subimage fraction's unmasked area
minfracAreaLCtoMCD = 0.10 # valid aggregated landsat fraction
minfracValidLC = 0.9 # minimum facation of valid landsat pixels in each aggregated modis pixels to estimate mean values
deltaRow = 1  # skip this many WRS rows when sampling Landsat scenes
deltaPath = 1 # skip this many WRS paths when sampling Landsat scenes
deltaDay = 15 # search this many contiguous days when looking for a cloud free Landsat scene
maxPixels = 300 # max landsat pixels allowed to be aggregated in an output pixel, should be about 20% larger than the ratio of (outputScale/30) (cannot exceed 1024)

#output files
InputFileNameB36 = '/home/richard_fernandes/LUTinputLC0XB36calv9'
InputFileNameB45 = '/home/richard_fernandes/LUTinputLC0XB45calv9'
InputFileNameMOD09 = '/home/richard_fernandes/LUTinputMOD09calv9'
InputFileNameMOD09bands = '/home/richard_fernandes/LUTinputMOD09bandscalv9'
InputFileNameLat = '/home/richard_fernandes/LUTinputLC0XLatcalv9'
InputFileNameLon = '/home/richard_fernandes/LUTinputLC0XLoncalv9'
OutputFileName = '/home/richard_fernandes/LUToutputLC0Xcalv9'
YearFileName = '/home/richard_fernandes/YearLC0Xcalv9'
MonthFileName = '/home/richard_fernandes/MonthLC0Xcalv9'
DayFileName = '/home/richard_fernandes/DayLC0Xcalv9'
PathFileName = '/home/richard_fernandes/PathLC0Xcalv9'
RowFileName = '/home/richard_fernandes/RowLC0Xcalv9'
FparLai_QCName = '/home/richard_fernandes/FparLai_QCcalv9'
FparExtra_QCName = '/home/richard_fernandes/FparExtra_QCcalv9'

# %%
# Match MOD09A1.006 daily reflectance data and MCD12Q1 annual biome type to  MCD15A3H.006 image composite
# masking any dates without exactly one MOD09A1 valid clear sky value and one valid MCD153AH terra retrieval
def matchMOD09A1toMCD15(imageMCD15):
    
    # get date range of MCD15A3Himage
    d1 = ee.Date(imageMCD15.get('system:time_start'));
    d2 = ee.Date(imageMCD15.get('system:time_end'));
    
#    print(d1.getInfo())
#    print(d2.getInfo())
    # find MOD09A1 products within date range of MCD15 and mask them 
    colMOD09A1 = ee.ImageCollection("MODIS/006/MOD09GA").filterDate(d1,d2).map(lambda image: image.updateMask(image.select('QC_500m').bitwiseAnd(1<<1).eq(0)) \
                                                                                                  .updateMask(image.select('state_1km').bitwiseAnd(1<<0).eq(0)) \
                                                                                                  .updateMask(image.select('state_1km').bitwiseAnd(1<<1).eq(0)) \
                                                                                                  .updateMask(image.select('state_1km').bitwiseAnd(1<<2).eq(0)) \
                                                                                                  .addBands(image.select('sur_refl_b02').divide(image.select('sur_refl_b01').add(1)).rename('SR_VI')))
                                                                                                 # .updateMask(image.select('state_1km').bitwiseAnd(1<<3).eq(1)) )
                                                                                                #  .updateMask(image.select('state_1km').bitwiseAnd(1<<4).eq(0)) \
                                                                                                #   .updateMask(image.select('state_1km').bitwiseAnd(1<<5).eq(0)) \
                                                                                               #   .updateMask(image.select('state_1km').bitwiseAnd(1<<6).gt(-1)) \
                                                                                              #    .updateMask(image.select('state_1km').bitwiseAnd(1<<7).eq(0)) \
                                                                                                #  .updateMask(image.select('state_1km').bitwiseAnd(1<<8).eq(8)) \
                                                                                                #  .updateMask(image.select('state_1km').bitwiseAnd(1<<9).eq(0)) \
                                                                                               #   .updateMask(image.select('state_1km').bitwiseAnd(1<<10).eq(0)) \
                                                                                                #  .updateMask(image.select('state_1km').bitwiseAnd(1<<11).eq(1)) \
                                                                                                 # .updateMask(image.select('state_1km').bitwiseAnd(1<<12).eq(0)) \
                                                                                                 # .updateMask(image.select('state_1km').bitwiseAnd(1<<13).eq(0)) \
                                                                                                 # .updateMask(image.select('state_1km').bitwiseAnd(1<<14).eq(0)) \
                                                                                                 # .updateMask(image.select('state_1km').bitwiseAnd(1<<15).eq(0)))
    #    print(colMOD09A1.size().getInfo())
    # get biome type map
    imageMCD12Q1 = ee.ImageCollection("MODIS/006/MCD12Q1").map(lambda image: image.set('daterange',ee.DateRange(ee.Date(image.get('system:time_start')),ee.Date(image.get('system:time_end')))))\
                                                            .filter(ee.Filter.dateRangeContains('daterange', d1)) \
                                                            .first() \
                                                            .select('LC_Type3') 
#    print(imageMCD12Q1.getInfo())

# make mask of pixels containing only one valid cloud free MOD09 500m retrieval
    # and a primary algorithm retyrieval from terra wigthout significant clouds
    # and add MOD09A1 composite created by apply the MCD15 mask to the MOOD9A1 collection and composite it
    # and add biome type
    imageMCD15 = imageMCD15.updateMask( colMOD09A1.count().select('sur_refl_b01').gt(-1) ) \
                            .updateMask( imageMCD15.select('FparLai_QC').bitwiseAnd(1<<0).eq(0)) \
                            .updateMask( imageMCD15.select('FparLai_QC').bitwiseAnd(1<<1).eq(0)) \
                            .updateMask( imageMCD15.select('FparLai_QC').bitwiseAnd(1<<2).eq(0)) \
                            .updateMask( imageMCD15.select('FparLai_QC').bitwiseAnd(1<<3).eq(0)) \
                            .updateMask( imageMCD15.select('FparLai_QC').bitwiseAnd(1<<4).eq(0)) \
                            .updateMask(imageMCD15.select('FparLai_QC').bitwiseAnd(1<<6).eq(0)) \
                            .updateMask(imageMCD15.select('FparLai_QC').bitwiseAnd(1<<7).eq(0)) \
                            .updateMask(imageMCD15.select('FparExtra_QC').bitwiseAnd(1<<1).eq(0)) \
                            .updateMask( imageMCD12Q1.select('LC_Type3').gt(0)) \
                            .addBands( imageMCD12Q1 )
    imageMCD15 = imageMCD15.addBands(colMOD09A1.map(lambda image: image.mask(imageMCD15.select('Lai'))).qualityMosaic('SR_VI'))


    
   
    
    
    return imageMCD15

# %%
# coded LUT for output MODIS MCD15
def getLUTout(imageMCD15):
    imageMCD15 = ee.Image(imageMCD15);

    return imageMCD15.select('Lai').min(99).multiply(1).toInt64() \
                        .add(imageMCD15.select('LaiStdDev').min(99).multiply(1e2).toInt64()) \
                        .add(imageMCD15.select('Fpar').min(99).multiply(1e4).toInt64()) \
                        .add(imageMCD15.select('FparStdDev').min(99).multiply(1e6).toInt64()) \
                        .add(imageMCD15.select('satFlag').multiply(100).multiply(1e9).toInt64()) \
                        .add(imageMCD15.select('snowFlag').multiply(100).multiply(1e12).toInt64()) \
                        .add(imageMCD15.select('LC_Type3').multiply(1e14).toInt64()) \
                        .rename('LUTout')

# %%
# Code LUT for an input MOD09 image , same as getLUTin but no satFlag
def getLUTinMOD09(imageMCD15MOD09):
    
     return imageMCD15MOD09.select('sur_refl_b01').add(100).max(0).min(9999).floor().toInt64().multiply(1).toInt64() \
                        .add(imageMCD15MOD09.select('sur_refl_b02').add(100).max(0).min(9999).floor().toInt64().multiply(1e4).toInt64()) \
                        .add(imageMCD15MOD09.select('SolarZenith').multiply(0.01).max(0).min(99).floor().toInt64().multiply(1e8).toInt64()) \
                        .add(imageMCD15MOD09.select('SolarAzimuth').multiply(0.01).add(180).max(0).min(360).floor().toInt64().multiply(1e10).toInt64()) \
                        .add(imageMCD15MOD09.select('SensorZenith').multiply(0.01).max(0).min(99).floor().toInt64().multiply(1e13).toInt64()) \
                        .add(imageMCD15MOD09.select('SensorAzimuth',).multiply(0.01).add(180).max(0).min(360).floor().toInt64().multiply(1e15).toInt64()) \
                        .rename('LUTinMOD09')

# %%
# Code LUT for an input MOD09 image , same as getLUTin but no satFlag
def getLUTinMOD09bands(imageMCD15MOD09):
    
     return imageMCD15MOD09.select('sur_refl_b03').add(100).max(0).min(9999).floor().toInt64().multiply(1).toInt64() \
                        .add(imageMCD15MOD09.select('sur_refl_b04').add(100).max(0).min(9999).floor().toInt64().multiply(1e4).toInt64()) \
                        .add(imageMCD15MOD09.select('sur_refl_b06').add(100).max(0).min(9999).floor().toInt64().multiply(1e8).toInt64()) \
                        .add(imageMCD15MOD09.select('sur_refl_b07').add(100).max(0).min(9999).floor().toInt64().multiply(1e12).toInt64()) \
                        .rename('LUTinMOD09bands')

# %%
# coded LUT for input landsat image red and nir band
def getLUTL0XinB45(imageMCD15):
    imageMCD15 = ee.Image(imageMCD15);
    return imageMCD15.select('SR_B4').multiply(2.75e-05).add(-0.2).max(0).min(0.999).multiply(1000).floor().multiply(1).toInt64() \
                        .add(imageMCD15.select('SR_B5').multiply(2.75e-05).add(-0.2).max(0).min(0.999).multiply(1000).floor().multiply(1e3).toInt64()) \
                        .add(imageMCD15.select('VZA').multiply(0.01).round().multiply(1e6).toInt64()) \
                        .add(imageMCD15.select('VAA').multiply(0.01).add(180).round().multiply(1e8).toInt64()) \
                        .add(imageMCD15.select('SZA').multiply(0.01).round().multiply(1e11).toInt64()) \
                        .add(imageMCD15.select('SAA').multiply(0.01).add(180).round().multiply(1e13).toInt64()) \
                        .rename('LUTL0XinB45')

# %%
# coded LUT for input landsat image green and swir
def getLUTL0XinB36(imageMCD15):
    imageMCD15 = ee.Image(imageMCD15);
    return imageMCD15.select('SR_B3').multiply(2.75e-05).add(-0.2).max(0).min(0.999).multiply(1000).floor().multiply(1).toInt64() \
                        .add(imageMCD15.select('SR_B6').multiply(2.75e-05).add(-0.2).max(0).min(0.999).multiply(1000).floor().multiply(1e3).toInt64()) \
                        .add(imageMCD15.select('VZA').multiply(0.01).round().multiply(1e6).toInt64()) \
                        .add(imageMCD15.select('VAA').multiply(0.01).add(180).round().multiply(1e8).toInt64()) \
                        .add(imageMCD15.select('SZA').multiply(0.01).round().multiply(1e11).toInt64()) \
                        .add(imageMCD15.select('SAA').multiply(0.01).add(180).round().multiply(1e13).toInt64()) \
                        .rename('LUTL0XinB36')

# %%
# sample worldwide 
# check each year and month
cumsam = 0
for year in range(2013,2022):#

        
    # specify land cover projected into MOD15 projection and aggregated using median to outputScale    
    projectionMCD15=  ee.ImageCollection('MODIS/006/MCD15A3H').first().select('Lai').projection()
    projectionMCD12 =  ee.ImageCollection("MODIS/006/MCD12Q1").first().select('LC_Type3').projection()
    imageMCD12Q1 = ee.ImageCollection("MODIS/006/MCD12Q1").filterDate(ee.Date.fromYMD(year,1,1),ee.Date.fromYMD(year,12,31)).first() \
                     .select('LC_Type3') \
                     .reproject(crs= projectionMCD15,crsTransform= None,scale=projectionMCD12.nominalScale() ) \
                     .reduceResolution(reducer= ee.Reducer.median(),maxPixels= 1024,bestEffort=False) \
                     .reproject(crs= projectionMCD15.atScale(outputScale))      

    # sample monthly data
    for month in [6,7,5,8,4,9,3,10,2,11,1,12]:  
        
        #sample WRS path rows
        for path in range(1,70,deltaPath): 
            for row in range(10,40,deltaRow): 
                
                # sample deltaDay intervals of each month
                for daystart in range (1,30-deltaDay,deltaDay):
                    
                    # find Landsat images for paht , row and date interval between 0 and maxCloudCover
                    imageLC = ee.ImageCollection(collectionLandsatL2a).filterMetadata('WRS_PATH','equals',path) \
                                                                          .filterMetadata('WRS_ROW','equals',row) \
                                                                          .filterDate(ee.Date.fromYMD(year,month,daystart),ee.Date.fromYMD(year,month,daystart).advance(deltaDay,'days')) \
                                                                          .filter(ee.Filter.lte('CLOUD_COVER_LAND',cloudCoverL0X))
                    
                    # only proceed if there is at least one filtered landsat image (we will only use the first one found)
                    if (imageLC.size().getInfo() > 0) : 

                        # only sample the first scene we found in the interval of deltaDay's 
                        imageLC = imageLC.first()
                        projectionLC = imageLC.select('QA_PIXEL').projection()
                        
                        # get date range of imageLC and print it out
                        d1 = ee.Date(imageLC.get('system:time_start'))
                        d2 = ee.Date(imageLC.get('system:time_end'))     
                        print('year',year,'month',month,'path',path,'row',row)

                        # get  MOD15 product containing the aquistion of the  Landsat image
                        imageMCD15 = ee.ImageCollection('MODIS/006/MCD15A3H') \
                                                    .map(lambda image: image.set('daterange',ee.DateRange(ee.Date(image.get('system:time_start')),ee.Date(image.get('system:time_end')))))\
                                                    .filter(ee.Filter.dateRangeContains('daterange', d1)) \
                                                    .map(lambda image: matchMOD09A1toMCD15(image) ) 

                        # only proceed if there is a MCD15 product containing the Landsat image aquisition
                        if (imageMCD15.size().getInfo() > 0)  :

                            
                            #randomly sample a sub-image to avoid memory issues, 
                            # add a validPixel we will use to determine aggregation and unmask since we will accept some missing data
                            imageGRID = imageLC.geometry().coveringGrid(projectionMCD15,subimageSize).randomColumn(columnName='randomIndex',seed=randomSeed)                                
                            imageLC = imageLC.addBands(ee.ImageCollection(collectionLandsatL1c) \
                                                                          .filterMetadata('system:index','equals',imageLC.get('system:index')) \
                                                                          .first() \
                                                                          .select(['VZA','VAA','SZA','SAA'])) \
                                             .clip(ee.Feature(imageGRID.sort('randomIndex').first()).geometry()) \
                                             .updateMask(imageLC.select('QA_PIXEL').bitwiseAnd(1<<0).eq(0)) \
                                             .updateMask(imageLC.select('QA_PIXEL').bitwiseAnd(1<<1).eq(0)) \
                                             .updateMask(imageLC.select('QA_PIXEL').bitwiseAnd(1<<2).eq(0)) \
                                             .updateMask(imageLC.select('QA_PIXEL').bitwiseAnd(1<<3).eq(0)) \
                                             .updateMask(imageLC.select('QA_PIXEL').bitwiseAnd(1<<4).eq(0)) 
        
                            
                            # get the fraction of area with unmasked LC data 
                            validArea = ee.Number(ee.Image.pixelArea().mask(imageLC.select('QA_PIXEL').mask()).reduceRegion(reducer=ee.Reducer.sum(),geometry=imageLC.geometry(),scale=30,bestEffort=True).get('area')).getInfo()
                            totalArea = ee.Number(ee.Image.pixelArea().mask(imageLC.select('QA_PIXEL').unmask().mask()).reduceRegion(reducer=ee.Reducer.sum(),geometry=imageLC.geometry(),scale=30,bestEffort=True).get('area')).getInfo()
                            
                            fracAreaLC = 0 
                            if (totalArea > 0) :
                                fracAreaLC = validArea / totalArea
                            #print('fracAreaLC:',fracAreaLC)  

                            # proceed if there is sufficient landsat area
                            if ( fracAreaLC > minfracAreaLC) :
                                                
                                # get MCD15 image from collection, clip to Landsat subimage
                                imageMCD15 = imageMCD15.first().clip(imageLC.geometry()) 
                                                
                                # update mask and add land cover and a saturation flag band
                                imageMCD15 = imageMCD15.updateMask( imageMCD15.select('FparLai_QC').bitwiseAnd(1<<0).eq(0)) \
                                                .updateMask( imageMCD15.select('FparLai_QC').bitwiseAnd(1<<2).eq(0)) \
                                                .updateMask( imageMCD15.select('FparLai_QC').bitwiseAnd(1<<3).eq(0)) \
                                                .updateMask( imageMCD15.select('FparLai_QC').bitwiseAnd(1<<4).eq(0)) \
                                                .updateMask( imageMCD15.select('FparLai_QC').bitwiseAnd(1<<6).eq(0)) \
                                                .updateMask( imageMCD15.select('FparLai_QC').bitwiseAnd(1<<7).eq(0)) \
                                                .addBands(imageMCD15.select('FparLai_QC').rename(['satFlag']).bitwiseAnd(1<<5).eq(1)) \
                                                .addBands(imageMCD15.select('FparExtra_QC').rename(['snowFlag']).bitwiseAnd(1<<2).eq(1)) \
                                                .updateMask( imageMCD15.select('FparExtra_QC').bitwiseAnd(1<<0).eq(0)) \
                                                .updateMask( imageMCD15.select('FparExtra_QC').bitwiseAnd(1<<1).eq(0)) \
                                                .updateMask( imageMCD15.select('FparExtra_QC').bitwiseAnd(1<<3).eq(0)) \
                                                .updateMask( imageMCD15.select('FparExtra_QC').bitwiseAnd(1<<4).eq(0)) \
                                                .updateMask( imageMCD15.select('FparExtra_QC').bitwiseAnd(1<<5).eq(0)) \
                                                .updateMask( imageMCD15.select('FparExtra_QC').bitwiseAnd(1<<6).eq(0)) \


                            
                                # get the fraction of area with unmasked MCD15 data 
                                validArea = ee.Number(ee.Image.pixelArea().mask(imageMCD15.select('Lai').mask()).reduceRegion(reducer=ee.Reducer.sum(),geometry=imageLC.geometry(),crs=projectionMCD15.atScale(outputScale)).get('area')).getInfo()
                                totalArea = ee.Number(ee.Image.pixelArea().mask(imageMCD15.select('Lai').unmask().mask()).reduceRegion(reducer=ee.Reducer.sum(),geometry=imageLC.geometry(),crs=projectionMCD15.atScale(outputScale)).get('area')).getInfo()
                                fracAreaMCD15 = 0 
                                if (totalArea > 0) :
                                    fracAreaMCD15 = validArea / totalArea
                                print('fracAreaMCD15:',fracAreaMCD15) 
                           
                                # sample if there is sufficient unmasked area
                                if ( fracAreaMCD15> minfracAreaMCD15 ) :
                                                
                                    
                                    # add a view zenith angle band and a validPixel band to the landsat image
                                    # then unmask and aggregate to output scale, we unmask first to allow for <100% validPixel s
                                    imageLCtoMCD = imageLC.addBands(imageLC.unmask().select('QA_PIXEL').gt(-1).rename('validPixel')) \
                                                         .reproject(crs= projectionMCD15,scale=projectionLC.nominalScale() ) \
                                                         .reduceResolution(reducer= ee.Reducer.mean(),maxPixels=maxPixels,bestEffort=False) \
                                                         .reproject(crs= projectionMCD15 , scale= outputScale) \
                                                         .updateMask(imageMCD15.select('FparLai_QC').mask())
                                   
                                    # mask bands not meeting fractional pixel threshold
                                    # we then have to divide by the fractional validPixel band to adjust for  zero masked values 
                                    validLCtoMCD = imageLCtoMCD.select('validPixel').gte(minfracValidLC);
                                    imageLCtoMCD = imageLCtoMCD.updateMask(validLCtoMCD)


                                    # add the aggregated LC image to the modis image and update the MCD image with the valid mask
                                    imageMCD15 = imageMCD15.addBands(imageLCtoMCD) \
                                                            .updateMask(validLCtoMCD) 
                                                            
                                    # get the fraction of area with unmasked LC data 
                                    validArea = ee.Number(ee.Image.pixelArea().mask(imageMCD15.select('QA_PIXEL').mask()).reduceRegion(reducer=ee.Reducer.sum(),geometry=imageMCD15.geometry(),scale=outputScale,bestEffort=True).get('area')).getInfo()
                                    totalArea = ee.Number(ee.Image.pixelArea().mask(imageMCD15.select('QA_PIXEL').unmask().mask()).reduceRegion(reducer=ee.Reducer.sum(),geometry=imageMCD15.geometry(),scale=outputScale,bestEffort=True).get('area')).getInfo()
                                    fracAreaLCtoMCD = 0 
                                    if (totalArea > 0) :
                                        fracAreaLCtoMCD = validArea / totalArea
                                    print('fracAreaLCtoMCD:',fracAreaLCtoMCD)  
                                    
                                    # check if we have enough valid cloud free aggregated matches
                                    if ( fracAreaLCtoMCD > minfracAreaLCtoMCD ) :
 

                                        imageMCD15 = imageMCD15.select(['satFlag','snowFlag','FparLai_QC','FparExtra_QC']) \
                                                                .addBands(getLUTout(imageMCD15)) \
                                                                 .addBands(getLUTL0XinB45(imageMCD15)) \
                                                                 .addBands(getLUTL0XinB36(imageMCD15)) \
                                                                 .addBands(getLUTinMOD09(imageMCD15)) \
                                                                 .addBands(getLUTinMOD09bands(imageMCD15)) \
                                                                 .addBands(ee.Image.pixelLonLat()) \
                                                                 .updateMask(validLCtoMCD)
        
                                        sampleData = imageMCD15.sample(projection=projectionMCD15.atScale(outputScale), numPixels=maxSample, dropNulls=True)
                                        sampleOutput = sampleData.aggregate_array('LUTout').flatten().getInfo()
                                        sampleInputB45 = sampleData.aggregate_array('LUTL0XinB45').flatten().getInfo()
                                        sampleInputB36 = sampleData.aggregate_array('LUTL0XinB36').flatten().getInfo()
                                        sampleInputMOD09 = sampleData.aggregate_array('LUTinMOD09').flatten().getInfo()
                                        sampleInputMOD09bands = sampleData.aggregate_array('LUTinMOD09bands').flatten().getInfo()
                                        sampleInputLon = sampleData.aggregate_array('longitude').flatten().getInfo()
                                        sampleInputLat = sampleData.aggregate_array('latitude').flatten().getInfo()
                                        sampleFparLai_QC = sampleData.aggregate_array('FparLai_QC').flatten().getInfo()
                                        sampleFparExtra_QC = sampleData.aggregate_array('FparExtra_QC').flatten().getInfo()

                                        if (len(sampleOutput)>0) :

                                            numsam = len(sampleOutput)
                                            cumsam = cumsam + numsam
                                            print('cumulative samples:',cumsam,'nsaminput',numsam)
                                            
                                            # write list after each landsat scene is done (comment out if it is too frequent)
                                            with open(InputFileNameLon, 'ab') as fp1:
                                                pickle.dump(sampleInputLon, fp1)
                                            with open(InputFileNameLat, 'ab') as fp1:
                                                pickle.dump(sampleInputLat, fp1)
                                            with open(InputFileNameB36, 'ab') as fp1:
                                                pickle.dump(sampleInputB36, fp1)
                                            with open(InputFileNameB45, 'ab') as fp1:
                                                pickle.dump(sampleInputB45, fp1)
                                            with open(InputFileNameMOD09, 'ab') as fp1:
                                                pickle.dump(sampleInputMOD09, fp1)
                                            with open(InputFileNameMOD09bands, 'ab') as fp1:
                                                pickle.dump(sampleInputMOD09bands, fp1)
                                            with open(OutputFileName, 'ab') as fp1:
                                                pickle.dump(sampleOutput, fp1)                                        
                                            with open(YearFileName, 'ab') as fp1:
                                                pickle.dump([year]*numsam, fp1)
                                            with open(MonthFileName, 'ab') as fp1:
                                                pickle.dump([month]*numsam, fp1)
                                            with open(DayFileName, 'ab') as fp1:
                                                pickle.dump([daystart]*numsam, fp1)
                                            with open(PathFileName, 'ab') as fp1:
                                                pickle.dump([path]*numsam, fp1 ) 
                                            with open(RowFileName, 'ab') as fp1:
                                                pickle.dump([row]*numsam, fp1)  
                                            with open(FparLai_QCName, 'ab') as fp1:
                                                pickle.dump(sampleFparLai_QC, fp1 ) 
                                            with open(FparExtra_QCName, 'ab') as fp1:
                                                pickle.dump(sampleFparExtra_QC, fp1)
# Out:
# year 2013 month 6 path 6 row 22
# fracAreaMCD15: 0.0
# year 2013 month 6 path 8 row 26
# year 2013 month 6 path 10 row 27
# year 2013 month 6 path 10 row 28
# fracAreaMCD15: 0.04336703958808371
# year 2013 month 6 path 11 row 10
# fracAreaMCD15: 0.00041663838584195105
# year 2013 month 6 path 11 row 12
# fracAreaMCD15: 0.0
# year 2013 month 6 path 11 row 19
# fracAreaMCD15: 0.0
# year 2013 month 6 path 11 row 21
# fracAreaMCD15: 0.0
# year 2013 month 6 path 11 row 22
# fracAreaMCD15: 0.012971281643266152
# year 2013 month 6 path 11 row 23
# fracAreaMCD15: 0.020624402203249546
# year 2013 month 6 path 11 row 24
# fracAreaMCD15: 0.24379043530083572
# year 2013 month 6 path 11 row 25
# year 2013 month 6 path 12 row 18
# year 2013 month 6 path 12 row 19
# fracAreaMCD15: 0.000312531954127939
# year 2013 month 6 path 13 row 16
# fracAreaMCD15: 0.0
# year 2013 month 6 path 13 row 17
# fracAreaMCD15: 0.0
# year 2013 month 6 path 13 row 18
# fracAreaMCD15: 0.0
# year 2013 month 6 path 13 row 19
# fracAreaMCD15: 0.0
# year 2013 month 6 path 13 row 20
# fracAreaMCD15: 0.0011813668213769431
# year 2013 month 6 path 13 row 21
# fracAreaMCD15: 0.09904013595894544
# year 2013 month 6 path 13 row 28
# fracAreaMCD15: 0.016112983232985618
# year 2013 month 6 path 14 row 31
# fracAreaMCD15: 0.10607212677704339
# year 2013 month 6 path 14 row 32
# year 2013 month 6 path 14 row 33
# fracAreaMCD15: 0.2042608257776211
# year 2013 month 6 path 14 row 34
# fracAreaMCD15: 0.4986182778428223
# fracAreaLCtoMCD: 0.5004171391562681
# cumulative samples: 1903 nsaminput 1903
# year 2013 month 6 path 14 row 35
# fracAreaMCD15: 0.3325042135137293
# fracAreaLCtoMCD: 0.33405953320493476
# cumulative samples: 4031 nsaminput 2128
# year 2013 month 6 path 15 row 13
# fracAreaMCD15: 0.0
# year 2013 month 6 path 15 row 14
# fracAreaMCD15: 0.0
# year 2013 month 6 path 15 row 16
# fracAreaMCD15: 0.0
# year 2013 month 6 path 15 row 18
# fracAreaMCD15: 0.0
# year 2013 month 6 path 15 row 19
# fracAreaMCD15: 0.0
# year 2013 month 6 path 15 row 20
# fracAreaMCD15: 0.025341639226968134
# year 2013 month 6 path 15 row 21
# fracAreaMCD15: 0.07280734548684095
# year 2013 month 6 path 15 row 22
# fracAreaMCD15: 0.03468316651603549
# year 2013 month 6 path 15 row 23
# year 2013 month 6 path 16 row 32
# fracAreaMCD15: 0.17874299719160786
# year 2013 month 6 path 16 row 35
# fracAreaMCD15: 0.3659346298996524
# fracAreaLCtoMCD: 0.371003005617868
# cumulative samples: 4267 nsaminput 236
# year 2013 month 6 path 16 row 36
# fracAreaMCD15: 0.5372005201601403
# fracAreaLCtoMCD: 0.4997592770260647
# cumulative samples: 5614 nsaminput 1347
# year 2013 month 6 path 17 row 12
# fracAreaMCD15: 0.0
# year 2013 month 6 path 17 row 13
# fracAreaMCD15: 0.0
# year 2013 month 6 path 17 row 14
# fracAreaMCD15: 0.0
# year 2013 month 6 path 17 row 15
# year 2013 month 6 path 17 row 22
# year 2013 month 6 path 17 row 23
# fracAreaMCD15: 0.1055028519955964
# year 2013 month 6 path 17 row 24
# fracAreaMCD15: 0.24420937959829858
# year 2013 month 6 path 17 row 25
# fracAreaMCD15: 0.23019417658400163
# year 2013 month 6 path 17 row 26
# fracAreaMCD15: 0.46880739833890195
# fracAreaLCtoMCD: 0.465727996732949
# cumulative samples: 8607 nsaminput 2993
# year 2013 month 6 path 17 row 27
# fracAreaMCD15: 0.023593999635530737
# year 2013 month 6 path 18 row 21
# fracAreaMCD15: 0.0529701401201942
# year 2013 month 6 path 18 row 22
# fracAreaMCD15: 0.004220371972654664
# year 2013 month 6 path 18 row 36
# fracAreaMCD15: 0.2115623373144742
# year 2013 month 6 path 18 row 37
# fracAreaMCD15: 0.2925449093948165
# fracAreaLCtoMCD: 0.2738103211534547
# cumulative samples: 8909 nsaminput 302
# year 2013 month 6 path 18 row 38
# fracAreaMCD15: 0.0
# year 2013 month 6 path 19 row 27
# fracAreaMCD15: 0.026955470815070538
# year 2013 month 6 path 19 row 28
# fracAreaMCD15: 0.34679688567189315
# fracAreaLCtoMCD: 0.4314577938997865
# cumulative samples: 8914 nsaminput 5
# year 2013 month 6 path 19 row 29
# fracAreaMCD15: 0.0
# year 2013 month 6 path 19 row 30
# fracAreaMCD15: 0.009999630630878038
# year 2013 month 6 path 19 row 31
# fracAreaMCD15: 0.0
# year 2013 month 6 path 19 row 32
# fracAreaMCD15: 0.08341995496552561
# year 2013 month 6 path 19 row 33
# fracAreaMCD15: 0.42527506383338676
# fracAreaLCtoMCD: 0.431936029003656
# cumulative samples: 9286 nsaminput 372
# year 2013 month 6 path 20 row 19
# fracAreaMCD15: 0.0027743971938230484
# year 2013 month 6 path 20 row 20
# fracAreaMCD15: 0.0
# year 2013 month 6 path 20 row 21
# fracAreaMCD15: 0.0
# year 2013 month 6 path 21 row 19
# fracAreaMCD15: 0.00016469379399406013
# year 2013 month 6 path 22 row 10
# fracAreaMCD15: 0.0
# year 2013 month 6 path 22 row 11
# fracAreaMCD15: 0.0
# year 2013 month 6 path 22 row 12
# fracAreaMCD15: 0.0
# year 2013 month 6 path 22 row 13
# fracAreaMCD15: 0.0
# year 2013 month 6 path 22 row 14
# fracAreaMCD15: 0.0
# year 2013 month 6 path 22 row 15
# fracAreaMCD15: 0.0
# year 2013 month 6 path 22 row 16
# fracAreaMCD15: 0.0
# year 2013 month 6 path 22 row 20
# fracAreaMCD15: 0.0
# year 2013 month 6 path 22 row 21
# fracAreaMCD15: 0.0
# year 2013 month 6 path 22 row 22
# fracAreaMCD15: 0.0
# year 2013 month 6 path 22 row 23
# fracAreaMCD15: 0.0
# year 2013 month 6 path 22 row 24
# fracAreaMCD15: 0.11871488499741725
# year 2013 month 6 path 22 row 25
# fracAreaMCD15: 0.13644200597050501
# year 2013 month 6 path 22 row 26
# fracAreaMCD15: 0.09534605572180341
# year 2013 month 6 path 24 row 10
# fracAreaMCD15: 0.0
# year 2013 month 6 path 24 row 12
# fracAreaMCD15: 0.0
# year 2013 month 6 path 24 row 13
# fracAreaMCD15: 0.0
# year 2013 month 6 path 24 row 14
# fracAreaMCD15: 0.0
# year 2013 month 6 path 24 row 15
# fracAreaMCD15: 0.0
# year 2013 month 6 path 24 row 16
# fracAreaMCD15: 0.0
# year 2013 month 6 path 24 row 21
# fracAreaMCD15: 0.0
# year 2013 month 6 path 24 row 22
# fracAreaMCD15: 0.28565015124266213
# fracAreaLCtoMCD: 0.2850783264141055
# cumulative samples: 10515 nsaminput 1229
# year 2013 month 6 path 24 row 35
# fracAreaMCD15: 0.07295637828729785
# year 2013 month 6 path 24 row 36
# fracAreaMCD15: 0.12245010803548742
# year 2013 month 6 path 25 row 10
# fracAreaMCD15: 0.0015626731806000363
# year 2013 month 6 path 25 row 11
# fracAreaMCD15: 0.0
# year 2013 month 6 path 25 row 12
# fracAreaMCD15: 0.0
# year 2013 month 6 path 25 row 13
# fracAreaMCD15: 0.0
# year 2013 month 6 path 25 row 14
# year 2013 month 6 path 25 row 21
# fracAreaMCD15: 0.333379787912706
# fracAreaLCtoMCD: 0.3303071020649431
# cumulative samples: 12649 nsaminput 2134
# year 2013 month 6 path 25 row 22
# fracAreaMCD15: 0.6737967422235545
# fracAreaLCtoMCD: 0.6698111823368634
# cumulative samples: 14758 nsaminput 2109
# year 2013 month 6 path 25 row 23
# fracAreaMCD15: 0.1798342671371661
# year 2013 month 6 path 25 row 24
# fracAreaMCD15: 0.1820066547531753
# year 2013 month 6 path 25 row 25
# fracAreaMCD15: 0.18232856301452935
# year 2013 month 6 path 25 row 26
# fracAreaMCD15: 0.030757374418906563
# year 2013 month 6 path 25 row 27
# fracAreaMCD15: 0.024868127745959197
# year 2013 month 6 path 25 row 35
# fracAreaMCD15: 0.0
# year 2013 month 6 path 25 row 36
# fracAreaMCD15: 0.03124355662192431
# year 2013 month 6 path 25 row 37
# fracAreaMCD15: 0.09593027095753218
# year 2013 month 6 path 25 row 38
# fracAreaMCD15: 0.02132641598079872
# year 2013 month 6 path 26 row 21
# fracAreaMCD15: 0.0
# year 2013 month 6 path 26 row 22
# fracAreaMCD15: 0.30845237947816845
# fracAreaLCtoMCD: 0.3045634093255737
# cumulative samples: 16712 nsaminput 1954
# year 2013 month 6 path 26 row 23
# fracAreaMCD15: 0.09499838077161833
# year 2013 month 6 path 27 row 20
# year 2013 month 6 path 27 row 32
# year 2013 month 6 path 27 row 33
# fracAreaMCD15: 0.6159397213859328
# fracAreaLCtoMCD: 0.6166752096300137
# cumulative samples: 20654 nsaminput 3942
# year 2013 month 6 path 27 row 34
# fracAreaMCD15: 0.3137374401423873
# fracAreaLCtoMCD: 0.3040326935890738
# cumulative samples: 21399 nsaminput 745
# year 2013 month 6 path 27 row 35
# fracAreaMCD15: 0.5879499992666715
# fracAreaLCtoMCD: 0.5845310400303226
# cumulative samples: 25162 nsaminput 3763
# year 2013 month 6 path 27 row 36
# fracAreaMCD15: 0.6807781456550868
# fracAreaLCtoMCD: 0.6290058590371495
# cumulative samples: 25329 nsaminput 167
# year 2013 month 6 path 27 row 37
# fracAreaMCD15: 0.6514330718330732
# fracAreaLCtoMCD: 0.65491462709936
# cumulative samples: 26930 nsaminput 1601
# year 2013 month 6 path 28 row 22
# fracAreaMCD15: 0.11304551268483068
# year 2013 month 6 path 28 row 23
# fracAreaMCD15: 0.02936516195050819
# year 2013 month 6 path 28 row 24
# fracAreaMCD15: 0.25377894682330376
# fracAreaLCtoMCD: 0.2599231239770243
# cumulative samples: 27219 nsaminput 289
# year 2013 month 6 path 28 row 25
# fracAreaMCD15: 0.053689126958163615
# year 2013 month 6 path 28 row 26
# fracAreaMCD15: 0.004622893460449627
# year 2013 month 6 path 28 row 31
# fracAreaMCD15: 0.03640677387594833
# year 2013 month 6 path 28 row 32
# fracAreaMCD15: 0.4153499446796655
# fracAreaLCtoMCD: 0.4170105902687689
# cumulative samples: 29856 nsaminput 2637
# year 2013 month 6 path 29 row 20
# fracAreaMCD15: 0.42042811866508123
# fracAreaLCtoMCD: 0.42006465335699517
# cumulative samples: 32547 nsaminput 2691
# year 2013 month 6 path 29 row 33
# fracAreaMCD15: 0.39829046733441137
# fracAreaLCtoMCD: 0.38434530497640834
# cumulative samples: 33382 nsaminput 835
# year 2013 month 6 path 29 row 34
# fracAreaMCD15: 0.4125412771415851
# fracAreaLCtoMCD: 0.40438425476148404
# cumulative samples: 35717 nsaminput 2335
# year 2013 month 6 path 29 row 35
# fracAreaMCD15: 0.5242580305201144
# fracAreaLCtoMCD: 0.5207680465273808
# cumulative samples: 39054 nsaminput 3337
# year 2013 month 6 path 29 row 36
# year 2013 month 6 path 29 row 37
# fracAreaMCD15: 0.47156005187524797
# fracAreaLCtoMCD: 0.4806076835139995
# cumulative samples: 42072 nsaminput 3018
# year 2013 month 6 path 29 row 38
# fracAreaMCD15: 0.35327300566678166
# fracAreaLCtoMCD: 0.3558164000838402
# cumulative samples: 44333 nsaminput 2261
# year 2013 month 6 path 29 row 39
# fracAreaMCD15: 0.03265422868837764
# year 2013 month 6 path 30 row 24
# fracAreaMCD15: 0.011182488394062804
# year 2013 month 6 path 30 row 35
# fracAreaMCD15: 0.09522166679968037
# year 2013 month 6 path 30 row 36
# fracAreaMCD15: 0.5996684505260074
# fracAreaLCtoMCD: 0.5830709340486196
# cumulative samples: 45428 nsaminput 1095
# year 2013 month 6 path 30 row 37
# fracAreaMCD15: 0.3032906975044621
# fracAreaLCtoMCD: 0.3029359222284562
# cumulative samples: 47221 nsaminput 1793
# year 2013 month 6 path 30 row 38
# fracAreaMCD15: 0.3982832735183471
# fracAreaLCtoMCD: 0.40056964032780196
# cumulative samples: 49770 nsaminput 2549
# year 2013 month 6 path 30 row 39
# fracAreaMCD15: 0.6189161871495185
# fracAreaLCtoMCD: 0.6202695808249945
# cumulative samples: 53731 nsaminput 3961
# year 2013 month 6 path 31 row 10
# fracAreaMCD15: 0.0
# year 2013 month 6 path 31 row 11
# fracAreaMCD15: 0.0
# year 2013 month 6 path 31 row 13
# fracAreaMCD15: 0.0
# year 2013 month 6 path 31 row 14
# fracAreaMCD15: 0.0
# year 2013 month 6 path 31 row 15
# fracAreaMCD15: 0.0
# year 2013 month 6 path 31 row 22
# fracAreaMCD15: 0.03672298236213554
# year 2013 month 6 path 31 row 23
# fracAreaMCD15: 0.07359038617753244
# year 2013 month 6 path 31 row 35
# fracAreaMCD15: 0.3352631785972975
# fracAreaLCtoMCD: 0.3262060892363777
# cumulative samples: 54773 nsaminput 1042
# year 2013 month 6 path 31 row 36
# fracAreaMCD15: 0.42865803823440707
# fracAreaLCtoMCD: 0.44586333545671875
# cumulative samples: 54866 nsaminput 93
# year 2013 month 6 path 31 row 37
# fracAreaMCD15: 0.01032108948277223
# year 2013 month 6 path 31 row 38
# fracAreaMCD15: 0.21519431161082708
# year 2013 month 6 path 31 row 39
# fracAreaMCD15: 0.3390375369664507
# fracAreaLCtoMCD: 0.33826942434738977
# cumulative samples: 57001 nsaminput 2135
# year 2013 month 6 path 32 row 10
# fracAreaMCD15: 0.00031650208534310696
# year 2013 month 6 path 32 row 11
# fracAreaMCD15: 0.0
# year 2013 month 6 path 32 row 12
# fracAreaMCD15: 0.000989151394932935
# year 2013 month 6 path 32 row 13
# fracAreaMCD15: 0.001646561124005398
# year 2013 month 6 path 32 row 15
# fracAreaMCD15: 0.0
# year 2013 month 6 path 32 row 16
# fracAreaMCD15: 0.0
# year 2013 month 6 path 32 row 17
# fracAreaMCD15: 0.06563565660019412
# year 2013 month 6 path 32 row 18
# fracAreaMCD15: 0.04481891433234514
# year 2013 month 6 path 32 row 19
# fracAreaMCD15: 0.02363625938312381
# year 2013 month 6 path 32 row 27
# fracAreaMCD15: 0.28927079740826034
# fracAreaLCtoMCD: 0.2924180418516251
# cumulative samples: 58849 nsaminput 1848
# year 2013 month 6 path 32 row 28
# fracAreaMCD15: 0.16337046118475218
# year 2013 month 6 path 32 row 33
# fracAreaMCD15: 0.27047152366610466
# fracAreaLCtoMCD: 0.26959185823041415
# cumulative samples: 60579 nsaminput 1730
# year 2013 month 6 path 32 row 34
# fracAreaMCD15: 0.5297822979114044
# fracAreaLCtoMCD: 0.46877931784527876
# cumulative samples: 63533 nsaminput 2954
# year 2013 month 6 path 32 row 35
# fracAreaMCD15: 0.7098974046662468
# fracAreaLCtoMCD: 0.6245300888874146
# cumulative samples: 65744 nsaminput 2211
# year 2013 month 6 path 32 row 36
# fracAreaMCD15: 0.4310491696261639
# fracAreaLCtoMCD: 0.4273405386187309
# cumulative samples: 68380 nsaminput 2636
# year 2013 month 6 path 32 row 37
# fracAreaMCD15: 0.6953299868666938
# fracAreaLCtoMCD: 0.6962225822787876
# cumulative samples: 72825 nsaminput 4445
# year 2013 month 6 path 32 row 38
# fracAreaMCD15: 0.4557882771986875
# fracAreaLCtoMCD: 0.4557985628785934
# cumulative samples: 75742 nsaminput 2917
# year 2013 month 6 path 32 row 39
# fracAreaMCD15: 0.2651864237630162
# fracAreaLCtoMCD: 0.2545532664351614
# cumulative samples: 75823 nsaminput 81
# year 2013 month 6 path 33 row 14
# year 2013 month 6 path 33 row 15
# fracAreaMCD15: 0.0
# year 2013 month 6 path 33 row 16
# fracAreaMCD15: 0.0
# year 2013 month 6 path 33 row 17
# fracAreaMCD15: 0.0
# year 2013 month 6 path 33 row 18
# fracAreaMCD15: 0.0
# year 2013 month 6 path 33 row 30
# fracAreaMCD15: 0.3142294194001607
# fracAreaLCtoMCD: 0.28517098385928064
# cumulative samples: 77664 nsaminput 1841
# year 2013 month 6 path 33 row 31
# fracAreaMCD15: 0.03484660108571083
# year 2013 month 6 path 33 row 32
# fracAreaMCD15: 0.177806252435653
# year 2013 month 6 path 33 row 33
# fracAreaMCD15: 0.5416538815975931
# fracAreaLCtoMCD: 0.49139255435288876
# cumulative samples: 80487 nsaminput 2823
# year 2013 month 6 path 33 row 34
# fracAreaMCD15: 0.1442927598507315
# year 2013 month 6 path 33 row 37
# fracAreaMCD15: 0.3641454982105389
# fracAreaLCtoMCD: 0.349266393979984
# cumulative samples: 81230 nsaminput 743
# year 2013 month 6 path 33 row 38
# fracAreaMCD15: 0.19453444753067498
# year 2013 month 6 path 33 row 39
# fracAreaMCD15: 0.4484521207738494
# fracAreaLCtoMCD: 0.42556487852471303
# cumulative samples: 81424 nsaminput 194
# year 2013 month 6 path 34 row 10
# year 2013 month 6 path 34 row 11
# fracAreaMCD15: 0.0
# year 2013 month 6 path 34 row 12
# fracAreaMCD15: 0.006092489641252428
# year 2013 month 6 path 34 row 13
# fracAreaMCD15: 0.0
# year 2013 month 6 path 34 row 17
# fracAreaMCD15: 0.0012682462305746377
# year 2013 month 6 path 34 row 27
# fracAreaMCD15: 0.04367449430870786
# year 2013 month 6 path 34 row 37
# fracAreaMCD15: 0.16910278879969476
# year 2013 month 6 path 34 row 38
# fracAreaMCD15: 0.19073002604430558
# year 2013 month 6 path 34 row 39
# fracAreaMCD15: 0.1852578969814527
# year 2013 month 6 path 35 row 11
# fracAreaMCD15: 0.0
# year 2013 month 6 path 35 row 12
# fracAreaMCD15: 0.005157234307593978
# year 2013 month 6 path 35 row 13
# fracAreaMCD15: 0.0
# year 2013 month 6 path 35 row 14
# fracAreaMCD15: 0.0
# year 2013 month 6 path 35 row 15
# fracAreaMCD15: 0.0
# year 2013 month 6 path 35 row 19
# fracAreaMCD15: 0.031098820107805344
# year 2013 month 6 path 35 row 20
# fracAreaMCD15: 0.07960213048556308
# year 2013 month 6 path 35 row 22
# fracAreaMCD15: 0.07736177183442121
# year 2013 month 6 path 35 row 23
# fracAreaMCD15: 0.21831599592685857
# year 2013 month 6 path 35 row 24
# fracAreaMCD15: 0.4240093717547664
# fracAreaLCtoMCD: 0.423671995136703
# cumulative samples: 83718 nsaminput 2294
# year 2013 month 6 path 35 row 31
# fracAreaMCD15: 0.45399694317825695
# fracAreaLCtoMCD: 0.47130413897697987
# cumulative samples: 83796 nsaminput 78
# year 2013 month 6 path 35 row 32
# fracAreaMCD15: 0.4321641567329395
# fracAreaLCtoMCD: 0.43011218963682246
# cumulative samples: 86271 nsaminput 2475
# year 2013 month 6 path 35 row 35
# fracAreaMCD15: 0.4676797838846313
# fracAreaLCtoMCD: 0.46734973071516556
# cumulative samples: 87728 nsaminput 1457
# year 2013 month 6 path 35 row 36
# fracAreaMCD15: 0.37178186642597133
# fracAreaLCtoMCD: 0.3619689025501121
# cumulative samples: 89119 nsaminput 1391
# year 2013 month 6 path 35 row 37
# fracAreaMCD15: 0.8137582241804595
# fracAreaLCtoMCD: 0.6913612017427745
# cumulative samples: 89123 nsaminput 4
# year 2013 month 6 path 35 row 38
# fracAreaMCD15: 0.4943771474571342
# fracAreaLCtoMCD: 0.49424976098144247
# cumulative samples: 92287 nsaminput 3164
# year 2013 month 6 path 35 row 39
# fracAreaMCD15: 0.5726147268209977
# fracAreaLCtoMCD: 0.5061484383906881
# cumulative samples: 92421 nsaminput 134
# year 2013 month 6 path 36 row 14
# fracAreaMCD15: 0.0
# year 2013 month 6 path 36 row 19
# year 2013 month 6 path 36 row 33
# fracAreaMCD15: 0.33591985802280133
# fracAreaLCtoMCD: 0.3378732844773362
# cumulative samples: 92809 nsaminput 388
# year 2013 month 6 path 36 row 34
# fracAreaMCD15: 0.3809082078269115
# fracAreaLCtoMCD: 0.3796822869546905
# cumulative samples: 95201 nsaminput 2392
# year 2013 month 6 path 36 row 35
# fracAreaMCD15: 1.0
# fracAreaLCtoMCD: 0.9390657541564198
# cumulative samples: 95202 nsaminput 1
# year 2013 month 6 path 36 row 37
# fracAreaMCD15: 0.4092570838087715
# fracAreaLCtoMCD: 0.40533719694738835
# cumulative samples: 97063 nsaminput 1861
# year 2013 month 6 path 36 row 38
# fracAreaMCD15: 0.6279295484906267
# fracAreaLCtoMCD: 0.62789143759824
# cumulative samples: 98269 nsaminput 1206
# year 2013 month 6 path 37 row 18
# fracAreaMCD15: 0.02903574922921361
# year 2013 month 6 path 37 row 19
# fracAreaMCD15: 0.0661061056940107
# year 2013 month 6 path 37 row 20
# fracAreaMCD15: 0.03265841148543293
# year 2013 month 6 path 37 row 21
# fracAreaMCD15: 0.028010493411691647
# year 2013 month 6 path 37 row 22
# fracAreaMCD15: 0.35265693120650426
# fracAreaLCtoMCD: 0.34595856567103217
# cumulative samples: 99024 nsaminput 755
# year 2013 month 6 path 37 row 31
# fracAreaMCD15: 0.2987897151964022
# fracAreaLCtoMCD: 0.2947514461105047
# cumulative samples: 100935 nsaminput 1911
# year 2013 month 6 path 37 row 32
# fracAreaMCD15: 0.5051179940119134
# fracAreaLCtoMCD: 0.49366993445535495
# cumulative samples: 101957 nsaminput 1022
# year 2013 month 6 path 37 row 33
# fracAreaMCD15: 0.24453230097650588
# year 2013 month 6 path 37 row 35
# fracAreaMCD15: 0.5337715447837773
# fracAreaLCtoMCD: 0.5239694181568506
# cumulative samples: 102018 nsaminput 61
# year 2013 month 6 path 37 row 36
# fracAreaMCD15: 0.4815874648407409
# fracAreaLCtoMCD: 0.48155947084102874
# cumulative samples: 103887 nsaminput 1869
# year 2013 month 6 path 37 row 37
# fracAreaMCD15: 0.24748962163154387
# year 2013 month 6 path 37 row 38
# fracAreaMCD15: 0.0
# year 2013 month 6 path 37 row 39
# fracAreaMCD15: 0.0
# year 2013 month 6 path 38 row 27
# fracAreaMCD15: 0.08985792285740914
# year 2013 month 6 path 38 row 28
# fracAreaMCD15: 1.0
# fracAreaLCtoMCD: 1.0
# cumulative samples: 103888 nsaminput 1
# year 2013 month 6 path 38 row 29
# fracAreaMCD15: 0.20597751912010892
# year 2013 month 6 path 38 row 30
# fracAreaMCD15: 0.2997984959405379
# fracAreaLCtoMCD: 0.2950794983038768
# cumulative samples: 103953 nsaminput 65
# year 2013 month 6 path 38 row 31
# fracAreaMCD15: 0.0
# year 2013 month 6 path 38 row 32
# fracAreaMCD15: 0.0
# year 2013 month 6 path 38 row 33
# fracAreaMCD15: 0.3456378994225823
# fracAreaLCtoMCD: 0.3432195442239671
# cumulative samples: 106071 nsaminput 2118
# year 2013 month 6 path 38 row 34
# fracAreaMCD15: 0.4514054960295032
# fracAreaLCtoMCD: 0.45690760555709653
# cumulative samples: 108960 nsaminput 2889
# year 2013 month 6 path 38 row 35
# fracAreaMCD15: 0.49415801762317657
# fracAreaLCtoMCD: 0.48613181566120883
# cumulative samples: 109040 nsaminput 80
# year 2013 month 6 path 38 row 36
# fracAreaMCD15: 0.44250330668369187
# fracAreaLCtoMCD: 0.44320638778039356
# cumulative samples: 111872 nsaminput 2832
# year 2013 month 6 path 38 row 37
# fracAreaMCD15: 0.12948914602926748
# year 2013 month 6 path 40 row 30
# fracAreaMCD15: 0.35754146707898865
# fracAreaLCtoMCD: 0.35927166087637
# cumulative samples: 113604 nsaminput 1732
# year 2013 month 6 path 40 row 31
# fracAreaMCD15: 0.04361977793325087
# year 2013 month 6 path 40 row 33
# fracAreaMCD15: 0.3038442977951781
# fracAreaLCtoMCD: 0.2900714401777198
# cumulative samples: 114720 nsaminput 1116
# year 2013 month 6 path 40 row 34
# fracAreaMCD15: 0.37825086991887735
# fracAreaLCtoMCD: 0.3792963312175048
# cumulative samples: 114913 nsaminput 193
# year 2013 month 6 path 40 row 35
# fracAreaMCD15: 0.36803389010270016
# fracAreaLCtoMCD: 0.37433867041370467
# cumulative samples: 114992 nsaminput 79
# year 2013 month 6 path 40 row 36
# fracAreaMCD15: 0.29226019071150194
# fracAreaLCtoMCD: 0.28979682421354347
# cumulative samples: 116863 nsaminput 1871
# year 2013 month 6 path 41 row 10
# fracAreaMCD15: 0.0
# year 2013 month 6 path 41 row 33
# fracAreaMCD15: 0.4866532484673375
# fracAreaLCtoMCD: 0.4880859744993375
# cumulative samples: 119797 nsaminput 2934
# year 2013 month 6 path 41 row 34
# fracAreaMCD15: 0.5025517658936716
# fracAreaLCtoMCD: 0.5031732979924638
# cumulative samples: 120219 nsaminput 422
# year 2013 month 6 path 41 row 35
# fracAreaMCD15: 0.1382025799904416
# year 2013 month 6 path 41 row 36
# fracAreaMCD15: 0.5820554455589144
# fracAreaLCtoMCD: 0.590001699446986
# cumulative samples: 120990 nsaminput 771
# year 2013 month 6 path 42 row 11
# fracAreaMCD15: 0.0
# year 2013 month 6 path 42 row 14
# fracAreaMCD15: 0.0
# year 2013 month 6 path 42 row 15
# fracAreaMCD15: 0.0003162509157680544
# year 2013 month 6 path 42 row 16
# fracAreaMCD15: 0.0
# year 2013 month 6 path 42 row 27
# fracAreaMCD15: 0.21005566323175928
# year 2013 month 6 path 42 row 28
# fracAreaMCD15: 0.4524691393566137
# fracAreaLCtoMCD: 0.4536957077339439
# cumulative samples: 123273 nsaminput 2283
# year 2013 month 6 path 42 row 29
# fracAreaMCD15: 0.5423398951262027
# fracAreaLCtoMCD: 0.5388881965162283
# cumulative samples: 125884 nsaminput 2611
# year 2013 month 6 path 42 row 30
# fracAreaMCD15: 0.17040524413119687
# year 2013 month 6 path 42 row 31
# fracAreaMCD15: 0.3332811899710452
# fracAreaLCtoMCD: 0.3314893744443345
# cumulative samples: 128017 nsaminput 2133
# year 2013 month 6 path 42 row 32
# fracAreaMCD15: 0.25545920905481356
# fracAreaLCtoMCD: 0.25431170416359444
# cumulative samples: 129652 nsaminput 1635
# year 2013 month 6 path 42 row 33
# fracAreaMCD15: 0.21696846988348853
# year 2013 month 6 path 42 row 34
# fracAreaMCD15: 0.1528116211211831
# year 2013 month 6 path 42 row 35
# fracAreaMCD15: 0.21750315394191963
# year 2013 month 6 path 42 row 36
# fracAreaMCD15: 0.1262135922330097
# year 2013 month 6 path 43 row 11
# fracAreaMCD15: 0.0
# year 2013 month 6 path 43 row 12
# fracAreaMCD15: 0.0
# year 2013 month 6 path 43 row 16
# fracAreaMCD15: 0.0
# year 2013 month 6 path 43 row 30
# fracAreaMCD15: 0.18258613551416264
# year 2013 month 6 path 43 row 31
# fracAreaMCD15: 0.09111771974250238
# year 2013 month 6 path 43 row 32
# fracAreaMCD15: 0.6900052752043316
# fracAreaLCtoMCD: 0.6901975978423703
# cumulative samples: 133004 nsaminput 3352
# year 2013 month 6 path 43 row 33
# fracAreaMCD15: 0.6545264002567963
# fracAreaLCtoMCD: 0.602735929197473
# cumulative samples: 136843 nsaminput 3839
# year 2013 month 6 path 43 row 34
# fracAreaMCD15: 0.4863791645583815
# fracAreaLCtoMCD: 0.4850769852324581
# cumulative samples: 137810 nsaminput 967
# year 2013 month 6 path 43 row 35
# fracAreaMCD15: 0.44297962306978383
# fracAreaLCtoMCD: 0.44131100554217556
# cumulative samples: 140645 nsaminput 2835
# year 2013 month 6 path 44 row 10
# fracAreaMCD15: 0.0
# year 2013 month 6 path 44 row 11
# fracAreaMCD15: 0.00015630764431510244
# year 2013 month 6 path 44 row 12
# fracAreaMCD15: 0.007968754144691498
# year 2013 month 6 path 44 row 13
# fracAreaMCD15: 0.0
# year 2013 month 6 path 44 row 14
# fracAreaMCD15: 0.0
# year 2013 month 6 path 44 row 15
# fracAreaMCD15: 0.0
# year 2013 month 6 path 44 row 28
# fracAreaMCD15: 0.22063599251992988
# year 2013 month 6 path 44 row 29
# fracAreaMCD15: 0.34874517244003833
# fracAreaLCtoMCD: 0.34268829751142654
# cumulative samples: 141960 nsaminput 1315
# year 2013 month 6 path 44 row 30
# fracAreaMCD15: 0.5666203345918523
# fracAreaLCtoMCD: 0.5571633237769508
# cumulative samples: 142827 nsaminput 867
# year 2013 month 6 path 44 row 31
# fracAreaMCD15: 0.35687380723927054
# fracAreaLCtoMCD: 0.3418117451305544
# cumulative samples: 143251 nsaminput 424
# year 2013 month 6 path 44 row 32
# fracAreaMCD15: 0.7759545283107184
# fracAreaLCtoMCD: 0.7762864043509307
# cumulative samples: 148217 nsaminput 4966
# year 2013 month 6 path 44 row 33
# fracAreaMCD15: 0.4529895777279795
# fracAreaLCtoMCD: 0.4248073672525158
# cumulative samples: 148226 nsaminput 9
# year 2013 month 6 path 44 row 34
# fracAreaMCD15: 0.43618031417072783
# fracAreaLCtoMCD: 0.4304056251521167
# cumulative samples: 148771 nsaminput 545
# year 2013 month 6 path 45 row 12
# fracAreaMCD15: 0.0
# year 2013 month 6 path 45 row 13
# fracAreaMCD15: 0.0
# year 2013 month 6 path 45 row 14
# fracAreaMCD15: 0.0
# year 2013 month 6 path 45 row 27
# fracAreaMCD15: 0.12100645832975848
# year 2013 month 6 path 45 row 28
# fracAreaMCD15: 0.24459925508378755
# year 2013 month 6 path 45 row 29
# year 2013 month 6 path 45 row 30
# fracAreaMCD15: 0.3381356880286298
# fracAreaLCtoMCD: 0.33265817452670376
# cumulative samples: 150666 nsaminput 1895
# year 2013 month 6 path 46 row 14
# fracAreaMCD15: 0.0029949589931326267
# year 2013 month 6 path 46 row 15
# fracAreaMCD15: 0.0
# year 2013 month 6 path 46 row 30
# fracAreaMCD15: 0.007141126922868647
# year 2013 month 6 path 46 row 31
# fracAreaMCD15: 0.008941748939522072
# year 2013 month 6 path 46 row 32
# fracAreaMCD15: 0.07878681953418422
# year 2013 month 6 path 47 row 28
# fracAreaMCD15: 0.01748855267077063
# year 2013 month 6 path 47 row 29
# fracAreaMCD15: 0.02547259957202189
# year 2013 month 6 path 47 row 30
# fracAreaMCD15: 0.0045318939228848895
# year 2013 month 6 path 49 row 19
# fracAreaMCD15: 0.30136610694421007
# fracAreaLCtoMCD: 0.2938576963284281
# cumulative samples: 151713 nsaminput 1047
# year 2013 month 6 path 50 row 10
# fracAreaMCD15: 0.003335235433999235
# year 2013 month 6 path 50 row 11
# year 2013 month 6 path 51 row 11
# fracAreaMCD15: 0.0006978984786794168
# year 2013 month 6 path 51 row 12
# fracAreaMCD15: 0.00015631762021867327
# year 2013 month 6 path 51 row 13
# fracAreaMCD15: 0.06560806801792061
# year 2013 month 6 path 51 row 14
# fracAreaMCD15: 0.10729785193161065
# year 2013 month 6 path 52 row 11
# fracAreaMCD15: 0.0002719656899326744
# year 2013 month 6 path 52 row 12
# fracAreaMCD15: 0.0
# year 2013 month 6 path 52 row 13
# fracAreaMCD15: 0.007035659136372481
# year 2013 month 6 path 52 row 14
# fracAreaMCD15: 0.0
# year 2013 month 6 path 52 row 15
# fracAreaMCD15: 0.20669764323869513
# year 2013 month 6 path 52 row 16
# fracAreaMCD15: 0.2492775248273821
# year 2013 month 6 path 52 row 18
# fracAreaMCD15: 0.19141266450892694
# year 2013 month 6 path 53 row 13
# fracAreaMCD15: 0.0034818772813030746
# year 2013 month 6 path 54 row 10
# fracAreaMCD15: 0.0
# year 2013 month 6 path 57 row 19
# fracAreaMCD15: 0.04501634696933295
# year 2013 month 6 path 59 row 10
# year 2013 month 6 path 59 row 19
# fracAreaMCD15: 0.0035951112489758766
# year 2013 month 6 path 60 row 11
# fracAreaMCD15: 0.06054247680474797
# year 2013 month 6 path 60 row 13
# fracAreaMCD15: 0.15529761679140383
# year 2013 month 6 path 60 row 17
# year 2013 month 6 path 63 row 11
# year 2013 month 6 path 63 row 12
# fracAreaMCD15: 0.0038983582262707606
# year 2013 month 6 path 63 row 13
# fracAreaMCD15: 0.22704147134197497
# year 2013 month 6 path 64 row 16
# fracAreaMCD15: 0.4728317671510145
# fracAreaLCtoMCD: 0.47384111645742877
# cumulative samples: 154634 nsaminput 2921
# year 2013 month 6 path 64 row 17
# fracAreaMCD15: 0.20754102616848594
# year 2013 month 6 path 66 row 11
# fracAreaMCD15: 0.0
# year 2013 month 6 path 66 row 13
# fracAreaMCD15: 0.35036463723983047
# fracAreaLCtoMCD: 0.35128636417682174
# cumulative samples: 155636 nsaminput 1002
# year 2013 month 6 path 66 row 14
# fracAreaMCD15: 0.1285990616554665
# year 2013 month 6 path 68 row 18
# year 2013 month 6 path 68 row 20
# fracAreaMCD15: 0.00796191123345626
# year 2013 month 6 path 69 row 11
# fracAreaMCD15: 0.018249259477148262
# year 2013 month 6 path 69 row 12
# fracAreaMCD15: 0.5184799016273378
# fracAreaLCtoMCD: 0.49710267672940267
# cumulative samples: 157791 nsaminput 2155
# year 2013 month 6 path 69 row 13
# fracAreaMCD15: 0.5157660873816012
# fracAreaLCtoMCD: 0.5176499722749435
# cumulative samples: 161092 nsaminput 3301
# year 2013 month 6 path 69 row 14
# fracAreaMCD15: 0.6797197211205155
# fracAreaLCtoMCD: 0.6527440566989512
# cumulative samples: 161915 nsaminput 823
# year 2013 month 7 path 3 row 27
# fracAreaMCD15: 0.002095448441350129
# year 2013 month 7 path 3 row 28
# fracAreaMCD15: 0.0
# year 2013 month 7 path 5 row 26
# fracAreaMCD15: 0.0009376085878848469
# year 2013 month 7 path 7 row 22
# fracAreaMCD15: 0.03834323382986811
# year 2013 month 7 path 7 row 23
# fracAreaMCD15: 0.07734501649647683
# year 2013 month 7 path 7 row 24
# fracAreaMCD15: 0.0008182032564286156
# year 2013 month 7 path 7 row 25
# fracAreaMCD15: 0.0
# year 2013 month 7 path 7 row 26
# fracAreaMCD15: 0.0
# year 2013 month 7 path 8 row 21
# fracAreaMCD15: 0.0
# year 2013 month 7 path 8 row 24
# fracAreaMCD15: 0.04940252060956586
# year 2013 month 7 path 8 row 25
# fracAreaMCD15: 0.11206292778826515
# year 2013 month 7 path 8 row 26
# fracAreaMCD15: 0.25747888472054276
# fracAreaLCtoMCD: 0.2512208859056985
# cumulative samples: 162450 nsaminput 535
# year 2013 month 7 path 8 row 27
# fracAreaMCD15: 0.0
# year 2013 month 7 path 10 row 25
# fracAreaMCD15: 0.012446464785017833
# year 2013 month 7 path 10 row 29
# fracAreaMCD15: 0.0
# year 2013 month 7 path 11 row 30
# fracAreaMCD15: 0.0
# year 2013 month 7 path 11 row 32
# fracAreaMCD15: 0.0
# year 2013 month 7 path 12 row 31
# fracAreaMCD15: 0.1420811516216323
# year 2013 month 7 path 12 row 32
# fracAreaMCD15: 0.0
# year 2013 month 7 path 13 row 27
# fracAreaMCD15: 0.2855420149765879
# fracAreaLCtoMCD: 0.2783608588981805
# cumulative samples: 162464 nsaminput 14
# year 2013 month 7 path 13 row 28
# fracAreaMCD15: 0.23826900562895584
# year 2013 month 7 path 14 row 21
# fracAreaMCD15: 0.08419819017013778
# year 2013 month 7 path 14 row 25
# fracAreaMCD15: 0.30782359695968614
# fracAreaLCtoMCD: 0.3058675620364111
# cumulative samples: 164434 nsaminput 1970
# year 2013 month 7 path 15 row 13
# fracAreaMCD15: 0.009057177694147118
# year 2013 month 7 path 15 row 15
# fracAreaMCD15: 0.00015628353082650684
# year 2013 month 7 path 16 row 25
# fracAreaMCD15: 0.03859485845307756
# year 2013 month 7 path 16 row 26
# fracAreaMCD15: 0.056936503857716037
# year 2013 month 7 path 17 row 22
# fracAreaMCD15: 0.0
# year 2013 month 7 path 17 row 23
# fracAreaMCD15: 0.002262676248987268
# year 2013 month 7 path 17 row 24
# fracAreaMCD15: 0.010396380443198166
# year 2013 month 7 path 17 row 25
# fracAreaMCD15: 0.02118668836148293
# year 2013 month 7 path 18 row 29
# fracAreaMCD15: 0.13137045309657658
# year 2013 month 7 path 18 row 30
# fracAreaMCD15: 0.00856065662910504
# year 2013 month 7 path 18 row 33
# fracAreaMCD15: 0.5640851969824756
# fracAreaLCtoMCD: 0.558657274212319
# cumulative samples: 168043 nsaminput 3609
# year 2013 month 7 path 19 row 28
# fracAreaMCD15: 0.0
# year 2013 month 7 path 20 row 20
# fracAreaMCD15: 0.02828538023083706
# year 2013 month 7 path 20 row 27
# fracAreaMCD15: 0.3212408425434682
# fracAreaLCtoMCD: 0.32879895543017623
# cumulative samples: 168230 nsaminput 187
# year 2013 month 7 path 20 row 28
# fracAreaMCD15: 0.0
# year 2013 month 7 path 20 row 29
# fracAreaMCD15: 0.0
# year 2013 month 7 path 20 row 30
# fracAreaMCD15: 0.06772406861161896
# year 2013 month 7 path 20 row 31
# fracAreaMCD15: 0.10624336632450512
# year 2013 month 7 path 21 row 10
# fracAreaMCD15: 0.0
# year 2013 month 7 path 21 row 11
# fracAreaMCD15: 0.00031350659506967666
# year 2013 month 7 path 21 row 12
# fracAreaMCD15: 0.004687905143024282
# year 2013 month 7 path 21 row 23
# fracAreaMCD15: 0.0
# year 2013 month 7 path 21 row 24
# fracAreaMCD15: 0.22992119549485526
# year 2013 month 7 path 21 row 25
# fracAreaMCD15: 0.20773524512356492
# year 2013 month 7 path 22 row 25
# fracAreaMCD15: 0.16120156353339885
# year 2013 month 7 path 22 row 27
# fracAreaMCD15: 0.0
# year 2013 month 7 path 22 row 28
# fracAreaMCD15: 0.04419021638944206
# year 2013 month 7 path 22 row 29
# fracAreaMCD15: 0.01537706614091155
# year 2013 month 7 path 22 row 33
# fracAreaMCD15: 0.00404982440445473
# year 2013 month 7 path 23 row 23
# fracAreaMCD15: 0.3060886430954164
# fracAreaLCtoMCD: 0.1994455471850729
# cumulative samples: 169532 nsaminput 1302
# year 2013 month 7 path 23 row 24
# fracAreaMCD15: 0.311711544069354
# fracAreaLCtoMCD: 0.3145841490115248
# cumulative samples: 170547 nsaminput 1015
# year 2013 month 7 path 23 row 27
# fracAreaMCD15: 0.0
# year 2013 month 7 path 23 row 28
# fracAreaMCD15: 0.12022988742748075
# year 2013 month 7 path 23 row 36
# fracAreaMCD15: 0.02859634090695
# year 2013 month 7 path 23 row 37
# fracAreaMCD15: 0.1161519166266465
# year 2013 month 7 path 23 row 38
# fracAreaMCD15: 0.055927317183933775
# year 2013 month 7 path 26 row 12
# fracAreaMCD15: 0.07505712312072926
# year 2013 month 7 path 26 row 13
# year 2013 month 7 path 26 row 15
# fracAreaMCD15: 0.02546738593727279
# year 2013 month 7 path 26 row 16
# fracAreaMCD15: 0.0
# year 2013 month 7 path 26 row 21
# fracAreaMCD15: 0.1823337855003438
# year 2013 month 7 path 26 row 22
# year 2013 month 7 path 27 row 16
# fracAreaMCD15: 0.0
# year 2013 month 7 path 27 row 31
# fracAreaMCD15: 0.10515475946681829
# year 2013 month 7 path 27 row 32
# fracAreaMCD15: 0.2807707796020131
# fracAreaLCtoMCD: 0.27791115234652364
# cumulative samples: 172334 nsaminput 1787
# year 2013 month 7 path 27 row 33
# fracAreaMCD15: 0.013439373268054765
# year 2013 month 7 path 28 row 20
# fracAreaMCD15: 0.0
# year 2013 month 7 path 28 row 23
# fracAreaMCD15: 0.05757208913713534
# year 2013 month 7 path 28 row 37
# fracAreaMCD15: 0.10943848283076388
# year 2013 month 7 path 28 row 38
# fracAreaMCD15: 0.15713289110435802
# year 2013 month 7 path 28 row 39
# fracAreaMCD15: 0.6239669421487604
# fracAreaLCtoMCD: 0.11513601578986396
# cumulative samples: 172335 nsaminput 1
# year 2013 month 7 path 29 row 29
# fracAreaMCD15: 0.007970257846566102
# year 2013 month 7 path 29 row 30
# fracAreaMCD15: 0.02422169258230716
# year 2013 month 7 path 29 row 31
# fracAreaMCD15: 0.0015366985109846528
# year 2013 month 7 path 29 row 32
# fracAreaMCD15: 0.020625325324785233
# year 2013 month 7 path 29 row 33
# fracAreaMCD15: 0.20100818688476196
# year 2013 month 7 path 29 row 34
# fracAreaMCD15: 0.5081108992739397
# fracAreaLCtoMCD: 0.494498445186436
# cumulative samples: 173579 nsaminput 1244
# year 2013 month 7 path 29 row 35
# fracAreaMCD15: 0.34061069971156177
# fracAreaLCtoMCD: 0.3302751363440142
# cumulative samples: 174211 nsaminput 632
# year 2013 month 7 path 29 row 36
# fracAreaMCD15: 0.3669560625345608
# fracAreaLCtoMCD: 0.3703944254876187
# cumulative samples: 176455 nsaminput 2244
# year 2013 month 7 path 29 row 37
# fracAreaMCD15: 0.4082529372935145
# fracAreaLCtoMCD: 0.4076325228802868
# cumulative samples: 178099 nsaminput 1644
# year 2013 month 7 path 29 row 38
# fracAreaMCD15: 0.2861832108559174
# fracAreaLCtoMCD: 0.2844050769709133
# cumulative samples: 178287 nsaminput 188
# year 2013 month 7 path 29 row 39
# fracAreaMCD15: 0.07126905110911165
# year 2013 month 7 path 30 row 19
# fracAreaMCD15: 0.0
# year 2013 month 7 path 30 row 21
# fracAreaMCD15: 0.16104288568913921
# year 2013 month 7 path 30 row 22
# fracAreaMCD15: 0.0
# year 2013 month 7 path 30 row 23
# fracAreaMCD15: 0.040314116854091066
# year 2013 month 7 path 30 row 24
# fracAreaMCD15: 0.11380566027155635
# year 2013 month 7 path 30 row 25
# fracAreaMCD15: 0.09623648304219859
# year 2013 month 7 path 30 row 26
# fracAreaMCD15: 0.0
# year 2013 month 7 path 30 row 27
# fracAreaMCD15: 0.0
# year 2013 month 7 path 30 row 28
# fracAreaMCD15: 0.0
# year 2013 month 7 path 30 row 29
# fracAreaMCD15: 0.0
# year 2013 month 7 path 30 row 30
# fracAreaMCD15: 0.00031284175874676535
# year 2013 month 7 path 30 row 31
# fracAreaMCD15: 0.0
# year 2013 month 7 path 30 row 32
# fracAreaMCD15: 0.0
# year 2013 month 7 path 30 row 33
# fracAreaMCD15: 0.032574241091575314
# year 2013 month 7 path 31 row 16
# fracAreaMCD15: 0.00024897697855929396
# year 2013 month 7 path 31 row 21
# fracAreaMCD15: 0.15578242562656675
# year 2013 month 7 path 31 row 22
# fracAreaMCD15: 0.06141468536040635
# year 2013 month 7 path 31 row 23
# fracAreaMCD15: 0.0010409249262634123
# year 2013 month 7 path 31 row 27
# fracAreaMCD15: 0.0
# year 2013 month 7 path 31 row 28
# fracAreaMCD15: 0.017227485059642007
# year 2013 month 7 path 31 row 34
# fracAreaMCD15: 0.5392757806512326
# fracAreaLCtoMCD: 0.37723856763487834
# cumulative samples: 178299 nsaminput 12
# year 2013 month 7 path 31 row 36
# fracAreaMCD15: 0.31897545935344385
# fracAreaLCtoMCD: 0.3046834024365008
# cumulative samples: 179674 nsaminput 1375
# year 2013 month 7 path 31 row 37
# fracAreaMCD15: 0.557172780036887
# fracAreaLCtoMCD: 0.36734158986835047
# cumulative samples: 182044 nsaminput 2370
# year 2013 month 7 path 33 row 32
# fracAreaMCD15: 0.21763393158764374
# year 2013 month 7 path 34 row 23
# fracAreaMCD15: 0.33456232997155766
# fracAreaLCtoMCD: 0.31973299831484364
# cumulative samples: 182809 nsaminput 765
# year 2013 month 7 path 35 row 14
# fracAreaMCD15: 0.3013695527043156
# fracAreaLCtoMCD: 0.2897851160643687
# cumulative samples: 183857 nsaminput 1048
# year 2013 month 7 path 35 row 15
# fracAreaMCD15: 0.051327400226970826
# year 2013 month 7 path 35 row 16
# fracAreaMCD15: 0.010542774354460103
# year 2013 month 7 path 35 row 17
# fracAreaMCD15: 0.02052845991103404
# year 2013 month 7 path 35 row 18
# fracAreaMCD15: 0.1214092034197572
# year 2013 month 7 path 35 row 19
# fracAreaMCD15: 0.0
# year 2013 month 7 path 35 row 20
# fracAreaMCD15: 0.0009193292431403567
# year 2013 month 7 path 35 row 26
# fracAreaMCD15: 0.2713046310473754
# fracAreaLCtoMCD: 0.2695347885363039
# cumulative samples: 185084 nsaminput 1227
# year 2013 month 7 path 35 row 27
# fracAreaMCD15: 0.4472449697032679
# fracAreaLCtoMCD: 0.45816842898999377
# cumulative samples: 185150 nsaminput 66
# year 2013 month 7 path 35 row 28
# fracAreaMCD15: 0.0966357972530788
# year 2013 month 7 path 35 row 29
# fracAreaMCD15: 0.07641380921488954
# year 2013 month 7 path 35 row 30
# year 2013 month 7 path 35 row 35
# fracAreaMCD15: 0.07022486272877564
# year 2013 month 7 path 35 row 38
# fracAreaMCD15: 0.4781998681774265
# fracAreaLCtoMCD: 0.4740631239747433
# cumulative samples: 185445 nsaminput 295
# year 2013 month 7 path 35 row 39
# fracAreaMCD15: 0.07115149797211336
# year 2013 month 7 path 36 row 27
# fracAreaMCD15: 0.042323472006973145
# year 2013 month 7 path 36 row 28
# fracAreaMCD15: 0.44001307640384973
# fracAreaLCtoMCD: 0.4436087448563549
# cumulative samples: 187055 nsaminput 1610
# year 2013 month 7 path 36 row 34
# fracAreaMCD15: 0.4321756564373622
# fracAreaLCtoMCD: 0.43223045979909425
# cumulative samples: 189821 nsaminput 2766
# year 2013 month 7 path 37 row 20
# fracAreaMCD15: 0.0
# year 2013 month 7 path 37 row 24
# fracAreaMCD15: 0.0
# year 2013 month 7 path 37 row 25
# fracAreaMCD15: 0.21259500968291106
# year 2013 month 7 path 37 row 38
# fracAreaMCD15: 0.0010526034631170597
# year 2013 month 7 path 38 row 22
# fracAreaMCD15: 0.03795620855507027
# year 2013 month 7 path 38 row 23
# fracAreaMCD15: 0.20942913797583598
# year 2013 month 7 path 38 row 24
# fracAreaMCD15: 0.36419817150006784
# fracAreaLCtoMCD: 0.3627944763675232
# cumulative samples: 192152 nsaminput 2331
# year 2013 month 7 path 39 row 21
# fracAreaMCD15: 0.01569558007777796
# year 2013 month 7 path 39 row 22
# fracAreaMCD15: 0.18673559117440505
# year 2013 month 7 path 39 row 23
# fracAreaMCD15: 0.30571974023846066
# fracAreaLCtoMCD: 0.3078785755466208
# cumulative samples: 193110 nsaminput 958
# year 2013 month 7 path 39 row 24
# fracAreaMCD15: 0.20448830088075706
# year 2013 month 7 path 39 row 25
# fracAreaMCD15: 0.3912606355150874
# fracAreaLCtoMCD: 0.38627294052382477
# cumulative samples: 195614 nsaminput 2504
# year 2013 month 7 path 39 row 26
# fracAreaMCD15: 0.17998786546338852
# year 2013 month 7 path 39 row 27
# fracAreaMCD15: 0.121091240947348
# year 2013 month 7 path 39 row 29
# fracAreaMCD15: 0.4301506192860068
# fracAreaLCtoMCD: 0.4236471190308524
# cumulative samples: 198326 nsaminput 2712
# year 2013 month 7 path 39 row 30
# fracAreaMCD15: 0.5073338291775404
# fracAreaLCtoMCD: 0.5044665426964428
# cumulative samples: 200167 nsaminput 1841
# year 2013 month 7 path 39 row 31
# fracAreaMCD15: 0.22578500566003068
# year 2013 month 7 path 39 row 32
# fracAreaMCD15: 0.0
# year 2013 month 7 path 39 row 33
# fracAreaMCD15: 0.045625678221614445
# year 2013 month 7 path 39 row 34
# fracAreaMCD15: 0.35463466255980514
# fracAreaLCtoMCD: 0.33775773107368856
# cumulative samples: 200293 nsaminput 126
# year 2013 month 7 path 40 row 23
# year 2013 month 7 path 40 row 24
# fracAreaMCD15: 0.27379483811962607
# fracAreaLCtoMCD: 0.2741783660407719
# cumulative samples: 201907 nsaminput 1614
# year 2013 month 7 path 40 row 25
# fracAreaMCD15: 0.5921141629674826
# fracAreaLCtoMCD: 0.48102969503815285
# cumulative samples: 201918 nsaminput 11
# year 2013 month 7 path 40 row 26
# fracAreaMCD15: 0.3932556326541644
# fracAreaLCtoMCD: 0.38743536912686405
# cumulative samples: 203836 nsaminput 1918
# year 2013 month 7 path 40 row 27
# fracAreaMCD15: 0.4295800419417477
# fracAreaLCtoMCD: 0.4062124063059348
# cumulative samples: 204427 nsaminput 591
# year 2013 month 7 path 40 row 28
# fracAreaMCD15: 0.2748264341580239
# fracAreaLCtoMCD: 0.2753926278772852
# cumulative samples: 204817 nsaminput 390
# year 2013 month 7 path 40 row 29
# fracAreaMCD15: 0.3205132505813962
# fracAreaLCtoMCD: 0.3148892510160463
# cumulative samples: 206852 nsaminput 2035
# year 2013 month 7 path 40 row 30
# fracAreaMCD15: 0.17364054751789446
# year 2013 month 7 path 40 row 31
# fracAreaMCD15: 0.4131921415524404
# fracAreaLCtoMCD: 0.4185048338849563
# cumulative samples: 209496 nsaminput 2644
# year 2013 month 7 path 40 row 32
# fracAreaMCD15: 0.315238852778074
# fracAreaLCtoMCD: 0.3155165440599942
# cumulative samples: 211513 nsaminput 2017
# year 2013 month 7 path 40 row 33
# fracAreaMCD15: 0.6276265548643533
# fracAreaLCtoMCD: 0.6204655763470021
# cumulative samples: 212354 nsaminput 841
# year 2013 month 7 path 40 row 34
# fracAreaMCD15: 0.46265822195681844
# fracAreaLCtoMCD: 0.4594912336377965
# cumulative samples: 215315 nsaminput 2961
# year 2013 month 7 path 40 row 38
# year 2013 month 7 path 42 row 15
# fracAreaMCD15: 0.11686687998407061
# year 2013 month 7 path 42 row 16
# year 2013 month 7 path 42 row 17
# fracAreaMCD15: 0.04250599938435413
# year 2013 month 7 path 42 row 27
# fracAreaMCD15: 0.2708159719618727
# fracAreaLCtoMCD: 0.2648191461878054
# cumulative samples: 216867 nsaminput 1552
# year 2013 month 7 path 42 row 28
# fracAreaMCD15: 0.2548577783066514
# fracAreaLCtoMCD: 0.2554737991669978
# cumulative samples: 218154 nsaminput 1287
# year 2013 month 7 path 42 row 29
# fracAreaMCD15: 0.3740749529906617
# fracAreaLCtoMCD: 0.3698153309387508
# cumulative samples: 218878 nsaminput 724
# year 2013 month 7 path 42 row 30
# fracAreaMCD15: 0.46966598591485403
# fracAreaLCtoMCD: 0.48321980602767356
# cumulative samples: 219878 nsaminput 1000
# year 2013 month 7 path 42 row 31
# fracAreaMCD15: 0.5059071589454524
# fracAreaLCtoMCD: 0.48812599187536077
# cumulative samples: 222938 nsaminput 3060
# year 2013 month 7 path 42 row 32
# fracAreaMCD15: 0.24350494431014116
# year 2013 month 7 path 42 row 33
# fracAreaMCD15: 0.09177188982842056
# year 2013 month 7 path 42 row 34
# fracAreaMCD15: 0.222544840487964
# year 2013 month 7 path 42 row 35
# fracAreaMCD15: 0.3273699713715267
# fracAreaLCtoMCD: 0.321102925743966
# cumulative samples: 224010 nsaminput 1072
# year 2013 month 7 path 42 row 36
# fracAreaMCD15: 0.28528802925799157
# fracAreaLCtoMCD: 0.2823030030139868
# cumulative samples: 225836 nsaminput 1826
# year 2013 month 7 path 43 row 26
# fracAreaMCD15: 0.2689323306234436
# fracAreaLCtoMCD: 0.26412039585423475
# cumulative samples: 227552 nsaminput 1716
# year 2013 month 7 path 43 row 27
# fracAreaMCD15: 0.28685053206840533
# fracAreaLCtoMCD: 0.25655745508177413
# cumulative samples: 227571 nsaminput 19
# year 2013 month 7 path 43 row 28
# fracAreaMCD15: 0.718216069416194
# fracAreaLCtoMCD: 0.714953757452363
# cumulative samples: 227943 nsaminput 372
# year 2013 month 7 path 43 row 29
# fracAreaMCD15: 0.7231948239324038
# fracAreaLCtoMCD: 0.7465272252435766
# cumulative samples: 227946 nsaminput 3
# year 2013 month 7 path 43 row 30
# fracAreaMCD15: 0.16629160583791627
# year 2013 month 7 path 43 row 31
# fracAreaMCD15: 0.3271873141226165
# fracAreaLCtoMCD: 0.31973041688988596
# cumulative samples: 229836 nsaminput 1890
# year 2013 month 7 path 43 row 32
# fracAreaMCD15: 0.3902824697418283
# fracAreaLCtoMCD: 0.39069702520424743
# cumulative samples: 232334 nsaminput 2498
# year 2013 month 7 path 43 row 33
# fracAreaMCD15: 0.7611878747988312
# fracAreaLCtoMCD: 0.7552999601408582
# cumulative samples: 235845 nsaminput 3511
# year 2013 month 7 path 43 row 34
# fracAreaMCD15: 0.7433852187865895
# fracAreaLCtoMCD: 0.7483259291415968
# cumulative samples: 235950 nsaminput 105
# year 2013 month 7 path 43 row 35
# year 2013 month 7 path 43 row 36
# year 2013 month 7 path 44 row 15
# fracAreaMCD15: 0.012213703822535777
# year 2013 month 7 path 44 row 27
# fracAreaMCD15: 0.4282237332921844
# fracAreaLCtoMCD: 0.4274986558693874
# cumulative samples: 236262 nsaminput 312
# year 2013 month 7 path 44 row 28
# fracAreaMCD15: 0.4723121019310829
# fracAreaLCtoMCD: 0.44623135329502145
# cumulative samples: 236550 nsaminput 288
# year 2013 month 7 path 44 row 29
# fracAreaMCD15: 0.274374324620165
# fracAreaLCtoMCD: 0.2750062389412684
# cumulative samples: 238306 nsaminput 1756
# year 2013 month 7 path 44 row 30
# fracAreaMCD15: 0.311686236006207
# fracAreaLCtoMCD: 0.3158328143756008
# cumulative samples: 239316 nsaminput 1010
# year 2013 month 7 path 44 row 31
# fracAreaMCD15: 0.3181226673987485
# fracAreaLCtoMCD: 0.3183995282367382
# cumulative samples: 241335 nsaminput 2019
# year 2013 month 7 path 44 row 32
# fracAreaMCD15: 0.4825778991341037
# fracAreaLCtoMCD: 0.47542391064990935
# cumulative samples: 241992 nsaminput 657
# year 2013 month 7 path 44 row 33
# fracAreaMCD15: 0.6415118460704535
# fracAreaLCtoMCD: 0.6397970339378701
# cumulative samples: 245913 nsaminput 3921
# year 2013 month 7 path 45 row 29
# fracAreaMCD15: 0.15810000797340004
# year 2013 month 7 path 45 row 30
# fracAreaMCD15: 0.21205727894559542
# year 2013 month 7 path 45 row 31
# fracAreaMCD15: 0.38135182490125213
# fracAreaLCtoMCD: 0.38318431903510874
# cumulative samples: 248001 nsaminput 2088
# year 2013 month 7 path 45 row 32
# fracAreaMCD15: 0.5258944743821691
# fracAreaLCtoMCD: 0.5236786491508078
# cumulative samples: 251367 nsaminput 3366
# year 2013 month 7 path 45 row 33
# year 2013 month 7 path 46 row 10
# fracAreaMCD15: 0.001650699396554139
# year 2013 month 7 path 46 row 11
# fracAreaMCD15: 0.042493839269245645
# year 2013 month 7 path 46 row 17
# fracAreaMCD15: 0.0012374947353954186
# year 2013 month 7 path 46 row 18
# fracAreaMCD15: 0.00941864190517293
# year 2013 month 7 path 46 row 19
# fracAreaMCD15: 0.6126041530254951
# fracAreaLCtoMCD: 0.6097136002733966
# cumulative samples: 252346 nsaminput 979
# year 2013 month 7 path 46 row 20
# fracAreaMCD15: 0.3368995798937785
# fracAreaLCtoMCD: 0.36484174575085837
# cumulative samples: 252386 nsaminput 40
# year 2013 month 7 path 46 row 21
# fracAreaMCD15: 0.16731250391361382
# year 2013 month 7 path 46 row 22
# fracAreaMCD15: 0.17694469913241512
# year 2013 month 7 path 46 row 23
# fracAreaMCD15: 0.02772761339425864
# year 2013 month 7 path 46 row 24
# fracAreaMCD15: 0.051597963825131
# year 2013 month 7 path 46 row 25
# fracAreaMCD15: 0.3973023099974851
# fracAreaLCtoMCD: 0.37489674220852726
# cumulative samples: 254569 nsaminput 2183
# year 2013 month 7 path 46 row 26
# fracAreaMCD15: 0.3111368458876074
# fracAreaLCtoMCD: 0.3207753172936505
# cumulative samples: 255279 nsaminput 710
# year 2013 month 7 path 46 row 27
# fracAreaMCD15: 0.26391697989229873
# fracAreaLCtoMCD: 0.26361088197471166
# cumulative samples: 256968 nsaminput 1689
# year 2013 month 7 path 46 row 28
# year 2013 month 7 path 46 row 29
# fracAreaMCD15: 0.03358252468972047
# year 2013 month 7 path 46 row 30
# fracAreaMCD15: 0.06531762037398453
# year 2013 month 7 path 46 row 31
# fracAreaMCD15: 0.10609629003735978
# year 2013 month 7 path 47 row 19
# fracAreaMCD15: 0.13471553492639815
# year 2013 month 7 path 47 row 29
# year 2013 month 7 path 47 row 30
# fracAreaMCD15: 0.03523358015292625
# year 2013 month 7 path 47 row 31
# year 2013 month 7 path 48 row 10
# fracAreaMCD15: 0.0
# year 2013 month 7 path 48 row 16
# fracAreaMCD15: 0.018109532433620863
# year 2013 month 7 path 49 row 11
# fracAreaMCD15: 0.13166621931209802
# year 2013 month 7 path 49 row 12
# fracAreaMCD15: 0.02353087619511562
# year 2013 month 7 path 49 row 16
# fracAreaMCD15: 0.0
# year 2013 month 7 path 49 row 22
# fracAreaMCD15: 0.03256641664982955
# year 2013 month 7 path 50 row 23
# fracAreaMCD15: 0.010657281677815097
# year 2013 month 7 path 50 row 24
# fracAreaMCD15: 0.8299643237406089
# fracAreaLCtoMCD: 0.8263709999415209
# cumulative samples: 257035 nsaminput 67
# year 2013 month 7 path 50 row 25
# fracAreaMCD15: 0.0
# year 2013 month 7 path 50 row 26
# fracAreaMCD15: 0.027756147999271282
# year 2013 month 7 path 52 row 16
# fracAreaMCD15: 0.06830082837994791
# ...
# fracAreaMCD15: 0.0
# year 2019 month 11 path 24 row 24
# fracAreaMCD15: 0.0
# year 2019 month 11 path 24 row 29
# fracAreaMCD15: 0.0
# year 2019 month 11 path 24 row 32
# fracAreaMCD15: 0.010021037177609798
# year 2019 month 11 path 24 row 33
# fracAreaMCD15: 0.004971736170949331
# year 2019 month 11 path 24 row 34
# fracAreaMCD15: 0.2168089982071524
# year 2019 month 11 path 24 row 35
# fracAreaMCD15: 0.22772831756843095
# year 2019 month 11 path 24 row 36
# fracAreaMCD15: 0.33513842402086713
# fracAreaLCtoMCD: 0.3338463875126822
# cumulative samples: 6937179 nsaminput 1882
# year 2019 month 11 path 24 row 37
# fracAreaMCD15: 0.6282841833841774
# fracAreaLCtoMCD: 0.6223017272069542
# cumulative samples: 6941200 nsaminput 4021
# year 2019 month 11 path 24 row 38
# fracAreaMCD15: 0.22923210117812415
# year 2019 month 11 path 24 row 39
# fracAreaMCD15: 0.7403066219811486
# fracAreaLCtoMCD: 0.7369345177618956
# cumulative samples: 6942355 nsaminput 1155
# year 2019 month 11 path 25 row 32
# fracAreaMCD15: 0.5312720960982936
# fracAreaLCtoMCD: 0.5296609299626989
# cumulative samples: 6942617 nsaminput 262
# year 2019 month 11 path 26 row 34
# fracAreaMCD15: 0.46696064734006065
# fracAreaLCtoMCD: 0.45703434622287903
# cumulative samples: 6943779 nsaminput 1162
# year 2019 month 11 path 26 row 35
# fracAreaMCD15: 0.4172045699565035
# fracAreaLCtoMCD: 0.41482768047987584
# cumulative samples: 6946449 nsaminput 2670
# year 2019 month 11 path 26 row 36
# fracAreaMCD15: 0.8065520433015482
# fracAreaLCtoMCD: 0.5155906130523673
# cumulative samples: 6949792 nsaminput 3343
# year 2019 month 11 path 27 row 35
# fracAreaMCD15: 0.03323876607354243
# year 2019 month 11 path 27 row 36
# fracAreaMCD15: 0.0735978138882904
# year 2019 month 11 path 27 row 37
# fracAreaMCD15: 0.05074260364914371
# year 2019 month 11 path 27 row 38
# fracAreaMCD15: 0.045109089489763374
# year 2019 month 11 path 27 row 39
# fracAreaMCD15: 0.14656781210656686
# year 2019 month 11 path 28 row 21
# fracAreaMCD15: 0.0
# year 2019 month 11 path 28 row 22
# year 2019 month 11 path 29 row 30
# fracAreaMCD15: 0.12902159981618774
# year 2019 month 11 path 29 row 31
# fracAreaMCD15: 0.0016780198653273488
# year 2019 month 11 path 29 row 32
# fracAreaMCD15: 0.039301699817375316
# year 2019 month 11 path 29 row 33
# fracAreaMCD15: 0.17172272373890177
# year 2019 month 11 path 29 row 34
# fracAreaMCD15: 0.26077795820308064
# fracAreaLCtoMCD: 0.2618208272368449
# cumulative samples: 6951461 nsaminput 1669
# year 2019 month 11 path 29 row 35
# fracAreaMCD15: 0.4333281016376267
# fracAreaLCtoMCD: 0.42719230116383466
# cumulative samples: 6952156 nsaminput 695
# year 2019 month 11 path 29 row 36
# fracAreaMCD15: 0.13048014668813288
# year 2019 month 11 path 29 row 37
# fracAreaMCD15: 0.23687973065582052
# year 2019 month 11 path 29 row 38
# fracAreaMCD15: 0.41532753709160936
# fracAreaLCtoMCD: 0.41662371061844783
# cumulative samples: 6954054 nsaminput 1898
# year 2019 month 11 path 29 row 39
# fracAreaMCD15: 0.701748207094406
# fracAreaLCtoMCD: 0.7003231270469306
# cumulative samples: 6958545 nsaminput 4491
# year 2019 month 11 path 30 row 22
# fracAreaMCD15: 0.0
# year 2019 month 11 path 30 row 31
# fracAreaMCD15: 0.11825416523549745
# year 2019 month 11 path 30 row 32
# fracAreaMCD15: 0.015515507360628945
# year 2019 month 11 path 30 row 33
# fracAreaMCD15: 0.3868450586038183
# fracAreaLCtoMCD: 0.37791875277953463
# cumulative samples: 6959559 nsaminput 1014
# year 2019 month 11 path 30 row 34
# fracAreaMCD15: 0.24515974404940097
# year 2019 month 11 path 30 row 35
# fracAreaMCD15: 0.4478458892221176
# fracAreaLCtoMCD: 0.44782917374444015
# cumulative samples: 6962425 nsaminput 2866
# year 2019 month 11 path 30 row 36
# fracAreaMCD15: 0.2195285752096926
# year 2019 month 11 path 30 row 37
# fracAreaMCD15: 0.312968991551452
# fracAreaLCtoMCD: 0.3122552772072897
# cumulative samples: 6964428 nsaminput 2003
# year 2019 month 11 path 30 row 38
# fracAreaMCD15: 0.027333925613009815
# year 2019 month 11 path 30 row 39
# fracAreaMCD15: 0.023659866575494827
# year 2019 month 11 path 32 row 19
# year 2019 month 11 path 32 row 20
# fracAreaMCD15: 0.0
# year 2019 month 11 path 32 row 22
# fracAreaMCD15: 0.0
# year 2019 month 11 path 32 row 30
# year 2019 month 11 path 32 row 32
# fracAreaMCD15: 0.3861648184155339
# fracAreaLCtoMCD: 0.4053045680393594
# cumulative samples: 6964678 nsaminput 250
# year 2019 month 11 path 33 row 27
# fracAreaMCD15: 0.0016298755270246208
# year 2019 month 11 path 33 row 28
# fracAreaMCD15: 0.41416146410380467
# fracAreaLCtoMCD: 0.40536743552205823
# cumulative samples: 6965185 nsaminput 507
# year 2019 month 11 path 33 row 29
# fracAreaMCD15: 0.32484024465710193
# fracAreaLCtoMCD: 0.321290002211706
# cumulative samples: 6966702 nsaminput 1517
# year 2019 month 11 path 33 row 30
# fracAreaMCD15: 0.018314734748154617
# year 2019 month 11 path 33 row 31
# fracAreaMCD15: 0.14930023742479553
# year 2019 month 11 path 33 row 33
# fracAreaMCD15: 0.27776931136496613
# fracAreaLCtoMCD: 0.2771736086239798
# cumulative samples: 6967066 nsaminput 364
# year 2019 month 11 path 33 row 34
# fracAreaMCD15: 0.2502494182571375
# fracAreaLCtoMCD: 0.25328437019805655
# cumulative samples: 6968318 nsaminput 1252
# year 2019 month 11 path 33 row 35
# fracAreaMCD15: 0.11358110837755173
# year 2019 month 11 path 33 row 36
# fracAreaMCD15: 0.27052963572343397
# fracAreaLCtoMCD: 0.2559767786036769
# cumulative samples: 6968342 nsaminput 24
# year 2019 month 11 path 33 row 37
# fracAreaMCD15: 0.3109397386334513
# fracAreaLCtoMCD: 0.31278409242908956
# cumulative samples: 6970332 nsaminput 1990
# year 2019 month 11 path 33 row 38
# fracAreaMCD15: 0.20125066510628578
# year 2019 month 11 path 33 row 39
# fracAreaMCD15: 0.39606693630644285
# fracAreaLCtoMCD: 0.3980942761266147
# cumulative samples: 6971195 nsaminput 863
# year 2019 month 11 path 34 row 32
# fracAreaMCD15: 0.12316161508809867
# year 2019 month 11 path 34 row 33
# fracAreaMCD15: 0.07796957102110424
# year 2019 month 11 path 34 row 34
# fracAreaMCD15: 0.4055344027908675
# fracAreaLCtoMCD: 0.40385328314873875
# cumulative samples: 6973763 nsaminput 2568
# year 2019 month 11 path 34 row 35
# fracAreaMCD15: 0.3305553085802063
# fracAreaLCtoMCD: 0.3318440972994892
# cumulative samples: 6975276 nsaminput 1513
# year 2019 month 11 path 34 row 36
# fracAreaMCD15: 0.15520912985765134
# year 2019 month 11 path 34 row 37
# fracAreaMCD15: 0.25407362391028615
# fracAreaLCtoMCD: 0.24697193969482054
# cumulative samples: 6976858 nsaminput 1582
# year 2019 month 11 path 34 row 38
# fracAreaMCD15: 0.26066396965568456
# fracAreaLCtoMCD: 0.25819978822109824
# cumulative samples: 6976909 nsaminput 51
# year 2019 month 11 path 34 row 39
# fracAreaMCD15: 0.017127290542126684
# year 2019 month 11 path 35 row 32
# fracAreaMCD15: 0.11353306387219705
# year 2019 month 11 path 35 row 33
# fracAreaMCD15: 0.3935957833876875
# fracAreaLCtoMCD: 0.3942065405528873
# cumulative samples: 6979329 nsaminput 2420
# year 2019 month 11 path 35 row 34
# fracAreaMCD15: 0.2121497137371199
# year 2019 month 11 path 35 row 35
# fracAreaMCD15: 0.3605383073705183
# fracAreaLCtoMCD: 0.35460705243804325
# cumulative samples: 6980601 nsaminput 1272
# year 2019 month 11 path 35 row 36
# fracAreaMCD15: 0.1868926720690518
# year 2019 month 11 path 36 row 33
# year 2019 month 11 path 36 row 34
# fracAreaMCD15: 0.3206676135370571
# fracAreaLCtoMCD: 0.3205211192883576
# cumulative samples: 6980900 nsaminput 299
# year 2019 month 11 path 36 row 35
# fracAreaMCD15: 0.5455637736507178
# fracAreaLCtoMCD: 0.5231781656136898
# cumulative samples: 6982385 nsaminput 1485
# year 2019 month 11 path 36 row 36
# fracAreaMCD15: 0.49010675802550374
# fracAreaLCtoMCD: 0.3628942274487072
# cumulative samples: 6984731 nsaminput 2346
# year 2019 month 11 path 37 row 33
# fracAreaMCD15: 0.4850945453291247
# fracAreaLCtoMCD: 0.48525710441088366
# cumulative samples: 6984838 nsaminput 107
# year 2019 month 11 path 37 row 34
# fracAreaMCD15: 0.36295620585354427
# fracAreaLCtoMCD: 0.32173911471274863
# cumulative samples: 6986893 nsaminput 2055
# year 2019 month 11 path 38 row 29
# fracAreaMCD15: 0.007901124505940663
# year 2019 month 11 path 38 row 30
# fracAreaMCD15: 0.05095667818552236
# year 2019 month 11 path 38 row 31
# fracAreaMCD15: 0.023287528684450175
# year 2019 month 11 path 38 row 32
# fracAreaMCD15: 0.01742854125535806
# year 2019 month 11 path 38 row 33
# fracAreaMCD15: 0.2145283220193181
# year 2019 month 11 path 38 row 34
# fracAreaMCD15: 0.19286932036664628
# year 2019 month 11 path 38 row 35
# fracAreaMCD15: 0.45346084232968903
# fracAreaLCtoMCD: 0.4514953714339255
# cumulative samples: 6989795 nsaminput 2902
# year 2019 month 11 path 38 row 36
# fracAreaMCD15: 0.43445218234458927
# fracAreaLCtoMCD: 0.4258934438742341
# cumulative samples: 6991797 nsaminput 2002
# year 2019 month 11 path 38 row 37
# fracAreaMCD15: 0.06276697730523247
# year 2019 month 11 path 38 row 38
# fracAreaMCD15: 0.0
# year 2019 month 11 path 39 row 29
# fracAreaMCD15: 0.06255198803851825
# year 2019 month 11 path 39 row 30
# fracAreaMCD15: 0.19926703449167843
# year 2019 month 11 path 39 row 31
# fracAreaMCD15: 0.17785192921205709
# year 2019 month 11 path 39 row 33
# fracAreaMCD15: 0.3216154255165659
# fracAreaLCtoMCD: 0.32044487737043637
# cumulative samples: 6993854 nsaminput 2057
# year 2019 month 11 path 39 row 34
# fracAreaMCD15: 0.33656399718432806
# fracAreaLCtoMCD: 0.33550826620638285
# cumulative samples: 6996008 nsaminput 2154
# year 2019 month 11 path 39 row 35
# fracAreaMCD15: 0.8338929284361024
# fracAreaLCtoMCD: 0.8561392428464458
# cumulative samples: 6996067 nsaminput 59
# year 2019 month 11 path 39 row 36
# fracAreaMCD15: 0.6490219735617628
# fracAreaLCtoMCD: 0.639697637892036
# cumulative samples: 6997224 nsaminput 1157
# year 2019 month 11 path 39 row 37
# fracAreaMCD15: 0.4145513499390838
# fracAreaLCtoMCD: 0.41921885001557324
# cumulative samples: 6999514 nsaminput 2290
# year 2019 month 11 path 39 row 38
# fracAreaMCD15: 0.025377970313363484
# year 2019 month 11 path 39 row 39
# fracAreaMCD15: 0.00027521567742712404
# year 2019 month 11 path 40 row 31
# fracAreaMCD15: 0.0668823955123808
# year 2019 month 11 path 40 row 33
# fracAreaMCD15: 0.17291212084906082
# year 2019 month 11 path 40 row 38
# fracAreaMCD15: 0.009542048745275894
# year 2019 month 11 path 41 row 23
# fracAreaMCD15: 0.04472770076818544
# year 2019 month 11 path 41 row 24
# fracAreaMCD15: 0.004913461256264389
# year 2019 month 11 path 41 row 25
# fracAreaMCD15: 0.012817146675044576
# year 2019 month 11 path 41 row 29
# fracAreaMCD15: 0.138438226418248
# year 2019 month 11 path 41 row 30
# fracAreaMCD15: 0.03495525424147464
# year 2019 month 11 path 41 row 31
# fracAreaMCD15: 0.37427677828070943
# fracAreaLCtoMCD: 0.3768813172328371
# cumulative samples: 7001733 nsaminput 2219
# year 2019 month 11 path 41 row 34
# fracAreaMCD15: 0.4670226150625136
# fracAreaLCtoMCD: 0.46476718604512735
# cumulative samples: 7003109 nsaminput 1376
# year 2019 month 11 path 41 row 35
# fracAreaMCD15: 0.5089414604062218
# fracAreaLCtoMCD: 0.40974230300808556
# cumulative samples: 7005550 nsaminput 2441
# year 2019 month 11 path 41 row 36
# fracAreaMCD15: 0.395304725618632
# fracAreaLCtoMCD: 0.3970356271665979
# cumulative samples: 7006028 nsaminput 478
# year 2019 month 11 path 42 row 31
# fracAreaMCD15: 0.13751271653989086
# year 2019 month 11 path 42 row 32
# fracAreaMCD15: 0.08492032701662576
# year 2019 month 11 path 43 row 30
# fracAreaMCD15: 0.22117093867441878
# year 2019 month 11 path 43 row 31
# fracAreaMCD15: 0.30218502979557954
# fracAreaLCtoMCD: 0.2997735219909231
# cumulative samples: 7006268 nsaminput 240
# year 2019 month 11 path 43 row 32
# fracAreaMCD15: 0.3093865191423128
# fracAreaLCtoMCD: 0.30973624900166874
# cumulative samples: 7008248 nsaminput 1980
# year 2019 month 11 path 43 row 33
# fracAreaMCD15: 0.4405202826309577
# fracAreaLCtoMCD: 0.4371848469718932
# cumulative samples: 7010604 nsaminput 2356
# year 2019 month 11 path 43 row 34
# fracAreaMCD15: 0.15953130936201798
# year 2019 month 11 path 43 row 35
# year 2019 month 11 path 43 row 36
# year 2019 month 11 path 44 row 35
# year 2019 month 11 path 45 row 27
# year 2019 month 11 path 45 row 28
# fracAreaMCD15: 0.054991899967736
# year 2019 month 11 path 45 row 29
# fracAreaMCD15: 0.09428525565878053
# year 2019 month 11 path 45 row 30
# fracAreaMCD15: 0.848
# fracAreaLCtoMCD: 0.558252427184466
# year 2019 month 11 path 45 row 31
# fracAreaMCD15: 0.19155490396065478
# year 2019 month 11 path 45 row 32
# fracAreaMCD15: 0.29358948834550985
# fracAreaLCtoMCD: 0.2914776564364331
# cumulative samples: 7012483 nsaminput 1879
# year 2019 month 11 path 45 row 33
# fracAreaMCD15: 0.3386399199504143
# fracAreaLCtoMCD: 0.33663582471207404
# cumulative samples: 7012604 nsaminput 121
# year 2019 month 11 path 45 row 34
# fracAreaMCD15: 0.0
# year 2019 month 11 path 50 row 19
# fracAreaMCD15: 0.0
# year 2019 month 11 path 53 row 20
# fracAreaMCD15: 0.0
# year 2019 month 1 path 7 row 24
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# File ~/anaconda3/envs/landsatModis/lib/python3.9/site-packages/ee/data.py:338, in _execute_cloud_call(call, num_retries)
#     337 try:
# --> 338   return call.execute(num_retries=num_retries)
#     339 except googleapiclient.errors.HttpError as e:
#
# File ~/anaconda3/envs/landsatModis/lib/python3.9/site-packages/googleapiclient/_helpers.py:134, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     133         logger.warning(message)
# --> 134 return wrapped(*args, **kwargs)
#
# File ~/anaconda3/envs/landsatModis/lib/python3.9/site-packages/googleapiclient/http.py:915, in HttpRequest.execute(self, http, num_retries)
#     914 if resp.status >= 300:
# --> 915     raise HttpError(resp, content, uri=self.uri)
#     916 return self.postproc(resp, content)
#
# HttpError: <HttpError 400 when requesting https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/value:compute?prettyPrint=false&alt=json returned "Image.select: Parameter 'input' is required.". Details: "Image.select: Parameter 'input' is required.">
#
# During handling of the above exception, another exception occurred:
#
# EEException                               Traceback (most recent call last)
# Input In [22], in <cell line: 4>()
#      57 imageLC = imageLC.addBands(ee.ImageCollection(collectionLandsatL1c) \
#      58                                               .filterMetadata('system:index','equals',imageLC.get('system:index')) \
#      59                                               .first() \
#    (...)
#      65                  .updateMask(imageLC.select('QA_PIXEL').bitwiseAnd(1<<3).eq(0)) \
#      66                  .updateMask(imageLC.select('QA_PIXEL').bitwiseAnd(1<<4).eq(0))
#      69 # get the fraction of area with unmasked LC data
# ---> 70 validArea = ee.Number(ee.Image.pixelArea().mask(imageLC.select('QA_PIXEL').mask()).reduceRegion(reducer=ee.Reducer.sum(),geometry=imageLC.geometry(),scale=30,bestEffort=True).get('area')).getInfo()
#      71 totalArea = ee.Number(ee.Image.pixelArea().mask(imageLC.select('QA_PIXEL').unmask().mask()).reduceRegion(reducer=ee.Reducer.sum(),geometry=imageLC.geometry(),scale=30,bestEffort=True).get('area')).getInfo()
#      73 fracAreaLC = 0
#
# File ~/anaconda3/envs/landsatModis/lib/python3.9/site-packages/ee/computedobject.py:98, in ComputedObject.getInfo(self)
#      92 def getInfo(self):
#      93   """Fetch and return information about this object.
#      94
#      95   Returns:
#      96     The object can evaluate to anything.
#      97   """
# ---> 98   return data.computeValue(self)
#
# File ~/anaconda3/envs/landsatModis/lib/python3.9/site-packages/ee/data.py:738, in computeValue(obj)
#     729 def computeValue(obj):
#     730   """Sends a request to compute a value.
#     731
#     732   Args:
#    (...)
#     736     The result of evaluating that object on the server.
#     737   """
# --> 738   return _execute_cloud_call(
#     739       _get_cloud_api_resource().projects().value().compute(
#     740           body={'expression': serializer.encode(obj, for_cloud_api=True)},
#     741           project=_get_projects_path(),
#     742           prettyPrint=False))['result']
#
# File ~/anaconda3/envs/landsatModis/lib/python3.9/site-packages/ee/data.py:340, in _execute_cloud_call(call, num_retries)
#     338   return call.execute(num_retries=num_retries)
#     339 except googleapiclient.errors.HttpError as e:
# --> 340   raise _translate_cloud_exception(e)
#
# EEException: Image.select: Parameter 'input' is required.
