# %%
import ee
import numpy as np
import pandas as pd
import pickle
import datetime

# %%
ee.Authenticate()
# Out:
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=-1LFnCGqu2kPGPFph3Ng6NH4_fpBQCHW8nIoZ2SzMbg&tc=dUl9fyybiUsEYL8q1v1H7WBrGWitmUa0uTrYW-3yJBs&cc=DwsDKJWaiLZe682XuIC4X8MxqWeUc90R9z_EH2CUvUg>https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=-1LFnCGqu2kPGPFph3Ng6NH4_fpBQCHW8nIoZ2SzMbg&tc=dUl9fyybiUsEYL8q1v1H7WBrGWitmUa0uTrYW-3yJBs&cc=DwsDKJWaiLZe682XuIC4X8MxqWeUc90R9z_EH2CUvUg</a></p>
#         <p>The authorization workflow will generate a code, which you
#         should paste in the box below</p>
# Enter verification code:  4/1AX4XfWh-nBbLoD-Rs47lov5FS-6BlLf59u0VY6O8IiWKe99C_iiK0rm9rlQ
# Successfully saved authorization token.

# %%
ee.Initialize()

# %%
# sampling paramaters
randomSeed = 12
collectionLandsatL1c = "LANDSAT/LC08/C02/T1_TOA" # landsat image collection
collectionLandsatL2a= "LANDSAT/LC08/C02/T1_L2" # landsat image collection
cloudCoverL0X = 10# maximum cloud cover of sampled Landsat images
maxSample = 10000 # maximum samples to extract from each Landsat image
outputScale = 500 # scale of output comparisons , increasing this will eventually exceed memory
subimageSize = 40000 # m dimension of subimage we will randomly extract from Landsat image to avoid memory limits
minfracAreaLC = 0.5 # minimum cloud free valid  Landsat subimage fraction
minfracAreaMCD15 = 0.25 # minimum cloud free valid MODIS area in Landsat subimage fraction's unmasked area
minfracAreaLCtoMCD = 0.10 # valid aggregated landsat fraction
minfracValidLC = 0.9 # minimum facation of valid landsat pixels in each aggregated modis pixels to estimate mean values
deltaRow = 1  # skip this many WRS rows when sampling Landsat scenes
deltaPath = 1 # skip this many WRS paths when sampling Landsat scenes
deltaDay = 15 # search this many contiguous days when looking for a cloud free Landsat scene
maxPixels = 300 # max landsat pixels allowed to be aggregated in an output pixel, should be about 20% larger than the ratio of (outputScale/30) (cannot exceed 1024)

#output files
InputFileNameB36 = '/home/richard_fernandes/LUTinputLC0XB36calv13'
InputFileNameB45 = '/home/richard_fernandes/LUTinputLC0XB45calv13'
InputFileNameMOD09 = '/home/richard_fernandes/LUTinputMOD09calv13'
InputFileNameMOD09bands = '/home/richard_fernandes/LUTinputMOD09bandscalv13'
InputFileNameLat = '/home/richard_fernandes/LUTinputLC0XLatcalv13'
InputFileNameLon = '/home/richard_fernandes/LUTinputLC0XLoncalv13'
OutputFileName = '/home/richard_fernandes/LUToutputLC0Xcalv13'
YearFileName = '/home/richard_fernandes/YearLC0Xcalv13'
MonthFileName = '/home/richard_fernandes/MonthLC0Xcalv13'
DayFileName = '/home/richard_fernandes/DayLC0Xcalv13'
PathFileName = '/home/richard_fernandes/PathLC0Xcalv13'
RowFileName = '/home/richard_fernandes/RowLC0Xcalv13'
FparLai_QCName = '/home/richard_fernandes/FparLai_QCcalv13'
FparExtra_QCName = '/home/richard_fernandes/FparExtra_QCcalv13'

# %%
# Match MOD09A1.006 daily reflectance data and MCD12Q1 annual biome type to  MCD15A3H.006 image composite
# masking any dates without exactly one MOD09A1 valid clear sky value and one valid MCD153AH terra retrieval
def matchMOD09A1toMCD15(imageMCD15):
    
    # get date range of MCD15A3Himage
    d1 = ee.Date(imageMCD15.get('system:time_start'));
    d2 = ee.Date(imageMCD15.get('system:time_end'));
    
#    print(d1.getInfo())
#    print(d2.getInfo())
    # find MOD09A1 products within date range of MCD15 and mask them 
    colMOD09A1 = ee.ImageCollection("MODIS/006/MOD09GA").filterDate(d1,d2).map(lambda image: image.updateMask(image.select('QC_500m').bitwiseAnd(1<<1).eq(0)) \
                                                                                                  .updateMask(image.select('state_1km').bitwiseAnd(1<<0).eq(0)) \
                                                                                                  .updateMask(image.select('state_1km').bitwiseAnd(1<<1).eq(0)) \
                                                                                                  .updateMask(image.select('state_1km').bitwiseAnd(1<<2).eq(0)) \
                                                                                                  .addBands(image.select('sur_refl_b02').divide(image.select('sur_refl_b01').add(1)).rename('SR_VI')))
                                                                                                 # .updateMask(image.select('state_1km').bitwiseAnd(1<<3).eq(1)) )
                                                                                                #  .updateMask(image.select('state_1km').bitwiseAnd(1<<4).eq(0)) \
                                                                                                #   .updateMask(image.select('state_1km').bitwiseAnd(1<<5).eq(0)) \
                                                                                               #   .updateMask(image.select('state_1km').bitwiseAnd(1<<6).gt(-1)) \
                                                                                              #    .updateMask(image.select('state_1km').bitwiseAnd(1<<7).eq(0)) \
                                                                                                #  .updateMask(image.select('state_1km').bitwiseAnd(1<<8).eq(8)) \
                                                                                                #  .updateMask(image.select('state_1km').bitwiseAnd(1<<9).eq(0)) \
                                                                                               #   .updateMask(image.select('state_1km').bitwiseAnd(1<<10).eq(0)) \
                                                                                                #  .updateMask(image.select('state_1km').bitwiseAnd(1<<11).eq(1)) \
                                                                                                 # .updateMask(image.select('state_1km').bitwiseAnd(1<<12).eq(0)) \
                                                                                                 # .updateMask(image.select('state_1km').bitwiseAnd(1<<13).eq(0)) \
                                                                                                 # .updateMask(image.select('state_1km').bitwiseAnd(1<<14).eq(0)) \
                                                                                                 # .updateMask(image.select('state_1km').bitwiseAnd(1<<15).eq(0)))
    #    print(colMOD09A1.size().getInfo())
    # get biome type map
    imageMCD12Q1 = ee.ImageCollection("MODIS/006/MCD12Q1").map(lambda image: image.set('daterange',ee.DateRange(ee.Date(image.get('system:time_start')),ee.Date(image.get('system:time_end')))))\
                                                            .filter(ee.Filter.dateRangeContains('daterange', d1)) \
                                                            .first() \
                                                            .select('LC_Type3') 
#    print(imageMCD12Q1.getInfo())

# make mask of pixels containing only one valid cloud free MOD09 500m retrieval
    # and a primary algorithm retyrieval from terra wigthout significant clouds
    # and add MOD09A1 composite created by apply the MCD15 mask to the MOOD9A1 collection and composite it
    # and add biome type
    imageMCD15 = imageMCD15.updateMask( colMOD09A1.count().select('sur_refl_b01').gt(-1) ) \
                            .updateMask( imageMCD15.select('FparLai_QC').bitwiseAnd(1<<0).eq(0)) \
                            .updateMask( imageMCD15.select('FparLai_QC').bitwiseAnd(1<<1).eq(0)) \
                            .updateMask( imageMCD15.select('FparLai_QC').bitwiseAnd(1<<2).eq(0)) \
                            .updateMask( imageMCD15.select('FparLai_QC').bitwiseAnd(1<<3).eq(0)) \
                            .updateMask( imageMCD15.select('FparLai_QC').bitwiseAnd(1<<4).eq(0)) \
                            .updateMask(imageMCD15.select('FparLai_QC').bitwiseAnd(1<<6).eq(0)) \
                            .updateMask(imageMCD15.select('FparLai_QC').bitwiseAnd(1<<7).eq(0)) \
                            .updateMask(imageMCD15.select('FparExtra_QC').bitwiseAnd(1<<1).eq(0)) \
                            .updateMask( imageMCD12Q1.select('LC_Type3').gt(0)) \
                            .addBands( imageMCD12Q1 )
    imageMCD15 = imageMCD15.addBands(colMOD09A1.map(lambda image: image.mask(imageMCD15.select('Lai'))).qualityMosaic('SR_VI'))


    
   
    
    
    return imageMCD15

# %%
# coded LUT for output MODIS MCD15
def getLUTout(imageMCD15):
    imageMCD15 = ee.Image(imageMCD15);

    return imageMCD15.select('Lai').min(99).multiply(1).toInt64() \
                        .add(imageMCD15.select('LaiStdDev').min(99).multiply(1e2).toInt64()) \
                        .add(imageMCD15.select('Fpar').min(99).multiply(1e4).toInt64()) \
                        .add(imageMCD15.select('FparStdDev').min(99).multiply(1e6).toInt64()) \
                        .add(imageMCD15.select('satFlag').multiply(100).multiply(1e9).toInt64()) \
                        .add(imageMCD15.select('snowFlag').multiply(100).multiply(1e12).toInt64()) \
                        .add(imageMCD15.select('LC_Type3').multiply(1e14).toInt64()) \
                        .rename('LUTout')

# %%
# Code LUT for an input MOD09 image , same as getLUTin but no satFlag
def getLUTinMOD09(imageMCD15MOD09):
    
     return imageMCD15MOD09.select('sur_refl_b01').add(100).max(0).min(9999).floor().toInt64().multiply(1).toInt64() \
                        .add(imageMCD15MOD09.select('sur_refl_b02').add(100).max(0).min(9999).floor().toInt64().multiply(1e4).toInt64()) \
                        .add(imageMCD15MOD09.select('SolarZenith').multiply(0.01).max(0).min(99).floor().toInt64().multiply(1e8).toInt64()) \
                        .add(imageMCD15MOD09.select('SolarAzimuth').multiply(0.01).add(180).max(0).min(360).floor().toInt64().multiply(1e10).toInt64()) \
                        .add(imageMCD15MOD09.select('SensorZenith').multiply(0.01).max(0).min(99).floor().toInt64().multiply(1e13).toInt64()) \
                        .add(imageMCD15MOD09.select('SensorAzimuth',).multiply(0.01).add(180).max(0).min(360).floor().toInt64().multiply(1e15).toInt64()) \
                        .rename('LUTinMOD09')

# %%
# Code LUT for an input MOD09 image , same as getLUTin but no satFlag
def getLUTinMOD09bands(imageMCD15MOD09):
    
     return imageMCD15MOD09.select('sur_refl_b03').add(100).max(0).min(9999).floor().toInt64().multiply(1).toInt64() \
                        .add(imageMCD15MOD09.select('sur_refl_b04').add(100).max(0).min(9999).floor().toInt64().multiply(1e4).toInt64()) \
                        .add(imageMCD15MOD09.select('sur_refl_b06').add(100).max(0).min(9999).floor().toInt64().multiply(1e8).toInt64()) \
                        .add(imageMCD15MOD09.select('sur_refl_b07').add(100).max(0).min(9999).floor().toInt64().multiply(1e12).toInt64()) \
                        .rename('LUTinMOD09bands')

# %%
# coded LUT for input landsat image red and nir band
def getLUTL0XinB45(imageMCD15):
    imageMCD15 = ee.Image(imageMCD15);
    return imageMCD15.select('SR_B4').multiply(2.75e-05).add(-0.2).max(0).min(0.999).multiply(1000).floor().multiply(1).toInt64() \
                        .add(imageMCD15.select('SR_B5').multiply(2.75e-05).add(-0.2).max(0).min(0.999).multiply(1000).floor().multiply(1e3).toInt64()) \
                        .add(imageMCD15.select('VZA').multiply(0.01).round().multiply(1e6).toInt64()) \
                        .add(imageMCD15.select('VAA').multiply(0.01).add(180).round().multiply(1e8).toInt64()) \
                        .add(imageMCD15.select('SZA').multiply(0.01).round().multiply(1e11).toInt64()) \
                        .add(imageMCD15.select('SAA').multiply(0.01).add(180).round().multiply(1e13).toInt64()) \
                        .rename('LUTL0XinB45')

# %%
# coded LUT for input landsat image green and swir
def getLUTL0XinB36(imageMCD15):
    imageMCD15 = ee.Image(imageMCD15);
    return imageMCD15.select('SR_B3').multiply(2.75e-05).add(-0.2).max(0).min(0.999).multiply(1000).floor().multiply(1).toInt64() \
                        .add(imageMCD15.select('SR_B6').multiply(2.75e-05).add(-0.2).max(0).min(0.999).multiply(1000).floor().multiply(1e3).toInt64()) \
                        .add(imageMCD15.select('VZA').multiply(0.01).round().multiply(1e6).toInt64()) \
                        .add(imageMCD15.select('VAA').multiply(0.01).add(180).round().multiply(1e8).toInt64()) \
                        .add(imageMCD15.select('SZA').multiply(0.01).round().multiply(1e11).toInt64()) \
                        .add(imageMCD15.select('SAA').multiply(0.01).add(180).round().multiply(1e13).toInt64()) \
                        .rename('LUTL0XinB36')

# %%
# sample worldwide 
# check each year and month
cumsam = 0
for year in range(2013,2022):#

        
    # specify land cover projected into MOD15 projection and aggregated using median to outputScale    
    projectionMCD15=  ee.ImageCollection('MODIS/006/MCD15A3H').first().select('Lai').projection()
    projectionMCD12 =  ee.ImageCollection("MODIS/006/MCD12Q1").first().select('LC_Type3').projection()
    imageMCD12Q1 = ee.ImageCollection("MODIS/006/MCD12Q1").filterDate(ee.Date.fromYMD(year,1,1),ee.Date.fromYMD(year,12,31)).first() \
                     .select('LC_Type3') \
                     .reproject(crs= projectionMCD15,crsTransform= None,scale=projectionMCD12.nominalScale() ) \
                     .reduceResolution(reducer= ee.Reducer.median(),maxPixels= 1024,bestEffort=False) \
                     .reproject(crs= projectionMCD15.atScale(outputScale))      

    # sample monthly data
    for month in [6,7,5,8,4,9,3,10,2,11,1,12]:  
        
        #sample WRS path rows
        for path in range(1,240,deltaPath): 
            for row in range(1,240,deltaRow): 
                
                # sample deltaDay intervals of each month
                for daystart in range (1,30-deltaDay,deltaDay):
                    
                    # find Landsat images for paht , row and date interval between 0 and maxCloudCover
                    imageLC = ee.ImageCollection(collectionLandsatL2a).filterMetadata('WRS_PATH','equals',path) \
                                                                          .filterMetadata('WRS_ROW','equals',row) \
                                                                          .filterDate(ee.Date.fromYMD(year,month,daystart),ee.Date.fromYMD(year,month,daystart).advance(deltaDay,'days')) \
                                                                          .filter(ee.Filter.lte('CLOUD_COVER_LAND',cloudCoverL0X))
                    
                    # only proceed if there is at least one filtered landsat image (we will only use the first one found)
                    if (imageLC.size().getInfo() > 0) : 

                        # only sample the first scene we found in the interval of deltaDay's 
                        imageLC = imageLC.first()
                        projectionLC = imageLC.select('QA_PIXEL').projection()
                        
                        # get date range of imageLC and print it out
                        d1 = ee.Date(imageLC.get('system:time_start'))
                        d2 = ee.Date(imageLC.get('system:time_end'))     
                        print('year',year,'month',month,'path',path,'row',row)

                        # get  MOD15 product containing the aquistion of the  Landsat image
                        imageMCD15 = ee.ImageCollection('MODIS/006/MCD15A3H') \
                                                    .map(lambda image: image.set('daterange',ee.DateRange(ee.Date(image.get('system:time_start')),ee.Date(image.get('system:time_end')))))\
                                                    .filter(ee.Filter.dateRangeContains('daterange', d1)) \
                                                    .map(lambda image: matchMOD09A1toMCD15(image) ) 

                        # only proceed if there is a MCD15 product containing the Landsat image aquisition
                        if (imageMCD15.size().getInfo() > 0)  :

                            
                            #randomly sample a sub-image to avoid memory issues, 
                            # add a validPixel we will use to determine aggregation and unmask since we will accept some missing data
                            imageGRID = imageLC.geometry().coveringGrid(projectionMCD15,subimageSize).randomColumn(columnName='randomIndex',seed=randomSeed)                                
                            imageLC = imageLC.addBands(ee.ImageCollection(collectionLandsatL1c) \
                                                                          .filterMetadata('system:index','equals',imageLC.get('system:index')) \
                                                                          .first() \
                                                                          .select(['VZA','VAA','SZA','SAA'])) \
                                             .clip(ee.Feature(imageGRID.sort('randomIndex').first()).geometry()) \
                                             .updateMask(imageLC.select('QA_PIXEL').bitwiseAnd(1<<0).eq(0)) \
                                             .updateMask(imageLC.select('QA_PIXEL').bitwiseAnd(1<<1).eq(0)) \
                                             .updateMask(imageLC.select('QA_PIXEL').bitwiseAnd(1<<2).eq(0)) \
                                             .updateMask(imageLC.select('QA_PIXEL').bitwiseAnd(1<<3).eq(0)) \
                                             .updateMask(imageLC.select('QA_PIXEL').bitwiseAnd(1<<4).eq(0)) 
        
                            
                            # get the fraction of area with unmasked LC data 
                            validArea = ee.Number(ee.Image.pixelArea().mask(imageLC.select('QA_PIXEL').mask()).reduceRegion(reducer=ee.Reducer.sum(),geometry=imageLC.geometry(),scale=30,bestEffort=True).get('area')).getInfo()
                            totalArea = ee.Number(ee.Image.pixelArea().mask(imageLC.select('QA_PIXEL').unmask().mask()).reduceRegion(reducer=ee.Reducer.sum(),geometry=imageLC.geometry(),scale=30,bestEffort=True).get('area')).getInfo()
                            
                            fracAreaLC = 0 
                            if (totalArea > 0) :
                                fracAreaLC = validArea / totalArea
                            #print('fracAreaLC:',fracAreaLC)  

                            # proceed if there is sufficient landsat area
                            if ( fracAreaLC > minfracAreaLC) :
                                                
                                # get MCD15 image from collection, clip to Landsat subimage
                                imageMCD15 = imageMCD15.first().clip(imageLC.geometry()) 
                                                
                                # update mask and add land cover and a saturation flag band
                                imageMCD15 = imageMCD15.updateMask( imageMCD15.select('FparLai_QC').bitwiseAnd(1<<0).eq(0)) \
                                                .updateMask( imageMCD15.select('FparLai_QC').bitwiseAnd(1<<2).eq(0)) \
                                                .updateMask( imageMCD15.select('FparLai_QC').bitwiseAnd(1<<3).eq(0)) \
                                                .updateMask( imageMCD15.select('FparLai_QC').bitwiseAnd(1<<4).eq(0)) \
                                                .updateMask( imageMCD15.select('FparLai_QC').bitwiseAnd(1<<6).eq(0)) \
                                                .updateMask( imageMCD15.select('FparLai_QC').bitwiseAnd(1<<7).eq(0)) \
                                                .addBands(imageMCD15.select('FparLai_QC').rename(['satFlag']).bitwiseAnd(1<<5).eq(1)) \
                                                .addBands(imageMCD15.select('FparExtra_QC').rename(['snowFlag']).bitwiseAnd(1<<2).eq(1)) \
                                                .updateMask( imageMCD15.select('FparExtra_QC').bitwiseAnd(1<<0).eq(0)) \
                                                .updateMask( imageMCD15.select('FparExtra_QC').bitwiseAnd(1<<1).eq(0)) \
                                                .updateMask( imageMCD15.select('FparExtra_QC').bitwiseAnd(1<<3).eq(0)) \
                                                .updateMask( imageMCD15.select('FparExtra_QC').bitwiseAnd(1<<4).eq(0)) \
                                                .updateMask( imageMCD15.select('FparExtra_QC').bitwiseAnd(1<<5).eq(0)) \
                                                .updateMask( imageMCD15.select('FparExtra_QC').bitwiseAnd(1<<6).eq(0)) \


                            
                                # get the fraction of area with unmasked MCD15 data 
                                validArea = ee.Number(ee.Image.pixelArea().mask(imageMCD15.select('Lai').mask()).reduceRegion(reducer=ee.Reducer.sum(),geometry=imageLC.geometry(),crs=projectionMCD15.atScale(outputScale)).get('area')).getInfo()
                                totalArea = ee.Number(ee.Image.pixelArea().mask(imageMCD15.select('Lai').unmask().mask()).reduceRegion(reducer=ee.Reducer.sum(),geometry=imageLC.geometry(),crs=projectionMCD15.atScale(outputScale)).get('area')).getInfo()
                                fracAreaMCD15 = 0 
                                if (totalArea > 0) :
                                    fracAreaMCD15 = validArea / totalArea
                                print('fracAreaMCD15:',fracAreaMCD15) 
                           
                                # sample if there is sufficient unmasked area
                                if ( fracAreaMCD15> minfracAreaMCD15 ) :
                                                
                                    
                                    # add a view zenith angle band and a validPixel band to the landsat image
                                    # then unmask and aggregate to output scale, we unmask first to allow for <100% validPixel s
                                    imageLCtoMCD = imageLC.addBands(imageLC.unmask().select('QA_PIXEL').gt(-1).rename('validPixel')) \
                                                         .reproject(crs= projectionMCD15,scale=projectionLC.nominalScale() ) \
                                                         .reduceResolution(reducer= ee.Reducer.mean(),maxPixels=maxPixels,bestEffort=False) \
                                                         .reproject(crs= projectionMCD15 , scale= outputScale) \
                                                         .updateMask(imageMCD15.select('FparLai_QC').mask())
                                   
                                    # mask bands not meeting fractional pixel threshold
                                    # we then have to divide by the fractional validPixel band to adjust for  zero masked values 
                                    validLCtoMCD = imageLCtoMCD.select('validPixel').gte(minfracValidLC);
                                    imageLCtoMCD = imageLCtoMCD.updateMask(validLCtoMCD)


                                    # add the aggregated LC image to the modis image and update the MCD image with the valid mask
                                    imageMCD15 = imageMCD15.addBands(imageLCtoMCD) \
                                                            .updateMask(validLCtoMCD) 
                                                            
                                    # get the fraction of area with unmasked LC data 
                                    validArea = ee.Number(ee.Image.pixelArea().mask(imageMCD15.select('QA_PIXEL').mask()).reduceRegion(reducer=ee.Reducer.sum(),geometry=imageMCD15.geometry(),scale=outputScale,bestEffort=True).get('area')).getInfo()
                                    totalArea = ee.Number(ee.Image.pixelArea().mask(imageMCD15.select('QA_PIXEL').unmask().mask()).reduceRegion(reducer=ee.Reducer.sum(),geometry=imageMCD15.geometry(),scale=outputScale,bestEffort=True).get('area')).getInfo()
                                    fracAreaLCtoMCD = 0 
                                    if (totalArea > 0) :
                                        fracAreaLCtoMCD = validArea / totalArea
                                    print('fracAreaLCtoMCD:',fracAreaLCtoMCD)  
                                    
                                    # check if we have enough valid cloud free aggregated matches
                                    if ( fracAreaLCtoMCD > minfracAreaLCtoMCD ) :
 

                                        imageMCD15 = imageMCD15.select(['satFlag','snowFlag','FparLai_QC','FparExtra_QC']) \
                                                                .addBands(getLUTout(imageMCD15)) \
                                                                 .addBands(getLUTL0XinB45(imageMCD15)) \
                                                                 .addBands(getLUTL0XinB36(imageMCD15)) \
                                                                 .addBands(getLUTinMOD09(imageMCD15)) \
                                                                 .addBands(getLUTinMOD09bands(imageMCD15)) \
                                                                 .addBands(ee.Image.pixelLonLat()) \
                                                                 .updateMask(validLCtoMCD)
        
                                        sampleData = imageMCD15.sample(projection=projectionMCD15.atScale(outputScale), numPixels=maxSample, dropNulls=True)
                                        sampleOutput = sampleData.aggregate_array('LUTout').flatten().getInfo()
                                        sampleInputB45 = sampleData.aggregate_array('LUTL0XinB45').flatten().getInfo()
                                        sampleInputB36 = sampleData.aggregate_array('LUTL0XinB36').flatten().getInfo()
                                        sampleInputMOD09 = sampleData.aggregate_array('LUTinMOD09').flatten().getInfo()
                                        sampleInputMOD09bands = sampleData.aggregate_array('LUTinMOD09bands').flatten().getInfo()
                                        sampleInputLon = sampleData.aggregate_array('longitude').flatten().getInfo()
                                        sampleInputLat = sampleData.aggregate_array('latitude').flatten().getInfo()
                                        sampleFparLai_QC = sampleData.aggregate_array('FparLai_QC').flatten().getInfo()
                                        sampleFparExtra_QC = sampleData.aggregate_array('FparExtra_QC').flatten().getInfo()

                                        if (len(sampleOutput)>0) :

                                            numsam = len(sampleOutput)
                                            cumsam = cumsam + numsam
                                            print('cumulative samples:',cumsam,'nsaminput',numsam)
                                            
                                            # write list after each landsat scene is done (comment out if it is too frequent)
                                            with open(InputFileNameLon, 'ab') as fp1:
                                                pickle.dump(sampleInputLon, fp1)
                                            with open(InputFileNameLat, 'ab') as fp1:
                                                pickle.dump(sampleInputLat, fp1)
                                            with open(InputFileNameB36, 'ab') as fp1:
                                                pickle.dump(sampleInputB36, fp1)
                                            with open(InputFileNameB45, 'ab') as fp1:
                                                pickle.dump(sampleInputB45, fp1)
                                            with open(InputFileNameMOD09, 'ab') as fp1:
                                                pickle.dump(sampleInputMOD09, fp1)
                                            with open(InputFileNameMOD09bands, 'ab') as fp1:
                                                pickle.dump(sampleInputMOD09bands, fp1)
                                            with open(OutputFileName, 'ab') as fp1:
                                                pickle.dump(sampleOutput, fp1)                                        
                                            with open(YearFileName, 'ab') as fp1:
                                                pickle.dump([year]*numsam, fp1)
                                            with open(MonthFileName, 'ab') as fp1:
                                                pickle.dump([month]*numsam, fp1)
                                            with open(DayFileName, 'ab') as fp1:
                                                pickle.dump([daystart]*numsam, fp1)
                                            with open(PathFileName, 'ab') as fp1:
                                                pickle.dump([path]*numsam, fp1 ) 
                                            with open(RowFileName, 'ab') as fp1:
                                                pickle.dump([row]*numsam, fp1)  
                                            with open(FparLai_QCName, 'ab') as fp1:
                                                pickle.dump(sampleFparLai_QC, fp1 ) 
                                            with open(FparExtra_QCName, 'ab') as fp1:
                                                pickle.dump(sampleFparExtra_QC, fp1)
# Out:
# year 2013 month 6 path 1 row 60
# fracAreaMCD15: 0.0
# year 2013 month 6 path 1 row 61
# fracAreaMCD15: 0.0
# year 2013 month 6 path 1 row 72
# fracAreaMCD15: 0.42937009727873415
# fracAreaLCtoMCD: 0.39720542506328077
# cumulative samples: 2524 nsaminput 2524
# year 2013 month 6 path 1 row 73
# fracAreaMCD15: 0.0
# year 2013 month 6 path 1 row 74
# fracAreaMCD15: 0.004628696898946487
# year 2013 month 6 path 1 row 75
# fracAreaMCD15: 0.0
# year 2013 month 6 path 1 row 76
# fracAreaMCD15: 0.0019171199763756113
# year 2013 month 6 path 1 row 77
# fracAreaMCD15: 0.004528827890964724
# year 2013 month 6 path 1 row 78
# fracAreaMCD15: 0.006540497460879944
# year 2013 month 6 path 1 row 82
# fracAreaMCD15: 0.13158206349895218
# year 2013 month 6 path 1 row 83
# fracAreaMCD15: 0.0
# year 2013 month 6 path 1 row 84
# fracAreaMCD15: 0.0
# year 2013 month 6 path 1 row 85
# fracAreaMCD15: 0.32562708111503225
# fracAreaLCtoMCD: 0.35591490234031453
# cumulative samples: 2616 nsaminput 92
# year 2013 month 6 path 2 row 64
# fracAreaMCD15: 0.0509435926052718
# year 2013 month 6 path 2 row 65
# fracAreaMCD15: 0.0743717322288507
# year 2013 month 6 path 2 row 66
# fracAreaMCD15: 0.1643779262779007
# year 2013 month 6 path 2 row 67
# fracAreaMCD15: 0.4824627894264735
# fracAreaLCtoMCD: 0.42562465385063486
# cumulative samples: 5318 nsaminput 2702
# year 2013 month 6 path 2 row 75
# fracAreaMCD15: 0.0
# year 2013 month 6 path 4 row 67
# year 2013 month 6 path 5 row 70
# fracAreaMCD15: 0.0
# year 2013 month 6 path 5 row 71
# year 2013 month 6 path 6 row 22
# fracAreaMCD15: 0.0
# year 2013 month 6 path 8 row 26
# fracAreaMCD15: 0.0
# year 2013 month 6 path 10 row 27
# fracAreaMCD15: 0.05514000815353475
# year 2013 month 6 path 10 row 28
# fracAreaMCD15: 0.04336703958808371
# year 2013 month 6 path 10 row 53
# fracAreaMCD15: 0.0
# year 2013 month 6 path 11 row 10
# fracAreaMCD15: 0.00032873039118454304
# year 2013 month 6 path 11 row 12
# fracAreaMCD15: 0.0
# year 2013 month 6 path 11 row 19
# fracAreaMCD15: 0.0
# year 2013 month 6 path 11 row 21
# fracAreaMCD15: 0.0004688511394154537
# year 2013 month 6 path 11 row 22
# fracAreaMCD15: 0.008121550672364908
# year 2013 month 6 path 11 row 23
# fracAreaMCD15: 0.013990100323833915
# year 2013 month 6 path 11 row 24
# fracAreaMCD15: 0.3113167645983287
# fracAreaLCtoMCD: 0.3077534643253889
# cumulative samples: 5443 nsaminput 125
# year 2013 month 6 path 11 row 25
# year 2013 month 6 path 11 row 63
# fracAreaMCD15: 0.16824735481086203
# year 2013 month 6 path 12 row 18
# year 2013 month 6 path 12 row 19
# fracAreaMCD15: 0.006094344426100273
# year 2013 month 6 path 13 row 16
# fracAreaMCD15: 0.0
# year 2013 month 6 path 13 row 17
# fracAreaMCD15: 0.0
# year 2013 month 6 path 13 row 18
# fracAreaMCD15: 0.0
# year 2013 month 6 path 13 row 19
# fracAreaMCD15: 0.00579164107077175
# year 2013 month 6 path 13 row 20
# fracAreaMCD15: 0.00015626946510824066
# year 2013 month 6 path 13 row 21
# fracAreaMCD15: 0.10909477189378881
# year 2013 month 6 path 13 row 28
# fracAreaMCD15: 0.0
# year 2013 month 6 path 14 row 31
# fracAreaMCD15: 0.10412061430348188
# year 2013 month 6 path 14 row 32
# fracAreaMCD15: 0.3590620674290179
# fracAreaLCtoMCD: 0.3495797236239047
# cumulative samples: 6109 nsaminput 666
# year 2013 month 6 path 14 row 33
# fracAreaMCD15: 0.298714394347354
# fracAreaLCtoMCD: 0.2981434733900003
# cumulative samples: 6577 nsaminput 468
# year 2013 month 6 path 14 row 34
# year 2013 month 6 path 14 row 35
# fracAreaMCD15: 0.5180257300905798
# fracAreaLCtoMCD: 0.4879259294701404
# cumulative samples: 6751 nsaminput 174
# year 2013 month 6 path 15 row 13
# fracAreaMCD15: 0.0
# year 2013 month 6 path 15 row 14
# fracAreaMCD15: 0.0
# year 2013 month 6 path 15 row 16
# fracAreaMCD15: 0.0
# year 2013 month 6 path 15 row 18
# fracAreaMCD15: 0.0
# year 2013 month 6 path 15 row 19
# fracAreaMCD15: 0.23054675482403686
# year 2013 month 6 path 15 row 20
# fracAreaMCD15: 0.06328875839680574
# year 2013 month 6 path 15 row 21
# fracAreaMCD15: 0.11836636373648748
# year 2013 month 6 path 15 row 22
# fracAreaMCD15: 0.0
# year 2013 month 6 path 15 row 23
# fracAreaMCD15: 0.028630947121527923
# year 2013 month 6 path 16 row 32
# year 2013 month 6 path 16 row 35
# fracAreaMCD15: 0.36932887482303683
# fracAreaLCtoMCD: 0.360367082200824
# cumulative samples: 7719 nsaminput 968
# year 2013 month 6 path 16 row 36
# fracAreaMCD15: 0.6128025451582549
# fracAreaLCtoMCD: 0.5965781898701964
# cumulative samples: 10855 nsaminput 3136
# year 2013 month 6 path 16 row 48
# fracAreaMCD15: 0.0
# year 2013 month 6 path 17 row 12
# fracAreaMCD15: 0.0
# year 2013 month 6 path 17 row 13
# fracAreaMCD15: 0.00031256732136575934
# year 2013 month 6 path 17 row 14
# fracAreaMCD15: 0.0
# year 2013 month 6 path 17 row 15
# fracAreaMCD15: 0.0
# year 2013 month 6 path 17 row 22
# year 2013 month 6 path 17 row 23
# fracAreaMCD15: 0.008886247342912528
# year 2013 month 6 path 17 row 24
# fracAreaMCD15: 0.07174588919499283
# year 2013 month 6 path 17 row 25
# fracAreaMCD15: 0.39667327836357474
# fracAreaLCtoMCD: 0.38902248044327264
# cumulative samples: 12217 nsaminput 1362
# year 2013 month 6 path 17 row 26
# fracAreaMCD15: 0.17607986397733133
# year 2013 month 6 path 17 row 27
# fracAreaMCD15: 0.14106726459078048
# year 2013 month 6 path 18 row 21
# fracAreaMCD15: 0.0
# year 2013 month 6 path 18 row 22
# fracAreaMCD15: 0.06320657342987394
# year 2013 month 6 path 18 row 36
# fracAreaMCD15: 0.13625385905431886
# year 2013 month 6 path 18 row 37
# fracAreaMCD15: 0.0
# year 2013 month 6 path 18 row 38
# fracAreaMCD15: 0.0
# year 2013 month 6 path 19 row 27
# fracAreaMCD15: 0.03955768584388144
# year 2013 month 6 path 19 row 28
# fracAreaMCD15: 0.06975914762016167
# year 2013 month 6 path 19 row 29
# fracAreaMCD15: 0.43390574096594725
# fracAreaLCtoMCD: 0.42897471692664896
# cumulative samples: 14994 nsaminput 2777
# year 2013 month 6 path 19 row 30
# fracAreaMCD15: 0.43469735757234096
# fracAreaLCtoMCD: 0.43092860050599874
# cumulative samples: 17776 nsaminput 2782
# year 2013 month 6 path 19 row 31
# year 2013 month 6 path 19 row 32
# fracAreaMCD15: 0.20192015834402716
# year 2013 month 6 path 19 row 33
# fracAreaMCD15: 0.36566959057482196
# fracAreaLCtoMCD: 0.3640479054206651
# cumulative samples: 20035 nsaminput 2259
# year 2013 month 6 path 20 row 1
# fracAreaMCD15: 0.0009130199580669196
# year 2013 month 6 path 20 row 6
# fracAreaMCD15: 0.0
# year 2013 month 6 path 20 row 19
# fracAreaMCD15: 0.0
# year 2013 month 6 path 20 row 20
# fracAreaMCD15: 0.0
# year 2013 month 6 path 20 row 21
# fracAreaMCD15: 0.11453713266743384
# year 2013 month 6 path 21 row 19
# fracAreaMCD15: 0.0001565490619680525
# year 2013 month 6 path 22 row 7
# fracAreaMCD15: 0.0
# year 2013 month 6 path 22 row 10
# fracAreaMCD15: 0.0
# year 2013 month 6 path 22 row 11
# year 2013 month 6 path 22 row 12
# fracAreaMCD15: 0.0
# year 2013 month 6 path 22 row 13
# fracAreaMCD15: 0.0
# year 2013 month 6 path 22 row 14
# fracAreaMCD15: 0.0
# year 2013 month 6 path 22 row 15
# fracAreaMCD15: 0.0
# year 2013 month 6 path 22 row 16
# fracAreaMCD15: 0.0
# year 2013 month 6 path 22 row 20
# fracAreaMCD15: 0.0
# year 2013 month 6 path 22 row 21
# fracAreaMCD15: 0.0
# year 2013 month 6 path 22 row 22
# fracAreaMCD15: 0.0
# year 2013 month 6 path 22 row 23
# fracAreaMCD15: 0.015622675052470582
# year 2013 month 6 path 22 row 24
# fracAreaMCD15: 0.1856810564362741
# year 2013 month 6 path 22 row 25
# fracAreaMCD15: 0.1852953689807309
# year 2013 month 6 path 22 row 26
# fracAreaMCD15: 0.08076736994119524
# year 2013 month 6 path 24 row 10
# fracAreaMCD15: 0.0
# year 2013 month 6 path 24 row 12
# fracAreaMCD15: 0.0
# year 2013 month 6 path 24 row 13
# fracAreaMCD15: 0.0
# year 2013 month 6 path 24 row 14
# fracAreaMCD15: 0.0
# year 2013 month 6 path 24 row 15
# fracAreaMCD15: 0.0
# year 2013 month 6 path 24 row 16
# fracAreaMCD15: 0.0
# year 2013 month 6 path 24 row 21
# fracAreaMCD15: 0.0
# year 2013 month 6 path 24 row 22
# year 2013 month 6 path 24 row 35
# fracAreaMCD15: 0.04156673304675049
# year 2013 month 6 path 24 row 36
# fracAreaMCD15: 0.03624559489964885
# year 2013 month 6 path 24 row 78
# fracAreaMCD15: 0.0
# year 2013 month 6 path 25 row 10
# fracAreaMCD15: 0.0
# year 2013 month 6 path 25 row 11
# fracAreaMCD15: 0.0
# year 2013 month 6 path 25 row 12
# fracAreaMCD15: 0.0
# year 2013 month 6 path 25 row 13
# fracAreaMCD15: 0.0
# year 2013 month 6 path 25 row 14
# year 2013 month 6 path 25 row 21
# fracAreaMCD15: 0.414091808472204
# fracAreaLCtoMCD: 0.38112772588343974
# cumulative samples: 20096 nsaminput 61
# year 2013 month 6 path 25 row 22
# fracAreaMCD15: 0.60038728362423
# fracAreaLCtoMCD: 0.5840253740887216
# cumulative samples: 20980 nsaminput 884
# year 2013 month 6 path 25 row 23
# fracAreaMCD15: 0.3169242920245519
# fracAreaLCtoMCD: 0.3116222682846664
# cumulative samples: 21146 nsaminput 166
# year 2013 month 6 path 25 row 24
# fracAreaMCD15: 0.36663513902537864
# fracAreaLCtoMCD: 0.3712452746448431
# cumulative samples: 22005 nsaminput 859
# year 2013 month 6 path 25 row 25
# fracAreaMCD15: 0.13923341051289895
# year 2013 month 6 path 25 row 26
# fracAreaMCD15: 0.016079446398141614
# year 2013 month 6 path 25 row 27
# fracAreaMCD15: 0.0
# year 2013 month 6 path 25 row 35
# fracAreaMCD15: 0.17713409032063143
# year 2013 month 6 path 25 row 36
# fracAreaMCD15: 0.01141581061888855
# year 2013 month 6 path 25 row 37
# fracAreaMCD15: 0.031719680227919315
# year 2013 month 6 path 25 row 38
# fracAreaMCD15: 0.15654095901485957
# year 2013 month 6 path 26 row 21
# fracAreaMCD15: 0.0
# year 2013 month 6 path 26 row 22
# fracAreaMCD15: 0.314571676794639
# fracAreaLCtoMCD: 0.3135476630534296
# cumulative samples: 24018 nsaminput 2013
# year 2013 month 6 path 26 row 23
# fracAreaMCD15: 0.010380387675578556
# year 2013 month 6 path 26 row 41
# year 2013 month 6 path 26 row 42
# fracAreaMCD15: 0.10954457904068571
# year 2013 month 6 path 26 row 43
# fracAreaMCD15: 0.013439614353398162
# year 2013 month 6 path 26 row 44
# fracAreaMCD15: 0.0
# year 2013 month 6 path 26 row 45
# fracAreaMCD15: 0.0636021113167957
# year 2013 month 6 path 26 row 46
# fracAreaMCD15: 0.2814853822057584
# fracAreaLCtoMCD: 0.2784256157048473
# cumulative samples: 24985 nsaminput 967
# year 2013 month 6 path 27 row 20
# fracAreaMCD15: 0.0
# year 2013 month 6 path 27 row 32
# fracAreaMCD15: 0.1441406474174386
# year 2013 month 6 path 27 row 33
# fracAreaMCD15: 0.22160981502763424
# year 2013 month 6 path 27 row 34
# fracAreaMCD15: 0.6106501345846451
# fracAreaLCtoMCD: 0.6018121468954051
# cumulative samples: 26644 nsaminput 1659
# year 2013 month 6 path 27 row 35
# fracAreaMCD15: 0.35398025298357305
# fracAreaLCtoMCD: 0.34951946029716197
# cumulative samples: 27994 nsaminput 1350
# year 2013 month 6 path 27 row 36
# fracAreaMCD15: 0.5029558370415829
# fracAreaLCtoMCD: 0.5027419149600897
# cumulative samples: 31213 nsaminput 3219
# year 2013 month 6 path 27 row 37
# fracAreaMCD15: 0.45483789039897804
# fracAreaLCtoMCD: 0.45889223604822604
# cumulative samples: 34121 nsaminput 2908
# year 2013 month 6 path 28 row 22
# fracAreaMCD15: 0.20507073144427967
# year 2013 month 6 path 28 row 23
# fracAreaMCD15: 0.05753174567312379
# year 2013 month 6 path 28 row 24
# fracAreaMCD15: 0.12845599345711858
# year 2013 month 6 path 28 row 25
# fracAreaMCD15: 0.1749106583821043
# year 2013 month 6 path 28 row 26
# year 2013 month 6 path 28 row 31
# fracAreaMCD15: 0.021012581177288624
# year 2013 month 6 path 28 row 32
# fracAreaMCD15: 0.10798322769403901
# year 2013 month 6 path 28 row 40
# fracAreaMCD15: 0.5103042489817975
# fracAreaLCtoMCD: 0.483706692027245
# cumulative samples: 37154 nsaminput 3033
# year 2013 month 6 path 28 row 41
# fracAreaMCD15: 0.05811854592253244
# year 2013 month 6 path 28 row 42
# fracAreaMCD15: 0.38014229554340084
# fracAreaLCtoMCD: 0.3358104728837481
# cumulative samples: 37293 nsaminput 139
# year 2013 month 6 path 28 row 43
# fracAreaMCD15: 0.22524556323747924
# year 2013 month 6 path 29 row 20
# year 2013 month 6 path 29 row 33
# fracAreaMCD15: 0.26828713422344375
# fracAreaLCtoMCD: 0.25018049135603093
# cumulative samples: 38906 nsaminput 1613
# year 2013 month 6 path 29 row 34
# fracAreaMCD15: 0.4188964936053468
# fracAreaLCtoMCD: 0.4171821165466815
# cumulative samples: 41441 nsaminput 2535
# year 2013 month 6 path 29 row 35
# fracAreaMCD15: 0.14895065447592049
# year 2013 month 6 path 29 row 36
# fracAreaMCD15: 0.5885048407062085
# fracAreaLCtoMCD: 0.5914383353135282
# cumulative samples: 42058 nsaminput 617
# year 2013 month 6 path 29 row 37
# fracAreaMCD15: 0.1846465581750908
# year 2013 month 6 path 29 row 38
# fracAreaMCD15: 0.25639769126507594
# fracAreaLCtoMCD: 0.24843818259628148
# cumulative samples: 43699 nsaminput 1641
# year 2013 month 6 path 29 row 39
# fracAreaMCD15: 0.2042601681709293
# year 2013 month 6 path 29 row 46
# fracAreaMCD15: 0.010157959043091138
# year 2013 month 6 path 30 row 24
# fracAreaMCD15: 0.7695866115840198
# fracAreaLCtoMCD: 0.7257072865377371
# cumulative samples: 47000 nsaminput 3301
# year 2013 month 6 path 30 row 35
# fracAreaMCD15: 0.650201660491519
# fracAreaLCtoMCD: 0.7256760034052272
# cumulative samples: 47002 nsaminput 2
# year 2013 month 6 path 30 row 36
# fracAreaMCD15: 0.6127019660281157
# fracAreaLCtoMCD: 0.6227488091445004
# cumulative samples: 47238 nsaminput 236
# year 2013 month 6 path 30 row 37
# fracAreaMCD15: 0.5532489703916114
# fracAreaLCtoMCD: 0.5593534027638468
# cumulative samples: 48719 nsaminput 1481
# year 2013 month 6 path 30 row 38
# fracAreaMCD15: 0.6557653045235926
# fracAreaLCtoMCD: 0.6380661806700837
# cumulative samples: 49259 nsaminput 540
# year 2013 month 6 path 30 row 39
# fracAreaMCD15: 0.582244483736768
# fracAreaLCtoMCD: 0.575050793074843
# cumulative samples: 52966 nsaminput 3707
# year 2013 month 6 path 30 row 40
# fracAreaMCD15: 0.19812540658762395
# year 2013 month 6 path 30 row 45
# fracAreaMCD15: 0.3482627365053899
# fracAreaLCtoMCD: 0.3497618360755212
# cumulative samples: 54214 nsaminput 1248
# year 2013 month 6 path 30 row 46
# fracAreaMCD15: 0.0
# year 2013 month 6 path 31 row 8
# year 2013 month 6 path 31 row 9
# year 2013 month 6 path 31 row 10
# fracAreaMCD15: 0.0
# year 2013 month 6 path 31 row 11
# fracAreaMCD15: 0.0
# year 2013 month 6 path 31 row 13
# fracAreaMCD15: 0.0
# year 2013 month 6 path 31 row 14
# fracAreaMCD15: 0.0
# year 2013 month 6 path 31 row 15
# year 2013 month 6 path 31 row 22
# fracAreaMCD15: 0.016879258936726708
# year 2013 month 6 path 31 row 23
# fracAreaMCD15: 0.014514572002047105
# year 2013 month 6 path 31 row 35
# fracAreaMCD15: 0.35416519148504194
# fracAreaLCtoMCD: 0.3523228100016992
# cumulative samples: 56120 nsaminput 1906
# year 2013 month 6 path 31 row 36
# fracAreaMCD15: 0.0746481526280452
# year 2013 month 6 path 31 row 37
# fracAreaMCD15: 0.2726969632129968
# fracAreaLCtoMCD: 0.2536945768565982
# cumulative samples: 56227 nsaminput 107
# year 2013 month 6 path 31 row 38
# fracAreaMCD15: 0.11842427122811909
# year 2013 month 6 path 31 row 39
# fracAreaMCD15: 0.3919425445244101
# fracAreaLCtoMCD: 0.3889443505710558
# cumulative samples: 56963 nsaminput 736
# year 2013 month 6 path 31 row 40
# fracAreaMCD15: 0.46585406583153527
# fracAreaLCtoMCD: 0.4614285281853508
# cumulative samples: 59197 nsaminput 2234
# year 2013 month 6 path 31 row 41
# fracAreaMCD15: 0.2273220389100595
# year 2013 month 6 path 31 row 42
# fracAreaMCD15: 0.19270090624689787
# year 2013 month 6 path 31 row 43
# fracAreaMCD15: 0.34795558979949054
# fracAreaLCtoMCD: 0.34408301650312273
# cumulative samples: 61424 nsaminput 2227
# year 2013 month 6 path 31 row 44
# fracAreaMCD15: 0.0
# year 2013 month 6 path 31 row 45
# fracAreaMCD15: 0.0
# year 2013 month 6 path 32 row 9
# fracAreaMCD15: 0.0006772760962190337
# year 2013 month 6 path 32 row 10
# fracAreaMCD15: 0.0006842018929755735
# year 2013 month 6 path 32 row 11
# fracAreaMCD15: 0.0
# year 2013 month 6 path 32 row 12
# year 2013 month 6 path 32 row 13
# fracAreaMCD15: 0.0012502149069983702
# year 2013 month 6 path 32 row 15
# fracAreaMCD15: 0.038024889344320426
# year 2013 month 6 path 32 row 16
# fracAreaMCD15: 0.0
# year 2013 month 6 path 32 row 17
# fracAreaMCD15: 0.0
# year 2013 month 6 path 32 row 18
# fracAreaMCD15: 0.0
# year 2013 month 6 path 32 row 19
# fracAreaMCD15: 0.054046542911310676
# year 2013 month 6 path 32 row 27
# fracAreaMCD15: 0.06146416984113452
# year 2013 month 6 path 32 row 28
# fracAreaMCD15: 0.1761552147616838
# year 2013 month 6 path 32 row 33
# fracAreaMCD15: 0.3487658457008386
# fracAreaLCtoMCD: 0.3479870263873571
# cumulative samples: 63656 nsaminput 2232
# year 2013 month 6 path 32 row 34
# fracAreaMCD15: 0.476117547479936
# fracAreaLCtoMCD: 0.48077933233209025
# cumulative samples: 65936 nsaminput 2280
# year 2013 month 6 path 32 row 35
# fracAreaMCD15: 0.40084797567954616
# fracAreaLCtoMCD: 0.39921143969762757
# cumulative samples: 66010 nsaminput 74
# year 2013 month 6 path 32 row 36
# fracAreaMCD15: 0.565452300317236
# fracAreaLCtoMCD: 0.5605210214487841
# cumulative samples: 69629 nsaminput 3619
# year 2013 month 6 path 32 row 37
# fracAreaMCD15: 0.04412616494775738
# year 2013 month 6 path 32 row 38
# fracAreaMCD15: 0.4544439590326048
# fracAreaLCtoMCD: 0.45589901781977576
# cumulative samples: 71379 nsaminput 1750
# year 2013 month 6 path 32 row 39
# fracAreaMCD15: 0.24338747271091585
# year 2013 month 6 path 32 row 40
# fracAreaMCD15: 0.42468965532033
# fracAreaLCtoMCD: 0.4162056118424373
# cumulative samples: 74060 nsaminput 2681
# year 2013 month 6 path 32 row 43
# fracAreaMCD15: 0.3617262695437857
# fracAreaLCtoMCD: 0.3600169948288488
# cumulative samples: 76375 nsaminput 2315
# year 2013 month 6 path 33 row 14
# fracAreaMCD15: 0.0
# year 2013 month 6 path 33 row 15
# fracAreaMCD15: 0.0007076439912730384
# year 2013 month 6 path 33 row 16
# fracAreaMCD15: 0.0
# year 2013 month 6 path 33 row 17
# fracAreaMCD15: 0.0
# year 2013 month 6 path 33 row 18
# fracAreaMCD15: 0.0
# year 2013 month 6 path 33 row 30
# fracAreaMCD15: 0.016224153440658945
# year 2013 month 6 path 33 row 31
# fracAreaMCD15: 0.0759097574432705
# year 2013 month 6 path 33 row 32
# fracAreaMCD15: 0.0
# year 2013 month 6 path 33 row 33
# year 2013 month 6 path 33 row 34
# fracAreaMCD15: 0.3813092431729325
# fracAreaLCtoMCD: 0.3923832133251465
# cumulative samples: 77217 nsaminput 842
# year 2013 month 6 path 33 row 37
# fracAreaMCD15: 0.30473837141811927
# fracAreaLCtoMCD: 0.3030104641687871
# cumulative samples: 79080 nsaminput 1863
# year 2013 month 6 path 33 row 38
# fracAreaMCD15: 0.05859856072071709
# year 2013 month 6 path 33 row 39
# fracAreaMCD15: 0.10682822548309408
# year 2013 month 6 path 33 row 40
# fracAreaMCD15: 0.747121901420314
# fracAreaLCtoMCD: 0.7453461333128779
# cumulative samples: 81814 nsaminput 2734
# year 2013 month 6 path 33 row 41
# fracAreaMCD15: 0.0
# year 2013 month 6 path 33 row 42
# fracAreaMCD15: 0.47838985832297976
# fracAreaLCtoMCD: 0.47462514552370305
# cumulative samples: 83885 nsaminput 2071
# year 2013 month 6 path 34 row 7
# fracAreaMCD15: 0.0
# year 2013 month 6 path 34 row 8
# year 2013 month 6 path 34 row 9
# fracAreaMCD15: 0.0
# year 2013 month 6 path 34 row 10
# fracAreaMCD15: 0.0
# year 2013 month 6 path 34 row 11
# fracAreaMCD15: 0.0
# year 2013 month 6 path 34 row 12
# fracAreaMCD15: 0.0
# year 2013 month 6 path 34 row 13
# fracAreaMCD15: 0.006555356727479154
# year 2013 month 6 path 34 row 17
# fracAreaMCD15: 0.0
# year 2013 month 6 path 34 row 27
# fracAreaMCD15: 0.19137670373245025
# year 2013 month 6 path 34 row 37
# fracAreaMCD15: 0.08124514404257865
# year 2013 month 6 path 34 row 38
# fracAreaMCD15: 0.20110803460012547
# year 2013 month 6 path 34 row 39
# fracAreaMCD15: 0.2467286282994178
# year 2013 month 6 path 34 row 40
# fracAreaMCD15: 0.1845391864218366
# year 2013 month 6 path 34 row 41
# fracAreaMCD15: 0.09032135987394921
# year 2013 month 6 path 34 row 43
# fracAreaMCD15: 0.43267122019461124
# fracAreaLCtoMCD: 0.4319899100011107
# cumulative samples: 84268 nsaminput 383
# year 2013 month 6 path 35 row 11
# fracAreaMCD15: 0.0
# year 2013 month 6 path 35 row 12
# fracAreaMCD15: 0.0003693420487456355
# year 2013 month 6 path 35 row 13
# fracAreaMCD15: 0.0
# year 2013 month 6 path 35 row 14
# fracAreaMCD15: 0.0
# year 2013 month 6 path 35 row 15
# fracAreaMCD15: 0.0
# year 2013 month 6 path 35 row 19
# fracAreaMCD15: 0.009688533265729994
# year 2013 month 6 path 35 row 20
# fracAreaMCD15: 0.30461579767294533
# fracAreaLCtoMCD: 0.26994685499590404
# cumulative samples: 84338 nsaminput 70
# year 2013 month 6 path 35 row 22
# fracAreaMCD15: 0.16458443415428137
# year 2013 month 6 path 35 row 23
# fracAreaMCD15: 0.597411326869705
# fracAreaLCtoMCD: 0.5901366811878055
# cumulative samples: 85575 nsaminput 1237
# year 2013 month 6 path 35 row 24
# fracAreaMCD15: 0.34049998638830664
# fracAreaLCtoMCD: 0.23368208017960967
# cumulative samples: 87089 nsaminput 1514
# year 2013 month 6 path 35 row 31
# fracAreaMCD15: 0.21579437389364758
# year 2013 month 6 path 35 row 32
# fracAreaMCD15: 0.4802139511316906
# fracAreaLCtoMCD: 0.4553540352102228
# cumulative samples: 90017 nsaminput 2928
# year 2013 month 6 path 35 row 35
# fracAreaMCD15: 0.5954515149219202
# fracAreaLCtoMCD: 0.593439659878403
# cumulative samples: 93827 nsaminput 3810
# year 2013 month 6 path 35 row 36
# fracAreaMCD15: 0.47660674184151647
# fracAreaLCtoMCD: 0.4795814922119272
# cumulative samples: 95613 nsaminput 1786
# year 2013 month 6 path 35 row 37
# fracAreaMCD15: 0.6084822288358046
# fracAreaLCtoMCD: 0.6022435442752232
# cumulative samples: 97304 nsaminput 1691
# year 2013 month 6 path 35 row 38
# fracAreaMCD15: 0.4642264226056509
# fracAreaLCtoMCD: 0.46539627573517406
# cumulative samples: 98422 nsaminput 1118
# year 2013 month 6 path 35 row 39
# fracAreaMCD15: 0.43942207524800825
# fracAreaLCtoMCD: 0.4377365253585199
# cumulative samples: 101143 nsaminput 2721
# year 2013 month 6 path 35 row 40
# fracAreaMCD15: 0.4150936795863568
# fracAreaLCtoMCD: 0.418135538700638
# cumulative samples: 102338 nsaminput 1195
# year 2013 month 6 path 35 row 41
# fracAreaMCD15: 0.0
# year 2013 month 6 path 36 row 14
# fracAreaMCD15: 0.0
# year 2013 month 6 path 36 row 19
# fracAreaMCD15: 0.03800793041510335
# year 2013 month 6 path 36 row 33
# fracAreaMCD15: 0.3640831550125225
# fracAreaLCtoMCD: 0.35774103951794445
# cumulative samples: 103223 nsaminput 885
# year 2013 month 6 path 36 row 34
# fracAreaMCD15: 0.43575787514567343
# fracAreaLCtoMCD: 0.43680338767584725
# cumulative samples: 106012 nsaminput 2789
# year 2013 month 6 path 36 row 35
# fracAreaMCD15: 0.5360285850858717
# fracAreaLCtoMCD: 0.5307752704582401
# cumulative samples: 108139 nsaminput 2127
# year 2013 month 6 path 36 row 37
# fracAreaMCD15: 0.18760211955698516
# year 2013 month 6 path 36 row 38
# fracAreaMCD15: 0.5991205952881581
# fracAreaLCtoMCD: 0.5961538656560206
# cumulative samples: 109982 nsaminput 1843
# year 2013 month 6 path 37 row 18
# fracAreaMCD15: 0.05647542653268668
# year 2013 month 6 path 37 row 19
# fracAreaMCD15: 0.04351384757102207
# year 2013 month 6 path 37 row 20
# fracAreaMCD15: 0.03240713159250843
# year 2013 month 6 path 37 row 21
# fracAreaMCD15: 0.06226814352393003
# year 2013 month 6 path 37 row 22
# fracAreaMCD15: 0.4872293984381765
# fracAreaLCtoMCD: 0.48950444383236313
# cumulative samples: 113100 nsaminput 3118
# year 2013 month 6 path 37 row 31
# fracAreaMCD15: 0.397563323675265
# fracAreaLCtoMCD: 0.4156708446142353
# cumulative samples: 113283 nsaminput 183
# year 2013 month 6 path 37 row 32
# fracAreaMCD15: 0.4342149524934975
# fracAreaLCtoMCD: 0.42750268851631174
# cumulative samples: 115317 nsaminput 2034
# year 2013 month 6 path 37 row 33
# fracAreaMCD15: 0.3690622054522419
# fracAreaLCtoMCD: 0.3675496762038476
# cumulative samples: 117679 nsaminput 2362
# year 2013 month 6 path 37 row 35
# fracAreaMCD15: 0.3805827886159898
# fracAreaLCtoMCD: 0.3775455019449572
# cumulative samples: 120115 nsaminput 2436
# year 2013 month 6 path 37 row 36
# fracAreaMCD15: 0.43559545518059734
# fracAreaLCtoMCD: 0.4348232626695912
# cumulative samples: 121049 nsaminput 934
# year 2013 month 6 path 37 row 37
# fracAreaMCD15: 0.3421753152863658
# fracAreaLCtoMCD: 0.3412380663222918
# cumulative samples: 123239 nsaminput 2190
# year 2013 month 6 path 37 row 38
# fracAreaMCD15: 0.00687321433106095
# year 2013 month 6 path 37 row 39
# fracAreaMCD15: 0.5414522011460116
# fracAreaLCtoMCD: 0.5431364855772997
# cumulative samples: 124637 nsaminput 1398
# year 2013 month 6 path 38 row 27
# fracAreaMCD15: 0.1648619200980642
# year 2013 month 6 path 38 row 28
# fracAreaMCD15: 0.08292858365164107
# year 2013 month 6 path 38 row 29
# fracAreaMCD15: 0.20597751912010892
# year 2013 month 6 path 38 row 30
# fracAreaMCD15: 0.24290558183620542
# year 2013 month 6 path 38 row 31
# fracAreaMCD15: 0.2857318606680137
# fracAreaLCtoMCD: 0.2893211987328586
# cumulative samples: 125249 nsaminput 612
# year 2013 month 6 path 38 row 32
# fracAreaMCD15: 0.0583377296661335
# year 2013 month 6 path 38 row 33
# fracAreaMCD15: 0.394932161811245
# fracAreaLCtoMCD: 0.3896331378273487
# cumulative samples: 126456 nsaminput 1207
# year 2013 month 6 path 38 row 34
# fracAreaMCD15: 0.4954916779882218
# fracAreaLCtoMCD: 0.50209300571023
# cumulative samples: 127391 nsaminput 935
# year 2013 month 6 path 38 row 35
# fracAreaMCD15: 0.549516331756305
# fracAreaLCtoMCD: 0.5301259511032553
# cumulative samples: 127705 nsaminput 314
# year 2013 month 6 path 38 row 36
# fracAreaMCD15: 0.1528572434641562
# year 2013 month 6 path 38 row 37
# fracAreaMCD15: 0.4711860891358604
# fracAreaLCtoMCD: 0.5028435612852314
# cumulative samples: 127764 nsaminput 59
# year 2013 month 6 path 40 row 30
# fracAreaMCD15: 0.33680016605432855
# fracAreaLCtoMCD: 0.3377310747641037
# cumulative samples: 129770 nsaminput 2006
# year 2013 month 6 path 40 row 31
# fracAreaMCD15: 0.24751954916276614
# year 2013 month 6 path 40 row 33
# fracAreaMCD15: 0.37656154417605575
# fracAreaLCtoMCD: 0.36104284403493475
# cumulative samples: 132122 nsaminput 2352
# year 2013 month 6 path 40 row 34
# fracAreaMCD15: 0.44061479328463693
# fracAreaLCtoMCD: 0.379151540709586
# cumulative samples: 134508 nsaminput 2386
# year 2013 month 6 path 40 row 35
# fracAreaMCD15: 0.08949215672718767
# year 2013 month 6 path 40 row 36
# fracAreaMCD15: 0.3727483623620982
# fracAreaLCtoMCD: 0.36842083277321935
# cumulative samples: 136229 nsaminput 1721
# year 2013 month 6 path 41 row 8
# fracAreaMCD15: 0.0
# year 2013 month 6 path 41 row 9
# fracAreaMCD15: 0.0019933980991602377
# year 2013 month 6 path 41 row 10
# fracAreaMCD15: 0.002504031429000934
# year 2013 month 6 path 41 row 33
# fracAreaMCD15: 0.29468164622620624
# fracAreaLCtoMCD: 0.26110814828459517
# cumulative samples: 136508 nsaminput 279
# year 2013 month 6 path 41 row 34
# fracAreaMCD15: 0.32885329985741035
# fracAreaLCtoMCD: 0.3301364883308744
# cumulative samples: 138555 nsaminput 2047
# year 2013 month 6 path 41 row 35
# fracAreaMCD15: 0.07527304641096713
# year 2013 month 6 path 41 row 36
# fracAreaMCD15: 0.5820554455589144
# fracAreaLCtoMCD: 0.590001699446986
# cumulative samples: 139326 nsaminput 771
# year 2013 month 6 path 42 row 11
# fracAreaMCD15: 0.0
# year 2013 month 6 path 42 row 14
# fracAreaMCD15: 0.0
# year 2013 month 6 path 42 row 15
# fracAreaMCD15: 0.0
# year 2013 month 6 path 42 row 16
# fracAreaMCD15: 0.0
# year 2013 month 6 path 42 row 27
# fracAreaMCD15: 0.3131883458079078
# fracAreaLCtoMCD: 0.30848005144806623
# cumulative samples: 140090 nsaminput 764
# year 2013 month 6 path 42 row 28
# fracAreaMCD15: 0.3164492300456567
# fracAreaLCtoMCD: 0.302562871631526
# cumulative samples: 140859 nsaminput 769
# year 2013 month 6 path 42 row 29
# fracAreaMCD15: 0.2551538385203081
# fracAreaLCtoMCD: 0.261387079573181
# cumulative samples: 142490 nsaminput 1631
# year 2013 month 6 path 42 row 30
# fracAreaMCD15: 0.3496947324388781
# fracAreaLCtoMCD: 0.34230148013718487
# cumulative samples: 144728 nsaminput 2238
# year 2013 month 6 path 42 row 31
# fracAreaMCD15: 0.40495230864634235
# fracAreaLCtoMCD: 0.39274227461344263
# cumulative samples: 145400 nsaminput 672
# year 2013 month 6 path 42 row 32
# fracAreaMCD15: 0.32157893606168875
# fracAreaLCtoMCD: 0.3202888025674399
# cumulative samples: 146090 nsaminput 690
# year 2013 month 6 path 42 row 33
# fracAreaMCD15: 0.194975140549141
# year 2013 month 6 path 42 row 34
# fracAreaMCD15: 0.10448313151197382
# year 2013 month 6 path 42 row 35
# year 2013 month 6 path 42 row 36
# year 2013 month 6 path 43 row 1
# fracAreaMCD15: 0.0
# year 2013 month 6 path 43 row 6
# fracAreaMCD15: 0.0
# year 2013 month 6 path 43 row 11
# fracAreaMCD15: 0.0
# year 2013 month 6 path 43 row 12
# fracAreaMCD15: 0.03786827444435617
# year 2013 month 6 path 43 row 16
# fracAreaMCD15: 0.0066775662625437205
# year 2013 month 6 path 43 row 30
# fracAreaMCD15: 0.10317091563710025
# year 2013 month 6 path 43 row 31
# fracAreaMCD15: 0.1408690639590978
# year 2013 month 6 path 43 row 32
# fracAreaMCD15: 0.19173066530141605
# year 2013 month 6 path 43 row 33
# fracAreaMCD15: 0.6909219233162379
# fracAreaLCtoMCD: 0.692865988248391
# cumulative samples: 150485 nsaminput 4395
# year 2013 month 6 path 43 row 34
# fracAreaMCD15: 0.42405281903203357
# fracAreaLCtoMCD: 0.4263647617459063
# cumulative samples: 152983 nsaminput 2498
# year 2013 month 6 path 43 row 35
# fracAreaMCD15: 0.5605317202514342
# fracAreaLCtoMCD: 0.5376029201929566
# cumulative samples: 153079 nsaminput 96
# year 2013 month 6 path 44 row 5
# fracAreaMCD15: 0.0
# year 2013 month 6 path 44 row 10
# fracAreaMCD15: 0.0
# year 2013 month 6 path 44 row 11
# fracAreaMCD15: 0.0
# year 2013 month 6 path 44 row 12
# fracAreaMCD15: 0.0
# year 2013 month 6 path 44 row 13
# fracAreaMCD15: 0.0
# year 2013 month 6 path 44 row 14
# fracAreaMCD15: 0.0
# year 2013 month 6 path 44 row 15
# fracAreaMCD15: 0.0006251575869060821
# year 2013 month 6 path 44 row 28
# fracAreaMCD15: 0.02733705874900372
# year 2013 month 6 path 44 row 29
# fracAreaMCD15: 0.12605123027652193
# year 2013 month 6 path 44 row 30
# fracAreaMCD15: 0.325613451600558
# fracAreaLCtoMCD: 0.325465912147332
# cumulative samples: 155163 nsaminput 2084
# year 2013 month 6 path 44 row 31
# fracAreaMCD15: 0.3639797208322669
# fracAreaLCtoMCD: 0.35867772832424943
# cumulative samples: 157482 nsaminput 2319
# year 2013 month 6 path 44 row 32
# fracAreaMCD15: 0.5284062821614546
# fracAreaLCtoMCD: 0.5258847745022522
# cumulative samples: 160864 nsaminput 3382
# year 2013 month 6 path 44 row 33
# fracAreaMCD15: 0.3778120054634916
# fracAreaLCtoMCD: 0.3713759109520727
# cumulative samples: 163282 nsaminput 2418
# year 2013 month 6 path 44 row 34
# year 2013 month 6 path 45 row 12
# fracAreaMCD15: 0.0
# year 2013 month 6 path 45 row 13
# fracAreaMCD15: 0.00858375746993711
# year 2013 month 6 path 45 row 14
# fracAreaMCD15: 0.06982633353857784
# year 2013 month 6 path 45 row 27
# fracAreaMCD15: 0.20236397526200908
# year 2013 month 6 path 45 row 28
# fracAreaMCD15: 0.05407181112873052
# year 2013 month 6 path 45 row 29
# fracAreaMCD15: 0.12828443502629922
# year 2013 month 6 path 45 row 30
# fracAreaMCD15: 0.43594954256999774
# fracAreaLCtoMCD: 0.4294431863870464
# cumulative samples: 166064 nsaminput 2782
# year 2013 month 6 path 45 row 73
# fracAreaMCD15: 0.0
# year 2013 month 6 path 46 row 14
# fracAreaMCD15: 0.0
# year 2013 month 6 path 46 row 15
# fracAreaMCD15: 0.0
# year 2013 month 6 path 46 row 30
# fracAreaMCD15: 0.7456589769719701
# fracAreaLCtoMCD: 0.7703896656718952
# cumulative samples: 166086 nsaminput 22
# year 2013 month 6 path 46 row 31
# fracAreaMCD15: 0.5337785952545019
# fracAreaLCtoMCD: 0.5377359945186675
# cumulative samples: 169502 nsaminput 3416
# year 2013 month 6 path 46 row 32
# year 2013 month 6 path 47 row 28
# year 2013 month 6 path 47 row 29
# fracAreaMCD15: 0.0
# year 2013 month 6 path 47 row 30
# fracAreaMCD15: 0.0
# year 2013 month 6 path 48 row 8
# fracAreaMCD15: 0.0
# year 2013 month 6 path 49 row 19
# year 2013 month 6 path 49 row 79
# fracAreaMCD15: 0.0
# year 2013 month 6 path 50 row 8
# fracAreaMCD15: 0.0
# year 2013 month 6 path 50 row 9
# fracAreaMCD15: 0.0018378328179040895
# year 2013 month 6 path 50 row 10
# fracAreaMCD15: 0.0
# year 2013 month 6 path 50 row 11
# fracAreaMCD15: 0.0
# year 2013 month 6 path 51 row 11
# fracAreaMCD15: 0.0001562664371405542
# year 2013 month 6 path 51 row 12
# fracAreaMCD15: 0.0
# year 2013 month 6 path 51 row 13
# fracAreaMCD15: 0.017948275058488394
# year 2013 month 6 path 51 row 14
# fracAreaMCD15: 0.0
# year 2013 month 6 path 52 row 7
# fracAreaMCD15: 0.0
# year 2013 month 6 path 52 row 11
# fracAreaMCD15: 0.0
# year 2013 month 6 path 52 row 12
# fracAreaMCD15: 0.06874945721547245
# year 2013 month 6 path 52 row 13
# fracAreaMCD15: 0.006871701800386294
# year 2013 month 6 path 52 row 14
# fracAreaMCD15: 0.0
# year 2013 month 6 path 52 row 15
# fracAreaMCD15: 0.058683544251926796
# year 2013 month 6 path 52 row 16
# fracAreaMCD15: 0.17782351568619933
# year 2013 month 6 path 52 row 18
# fracAreaMCD15: 0.2023482557209586
# year 2013 month 6 path 52 row 76
# fracAreaMCD15: 0.0
# year 2013 month 6 path 53 row 13
# year 2013 month 6 path 54 row 10
# fracAreaMCD15: 0.0
# year 2013 month 6 path 57 row 8
# fracAreaMCD15: 0.0
# year 2013 month 6 path 57 row 9
# fracAreaMCD15: 0.0
# year 2013 month 6 path 57 row 19
# fracAreaMCD15: 0.01114474570932181
# year 2013 month 6 path 59 row 9
# fracAreaMCD15: 0.0
# year 2013 month 6 path 59 row 10
# fracAreaMCD15: 0.0
# year 2013 month 6 path 59 row 19
# fracAreaMCD15: 0.0009502899881344385
# year 2013 month 6 path 60 row 11
# fracAreaMCD15: 0.025003461739007186
# year 2013 month 6 path 60 row 13
# fracAreaMCD15: 0.03696311584274227
# year 2013 month 6 path 60 row 17
# fracAreaMCD15: 0.07292836375544005
# year 2013 month 6 path 60 row 66
# fracAreaMCD15: 0.0
# year 2013 month 6 path 61 row 7
# fracAreaMCD15: 0.002248263798510878
# year 2013 month 6 path 61 row 59
# fracAreaMCD15: 0.0
# year 2013 month 6 path 63 row 11
# fracAreaMCD15: 0.0
# year 2013 month 6 path 63 row 12
# fracAreaMCD15: 0.002031540427603862
# year 2013 month 6 path 63 row 13
# fracAreaMCD15: 0.13163018436223267
# year 2013 month 6 path 63 row 57
# year 2013 month 6 path 63 row 69
# fracAreaMCD15: 0.0
# year 2013 month 6 path 64 row 16
# fracAreaMCD15: 0.31655230124736183
# fracAreaLCtoMCD: 0.30532223871850755
# cumulative samples: 170909 nsaminput 1407
# year 2013 month 6 path 64 row 17
# fracAreaMCD15: 0.043962218173055116
# year 2013 month 6 path 65 row 68
# fracAreaMCD15: 0.0
# year 2013 month 6 path 66 row 11
# fracAreaMCD15: 0.0
# year 2013 month 6 path 66 row 13
# fracAreaMCD15: 0.35851606888901216
# fracAreaLCtoMCD: 0.3583152527484309
# cumulative samples: 172787 nsaminput 1878
# year 2013 month 6 path 66 row 14
# year 2013 month 6 path 66 row 70
# fracAreaMCD15: 0.0
# year 2013 month 6 path 68 row 18
# fracAreaMCD15: 0.0
# year 2013 month 6 path 68 row 20
# fracAreaMCD15: 0.0
# year 2013 month 6 path 68 row 68
# fracAreaMCD15: 0.0
# year 2013 month 6 path 69 row 11
# fracAreaMCD15: 0.0
# year 2013 month 6 path 69 row 12
# fracAreaMCD15: 0.0
# year 2013 month 6 path 69 row 13
# fracAreaMCD15: 0.42957004508025165
# fracAreaLCtoMCD: 0.42646097309755726
# cumulative samples: 175229 nsaminput 2442
# year 2013 month 6 path 69 row 14
# fracAreaMCD15: 0.25142226665801276
# fracAreaLCtoMCD: 0.2573302027125417
# cumulative samples: 176059 nsaminput 830
# year 2013 month 6 path 69 row 66
# fracAreaMCD15: 0.0
# year 2013 month 6 path 70 row 17
# fracAreaMCD15: 0.2363668682098528
# year 2013 month 6 path 70 row 20
# fracAreaMCD15: 0.006878715298927904
# year 2013 month 6 path 72 row 10
# year 2013 month 6 path 72 row 22
# fracAreaMCD15: 0.00433838392233492
# year 2013 month 6 path 72 row 88
# year 2013 month 6 path 73 row 14
# fracAreaMCD15: 0.6089917406109918
# fracAreaLCtoMCD: 0.5562623744739345
# cumulative samples: 177695 nsaminput 1636
# year 2013 month 6 path 74 row 42
# fracAreaMCD15: 0.0
# year 2013 month 6 path 74 row 86
# year 2013 month 6 path 74 row 87
# year 2013 month 6 path 74 row 88
# year 2013 month 6 path 74 row 91
# fracAreaMCD15: 0.17624387646280512
# year 2013 month 6 path 75 row 10
# fracAreaMCD15: 0.0
# year 2013 month 6 path 75 row 11
# fracAreaMCD15: 0.08924333930165884
# year 2013 month 6 path 75 row 15
# fracAreaMCD15: 0.6149072143840992
# fracAreaLCtoMCD: 0.5850170108171222
# cumulative samples: 178004 nsaminput 309
# year 2013 month 6 path 75 row 16
# fracAreaMCD15: 0.8275002675248718
# fracAreaLCtoMCD: 0.8174987818101261
# cumulative samples: 183244 nsaminput 5240
# year 2013 month 6 path 75 row 17
# fracAreaMCD15: 0.3042069145654634
# fracAreaLCtoMCD: 0.3025373187945117
# cumulative samples: 185191 nsaminput 1947
# year 2013 month 6 path 75 row 42
# year 2013 month 6 path 78 row 12
# fracAreaMCD15: 0.006561980529612299
# year 2013 month 6 path 78 row 13
# year 2013 month 6 path 78 row 14
# fracAreaMCD15: 0.0
# year 2013 month 6 path 78 row 15
# fracAreaMCD15: 0.01444167093830956
# year 2013 month 6 path 78 row 16
# fracAreaMCD15: 0.00024501536717832855
# year 2013 month 6 path 82 row 13
# fracAreaMCD15: 0.0
# year 2013 month 6 path 82 row 15
# year 2013 month 6 path 82 row 16
# year 2013 month 6 path 84 row 13
# fracAreaMCD15: 0.0
# year 2013 month 6 path 84 row 60
# year 2013 month 6 path 85 row 13
# fracAreaMCD15: 0.0
# year 2013 month 6 path 85 row 14
# fracAreaMCD15: 0.0
# year 2013 month 6 path 86 row 75
# fracAreaMCD15: 0.0
# year 2013 month 6 path 88 row 66
# year 2013 month 6 path 89 row 65
# fracAreaMCD15: 0.0
# year 2013 month 6 path 89 row 78
# fracAreaMCD15: 0.0014051994440557167
# year 2013 month 6 path 92 row 76
# fracAreaMCD15: 0.3082938196364317
# fracAreaLCtoMCD: 0.29349515279765953
# cumulative samples: 186947 nsaminput 1756
# year 2013 month 6 path 92 row 77
# fracAreaMCD15: 0.7639477452935535
# fracAreaLCtoMCD: 0.781534233591657
# cumulative samples: 187762 nsaminput 815
# year 2013 month 6 path 92 row 78
# fracAreaMCD15: 0.32952324452024156
# fracAreaLCtoMCD: 0.3475907764992381
# cumulative samples: 187811 nsaminput 49
# year 2013 month 6 path 92 row 79
# fracAreaMCD15: 0.09482946573290883
# year 2013 month 6 path 92 row 80
# fracAreaMCD15: 0.13670846300072154
# year 2013 month 6 path 92 row 81
# year 2013 month 6 path 93 row 11
# year 2013 month 6 path 93 row 78
# fracAreaMCD15: 0.5709933483364424
# fracAreaLCtoMCD: 0.570559611216307
# cumulative samples: 191024 nsaminput 3213
# year 2013 month 6 path 93 row 79
# fracAreaMCD15: 0.0053318709492546894
# year 2013 month 6 path 93 row 80
# fracAreaMCD15: 0.0
# year 2013 month 6 path 94 row 74
# fracAreaMCD15: 0.599095314005552
# fracAreaLCtoMCD: 0.5939814773134912
# cumulative samples: 194848 nsaminput 3824
# year 2013 month 6 path 94 row 75
# fracAreaMCD15: 4.9483252468893556e-05
# year 2013 month 6 path 94 row 84
# fracAreaMCD15: 0.26156017410660365
# fracAreaLCtoMCD: 0.26396137707542366
# cumulative samples: 195174 nsaminput 326
# year 2013 month 6 path 95 row 14
# fracAreaMCD15: 0.1575781747681944
# year 2013 month 6 path 95 row 82
# fracAreaMCD15: 0.2691937040631783
# fracAreaLCtoMCD: 0.2682098966919927
# cumulative samples: 196897 nsaminput 1723
# year 2013 month 6 path 95 row 83
# fracAreaMCD15: 0.17373462858356484
# year 2013 month 6 path 96 row 10
# year 2013 month 6 path 97 row 73
# fracAreaMCD15: 0.3839254193682782
# fracAreaLCtoMCD: 0.38702215191981476
# cumulative samples: 199354 nsaminput 2457
# year 2013 month 6 path 97 row 74
# fracAreaMCD15: 0.4788362409575537
# fracAreaLCtoMCD: 0.47840711163575816
# cumulative samples: 201284 nsaminput 1930
# year 2013 month 6 path 97 row 75
# fracAreaMCD15: 0.2173618193134785
# year 2013 month 6 path 98 row 14
# fracAreaMCD15: 0.0
# year 2013 month 6 path 98 row 15
# fracAreaMCD15: 0.0
# year 2013 month 6 path 98 row 16
# fracAreaMCD15: 0.004753649478670193
# year 2013 month 6 path 98 row 17
# fracAreaMCD15: 0.0
# year 2013 month 6 path 98 row 19
# fracAreaMCD15: 0.0
# year 2013 month 6 path 98 row 70
# fracAreaMCD15: 0.4323558730399797
# fracAreaLCtoMCD: 0.4319059655259483
# cumulative samples: 203892 nsaminput 2608
# year 2013 month 6 path 98 row 71
# fracAreaMCD15: 1.0
# fracAreaLCtoMCD: 0
# year 2013 month 6 path 98 row 72
# fracAreaMCD15: 0.3404225561632271
# fracAreaLCtoMCD: 0.3404221988820866
# cumulative samples: 205718 nsaminput 1826
# year 2013 month 6 path 98 row 73
# fracAreaMCD15: 0.5629136343414453
# fracAreaLCtoMCD: 0.5589208063944802
# cumulative samples: 208621 nsaminput 2903
# year 2013 month 6 path 98 row 74
# fracAreaMCD15: 0.49834467411846917
# fracAreaLCtoMCD: 0.497441124426756
# cumulative samples: 210693 nsaminput 2072
# year 2013 month 6 path 98 row 75
# fracAreaMCD15: 0.4962399357600528
# fracAreaLCtoMCD: 0.5015598255459189
# cumulative samples: 213869 nsaminput 3176
# year 2013 month 6 path 98 row 76
# fracAreaMCD15: 0.4571248120236984
# fracAreaLCtoMCD: 0.4594546278732344
# cumulative samples: 216795 nsaminput 2926
# year 2013 month 6 path 98 row 77
# fracAreaMCD15: 0.0
# year 2013 month 6 path 98 row 78
# fracAreaMCD15: 0.3971648206903639
# fracAreaLCtoMCD: 0.3950842121760571
# cumulative samples: 217558 nsaminput 763
# year 2013 month 6 path 98 row 79
# fracAreaMCD15: 0.09177839685754713
# year 2013 month 6 path 98 row 80
# fracAreaMCD15: 0.034598136116565655
# year 2013 month 6 path 99 row 18
# fracAreaMCD15: 0.0034753910813913685
# year 2013 month 6 path 99 row 23
# fracAreaMCD15: 0.00016439452649142923
# year 2013 month 6 path 99 row 24
# fracAreaMCD15: 0.00015629747264451037
# year 2013 month 6 path 99 row 70
# fracAreaMCD15: 0.0
# year 2013 month 6 path 99 row 71
# fracAreaMCD15: 0.0
# year 2013 month 6 path 99 row 72
# fracAreaMCD15: 0.11792199529994264
# year 2013 month 6 path 99 row 73
# fracAreaMCD15: 0.2916905764780948
# fracAreaLCtoMCD: 0.2792096854787523
# cumulative samples: 217824 nsaminput 266
# year 2013 month 6 path 99 row 74
# fracAreaMCD15: 0.34663358694888957
# fracAreaLCtoMCD: 0.3467446454560126
# cumulative samples: 218337 nsaminput 513
# year 2013 month 6 path 100 row 73
# fracAreaMCD15: 0.18253886501426142
# year 2013 month 6 path 100 row 74
# fracAreaMCD15: 0.27976366404161174
# fracAreaLCtoMCD: 0.27208641954152973
# cumulative samples: 219512 nsaminput 1175
# year 2013 month 6 path 100 row 75
# fracAreaMCD15: 0.6262326145606278
# fracAreaLCtoMCD: 0.6187752886033938
# cumulative samples: 223520 nsaminput 4008
# year 2013 month 6 path 100 row 76
# fracAreaMCD15: 0.3073385951036816
# fracAreaLCtoMCD: 0.3062182105754535
# cumulative samples: 225487 nsaminput 1967
# year 2013 month 6 path 100 row 77
# fracAreaMCD15: 0.5767077735012077
# fracAreaLCtoMCD: 0.5736244645831352
# cumulative samples: 228526 nsaminput 3039
# year 2013 month 6 path 101 row 16
# fracAreaMCD15: 0.005203064510236679
# year 2013 month 6 path 101 row 23
# year 2013 month 6 path 101 row 55
# fracAreaMCD15: 0.0
# year 2013 month 6 path 101 row 71
# fracAreaMCD15: 0.1158197577474311
# year 2013 month 6 path 101 row 72
# fracAreaMCD15: 0.4897140090821045
# fracAreaLCtoMCD: 0.4940419485037454
# cumulative samples: 231660 nsaminput 3134
# year 2013 month 6 path 101 row 73
# fracAreaMCD15: 0.33478019036479084
# fracAreaLCtoMCD: 0.3442851093271915
# cumulative samples: 232133 nsaminput 473
# year 2013 month 6 path 101 row 74
# fracAreaMCD15: 0.8503068698464131
# fracAreaLCtoMCD: 0.7707710351712833
# cumulative samples: 232151 nsaminput 18
# year 2013 month 6 path 102 row 72
# fracAreaMCD15: 0.19667006438915852
# year 2013 month 6 path 102 row 73
# fracAreaMCD15: 0.4217381228320905
# fracAreaLCtoMCD: 0.41157411772149516
# cumulative samples: 232174 nsaminput 23
# year 2013 month 6 path 102 row 74
# fracAreaMCD15: 0.22922664099161724
# year 2013 month 6 path 102 row 75
# fracAreaMCD15: 0.13700998907145517
# year 2013 month 6 path 102 row 76
# fracAreaMCD15: 0.35778983041762613
# fracAreaLCtoMCD: 0.33680203978899886
# cumulative samples: 232405 nsaminput 231
# year 2013 month 6 path 102 row 81
# fracAreaMCD15: 0.5085884942072115
# fracAreaLCtoMCD: 0.5024265014076251
# cumulative samples: 233506 nsaminput 1101
# year 2013 month 6 path 103 row 70
# fracAreaMCD15: 0.5334603466561896
# fracAreaLCtoMCD: 0.5365421201618118
# cumulative samples: 234228 nsaminput 722
# year 2013 month 6 path 103 row 71
# fracAreaMCD15: 0.46601630215319945
# fracAreaLCtoMCD: 0.4457444406362372
# cumulative samples: 234324 nsaminput 96
# year 2013 month 6 path 103 row 72
# fracAreaMCD15: 1.0
# fracAreaLCtoMCD: 0.9510716907995753
# cumulative samples: 234327 nsaminput 3
# year 2013 month 6 path 103 row 73
# fracAreaMCD15: 0.3340630090506196
# fracAreaLCtoMCD: 0.3347782523331808
# cumulative samples: 236009 nsaminput 1682
# year 2013 month 6 path 103 row 74
# fracAreaMCD15: 0.05003577863747008
# year 2013 month 6 path 103 row 75
# fracAreaMCD15: 0.17107143112049428
# year 2013 month 6 path 104 row 11
# fracAreaMCD15: 0.01938244211490277
# year 2013 month 6 path 104 row 12
# fracAreaMCD15: 0.06049385739758275
# year 2013 month 6 path 104 row 75
# fracAreaMCD15: 0.22297896168023645
# year 2013 month 6 path 105 row 11
# fracAreaMCD15: 0.0
# year 2013 month 6 path 105 row 69
# fracAreaMCD15: 0.0
# year 2013 month 6 path 105 row 70
# fracAreaMCD15: 0.3264455372926142
# fracAreaLCtoMCD: 0.32440640861860487
# cumulative samples: 238058 nsaminput 2049
# year 2013 month 6 path 105 row 71
# fracAreaMCD15: 0.28365136687217407
# fracAreaLCtoMCD: 0.286343644584577
# cumulative samples: 238200 nsaminput 142
# year 2013 month 6 path 105 row 72
# fracAreaMCD15: 0.6118594765946905
# fracAreaLCtoMCD: 0.6095344528761458
# cumulative samples: 242116 nsaminput 3916
# year 2013 month 6 path 105 row 73
# fracAreaMCD15: 0.6389085020152676
# fracAreaLCtoMCD: 0.6308264224141751
# cumulative samples: 246110 nsaminput 3994
# year 2013 month 6 path 105 row 74
# fracAreaMCD15: 0.510394563326116
# fracAreaLCtoMCD: 0.45727759327482154
# cumulative samples: 249029 nsaminput 2919
# year 2013 month 6 path 106 row 12
# fracAreaMCD15: 0.004473227937041145
# year 2013 month 6 path 106 row 32
# fracAreaMCD15: 0.0
# year 2013 month 6 path 106 row 80
# fracAreaMCD15: 0.19204415375153314
# year 2013 month 6 path 106 row 81
# fracAreaMCD15: 0.10201618568074558
# year 2013 month 6 path 106 row 82
# fracAreaMCD15: 0.23391386160858962
# year 2013 month 6 path 107 row 14
# fracAreaMCD15: 0.5378032678659334
# fracAreaLCtoMCD: 0.4832233244509237
# cumulative samples: 249508 nsaminput 479
# year 2013 month 6 path 107 row 15
# fracAreaMCD15: 0.3447425107127307
# fracAreaLCtoMCD: 0.352965189338659
# cumulative samples: 250024 nsaminput 516
# year 2013 month 6 path 107 row 16
# year 2013 month 6 path 107 row 17
# fracAreaMCD15: 0.013936934425954438
# year 2013 month 6 path 107 row 18
# fracAreaMCD15: 0.07523505347344352
# year 2013 month 6 path 107 row 70
# fracAreaMCD15: 0.6609596691778306
# fracAreaLCtoMCD: 0.6644659566472279
# cumulative samples: 250361 nsaminput 337
# year 2013 month 6 path 107 row 71
# fracAreaMCD15: 0.7354665570745095
# fracAreaLCtoMCD: 0.7321363524011233
# cumulative samples: 252509 nsaminput 2148
# year 2013 month 6 path 107 row 72
# fracAreaMCD15: 0.39417108916505905
# fracAreaLCtoMCD: 0.38795056754860396
# cumulative samples: 252733 nsaminput 224
# year 2013 month 6 path 107 row 73
# fracAreaMCD15: 0.5517988688407367
# fracAreaLCtoMCD: 0.5213200980976361
# cumulative samples: 252782 nsaminput 49
# year 2013 month 6 path 107 row 74
# fracAreaMCD15: 0.29099141329191275
# fracAreaLCtoMCD: 0.291395293215545
# cumulative samples: 253804 nsaminput 1022
# year 2013 month 6 path 107 row 75
# fracAreaMCD15: 0.26557180551106085
# fracAreaLCtoMCD: 0.2627242972012628
# cumulative samples: 255479 nsaminput 1675
# year 2013 month 6 path 107 row 76
# fracAreaMCD15: 0.10467517734422001
# year 2013 month 6 path 107 row 77
# fracAreaMCD15: 0.3686331194818753
# fracAreaLCtoMCD: 0.3700780864274795
# cumulative samples: 257328 nsaminput 1849
# year 2013 month 6 path 107 row 78
# fracAreaMCD15: 0.4132457271346907
# fracAreaLCtoMCD: 0.4352219653554517
# cumulative samples: 257337 nsaminput 9
# year 2013 month 6 path 107 row 79
# fracAreaMCD15: 0.10578954824489933
# year 2013 month 6 path 108 row 15
# fracAreaMCD15: 0.021707678638723468
# year 2013 month 6 path 108 row 30
# fracAreaMCD15: 0.11555037290587386
# year 2013 month 6 path 108 row 31
# fracAreaMCD15: 0.05852532932584751
# year 2013 month 6 path 108 row 32
# year 2013 month 6 path 108 row 33
# fracAreaMCD15: 0.3256327491811466
# fracAreaLCtoMCD: 0.3278000416075192
# cumulative samples: 258593 nsaminput 1256
# year 2013 month 6 path 108 row 34
# fracAreaMCD15: 0.09914161377708637
# year 2013 month 6 path 108 row 70
# fracAreaMCD15: 0.0
# year 2013 month 6 path 108 row 71
# fracAreaMCD15: 0.22083907231372968
# year 2013 month 6 path 109 row 69
# fracAreaMCD15: 0.0
# year 2013 month 6 path 109 row 70
# fracAreaMCD15: 0.0
# year 2013 month 6 path 109 row 71
# fracAreaMCD15: 0.19019704356644976
# year 2013 month 6 path 109 row 72
# fracAreaMCD15: 0.8961358299775949
# fracAreaLCtoMCD: 0.8632191094285703
# cumulative samples: 258986 nsaminput 393
# year 2013 month 6 path 109 row 73
# fracAreaMCD15: 0.6293778250199814
# fracAreaLCtoMCD: 0.6336044416758349
# cumulative samples: 263014 nsaminput 4028
# year 2013 month 6 path 109 row 74
# year 2013 month 6 path 109 row 75
# fracAreaMCD15: 0.15222820437296145
# year 2013 month 6 path 109 row 76
# fracAreaMCD15: 0.31055619996720074
# fracAreaLCtoMCD: 0.2979971107245155
# cumulative samples: 264964 nsaminput 1950
# year 2013 month 6 path 109 row 77
# fracAreaMCD15: 0.32750015555263157
# fracAreaLCtoMCD: 0.32592033306924334
# cumulative samples: 267060 nsaminput 2096
# year 2013 month 6 path 109 row 78
# fracAreaMCD15: 0.15812285162439513
# year 2013 month 6 path 109 row 79
# fracAreaMCD15: 0.02676832052946689
# year 2013 month 6 path 109 row 80
# fracAreaMCD15: 0.6012334282808223
# fracAreaLCtoMCD: 0.6033995904086031
# cumulative samples: 270908 nsaminput 3848
# year 2013 month 6 path 110 row 27
# year 2013 month 6 path 110 row 70
# fracAreaMCD15: 0.0
# year 2013 month 6 path 111 row 29
# fracAreaMCD15: 0.18657450839859405
# year 2013 month 6 path 111 row 42
# fracAreaMCD15: 0.0
# year 2013 month 6 path 111 row 60
# fracAreaMCD15: 0.0
# year 2013 month 6 path 111 row 67
# fracAreaMCD15: 0.0
# year 2013 month 6 path 111 row 68
# fracAreaMCD15: 0.0
# year 2013 month 6 path 111 row 69
# fracAreaMCD15: 0.0
# year 2013 month 6 path 111 row 71
# fracAreaMCD15: 0.0
# year 2013 month 6 path 111 row 72
# fracAreaMCD15: 0.0
# year 2013 month 6 path 111 row 74
# fracAreaMCD15: 0.08549245882577458
# year 2013 month 6 path 111 row 75
# fracAreaMCD15: 0.3668541048106243
# ...
# fracAreaMCD15: 0.3401710429195801
# fracAreaLCtoMCD: 0.3395509362667616
# cumulative samples: 10106621 nsaminput 1392
# year 2014 month 7 path 98 row 74
# fracAreaMCD15: 0.230036597048926
# year 2014 month 7 path 98 row 75
# fracAreaMCD15: 0.16760286252178697
# year 2014 month 7 path 98 row 76
# fracAreaMCD15: 0.38932303700526705
# fracAreaLCtoMCD: 0.3899262431685199
# cumulative samples: 10107895 nsaminput 1274
# year 2014 month 7 path 98 row 77
# fracAreaMCD15: 0.351080263427776
# fracAreaLCtoMCD: 0.35986368794757057
# cumulative samples: 10108404 nsaminput 509
# year 2014 month 7 path 98 row 78
# fracAreaMCD15: 0.5592165199253911
# fracAreaLCtoMCD: 0.5529507947985174
# cumulative samples: 10111130 nsaminput 2726
# year 2014 month 7 path 98 row 79
# fracAreaMCD15: 0.254940718721504
# fracAreaLCtoMCD: 0.255419255137184
# cumulative samples: 10112757 nsaminput 1627
# year 2014 month 7 path 98 row 80
# fracAreaMCD15: 0.0027972216492578683
# year 2014 month 7 path 98 row 81
# fracAreaMCD15: 0.3040104743662957
# fracAreaLCtoMCD: 0.3082250989674279
# cumulative samples: 10114638 nsaminput 1881
# year 2014 month 7 path 98 row 82
# fracAreaMCD15: 0.3643996586820556
# fracAreaLCtoMCD: 0.35711941362332866
# cumulative samples: 10116960 nsaminput 2322
# year 2014 month 7 path 98 row 83
# fracAreaMCD15: 0.3722386124120052
# fracAreaLCtoMCD: 0.38725534732042255
# cumulative samples: 10117166 nsaminput 206
# year 2014 month 7 path 98 row 84
# fracAreaMCD15: 0.02812931821852185
# year 2014 month 7 path 98 row 85
# fracAreaMCD15: 0.0
# year 2014 month 7 path 99 row 12
# fracAreaMCD15: 0.07139293970258681
# year 2014 month 7 path 99 row 13
# fracAreaMCD15: 0.3401161278103243
# fracAreaLCtoMCD: 0.3853748476638875
# cumulative samples: 10117518 nsaminput 352
# year 2014 month 7 path 99 row 23
# year 2014 month 7 path 99 row 24
# fracAreaMCD15: 0.10537916208104996
# year 2014 month 7 path 99 row 68
# fracAreaMCD15: 0.5615872144907462
# fracAreaLCtoMCD: 0.556740715700038
# cumulative samples: 10119645 nsaminput 2127
# year 2014 month 7 path 99 row 69
# fracAreaMCD15: 0.033281703778104674
# year 2014 month 7 path 99 row 70
# fracAreaMCD15: 0.0
# year 2014 month 7 path 99 row 71
# fracAreaMCD15: 0.0
# year 2014 month 7 path 99 row 72
# fracAreaMCD15: 0.0
# year 2014 month 7 path 99 row 73
# fracAreaMCD15: 0.17978568698181008
# year 2014 month 7 path 99 row 74
# fracAreaMCD15: 0.49570509450675565
# fracAreaLCtoMCD: 0.4820576843691598
# cumulative samples: 10119788 nsaminput 143
# year 2014 month 7 path 99 row 75
# fracAreaMCD15: 0.4810708281347661
# fracAreaLCtoMCD: 0.4858186775757661
# cumulative samples: 10122867 nsaminput 3079
# year 2014 month 7 path 99 row 76
# fracAreaMCD15: 0.4547183838080006
# fracAreaLCtoMCD: 0.4554981719727459
# cumulative samples: 10124609 nsaminput 1742
# year 2014 month 7 path 99 row 77
# fracAreaMCD15: 0.28101516118180997
# fracAreaLCtoMCD: 0.2857921662052648
# cumulative samples: 10126296 nsaminput 1687
# year 2014 month 7 path 99 row 78
# fracAreaMCD15: 0.2052004550641256
# year 2014 month 7 path 99 row 79
# fracAreaMCD15: 0.0003125412663526147
# year 2014 month 7 path 99 row 81
# fracAreaMCD15: 0.19311237730617203
# year 2014 month 7 path 99 row 82
# fracAreaMCD15: 0.012338342122136711
# year 2014 month 7 path 100 row 71
# fracAreaMCD15: 0.0
# year 2014 month 7 path 100 row 72
# fracAreaMCD15: 0.7563049900115704
# fracAreaLCtoMCD: 0.7494066747233007
# cumulative samples: 10127582 nsaminput 1286
# year 2014 month 7 path 100 row 73
# fracAreaMCD15: 0.5936626619321366
# fracAreaLCtoMCD: 0.5930387644126724
# cumulative samples: 10130500 nsaminput 2918
# year 2014 month 7 path 100 row 74
# fracAreaMCD15: 0.82355899099189
# fracAreaLCtoMCD: 0.8245837967605681
# cumulative samples: 10135061 nsaminput 4561
# year 2014 month 7 path 100 row 75
# fracAreaMCD15: 0.4531301714410737
# fracAreaLCtoMCD: 0.45466575199751263
# cumulative samples: 10135597 nsaminput 536
# year 2014 month 7 path 100 row 76
# fracAreaMCD15: 0.877593520264868
# fracAreaLCtoMCD: 0.7628256393669238
# cumulative samples: 10135606 nsaminput 9
# year 2014 month 7 path 100 row 77
# fracAreaMCD15: 0.5563180793767305
# fracAreaLCtoMCD: 0.5580935087585891
# cumulative samples: 10136003 nsaminput 397
# year 2014 month 7 path 100 row 78
# fracAreaMCD15: 0.28936398598654767
# fracAreaLCtoMCD: 0.2952982258135418
# cumulative samples: 10137855 nsaminput 1852
# year 2014 month 7 path 100 row 79
# fracAreaMCD15: 0.4522034948211442
# fracAreaLCtoMCD: 0.4525242992926651
# cumulative samples: 10140749 nsaminput 2894
# year 2014 month 7 path 100 row 80
# fracAreaMCD15: 0.16737923540061955
# year 2014 month 7 path 101 row 19
# fracAreaMCD15: 0.0
# year 2014 month 7 path 101 row 23
# fracAreaMCD15: 0.11747489074836903
# year 2014 month 7 path 101 row 24
# fracAreaMCD15: 0.0
# year 2014 month 7 path 101 row 46
# fracAreaMCD15: 0.0
# year 2014 month 7 path 101 row 71
# fracAreaMCD15: 0.6136282231814042
# fracAreaLCtoMCD: 0.6101389855121988
# cumulative samples: 10140863 nsaminput 114
# year 2014 month 7 path 101 row 72
# fracAreaMCD15: 0.284825056436449
# fracAreaLCtoMCD: 0.285940656755722
# cumulative samples: 10142686 nsaminput 1823
# year 2014 month 7 path 101 row 73
# fracAreaMCD15: 0.5032881688633107
# fracAreaLCtoMCD: 0.5109319482871985
# cumulative samples: 10143166 nsaminput 480
# year 2014 month 7 path 101 row 74
# fracAreaMCD15: 0.33065867540546656
# fracAreaLCtoMCD: 0.3259216317070665
# cumulative samples: 10145282 nsaminput 2116
# year 2014 month 7 path 101 row 75
# fracAreaMCD15: 0.2838249887062234
# fracAreaLCtoMCD: 0.3058210911288763
# cumulative samples: 10145357 nsaminput 75
# year 2014 month 7 path 101 row 76
# fracAreaMCD15: 0.7128613402531242
# fracAreaLCtoMCD: 0.6813215326396078
# cumulative samples: 10145559 nsaminput 202
# year 2014 month 7 path 101 row 77
# fracAreaMCD15: 0.4426649024702441
# fracAreaLCtoMCD: 0.44099871934165796
# cumulative samples: 10148392 nsaminput 2833
# year 2014 month 7 path 101 row 78
# fracAreaMCD15: 0.7220820114431628
# fracAreaLCtoMCD: 0.7112064086028487
# cumulative samples: 10148637 nsaminput 245
# year 2014 month 7 path 101 row 79
# fracAreaMCD15: 0.6569460099911816
# fracAreaLCtoMCD: 0.6624313798107657
# cumulative samples: 10152800 nsaminput 4163
# year 2014 month 7 path 101 row 80
# fracAreaMCD15: 0.26091986653014354
# fracAreaLCtoMCD: 0.2575387797555246
# cumulative samples: 10154470 nsaminput 1670
# year 2014 month 7 path 101 row 83
# year 2014 month 7 path 102 row 71
# year 2014 month 7 path 102 row 72
# fracAreaMCD15: 0.3748254101708206
# fracAreaLCtoMCD: 0.3784943375133809
# cumulative samples: 10156869 nsaminput 2399
# year 2014 month 7 path 102 row 77
# fracAreaMCD15: 0.5298893681506021
# fracAreaLCtoMCD: 0.5209223822932123
# cumulative samples: 10159153 nsaminput 2284
# year 2014 month 7 path 102 row 78
# fracAreaMCD15: 0.09175193612305624
# year 2014 month 7 path 102 row 81
# fracAreaMCD15: 0.5862133281322023
# fracAreaLCtoMCD: 0.5797725540696843
# cumulative samples: 10161399 nsaminput 2246
# year 2014 month 7 path 103 row 20
# year 2014 month 7 path 103 row 68
# fracAreaMCD15: 0.0
# year 2014 month 7 path 103 row 69
# fracAreaMCD15: 0.6065215644038685
# fracAreaLCtoMCD: 0.6103247143314711
# cumulative samples: 10161951 nsaminput 552
# year 2014 month 7 path 103 row 70
# fracAreaMCD15: 0.5460963826408726
# fracAreaLCtoMCD: 0.5317692860680119
# cumulative samples: 10162366 nsaminput 415
# year 2014 month 7 path 103 row 71
# fracAreaMCD15: 0.3413717361626694
# fracAreaLCtoMCD: 0.3415021948235667
# cumulative samples: 10164551 nsaminput 2185
# year 2014 month 7 path 103 row 72
# fracAreaMCD15: 0.34029448181365085
# fracAreaLCtoMCD: 0.3356136298389117
# cumulative samples: 10166708 nsaminput 2157
# year 2014 month 7 path 103 row 73
# fracAreaMCD15: 0.23001782448473146
# year 2014 month 7 path 103 row 74
# fracAreaMCD15: 0.2010977076031884
# year 2014 month 7 path 103 row 75
# fracAreaMCD15: 0.16918310923440222
# year 2014 month 7 path 103 row 76
# fracAreaMCD15: 0.2950889901071419
# fracAreaLCtoMCD: 0.29393704623875483
# cumulative samples: 10168065 nsaminput 1357
# year 2014 month 7 path 103 row 77
# fracAreaMCD15: 0.5865429240801612
# fracAreaLCtoMCD: 0.5849715987302164
# cumulative samples: 10169553 nsaminput 1488
# year 2014 month 7 path 103 row 78
# fracAreaMCD15: 0.868551505086412
# fracAreaLCtoMCD: 0.8672666868739167
# cumulative samples: 10174395 nsaminput 4842
# year 2014 month 7 path 103 row 79
# fracAreaMCD15: 0.5652860709209772
# fracAreaLCtoMCD: 0.5585097122071384
# cumulative samples: 10178013 nsaminput 3618
# year 2014 month 7 path 103 row 80
# fracAreaMCD15: 0.8746021699876504
# fracAreaLCtoMCD: 0.8774849386291953
# cumulative samples: 10178175 nsaminput 162
# year 2014 month 7 path 103 row 81
# fracAreaMCD15: 0.6753757859426139
# fracAreaLCtoMCD: 0.6854881407849212
# cumulative samples: 10179529 nsaminput 1354
# year 2014 month 7 path 103 row 82
# fracAreaMCD15: 0.0
# year 2014 month 7 path 104 row 14
# fracAreaMCD15: 0.3305760962732063
# fracAreaLCtoMCD: 0.3224347405510452
# cumulative samples: 10180619 nsaminput 1090
# year 2014 month 7 path 104 row 68
# year 2014 month 7 path 104 row 69
# fracAreaMCD15: 0.29562635678998644
# fracAreaLCtoMCD: 0.29689770532328397
# cumulative samples: 10182458 nsaminput 1839
# year 2014 month 7 path 104 row 70
# fracAreaMCD15: 0.4143858978264606
# fracAreaLCtoMCD: 0.41328507031872624
# cumulative samples: 10185110 nsaminput 2652
# year 2014 month 7 path 104 row 71
# fracAreaMCD15: 0.23440956870315618
# year 2014 month 7 path 104 row 72
# fracAreaMCD15: 0.34889652554574363
# fracAreaLCtoMCD: 0.35046095993922405
# cumulative samples: 10185998 nsaminput 888
# year 2014 month 7 path 104 row 238
# fracAreaMCD15: 0.0
# year 2014 month 7 path 104 row 239
# fracAreaMCD15: 0.0
# year 2014 month 7 path 105 row 68
# fracAreaMCD15: 0.0
# year 2014 month 7 path 105 row 69
# fracAreaMCD15: 0.6065211706862357
# fracAreaLCtoMCD: 0.6171078462550832
# cumulative samples: 10186331 nsaminput 333
# year 2014 month 7 path 105 row 70
# fracAreaMCD15: 0.5229357635582025
# fracAreaLCtoMCD: 0.5259560478687232
# cumulative samples: 10186356 nsaminput 25
# year 2014 month 7 path 105 row 71
# fracAreaMCD15: 0.4959099736932182
# fracAreaLCtoMCD: 0.48963729502421593
# cumulative samples: 10188461 nsaminput 2105
# year 2014 month 7 path 105 row 72
# fracAreaMCD15: 0.7155676511983422
# fracAreaLCtoMCD: 0.7117303201383136
# cumulative samples: 10188638 nsaminput 177
# year 2014 month 7 path 105 row 73
# fracAreaMCD15: 0.08065161233912205
# year 2014 month 7 path 105 row 74
# fracAreaMCD15: 0.5226487036125227
# fracAreaLCtoMCD: 0.5233280170757545
# cumulative samples: 10191983 nsaminput 3345
# year 2014 month 7 path 105 row 75
# fracAreaMCD15: 0.29735142652581087
# fracAreaLCtoMCD: 0.3031755006149435
# cumulative samples: 10193881 nsaminput 1898
# year 2014 month 7 path 105 row 76
# fracAreaMCD15: 0.272835682534742
# fracAreaLCtoMCD: 0.27222982384762
# cumulative samples: 10195495 nsaminput 1614
# year 2014 month 7 path 105 row 77
# fracAreaMCD15: 0.41491973679380106
# fracAreaLCtoMCD: 0.4049437200032564
# cumulative samples: 10197784 nsaminput 2289
# year 2014 month 7 path 105 row 78
# fracAreaMCD15: 0.7412575100478703
# fracAreaLCtoMCD: 0.740495098080139
# cumulative samples: 10202528 nsaminput 4744
# year 2014 month 7 path 105 row 79
# fracAreaMCD15: 0.21636348774928077
# year 2014 month 7 path 105 row 80
# fracAreaMCD15: 0.7350542550257182
# fracAreaLCtoMCD: 0.5414436317859065
# cumulative samples: 10202548 nsaminput 20
# year 2014 month 7 path 106 row 68
# fracAreaMCD15: 0.00015624737245598357
# year 2014 month 7 path 106 row 69
# fracAreaMCD15: 0.0
# year 2014 month 7 path 106 row 70
# fracAreaMCD15: 0.7048872644673297
# fracAreaLCtoMCD: 0.6962050099009164
# cumulative samples: 10202959 nsaminput 411
# year 2014 month 7 path 106 row 71
# fracAreaMCD15: 0.4993663221876391
# fracAreaLCtoMCD: 0.5077259365556817
# cumulative samples: 10206155 nsaminput 3196
# year 2014 month 7 path 106 row 72
# fracAreaMCD15: 0.728990451082368
# fracAreaLCtoMCD: 0.7324745070214294
# cumulative samples: 10210723 nsaminput 4568
# year 2014 month 7 path 106 row 73
# fracAreaMCD15: 0.0
# year 2014 month 7 path 106 row 74
# fracAreaMCD15: 0.2615604341804443
# fracAreaLCtoMCD: 0.25191587778786634
# cumulative samples: 10211083 nsaminput 360
# year 2014 month 7 path 106 row 75
# fracAreaMCD15: 0.4779077325375497
# fracAreaLCtoMCD: 0.48163526008581947
# cumulative samples: 10214098 nsaminput 3015
# year 2014 month 7 path 106 row 76
# year 2014 month 7 path 106 row 77
# fracAreaMCD15: 0.6746090244650035
# fracAreaLCtoMCD: 0.6749338944301594
# cumulative samples: 10215061 nsaminput 963
# year 2014 month 7 path 106 row 78
# fracAreaMCD15: 0.5848212419032642
# fracAreaLCtoMCD: 0.5973220579231233
# cumulative samples: 10215270 nsaminput 209
# year 2014 month 7 path 106 row 79
# fracAreaMCD15: 0.45467617798252125
# fracAreaLCtoMCD: 0.45166441991619777
# cumulative samples: 10218180 nsaminput 2910
# year 2014 month 7 path 106 row 80
# fracAreaMCD15: 0.3798256131946511
# fracAreaLCtoMCD: 0.3752144418393019
# cumulative samples: 10220611 nsaminput 2431
# year 2014 month 7 path 106 row 83
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# File ~/anaconda3/envs/landsatModis/lib/python3.9/site-packages/ee/data.py:328, in _execute_cloud_call(call, num_retries)
#     327 try:
# --> 328   return call.execute(num_retries=num_retries)
#     329 except googleapiclient.errors.HttpError as e:
#
# File ~/anaconda3/envs/landsatModis/lib/python3.9/site-packages/googleapiclient/_helpers.py:134, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     133         logger.warning(message)
# --> 134 return wrapped(*args, **kwargs)
#
# File ~/anaconda3/envs/landsatModis/lib/python3.9/site-packages/googleapiclient/http.py:915, in HttpRequest.execute(self, http, num_retries)
#     914 if resp.status >= 300:
# --> 915     raise HttpError(resp, content, uri=self.uri)
#     916 return self.postproc(resp, content)
#
# HttpError: <HttpError 403 when requesting https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/value:compute?prettyPrint=false&alt=json returned "The caller does not have permission". Details: "The caller does not have permission">
#
# During handling of the above exception, another exception occurred:
#
# EEException                               Traceback (most recent call last)
# Input In [11], in <cell line: 4>()
#      27 imageLC = ee.ImageCollection(collectionLandsatL2a).filterMetadata('WRS_PATH','equals',path) \
#      28                                                       .filterMetadata('WRS_ROW','equals',row) \
#      29                                                       .filterDate(ee.Date.fromYMD(year,month,daystart),ee.Date.fromYMD(year,month,daystart).advance(deltaDay,'days')) \
#      30                                                       .filter(ee.Filter.lte('CLOUD_COVER_LAND',cloudCoverL0X))
#      32 # only proceed if there is at least one filtered landsat image (we will only use the first one found)
# ---> 33 if (imageLC.size().getInfo() > 0) :
#      34
#      35     # only sample the first scene we found in the interval of deltaDay's
#      36     imageLC = imageLC.first()
#      37     projectionLC = imageLC.select('QA_PIXEL').projection()
#
# File ~/anaconda3/envs/landsatModis/lib/python3.9/site-packages/ee/computedobject.py:98, in ComputedObject.getInfo(self)
#      92 def getInfo(self):
#      93   """Fetch and return information about this object.
#      94
#      95   Returns:
#      96     The object can evaluate to anything.
#      97   """
# ---> 98   return data.computeValue(self)
#
# File ~/anaconda3/envs/landsatModis/lib/python3.9/site-packages/ee/data.py:735, in computeValue(obj)
#     725 """Sends a request to compute a value.
#     726
#     727 Args:
#    (...)
#     731   The result of evaluating that object on the server.
#     732 """
#     733 body = {'expression': serializer.encode(obj, for_cloud_api=True)}
# --> 735 return _execute_cloud_call(
#     736     _get_cloud_api_resource().projects().value().compute(
#     737         body=body,
#     738         project=_get_projects_path(),
#     739         prettyPrint=False))['result']
#
# File ~/anaconda3/envs/landsatModis/lib/python3.9/site-packages/ee/data.py:330, in _execute_cloud_call(call, num_retries)
#     328   return call.execute(num_retries=num_retries)
#     329 except googleapiclient.errors.HttpError as e:
# --> 330   raise _translate_cloud_exception(e)
#
# EEException: The caller does not have permission
